# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/torch_scatter-2.1.2-cp310-cp310-linux_x86_64.whl
# /kaggle/input/torch_geometric-2.5.3-py3-none-any.whl
# /kaggle/input/torch_cluster-1.6.3-cp310-cp310-linux_x86_64.whl
# /kaggle/input/torch_spline_conv-1.2.2-cp310-cp310-linux_x86_64.whl
# /kaggle/input/torch_sparse-0.6.18-cp310-cp310-linux_x86_64.whl

# %%
# !git clone https://github.com/rampasek/GraphGPS.git
# Out:
# Cloning into 'GraphGPS'...
# remote: Enumerating objects: 526, done.
# remote: Counting objects: 100% (316/316), done.
# remote: Compressing objects: 100% (91/91), done.
# remote: Total 526 (delta 254), reused 225 (delta 225), pack-reused 210 (from 1)
# Receiving objects: 100% (526/526), 12.93 MiB | 31.15 MiB/s, done.
# Resolving deltas: 100% (336/336), done.

# %%
# %cd /kaggle/working/GraphGPS
# !ls
# Out:
# /kaggle/working/GraphGPS
# GraphGPS.png  README.md  final-results.zip  main.py  setup.py  unittests
# LICENSE       configs	 graphgps	    run      tests

# %% [markdown]
# ##  installation for slurm if needed using conda

# %%
# # for slurm if needed using conda 
# conda create -n graphgps python=3.10
# conda activate graphgps

# conda install pytorch=1.13 torchvision torchaudio pytorch-cuda=11.7 -c pytorch -c nvidia
# conda install pyg=2.2 -c pyg -c conda-forge
# pip install pyg-lib -f https://data.pyg.org/whl/torch-1.13.0+cu117.html

# # RDKit is required for OGB-LSC PCQM4Mv2 and datasets derived from it.  
# conda install openbabel fsspec rdkit -c conda-forge

# pip install pytorch-lightning yacs torchmetrics
# pip install performer-pytorch
# pip install tensorboardX
# pip install ogb
# pip install wandb

# conda clean --all

# %% [markdown]
# # installation for kaggle

# %%
# Check existing environment
import sys
print("Python version:", sys.version)
import torch
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)

# !pip uninstall -y torch torchvision torchaudio
# !pip install torch==2.0.1+cu118 torchvision==0.15.2+cu118 torchaudio==2.0.2+cu118 --index-url https://download.pytorch.org/whl/cu118

# !pip install torch_geometric

# Optional dependencies:
# !pip install pyg_lib torch_scatter torch_sparse torch_cluster torch_spline_conv -f https://data.pyg.org/whl/torch-2.4.0+cu124.html
# Install other required packages
# !pip install pytorch-lightning yacs torchmetrics
# !pip install performer-pytorch
# !pip install tensorboardX
# !pip install ogb
# !pip install wandb

# Attempt to install RDKit (may have limitations)
# !pip install rdkit-pypi
# !pip install openbabel fsspec
# !pip install  fsspec

# Clean up pip cache (optional)
# !pip cache purge
# Out:
# Python version: 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:45:18) [GCC 12.3.0]
# PyTorch version: 2.4.0
# CUDA available: True
# CUDA version: 12.3
# Found existing installation: torch 2.4.0
# Uninstalling torch-2.4.0:
#   Successfully uninstalled torch-2.4.0
# Found existing installation: torchvision 0.19.0
# Uninstalling torchvision-0.19.0:
#   Successfully uninstalled torchvision-0.19.0
# Found existing installation: torchaudio 2.4.0
# Uninstalling torchaudio-2.4.0:
#   Successfully uninstalled torchaudio-2.4.0
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Collecting torch==2.0.1+cu118
#   Downloading https://download.pytorch.org/whl/cu118/torch-2.0.1%2Bcu118-cp310-cp310-linux_x86_64.whl (2267.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 GB 391.0 kB/s eta 0:00:0000:0100:01
# Collecting torchvision==0.15.2+cu118
#   Downloading https://download.pytorch.org/whl/cu118/torchvision-0.15.2%2Bcu118-cp310-cp310-linux_x86_64.whl (6.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 4.0 MB/s eta 0:00:000:00:0100:01
# Collecting torchaudio==2.0.2+cu118
#   Downloading https://download.pytorch.org/whl/cu118/torchaudio-2.0.2%2Bcu118-cp310-cp310-linux_x86_64.whl (4.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 85.2 MB/s eta 0:00:00:00:01
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch==2.0.1+cu118) (3.15.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch==2.0.1+cu118) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch==2.0.1+cu118) (1.13.2)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch==2.0.1+cu118) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch==2.0.1+cu118) (3.1.4)
# Collecting triton==2.0.0 (from torch==2.0.1+cu118)
#   Downloading https://download.pytorch.org/whl/triton-2.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 28.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision==0.15.2+cu118) (1.26.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torchvision==0.15.2+cu118) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision==0.15.2+cu118) (9.5.0)
# Collecting cmake (from triton==2.0.0->torch==2.0.1+cu118)
#   Downloading https://download.pytorch.org/whl/cmake-3.25.0-py2.py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 63.4 MB/s eta 0:00:0000:0100:01
# Collecting lit (from triton==2.0.0->torch==2.0.1+cu118)
#   Downloading https://download.pytorch.org/whl/lit-15.0.7.tar.gz (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.3/132.3 kB 11.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch==2.0.1+cu118) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.15.2+cu118) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.15.2+cu118) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.15.2+cu118) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.15.2+cu118) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch==2.0.1+cu118) (1.3.0)
# Building wheels for collected packages: lit
#   Building wheel for lit (setup.py) ... done
#   Created wheel for lit: filename=lit-15.0.7-py3-none-any.whl size=89987 sha256=685b3e4b5fc38a88b2182aae1deea59305c477dd6f9d336fb494892139735907
#   Stored in directory: /root/.cache/pip/wheels/27/2c/b6/3ed2983b1b44fe0dea1bb35234b09f2c22fb8ebb308679c922
# Successfully built lit
# Installing collected packages: lit, cmake, triton, torch, torchvision, torchaudio
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytorch-lightning 2.4.0 requires torch>=2.1.0, but you have torch 2.0.1+cu118 which is incompatible.
# Successfully installed cmake-3.25.0 lit-15.0.7 torch-2.0.1+cu118 torchaudio-2.0.2+cu118 torchvision-0.15.2+cu118 triton-2.0.0
# Collecting torch_geometric
#   Downloading torch_geometric-2.6.0-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 638.5 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (3.9.5)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (2024.6.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (3.1.4)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (1.26.4)
# Requirement already satisfied: psutil>=5.8.0 in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (5.9.3)
# Requirement already satisfied: pyparsing in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (3.1.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (2.32.3)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (4.66.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch_geometric) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (2024.7.4)
# Downloading torch_geometric-2.6.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 1.4 MB/s eta 0:00:0000:0100:01
# Installing collected packages: torch_geometric
# Successfully installed torch_geometric-2.6.0
# Looking in links: https://data.pyg.org/whl/torch-2.4.0+cu124.html
# Collecting pyg_lib
#   Downloading https://data.pyg.org/whl/torch-2.4.0%2Bcu124/pyg_lib-0.4.0%2Bpt24cu124-cp310-cp310-linux_x86_64.whl (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 14.8 MB/s eta 0:00:0000:0100:01
# Collecting torch_scatter
#   Downloading https://data.pyg.org/whl/torch-2.4.0%2Bcu124/torch_scatter-2.1.2%2Bpt24cu124-cp310-cp310-linux_x86_64.whl (10.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 41.0 MB/s eta 0:00:0000:010:01
# Collecting torch_sparse
#   Downloading https://data.pyg.org/whl/torch-2.4.0%2Bcu124/torch_sparse-0.6.18%2Bpt24cu124-cp310-cp310-linux_x86_64.whl (5.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 92.3 MB/s eta 0:00:00:00:01
# Collecting torch_cluster
#   Downloading https://data.pyg.org/whl/torch-2.4.0%2Bcu124/torch_cluster-1.6.3%2Bpt24cu124-cp310-cp310-linux_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 53.2 MB/s eta 0:00:00ta 0:00:01
# Collecting torch_spline_conv
#   Downloading https://data.pyg.org/whl/torch-2.4.0%2Bcu124/torch_spline_conv-1.2.2%2Bpt24cu124-cp310-cp310-linux_x86_64.whl (992 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 992.4/992.4 kB 49.8 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from torch_sparse) (1.14.0)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in /opt/conda/lib/python3.10/site-packages (from scipy->torch_sparse) (1.26.4)
# Installing collected packages: torch_spline_conv, torch_scatter, pyg_lib, torch_sparse, torch_cluster
# Successfully installed pyg_lib-0.4.0+pt24cu124 torch_cluster-1.6.3+pt24cu124 torch_scatter-2.1.2+pt24cu124 torch_sparse-0.6.18+pt24cu124 torch_spline_conv-1.2.2+pt24cu124
# Requirement already satisfied: pytorch-lightning in /opt/conda/lib/python3.10/site-packages (2.4.0)
# Collecting yacs
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: torchmetrics in /opt/conda/lib/python3.10/site-packages (1.4.1)
# Collecting torch>=2.1.0 (from pytorch-lightning)
#   Downloading torch-2.4.1-cp310-cp310-manylinux1_x86_64.whl.metadata (26 kB)
# Requirement already satisfied: tqdm>=4.57.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (4.66.4)
# Requirement already satisfied: PyYAML>=5.4 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (6.0.2)
# Requirement already satisfied: fsspec>=2022.5.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (2024.6.1)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (21.3)
# Requirement already satisfied: typing-extensions>=4.4.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (4.12.2)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (0.11.6)
# Requirement already satisfied: numpy>1.20.0 in /opt/conda/lib/python3.10/site-packages (from torchmetrics) (1.26.4)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (3.9.5)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from lightning-utilities>=0.10.0->pytorch-lightning) (70.0.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->pytorch-lightning) (3.1.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=2.1.0->pytorch-lightning) (3.15.1)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=2.1.0->pytorch-lightning) (1.13.2)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=2.1.0->pytorch-lightning) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=2.1.0->pytorch-lightning) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.0.0 (from torch>=2.1.0->pytorch-lightning)
#   Downloading triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_nvjitlink_cu12-12.6.68-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=2.1.0->pytorch-lightning) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=2.1.0->pytorch-lightning) (1.3.0)
# Requirement already satisfied: idna>=2.0 in /opt/conda/lib/python3.10/site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (3.7)
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Downloading torch-2.4.1-cp310-cp310-manylinux1_x86_64.whl (797.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.1/797.1 MB 2.0 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.5 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 58.4 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 48.5 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 43.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.5 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 6.1 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 8.8 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.0 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 2.8 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 6.6 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 7.3 MB/s eta 0:00:00
# Downloading triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (209.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 4.9 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.6.68-py3-none-manylinux2014_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 12.7 MB/s eta 0:00:0000:0100:01
# Installing collected packages: yacs, triton, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch
#   Attempting uninstall: triton
#     Found existing installation: triton 2.0.0
#     Uninstalling triton-2.0.0:
#       Successfully uninstalled triton-2.0.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.1+cu118
#     Uninstalling torch-2.0.1+cu118:
#       Successfully uninstalled torch-2.0.1+cu118
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.0.2+cu118 requires torch==2.0.1, but you have torch 2.4.1 which is incompatible.
# torchvision 0.15.2+cu118 requires torch==2.0.1, but you have torch 2.4.1 which is incompatible.
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.6.68 nvidia-nvtx-cu12-12.1.105 torch-2.4.1 triton-3.0.0 yacs-0.1.8
# Collecting performer-pytorch
#   Downloading performer_pytorch-1.1.4-py3-none-any.whl.metadata (763 bytes)
# Collecting einops>=0.3 (from performer-pytorch)
#   Downloading einops-0.8.0-py3-none-any.whl.metadata (12 kB)
# Collecting local-attention>=1.1.1 (from performer-pytorch)
#   Downloading local_attention-1.9.15-py3-none-any.whl.metadata (683 bytes)
# Requirement already satisfied: torch>=1.6 in /opt/conda/lib/python3.10/site-packages (from performer-pytorch) (2.4.1)
# Collecting axial-positional-embedding>=0.1.0 (from performer-pytorch)
#   Downloading axial_positional_embedding-0.2.1.tar.gz (2.6 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (1.13.2)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.6->performer-pytorch) (12.6.68)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.6->performer-pytorch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.6->performer-pytorch) (1.3.0)
# Downloading performer_pytorch-1.1.4-py3-none-any.whl (13 kB)
# Downloading einops-0.8.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 890.5 kB/s eta 0:00:000:00:01
# Downloading local_attention-1.9.15-py3-none-any.whl (9.0 kB)
# Building wheels for collected packages: axial-positional-embedding
#   Building wheel for axial-positional-embedding (setup.py) ... done
#   Created wheel for axial-positional-embedding: filename=axial_positional_embedding-0.2.1-py3-none-any.whl size=2889 sha256=a711b5646e82ea93d3536d2df28c677d4ab89c44e123f2e9e89472341634b68e
#   Stored in directory: /root/.cache/pip/wheels/b1/cb/39/7ce7ff2d2fd37cfe1fe7b3a3c43cf410632b2ad3b3f3986d73
# Successfully built axial-positional-embedding
# Installing collected packages: einops, local-attention, axial-positional-embedding, performer-pytorch
# Successfully installed axial-positional-embedding-0.2.1 einops-0.8.0 local-attention-1.9.15 performer-pytorch-1.1.4
# Requirement already satisfied: tensorboardX in /opt/conda/lib/python3.10/site-packages (2.6.2.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from tensorboardX) (1.26.4)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorboardX) (21.3)
# Requirement already satisfied: protobuf>=3.20 in /opt/conda/lib/python3.10/site-packages (from tensorboardX) (3.20.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->tensorboardX) (3.1.2)
# Collecting ogb
#   Downloading ogb-1.3.6-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: torch>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (2.4.1)
# Requirement already satisfied: numpy>=1.16.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (1.26.4)
# Requirement already satisfied: tqdm>=4.29.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (4.66.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (1.2.2)
# Requirement already satisfied: pandas>=0.24.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (2.2.2)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (1.16.0)
# Requirement already satisfied: urllib3>=1.24.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (1.26.18)
# Collecting outdated>=0.2.0 (from ogb)
#   Downloading outdated-0.2.2-py2.py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: setuptools>=44 in /opt/conda/lib/python3.10/site-packages (from outdated>=0.2.0->ogb) (70.0.0)
# Collecting littleutils (from outdated>=0.2.0->ogb)
#   Downloading littleutils-0.2.4-py3-none-any.whl.metadata (679 bytes)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from outdated>=0.2.0->ogb) (2.32.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24.0->ogb) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24.0->ogb) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24.0->ogb) (2024.1)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.20.0->ogb) (1.14.0)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.20.0->ogb) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.20.0->ogb) (3.5.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (1.13.2)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.6.0->ogb) (12.6.68)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.6.0->ogb) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->outdated>=0.2.0->ogb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->outdated>=0.2.0->ogb) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->outdated>=0.2.0->ogb) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.6.0->ogb) (1.3.0)
# Downloading ogb-1.3.6-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 1.3 MB/s eta 0:00:00eta 0:00:01
# Downloading outdated-0.2.2-py2.py3-none-any.whl (7.5 kB)
# Downloading littleutils-0.2.4-py3-none-any.whl (8.1 kB)
# Installing collected packages: littleutils, outdated, ogb
# Successfully installed littleutils-0.2.4 ogb-1.3.6 outdated-0.2.2
# Requirement already satisfied: wandb in /opt/conda/lib/python3.10/site-packages (0.17.7)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /opt/conda/lib/python3.10/site-packages (from wandb) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.1.43)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.10/site-packages (from wandb) (3.11.0)
# Requirement already satisfied: protobuf!=4.21.0,<6,>=3.19.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.20.3)
# Requirement already satisfied: psutil>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from wandb) (6.0.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.32.3)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.13.0)
# Requirement already satisfied: setproctitle in /opt/conda/lib/python3.10/site-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from wandb) (70.0.0)
# Requirement already satisfied: six>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2024.7.4)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.1)
# Collecting rdkit-pypi
#   Downloading rdkit_pypi-2022.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from rdkit-pypi) (1.26.4)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from rdkit-pypi) (9.5.0)
# Downloading rdkit_pypi-2022.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 40.1 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: rdkit-pypi
# Successfully installed rdkit-pypi-2022.9.5
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (2024.6.1)
# Files removed: 184

# %%
import sys
print("Python version:", sys.version)
import torch
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)
# Out:
# Python version: 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:45:18) [GCC 12.3.0]
# PyTorch version: 2.4.0
# CUDA available: True
# CUDA version: 12.3

# %%
import torch_geometric
print("PyG version:", torch_geometric.__version__)

import pytorch_lightning
print("PyTorch Lightning version:", pytorch_lightning.__version__)

import rdkit
print("RDKit version:", rdkit.__version__)
# Out:
# /opt/conda/lib/python3.10/site-packages/torch_geometric/typing.py:68: UserWarning: An issue occurred while importing 'pyg-lib'. Disabling its usage. Stacktrace: /opt/conda/lib/python3.10/site-packages/libpyg.so: undefined symbol: _ZNK5torch8autograd4Node4nameEv
#   warnings.warn(f"An issue occurred while importing 'pyg-lib'. "
# /opt/conda/lib/python3.10/site-packages/torch_geometric/typing.py:86: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: /opt/conda/lib/python3.10/site-packages/torch_scatter/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
#   warnings.warn(f"An issue occurred while importing 'torch-scatter'. "
# /opt/conda/lib/python3.10/site-packages/torch_geometric/typing.py:97: UserWarning: An issue occurred while importing 'torch-cluster'. Disabling its usage. Stacktrace: /opt/conda/lib/python3.10/site-packages/torch_cluster/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
#   warnings.warn(f"An issue occurred while importing 'torch-cluster'. "
# /opt/conda/lib/python3.10/site-packages/torch_geometric/typing.py:113: UserWarning: An issue occurred while importing 'torch-spline-conv'. Disabling its usage. Stacktrace: /opt/conda/lib/python3.10/site-packages/torch_spline_conv/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torch_geometric/typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: /opt/conda/lib/python3.10/site-packages/torch_sparse/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
#   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "
# PyG version: 2.6.0
# PyTorch Lightning version: 2.4.0
# RDKit version: 2022.09.5

# %%
print("Torch version:", torch.__version__)
# Out:
# Torch version: 2.4.0

# %%
# %cd /kaggle/working/GraphGPS
# !WANDB_MODE=disabled python main.py --cfg configs/GPS/ogbg-molhiv-GPS.yaml
# Out:
# /kaggle/working/GraphGPS
# [*] Run ID 0: seed=0, split_index=0
#     Starting now: 2024-09-23 13:16:20.178181
# Downloading http://snap.stanford.edu/ogb/data/graphproppred/csv_mol_download/hiv.zip
# Downloaded 0.00 GB: 100%|█████████████████████████| 3/3 [00:00<00:00,  3.88it/s]
# Extracting ./datasets/hiv.zip
# Processing...
# Loading necessary files...
# This might take a while.
# Processing graphs...
# 100%|██████████████████████████████████| 41127/41127 [00:00<00:00, 60420.42it/s]
# Converting graphs into PyG objects...
# 100%|██████████████████████████████████| 41127/41127 [00:02<00:00, 18891.90it/s]
# Saving...
# Done!
# /opt/conda/lib/python3.10/site-packages/ogb/graphproppred/dataset_pyg.py:68: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.data, self.slices = torch.load(self.processed_paths[0])
# [*] Loaded dataset 'ogbg-molhiv' from 'OGB':
# /opt/conda/lib/python3.10/site-packages/torch_geometric/data/in_memory_dataset.py:300: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
#   Data(edge_index=[2, 2259376], edge_attr=[2259376, 3], x=[1049163, 9], y=[41127, 1], num_nodes=1049163)
#   undirected: True
#   num graphs: 41127
# /opt/conda/lib/python3.10/site-packages/torch_geometric/data/in_memory_dataset.py:300: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. The data of the dataset is already cached, so any modifications to `data` will not be reflected when accessing its elements. Clearing the cache now by removing all elements in `dataset._data_list`. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
#   avg num_nodes/graph: 25
#   num node features: 9
#   num edge features: 3
#   num tasks: 1
#   num classes: 2
# Precomputing Positional Encoding statistics: ['LapPE'] for all graphs...
#   ...estimated to be undirected: True
# 100%|████████████████████████████████████| 41127/41127 [00:53<00:00, 764.44it/s]
# Done! Took 00:00:55.39
# GraphGymModule(
#   (model): GPSModel(
#     (encoder): FeatureEncoder(
#       (node_encoder): Concat2NodeEncoder(
#         (encoder1): AtomEncoder(
#           (atom_embedding_list): ModuleList(
#             (0): Embedding(119, 56)
#             (1): Embedding(5, 56)
#             (2-3): 2 x Embedding(12, 56)
#             (4): Embedding(10, 56)
#             (5-6): 2 x Embedding(6, 56)
#             (7-8): 2 x Embedding(2, 56)
#           )
#         )
#         (encoder2): LapPENodeEncoder(
#           (linear_A): Linear(in_features=2, out_features=16, bias=True)
#           (pe_encoder): Sequential(
#             (0): ReLU()
#             (1): Linear(in_features=16, out_features=8, bias=True)
#             (2): ReLU()
#           )
#         )
#       )
#       (edge_encoder): BondEncoder(
#         (bond_embedding_list): ModuleList(
#           (0): Embedding(5, 64)
#           (1): Embedding(6, 64)
#           (2): Embedding(2, 64)
#         )
#       )
#     )
#     (layers): Sequential(
#       (0): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (1): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (2): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (3): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (4): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (5): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (6): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (7): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (8): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (9): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#     )
#     (post_mp): SANGraphHead(
#       (FC_layers): ModuleList(
#         (0): Linear(in_features=64, out_features=32, bias=True)
#         (1): Linear(in_features=32, out_features=16, bias=True)
#         (2): Linear(in_features=16, out_features=1, bias=True)
#       )
#       (activation): ReLU()
#     )
#   )
# )
# accelerator: cuda
# benchmark: False
# bn:
#   eps: 1e-05
#   mom: 0.1
# cfg_dest: config.yaml
# custom_metrics: []
# dataset:
#   cache_load: False
#   cache_save: False
#   dir: ./datasets
#   edge_dim: 128
#   edge_encoder: True
#   edge_encoder_bn: False
#   edge_encoder_name: Bond
#   edge_encoder_num_types: 0
#   edge_message_ratio: 0.8
#   edge_negative_sampling_ratio: 1.0
#   edge_train_mode: all
#   encoder: True
#   encoder_bn: True
#   encoder_dim: 128
#   encoder_name: db
#   format: OGB
#   infer_link_label: None
#   label_column: none
#   label_table: none
#   location: local
#   name: ogbg-molhiv
#   node_encoder: True
#   node_encoder_bn: False
#   node_encoder_name: Atom+LapPE
#   node_encoder_num_types: 0
#   remove_feature: False
#   resample_disjoint: False
#   resample_negative: False
#   shuffle_split: True
#   slic_compactness: 10
#   split: [0.8, 0.1, 0.1]
#   split_dir: ./splits
#   split_index: 0
#   split_mode: standard
#   task: graph
#   task_type: classification
#   to_undirected: False
#   transductive: False
#   transform: none
#   tu_simple: True
# devices: 1
# example_arg: example
# example_group:
#   example_arg: example
# gnn:
#   act: relu
#   agg: mean
#   att_final_linear: False
#   att_final_linear_bn: False
#   att_heads: 1
#   batchnorm: True
#   clear_feature: True
#   dim_edge: 64
#   dim_inner: 64
#   dropout: 0.0
#   head: san_graph
#   keep_edge: 0.5
#   l2norm: True
#   layer_type: generalconv
#   layers_mp: 2
#   layers_post_mp: 3
#   layers_pre_mp: 0
#   msg_direction: single
#   normalize_adj: False
#   residual: False
#   self_msg: concat
#   skip_every: 1
#   stage_type: stack
# gpu_mem: False
# graphormer:
#   attention_dropout: 0.0
#   dropout: 0.0
#   embed_dim: 80
#   input_dropout: 0.0
#   mlp_dropout: 0.0
#   num_heads: 4
#   num_layers: 6
#   use_graph_token: True
# gt:
#   attn_dropout: 0.5
#   batch_norm: True
#   bigbird:
#     add_cross_attention: False
#     attention_type: block_sparse
#     block_size: 3
#     chunk_size_feed_forward: 0
#     hidden_act: relu
#     is_decoder: False
#     layer_norm_eps: 1e-06
#     max_position_embeddings: 128
#     num_random_blocks: 3
#     use_bias: False
#   dim_hidden: 64
#   dropout: 0.05
#   full_graph: True
#   gamma: 1e-05
#   layer_norm: False
#   layer_type: CustomGatedGCN+Transformer
#   layers: 10
#   n_heads: 4
#   pna_degrees: []
#   residual: True
# mem:
#   inplace: False
# metric_agg: argmax
# metric_best: auc
# model:
#   edge_decoding: dot
#   graph_pooling: mean
#   loss_fun: cross_entropy
#   match_upper: True
#   size_average: mean
#   thresh: 0.5
#   type: GPSModel
# name_tag:
# num_threads: 6
# num_workers: 0
# optim:
#   base_lr: 0.0001
#   batch_accumulation: 1
#   clip_grad_norm: True
#   clip_grad_norm_value: 1.0
#   lr_decay: 0.1
#   max_epoch: 100
#   min_lr: 0.0
#   momentum: 0.9
#   num_warmup_epochs: 5
#   optimizer: adamW
#   reduce_factor: 0.1
#   schedule_patience: 10
#   scheduler: cosine_with_warmup
#   steps: [30, 60, 90]
#   weight_decay: 1e-05
# out_dir: results/ogbg-molhiv-GPS
# posenc_ElstaticSE:
#   dim_pe: 16
#   enable: False
#   kernel:
#     times: []
#     times_func: range(10)
#   layers: 3
#   model: none
#   n_heads: 4
#   pass_as_var: False
#   post_layers: 0
#   raw_norm_type: none
# posenc_EquivStableLapPE:
#   eigen:
#     eigvec_norm: L2
#     laplacian_norm: sym
#     max_freqs: 10
#   enable: False
#   raw_norm_type: none
# posenc_GraphormerBias:
#   dim_pe: 0
#   enable: False
#   node_degrees_only: False
#   num_in_degrees: None
#   num_out_degrees: None
#   num_spatial_types: None
# posenc_HKdiagSE:
#   dim_pe: 16
#   enable: False
#   kernel:
#     times: []
#     times_func:
#   layers: 3
#   model: none
#   n_heads: 4
#   pass_as_var: False
#   post_layers: 0
#   raw_norm_type: none
# posenc_LapPE:
#   dim_pe: 8
#   eigen:
#     eigvec_norm: L2
#     laplacian_norm: none
#     max_freqs: 8
#   enable: True
#   layers: 2
#   model: DeepSet
#   n_heads: 4
#   pass_as_var: False
#   post_layers: 0
#   raw_norm_type: none
# posenc_RWSE:
#   dim_pe: 16
#   enable: False
#   kernel:
#     times: []
#     times_func:
#   layers: 3
#   model: none
#   n_heads: 4
#   pass_as_var: False
#   post_layers: 0
#   raw_norm_type: none
# posenc_SignNet:
#   dim_pe: 16
#   eigen:
#     eigvec_norm: L2
#     laplacian_norm: sym
#     max_freqs: 10
#   enable: False
#   layers: 3
#   model: none
#   n_heads: 4
#   pass_as_var: False
#   phi_hidden_dim: 64
#   phi_out_dim: 4
#   post_layers: 0
#   raw_norm_type: none
# pretrained:
#   dir:
#   freeze_main: False
#   reset_prediction_head: True
# print: both
# round: 5
# run_dir: results/ogbg-molhiv-GPS/0
# run_id: 0
# run_multiple_splits: []
# seed: 0
# share:
#   dim_in: 9
#   dim_out: 2
#   num_splits: 3
# tensorboard_agg: True
# tensorboard_each_run: False
# train:
#   auto_resume: False
#   batch_size: 32
#   ckpt_best: False
#   ckpt_clean: True
#   ckpt_period: 100
#   enable_ckpt: True
#   epoch_resume: -1
#   eval_period: 1
#   iter_per_epoch: 32
#   mode: custom
#   neighbor_sizes: [20, 15, 10, 5]
#   node_per_graph: 32
#   radius: extend
#   sample_node: False
#   sampler: full_batch
#   skip_train_eval: False
#   walk_length: 4
# val:
#   node_per_graph: 32
#   radius: extend
#   sample_node: False
#   sampler: full_batch
# view_emb: False
# wandb:
#   entity: gtransformers
#   name:
#   project: molhiv
#   use: True
# Num parameters: 559945
# Start from epoch 0
# Key posenc_GraphormerBias.num_spatial_types with value <class 'NoneType'> is not a valid type; valid types: {<class 'list'>, <class 'str'>, <class 'bool'>, <class 'int'>, <class 'tuple'>, <class 'float'>}
# Key posenc_GraphormerBias.num_in_degrees with value <class 'NoneType'> is not a valid type; valid types: {<class 'list'>, <class 'str'>, <class 'bool'>, <class 'int'>, <class 'tuple'>, <class 'float'>}
# Key posenc_GraphormerBias.num_out_degrees with value <class 'NoneType'> is not a valid type; valid types: {<class 'list'>, <class 'str'>, <class 'bool'>, <class 'int'>, <class 'tuple'>, <class 'float'>}
# train: {'epoch': 0, 'time_epoch': 84.40366, 'eta': 8355.96265, 'eta_hours': 2.3211, 'loss': 0.79160294, 'lr': 0.0, 'params': 559945, 'time_iter': 0.08202, 'accuracy': 0.03748, 'precision': 0.03745, 'recall': 1.0, 'f1': 0.07219, 'auc': 0.55785}
# ...computing epoch stats took: 0.09s
# val: {'epoch': 0, 'time_epoch': 4.67517, 'loss': 0.79690719, 'lr': 0, 'params': 559945, 'time_iter': 0.03624, 'accuracy': 0.01969, 'precision': 0.01969, 'recall': 1.0, 'f1': 0.03863, 'auc': 0.53566}
# ...computing epoch stats took: 0.01s
# test: {'epoch': 0, 'time_epoch': 4.69167, 'loss': 0.79430784, 'lr': 0, 'params': 559945, 'time_iter': 0.03637, 'accuracy': 0.03161, 'precision': 0.03161, 'recall': 1.0, 'f1': 0.06128, 'auc': 0.57793}
# ...computing epoch stats took: 0.01s
# > Epoch 0: took 93.9s (avg 93.9s) | Best so far: epoch 0	train_loss: 0.7916 train_auc: 0.5578	val_loss: 0.7969 val_auc: 0.5357	test_loss: 0.7943 test_auc: 0.5779
# train: {'epoch': 1, 'time_epoch': 85.05092, 'eta': 8303.27479, 'eta_hours': 2.30647, 'loss': 0.49213173, 'lr': 2e-05, 'params': 559945, 'time_iter': 0.08265, 'accuracy': 0.76715, 'precision': 0.04719, 'recall': 0.27192, 'f1': 0.08042, 'auc': 0.56012}
# ...computing epoch stats took: 0.08s
# val: {'epoch': 1, 'time_epoch': 4.29309, 'loss': 0.2666023, 'lr': 0, 'params': 559945, 'time_iter': 0.03328, 'accuracy': 0.97788, 'precision': 0.1875, 'recall': 0.03704, 'f1': 0.06186, 'auc': 0.65604}
# ...computing epoch stats took: 0.02s
# test: {'epoch': 1, 'time_epoch': 4.12836, 'loss': 0.26772595, 'lr': 0, 'params': 559945, 'time_iter': 0.032, 'accuracy': 0.96791, 'precision': 0.4375, 'recall': 0.05385, 'f1': 0.09589, 'auc': 0.65993}
# ...computing epoch stats took: 0.01s
# > Epoch 1: took 93.6s (avg 93.8s) | Best so far: epoch 1	train_loss: 0.4921 train_auc: 0.5601	val_loss: 0.2666 val_auc: 0.6560	test_loss: 0.2677 test_auc: 0.6599
# train: {'epoch': 2, 'time_epoch': 82.26323, 'eta': 8138.87595, 'eta_hours': 2.2608, 'loss': 0.19033828, 'lr': 4e-05, 'params': 559945, 'time_iter': 0.07994, 'accuracy': 0.96213, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.61406}
# ...computing epoch stats took: 0.07s
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 2, 'time_epoch': 4.00851, 'loss': 0.10388157, 'lr': 0, 'params': 559945, 'time_iter': 0.03107, 'accuracy': 0.98031, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.67792}
# ...computing epoch stats took: 0.02s
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# test: {'epoch': 2, 'time_epoch': 3.92167, 'loss': 0.13049798, 'lr': 0, 'params': 559945, 'time_iter': 0.0304, 'accuracy': 0.96839, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.73954}
# ...computing epoch stats took: 0.01s
# > Epoch 2: took 90.3s (avg 92.6s) | Best so far: epoch 2	train_loss: 0.1903 train_auc: 0.6141	val_loss: 0.1039 val_auc: 0.6779	test_loss: 0.1305 test_auc: 0.7395
# train: {'epoch': 3, 'time_epoch': 81.60161, 'eta': 7999.66604, 'eta_hours': 2.22213, 'loss': 0.14729549, 'lr': 6e-05, 'params': 559945, 'time_iter': 0.0793, 'accuracy': 0.96246, 'precision': 0.44444, 'recall': 0.00974, 'f1': 0.01906, 'auc': 0.70096}
# val: {'epoch': 3, 'time_epoch': 4.08507, 'loss': 0.08416821, 'lr': 0, 'params': 559945, 'time_iter': 0.03167, 'accuracy': 0.98177, 'precision': 0.8, 'recall': 0.09877, 'f1': 0.17582, 'auc': 0.71341}
# test: {'epoch': 3, 'time_epoch': 4.06441, 'loss': 0.11695114, 'lr': 0, 'params': 559945, 'time_iter': 0.03151, 'accuracy': 0.97009, 'precision': 0.73333, 'recall': 0.08462, 'f1': 0.15172, 'auc': 0.74161}
# > Epoch 3: took 89.9s (avg 91.9s) | Best so far: epoch 3	train_loss: 0.1473 train_auc: 0.7010	val_loss: 0.0842 val_auc: 0.7134	test_loss: 0.1170 test_auc: 0.7416
# train: {'epoch': 4, 'time_epoch': 90.12413, 'eta': 8045.42749, 'eta_hours': 2.23484, 'loss': 0.139009, 'lr': 8e-05, 'params': 559945, 'time_iter': 0.08758, 'accuracy': 0.96365, 'precision': 0.65254, 'recall': 0.0625, 'f1': 0.11407, 'auc': 0.73357}
# val: {'epoch': 4, 'time_epoch': 4.46761, 'loss': 0.07925676, 'lr': 0, 'params': 559945, 'time_iter': 0.03463, 'accuracy': 0.98128, 'precision': 0.59091, 'recall': 0.16049, 'f1': 0.25243, 'auc': 0.77718}
# test: {'epoch': 4, 'time_epoch': 4.39571, 'loss': 0.11466429, 'lr': 0, 'params': 559945, 'time_iter': 0.03408, 'accuracy': 0.97204, 'precision': 0.71429, 'recall': 0.19231, 'f1': 0.30303, 'auc': 0.75446}
# > Epoch 4: took 99.1s (avg 93.4s) | Best so far: epoch 4	train_loss: 0.1390 train_auc: 0.7336	val_loss: 0.0793 val_auc: 0.7772	test_loss: 0.1147 test_auc: 0.7545
# train: {'epoch': 5, 'time_epoch': 91.05291, 'eta': 8060.44458, 'eta_hours': 2.23901, 'loss': 0.13337819, 'lr': 0.0001, 'params': 559945, 'time_iter': 0.08849, 'accuracy': 0.96459, 'precision': 0.66667, 'recall': 0.10877, 'f1': 0.18702, 'auc': 0.76058}
# val: {'epoch': 5, 'time_epoch': 4.40095, 'loss': 0.07868337, 'lr': 0, 'params': 559945, 'time_iter': 0.03412, 'accuracy': 0.98201, 'precision': 0.65217, 'recall': 0.18519, 'f1': 0.28846, 'auc': 0.80137}
# test: {'epoch': 5, 'time_epoch': 4.40035, 'loss': 0.11791497, 'lr': 0, 'params': 559945, 'time_iter': 0.03411, 'accuracy': 0.97277, 'precision': 0.70455, 'recall': 0.23846, 'f1': 0.35632, 'auc': 0.73834}
# > Epoch 5: took 100.0s (avg 94.5s) | Best so far: epoch 5	train_loss: 0.1334 train_auc: 0.7606	val_loss: 0.0787 val_auc: 0.8014	test_loss: 0.1179 test_auc: 0.7383
# train: {'epoch': 6, 'time_epoch': 91.18149, 'eta': 8046.86421, 'eta_hours': 2.23524, 'loss': 0.12866286, 'lr': 9.997e-05, 'params': 559945, 'time_iter': 0.08861, 'accuracy': 0.96541, 'precision': 0.66786, 'recall': 0.15179, 'f1': 0.24735, 'auc': 0.78484}
# val: {'epoch': 6, 'time_epoch': 4.38265, 'loss': 0.08027428, 'lr': 0, 'params': 559945, 'time_iter': 0.03397, 'accuracy': 0.98152, 'precision': 0.6, 'recall': 0.18519, 'f1': 0.28302, 'auc': 0.7706}
# test: {'epoch': 6, 'time_epoch': 4.36296, 'loss': 0.11583503, 'lr': 0, 'params': 559945, 'time_iter': 0.03382, 'accuracy': 0.97228, 'precision': 0.7, 'recall': 0.21538, 'f1': 0.32941, 'auc': 0.74859}
# > Epoch 6: took 100.1s (avg 95.3s) | Best so far: epoch 5	train_loss: 0.1334 train_auc: 0.7606	val_loss: 0.0787 val_auc: 0.8014	test_loss: 0.1179 test_auc: 0.7383
# train: {'epoch': 7, 'time_epoch': 91.64785, 'eta': 8019.24666, 'eta_hours': 2.22757, 'loss': 0.12493481, 'lr': 9.989e-05, 'params': 559945, 'time_iter': 0.08906, 'accuracy': 0.9652, 'precision': 0.62254, 'recall': 0.17938, 'f1': 0.27851, 'auc': 0.79837}
# val: {'epoch': 7, 'time_epoch': 4.38963, 'loss': 0.08174635, 'lr': 0, 'params': 559945, 'time_iter': 0.03403, 'accuracy': 0.97812, 'precision': 0.40426, 'recall': 0.23457, 'f1': 0.29688, 'auc': 0.80875}
# test: {'epoch': 7, 'time_epoch': 4.43311, 'loss': 0.12535343, 'lr': 0, 'params': 559945, 'time_iter': 0.03437, 'accuracy': 0.9662, 'precision': 0.42857, 'recall': 0.20769, 'f1': 0.27979, 'auc': 0.74739}
# > Epoch 7: took 100.6s (avg 96.0s) | Best so far: epoch 7	train_loss: 0.1249 train_auc: 0.7984	val_loss: 0.0817 val_auc: 0.8087	test_loss: 0.1254 test_auc: 0.7474
# train: {'epoch': 8, 'time_epoch': 91.73049, 'eta': 7978.23583, 'eta_hours': 2.21618, 'loss': 0.12176636, 'lr': 9.975e-05, 'params': 559945, 'time_iter': 0.08915, 'accuracy': 0.96562, 'precision': 0.6211, 'recall': 0.21023, 'f1': 0.31413, 'auc': 0.81242}
# val: {'epoch': 8, 'time_epoch': 4.34453, 'loss': 0.073936, 'lr': 0, 'params': 559945, 'time_iter': 0.03368, 'accuracy': 0.98177, 'precision': 0.6, 'recall': 0.22222, 'f1': 0.32432, 'auc': 0.80337}
# test: {'epoch': 8, 'time_epoch': 4.2437, 'loss': 0.12585412, 'lr': 0, 'params': 559945, 'time_iter': 0.0329, 'accuracy': 0.96864, 'precision': 0.53846, 'recall': 0.05385, 'f1': 0.0979, 'auc': 0.72682}
# > Epoch 8: took 100.5s (avg 96.5s) | Best so far: epoch 7	train_loss: 0.1249 train_auc: 0.7984	val_loss: 0.0817 val_auc: 0.8087	test_loss: 0.1254 test_auc: 0.7474
# train: {'epoch': 9, 'time_epoch': 87.84393, 'eta': 7892.10202, 'eta_hours': 2.19225, 'loss': 0.1173127, 'lr': 9.956e-05, 'params': 559945, 'time_iter': 0.08537, 'accuracy': 0.96626, 'precision': 0.63319, 'recall': 0.23539, 'f1': 0.3432, 'auc': 0.83017}
# val: {'epoch': 9, 'time_epoch': 4.41907, 'loss': 0.07359199, 'lr': 0, 'params': 559945, 'time_iter': 0.03426, 'accuracy': 0.98152, 'precision': 0.57576, 'recall': 0.23457, 'f1': 0.33333, 'auc': 0.79728}
# test: {'epoch': 9, 'time_epoch': 4.43283, 'loss': 0.11204209, 'lr': 0, 'params': 559945, 'time_iter': 0.03436, 'accuracy': 0.97204, 'precision': 0.7027, 'recall': 0.2, 'f1': 0.31138, 'auc': 0.76026}
# > Epoch 9: took 96.9s (avg 96.5s) | Best so far: epoch 7	train_loss: 0.1249 train_auc: 0.7984	val_loss: 0.0817 val_auc: 0.8087	test_loss: 0.1254 test_auc: 0.7474
# train: {'epoch': 10, 'time_epoch': 90.93576, 'eta': 7830.67297, 'eta_hours': 2.17519, 'loss': 0.11654024, 'lr': 9.932e-05, 'params': 559945, 'time_iter': 0.08837, 'accuracy': 0.96714, 'precision': 0.65895, 'recall': 0.25406, 'f1': 0.36673, 'auc': 0.82992}
# val: {'epoch': 10, 'time_epoch': 4.38048, 'loss': 0.08608254, 'lr': 0, 'params': 559945, 'time_iter': 0.03396, 'accuracy': 0.9735, 'precision': 0.31579, 'recall': 0.2963, 'f1': 0.30573, 'auc': 0.80887}
# test: {'epoch': 10, 'time_epoch': 4.40179, 'loss': 0.13245251, 'lr': 0, 'params': 559945, 'time_iter': 0.03412, 'accuracy': 0.96159, 'precision': 0.32051, 'recall': 0.19231, 'f1': 0.24038, 'auc': 0.75078}
# > Epoch 10: took 99.9s (avg 96.8s) | Best so far: epoch 10	train_loss: 0.1165 train_auc: 0.8299	val_loss: 0.0861 val_auc: 0.8089	test_loss: 0.1325 test_auc: 0.7508
# train: {'epoch': 11, 'time_epoch': 90.52255, 'eta': 7761.29594, 'eta_hours': 2.15592, 'loss': 0.1147073, 'lr': 9.902e-05, 'params': 559945, 'time_iter': 0.08797, 'accuracy': 0.96821, 'precision': 0.68526, 'recall': 0.27922, 'f1': 0.39677, 'auc': 0.83273}
# val: {'epoch': 11, 'time_epoch': 4.36263, 'loss': 0.06772218, 'lr': 0, 'params': 559945, 'time_iter': 0.03382, 'accuracy': 0.98177, 'precision': 0.60714, 'recall': 0.20988, 'f1': 0.31193, 'auc': 0.84713}
# test: {'epoch': 11, 'time_epoch': 4.39689, 'loss': 0.11511386, 'lr': 0, 'params': 559945, 'time_iter': 0.03408, 'accuracy': 0.97228, 'precision': 0.76667, 'recall': 0.17692, 'f1': 0.2875, 'auc': 0.76493}
# > Epoch 11: took 99.4s (avg 97.0s) | Best so far: epoch 11	train_loss: 0.1147 train_auc: 0.8327	val_loss: 0.0677 val_auc: 0.8471	test_loss: 0.1151 test_auc: 0.7649
# train: {'epoch': 12, 'time_epoch': 91.41145, 'eta': 7694.6145, 'eta_hours': 2.13739, 'loss': 0.1118576, 'lr': 9.867e-05, 'params': 559945, 'time_iter': 0.08884, 'accuracy': 0.96833, 'precision': 0.67086, 'recall': 0.30276, 'f1': 0.41723, 'auc': 0.84482}
# val: {'epoch': 12, 'time_epoch': 4.35081, 'loss': 0.07778883, 'lr': 0, 'params': 559945, 'time_iter': 0.03373, 'accuracy': 0.98079, 'precision': 0.52, 'recall': 0.32099, 'f1': 0.39695, 'auc': 0.8176}
# test: {'epoch': 12, 'time_epoch': 4.35684, 'loss': 0.11871899, 'lr': 0, 'params': 559945, 'time_iter': 0.03377, 'accuracy': 0.96937, 'precision': 0.52564, 'recall': 0.31538, 'f1': 0.39423, 'auc': 0.76064}
# > Epoch 12: took 100.3s (avg 97.3s) | Best so far: epoch 11	train_loss: 0.1147 train_auc: 0.8327	val_loss: 0.0677 val_auc: 0.8471	test_loss: 0.1151 test_auc: 0.7649
# train: {'epoch': 13, 'time_epoch': 90.82026, 'eta': 7620.76865, 'eta_hours': 2.11688, 'loss': 0.11112533, 'lr': 9.826e-05, 'params': 559945, 'time_iter': 0.08826, 'accuracy': 0.96824, 'precision': 0.6781, 'recall': 0.28896, 'f1': 0.40524, 'auc': 0.85051}
# val: {'epoch': 13, 'time_epoch': 4.33339, 'loss': 0.06962319, 'lr': 0, 'params': 559945, 'time_iter': 0.03359, 'accuracy': 0.98347, 'precision': 0.78261, 'recall': 0.22222, 'f1': 0.34615, 'auc': 0.83401}
# test: {'epoch': 13, 'time_epoch': 4.52311, 'loss': 0.12011549, 'lr': 0, 'params': 559945, 'time_iter': 0.03506, 'accuracy': 0.97131, 'precision': 0.83333, 'recall': 0.11538, 'f1': 0.2027, 'auc': 0.759}
# > Epoch 13: took 99.8s (avg 97.5s) | Best so far: epoch 11	train_loss: 0.1147 train_auc: 0.8327	val_loss: 0.0677 val_auc: 0.8471	test_loss: 0.1151 test_auc: 0.7649
# ^C
# Traceback (most recent call last):
#   File "/kaggle/working/GraphGPS/main.py", line 166, in <module>
#     train_dict[cfg.train.mode](loggers, loaders, model, optimizer,
#   File "/kaggle/working/GraphGPS/graphgps/train/custom_train.py", line 121, in custom_train
#     train_epoch(loggers[0], loaders[0], model, optimizer, scheduler,
#   File "/kaggle/working/GraphGPS/graphgps/train/custom_train.py", line 23, in train_epoch
#     pred, true = model(batch)
#   File "/opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/torch_geometric/graphgym/model_builder.py", line 24, in forward
#     return self.model(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/kaggle/working/GraphGPS/graphgps/network/gps_model.py", line 107, in forward
#     batch = module(batch)
#   File "/opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/torch/nn/modules/container.py", line 219, in forward
#     input = module(input)
#   File "/opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/kaggle/working/GraphGPS/graphgps/layer/gps_layer.py", line 167, in forward
#     local_out = self.local_model(Batch(batch=batch,
#   File "/opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/kaggle/working/GraphGPS/graphgps/layer/gatedgcn_layer.py", line 61, in forward
#     Ex = self.E(x)
#   File "/opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/torch_geometric/nn/dense/linear.py", line 147, in forward
#     return F.linear(x, self.weight, self.bias)
#   File "/opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1716, in __getattr__
#     def __getattr__(self, name: str) -> Any:
# KeyboardInterrupt

# %% [raw]
# Runned 1:15

# %% [markdown]
# The error: https://discuss.pytorch.org/t/undefined-symbol-zn3c1017registeroperatorsd1ev/197979/9

# %%
#clone for our project
# %cd ..
# !git clone --branch add-scalar https://github.com/omertalmi5/WeightedGraphGPS.git
# Out:
# /kaggle/working
# Cloning into 'WeightedGraphGPS'...
# remote: Enumerating objects: 521, done.
# remote: Counting objects: 100% (313/313), done.
# remote: Compressing objects: 100% (91/91), done.
# remote: Total 521 (delta 253), reused 222 (delta 222), pack-reused 208 (from 1)
# Receiving objects: 100% (521/521), 12.92 MiB | 33.50 MiB/s, done.
# Resolving deltas: 100% (335/335), done.

# %%
# %cd /kaggle/working/WeightedGraphGPS
# !WANDB_MODE=disabled python main.py --cfg configs/GPS/ogbg-molhiv-GPS.yaml
# Out:
# /kaggle/working/WeightedGraphGPS
# [*] Run ID 0: seed=0, split_index=0
#     Starting now: 2024-09-23 13:45:48.664497
# Downloading http://snap.stanford.edu/ogb/data/graphproppred/csv_mol_download/hiv.zip
# Downloaded 0.00 GB: 100%|█████████████████████████| 3/3 [00:00<00:00,  3.65it/s]
# Extracting ./datasets/hiv.zip
# Processing...
# Loading necessary files...
# This might take a while.
# Processing graphs...
# 100%|██████████████████████████████████| 41127/41127 [00:00<00:00, 56442.38it/s]
# Converting graphs into PyG objects...
# 100%|██████████████████████████████████| 41127/41127 [00:02<00:00, 16889.88it/s]
# Saving...
# Done!
# /opt/conda/lib/python3.10/site-packages/ogb/graphproppred/dataset_pyg.py:68: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.data, self.slices = torch.load(self.processed_paths[0])
# [*] Loaded dataset 'ogbg-molhiv' from 'OGB':
# /opt/conda/lib/python3.10/site-packages/torch_geometric/data/in_memory_dataset.py:300: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
#   Data(edge_index=[2, 2259376], edge_attr=[2259376, 3], x=[1049163, 9], y=[41127, 1], num_nodes=1049163)
#   undirected: True
#   num graphs: 41127
# /opt/conda/lib/python3.10/site-packages/torch_geometric/data/in_memory_dataset.py:300: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. The data of the dataset is already cached, so any modifications to `data` will not be reflected when accessing its elements. Clearing the cache now by removing all elements in `dataset._data_list`. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
#   avg num_nodes/graph: 25
#   num node features: 9
#   num edge features: 3
#   num tasks: 1
#   num classes: 2
# Precomputing Positional Encoding statistics: ['LapPE'] for all graphs...
#   ...estimated to be undirected: True
# 100%|████████████████████████████████████| 41127/41127 [00:57<00:00, 718.69it/s]
# Done! Took 00:00:59.02
# GraphGymModule(
#   (model): GPSModel(
#     (encoder): FeatureEncoder(
#       (node_encoder): Concat2NodeEncoder(
#         (encoder1): AtomEncoder(
#           (atom_embedding_list): ModuleList(
#             (0): Embedding(119, 56)
#             (1): Embedding(5, 56)
#             (2-3): 2 x Embedding(12, 56)
#             (4): Embedding(10, 56)
#             (5-6): 2 x Embedding(6, 56)
#             (7-8): 2 x Embedding(2, 56)
#           )
#         )
#         (encoder2): LapPENodeEncoder(
#           (linear_A): Linear(in_features=2, out_features=16, bias=True)
#           (pe_encoder): Sequential(
#             (0): ReLU()
#             (1): Linear(in_features=16, out_features=8, bias=True)
#             (2): ReLU()
#           )
#         )
#       )
#       (edge_encoder): BondEncoder(
#         (bond_embedding_list): ModuleList(
#           (0): Embedding(5, 64)
#           (1): Embedding(6, 64)
#           (2): Embedding(2, 64)
#         )
#       )
#     )
#     (layers): Sequential(
#       (0): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (1): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (2): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (3): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (4): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (5): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (6): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (7): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (8): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (9): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#     )
#     (post_mp): SANGraphHead(
#       (FC_layers): ModuleList(
#         (0): Linear(in_features=64, out_features=32, bias=True)
#         (1): Linear(in_features=32, out_features=16, bias=True)
#         (2): Linear(in_features=16, out_features=1, bias=True)
#       )
#       (activation): ReLU()
#     )
#   )
# )
# accelerator: cuda
# benchmark: False
# bn:
#   eps: 1e-05
#   mom: 0.1
# cfg_dest: config.yaml
# custom_metrics: []
# dataset:
#   cache_load: False
#   cache_save: False
#   dir: ./datasets
#   edge_dim: 128
#   edge_encoder: True
#   edge_encoder_bn: False
#   edge_encoder_name: Bond
#   edge_encoder_num_types: 0
#   edge_message_ratio: 0.8
#   edge_negative_sampling_ratio: 1.0
#   edge_train_mode: all
#   encoder: True
#   encoder_bn: True
#   encoder_dim: 128
#   encoder_name: db
#   format: OGB
#   infer_link_label: None
#   label_column: none
#   label_table: none
#   location: local
#   name: ogbg-molhiv
#   node_encoder: True
#   node_encoder_bn: False
#   node_encoder_name: Atom+LapPE
#   node_encoder_num_types: 0
#   remove_feature: False
#   resample_disjoint: False
#   resample_negative: False
#   shuffle_split: True
#   slic_compactness: 10
#   split: [0.8, 0.1, 0.1]
#   split_dir: ./splits
#   split_index: 0
#   split_mode: standard
#   task: graph
#   task_type: classification
#   to_undirected: False
#   transductive: False
#   transform: none
#   tu_simple: True
# devices: 1
# example_arg: example
# example_group:
#   example_arg: example
# gnn:
#   act: relu
#   agg: mean
#   att_final_linear: False
#   att_final_linear_bn: False
#   att_heads: 1
#   batchnorm: True
#   clear_feature: True
#   dim_edge: 64
#   dim_inner: 64
#   dropout: 0.0
#   head: san_graph
#   keep_edge: 0.5
#   l2norm: True
#   layer_type: generalconv
#   layers_mp: 2
#   layers_post_mp: 3
#   layers_pre_mp: 0
#   msg_direction: single
#   normalize_adj: False
#   residual: False
#   self_msg: concat
#   skip_every: 1
#   stage_type: stack
# gpu_mem: False
# graphormer:
#   attention_dropout: 0.0
#   dropout: 0.0
#   embed_dim: 80
#   input_dropout: 0.0
#   mlp_dropout: 0.0
#   num_heads: 4
#   num_layers: 6
#   use_graph_token: True
# gt:
#   attn_dropout: 0.5
#   batch_norm: True
#   bigbird:
#     add_cross_attention: False
#     attention_type: block_sparse
#     block_size: 3
#     chunk_size_feed_forward: 0
#     hidden_act: relu
#     is_decoder: False
#     layer_norm_eps: 1e-06
#     max_position_embeddings: 128
#     num_random_blocks: 3
#     use_bias: False
#   dim_hidden: 64
#   dropout: 0.05
#   full_graph: True
#   gamma: 1e-05
#   layer_norm: False
#   layer_type: CustomGatedGCN+Transformer
#   layers: 10
#   n_heads: 4
#   pna_degrees: []
#   residual: True
# mem:
#   inplace: False
# metric_agg: argmax
# metric_best: auc
# model:
#   edge_decoding: dot
#   graph_pooling: mean
#   loss_fun: cross_entropy
#   match_upper: True
#   size_average: mean
#   thresh: 0.5
#   type: GPSModel
# name_tag:
# num_threads: 6
# num_workers: 0
# optim:
#   base_lr: 0.0001
#   batch_accumulation: 1
#   clip_grad_norm: True
#   clip_grad_norm_value: 1.0
#   lr_decay: 0.1
#   max_epoch: 100
#   min_lr: 0.0
#   momentum: 0.9
#   num_warmup_epochs: 5
#   optimizer: adamW
#   reduce_factor: 0.1
#   schedule_patience: 10
#   scheduler: cosine_with_warmup
#   steps: [30, 60, 90]
#   weight_decay: 1e-05
# out_dir: results/ogbg-molhiv-GPS
# posenc_ElstaticSE:
#   dim_pe: 16
#   enable: False
#   kernel:
#     times: []
#     times_func: range(10)
#   layers: 3
#   model: none
#   n_heads: 4
#   pass_as_var: False
#   post_layers: 0
#   raw_norm_type: none
# posenc_EquivStableLapPE:
#   eigen:
#     eigvec_norm: L2
#     laplacian_norm: sym
#     max_freqs: 10
#   enable: False
#   raw_norm_type: none
# posenc_GraphormerBias:
#   dim_pe: 0
#   enable: False
#   node_degrees_only: False
#   num_in_degrees: None
#   num_out_degrees: None
#   num_spatial_types: None
# posenc_HKdiagSE:
#   dim_pe: 16
#   enable: False
#   kernel:
#     times: []
#     times_func:
#   layers: 3
#   model: none
#   n_heads: 4
#   pass_as_var: False
#   post_layers: 0
#   raw_norm_type: none
# posenc_LapPE:
#   dim_pe: 8
#   eigen:
#     eigvec_norm: L2
#     laplacian_norm: none
#     max_freqs: 8
#   enable: True
#   layers: 2
#   model: DeepSet
#   n_heads: 4
#   pass_as_var: False
#   post_layers: 0
#   raw_norm_type: none
# posenc_RWSE:
#   dim_pe: 16
#   enable: False
#   kernel:
#     times: []
#     times_func:
#   layers: 3
#   model: none
#   n_heads: 4
#   pass_as_var: False
#   post_layers: 0
#   raw_norm_type: none
# posenc_SignNet:
#   dim_pe: 16
#   eigen:
#     eigvec_norm: L2
#     laplacian_norm: sym
#     max_freqs: 10
#   enable: False
#   layers: 3
#   model: none
#   n_heads: 4
#   pass_as_var: False
#   phi_hidden_dim: 64
#   phi_out_dim: 4
#   post_layers: 0
#   raw_norm_type: none
# pretrained:
#   dir:
#   freeze_main: False
#   reset_prediction_head: True
# print: both
# round: 5
# run_dir: results/ogbg-molhiv-GPS/0
# run_id: 0
# run_multiple_splits: []
# seed: 0
# share:
#   dim_in: 9
#   dim_out: 2
#   num_splits: 3
# tensorboard_agg: True
# tensorboard_each_run: False
# train:
#   auto_resume: False
#   batch_size: 32
#   ckpt_best: False
#   ckpt_clean: True
#   ckpt_period: 100
#   enable_ckpt: True
#   epoch_resume: -1
#   eval_period: 1
#   iter_per_epoch: 32
#   mode: custom
#   neighbor_sizes: [20, 15, 10, 5]
#   node_per_graph: 32
#   radius: extend
#   sample_node: False
#   sampler: full_batch
#   skip_train_eval: False
#   walk_length: 4
# val:
#   node_per_graph: 32
#   radius: extend
#   sample_node: False
#   sampler: full_batch
# view_emb: False
# wandb:
#   entity: gtransformers
#   name:
#   project: molhiv
#   use: True
# Num parameters: 559955
# Start from epoch 0
# Key posenc_GraphormerBias.num_spatial_types with value <class 'NoneType'> is not a valid type; valid types: {<class 'tuple'>, <class 'list'>, <class 'str'>, <class 'bool'>, <class 'int'>, <class 'float'>}
# Key posenc_GraphormerBias.num_in_degrees with value <class 'NoneType'> is not a valid type; valid types: {<class 'tuple'>, <class 'list'>, <class 'str'>, <class 'bool'>, <class 'int'>, <class 'float'>}
# Key posenc_GraphormerBias.num_out_degrees with value <class 'NoneType'> is not a valid type; valid types: {<class 'tuple'>, <class 'list'>, <class 'str'>, <class 'bool'>, <class 'int'>, <class 'float'>}
# train: {'epoch': 0, 'time_epoch': 102.23564, 'eta': 10121.32884, 'eta_hours': 2.81148, 'loss': 0.79160831, 'lr': 0.0, 'params': 559955, 'time_iter': 0.09935, 'accuracy': 0.03748, 'precision': 0.03745, 'recall': 1.0, 'f1': 0.07219, 'auc': 0.55613}
# ...computing epoch stats took: 0.09s
# val: {'epoch': 0, 'time_epoch': 5.25962, 'loss': 0.79657471, 'lr': 0, 'params': 559955, 'time_iter': 0.04077, 'accuracy': 0.01969, 'precision': 0.01969, 'recall': 1.0, 'f1': 0.03863, 'auc': 0.53256}
# ...computing epoch stats took: 0.01s
# test: {'epoch': 0, 'time_epoch': 5.30657, 'loss': 0.79389983, 'lr': 0, 'params': 559955, 'time_iter': 0.04114, 'accuracy': 0.03161, 'precision': 0.03161, 'recall': 1.0, 'f1': 0.06128, 'auc': 0.57868}
# ...computing epoch stats took: 0.01s
# > Epoch 0: took 113.0s (avg 113.0s) | Best so far: epoch 0	train_loss: 0.7916 train_auc: 0.5561	val_loss: 0.7966 val_auc: 0.5326	test_loss: 0.7939 test_auc: 0.5787
# train: {'epoch': 1, 'time_epoch': 95.28158, 'eta': 9678.34384, 'eta_hours': 2.68843, 'loss': 0.49182646, 'lr': 2e-05, 'params': 559955, 'time_iter': 0.0926, 'accuracy': 0.76742, 'precision': 0.04725, 'recall': 0.27192, 'f1': 0.08051, 'auc': 0.55999}
# ...computing epoch stats took: 0.08s
# val: {'epoch': 1, 'time_epoch': 4.50143, 'loss': 0.26743571, 'lr': 0, 'params': 559955, 'time_iter': 0.03489, 'accuracy': 0.97812, 'precision': 0.2, 'recall': 0.03704, 'f1': 0.0625, 'auc': 0.66095}
# ...computing epoch stats took: 0.02s
# test: {'epoch': 1, 'time_epoch': 4.36603, 'loss': 0.26762706, 'lr': 0, 'params': 559955, 'time_iter': 0.03385, 'accuracy': 0.96693, 'precision': 0.33333, 'recall': 0.04615, 'f1': 0.08108, 'auc': 0.67458}
# ...computing epoch stats took: 0.02s
# > Epoch 1: took 104.3s (avg 108.6s) | Best so far: epoch 1	train_loss: 0.4918 train_auc: 0.5600	val_loss: 0.2674 val_auc: 0.6610	test_loss: 0.2676 test_auc: 0.6746
# train: {'epoch': 2, 'time_epoch': 82.87578, 'eta': 9066.04051, 'eta_hours': 2.51834, 'loss': 0.189584, 'lr': 4e-05, 'params': 559955, 'time_iter': 0.08054, 'accuracy': 0.96243, 'precision': 0.25, 'recall': 0.00162, 'f1': 0.00323, 'auc': 0.61128}
# ...computing epoch stats took: 0.07s
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 2, 'time_epoch': 4.01762, 'loss': 0.10344022, 'lr': 0, 'params': 559955, 'time_iter': 0.03114, 'accuracy': 0.98031, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.66613}
# ...computing epoch stats took: 0.01s
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# test: {'epoch': 2, 'time_epoch': 3.98715, 'loss': 0.13198355, 'lr': 0, 'params': 559955, 'time_iter': 0.03091, 'accuracy': 0.96839, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.71617}
# ...computing epoch stats took: 0.01s
# > Epoch 2: took 91.0s (avg 102.8s) | Best so far: epoch 2	train_loss: 0.1896 train_auc: 0.6113	val_loss: 0.1034 val_auc: 0.6661	test_loss: 0.1320 test_auc: 0.7162
# train: {'epoch': 3, 'time_epoch': 81.18254, 'eta': 8677.81301, 'eta_hours': 2.4105, 'loss': 0.14560109, 'lr': 6e-05, 'params': 559955, 'time_iter': 0.07889, 'accuracy': 0.96265, 'precision': 0.54286, 'recall': 0.01542, 'f1': 0.02999, 'auc': 0.70604}
# val: {'epoch': 3, 'time_epoch': 3.98618, 'loss': 0.08285081, 'lr': 0, 'params': 559955, 'time_iter': 0.0309, 'accuracy': 0.98177, 'precision': 0.8, 'recall': 0.09877, 'f1': 0.17582, 'auc': 0.7488}
# test: {'epoch': 3, 'time_epoch': 4.01407, 'loss': 0.11693812, 'lr': 0, 'params': 559955, 'time_iter': 0.03112, 'accuracy': 0.97058, 'precision': 0.76471, 'recall': 0.1, 'f1': 0.17687, 'auc': 0.75163}
# > Epoch 3: took 89.3s (avg 99.4s) | Best so far: epoch 3	train_loss: 0.1456 train_auc: 0.7060	val_loss: 0.0829 val_auc: 0.7488	test_loss: 0.1169 test_auc: 0.7516
# train: {'epoch': 4, 'time_epoch': 80.55709, 'eta': 8400.51997, 'eta_hours': 2.33348, 'loss': 0.13854645, 'lr': 8e-05, 'params': 559955, 'time_iter': 0.07829, 'accuracy': 0.96441, 'precision': 0.72263, 'recall': 0.08036, 'f1': 0.14463, 'auc': 0.7353}
# val: {'epoch': 4, 'time_epoch': 4.02856, 'loss': 0.07895742, 'lr': 0, 'params': 559955, 'time_iter': 0.03123, 'accuracy': 0.98177, 'precision': 0.63636, 'recall': 0.17284, 'f1': 0.27184, 'auc': 0.77558}
# test: {'epoch': 4, 'time_epoch': 3.98369, 'loss': 0.11458297, 'lr': 0, 'params': 559955, 'time_iter': 0.03088, 'accuracy': 0.97253, 'precision': 0.72973, 'recall': 0.20769, 'f1': 0.32335, 'auc': 0.7548}
# > Epoch 4: took 88.7s (avg 97.3s) | Best so far: epoch 4	train_loss: 0.1385 train_auc: 0.7353	val_loss: 0.0790 val_auc: 0.7756	test_loss: 0.1146 test_auc: 0.7548
# train: {'epoch': 5, 'time_epoch': 83.40976, 'eta': 8233.49744, 'eta_hours': 2.28708, 'loss': 0.13294054, 'lr': 0.0001, 'params': 559955, 'time_iter': 0.08106, 'accuracy': 0.96426, 'precision': 0.63084, 'recall': 0.10958, 'f1': 0.18672, 'auc': 0.7622}
# val: {'epoch': 5, 'time_epoch': 4.17332, 'loss': 0.07850339, 'lr': 0, 'params': 559955, 'time_iter': 0.03235, 'accuracy': 0.98152, 'precision': 0.6087, 'recall': 0.17284, 'f1': 0.26923, 'auc': 0.80477}
# test: {'epoch': 5, 'time_epoch': 4.21375, 'loss': 0.12130064, 'lr': 0, 'params': 559955, 'time_iter': 0.03266, 'accuracy': 0.97131, 'precision': 0.64286, 'recall': 0.20769, 'f1': 0.31395, 'auc': 0.72325}
# > Epoch 5: took 91.9s (avg 96.4s) | Best so far: epoch 5	train_loss: 0.1329 train_auc: 0.7622	val_loss: 0.0785 val_auc: 0.8048	test_loss: 0.1213 test_auc: 0.7232
# train: {'epoch': 6, 'time_epoch': 88.07223, 'eta': 8152.3085, 'eta_hours': 2.26453, 'loss': 0.12704734, 'lr': 9.997e-05, 'params': 559955, 'time_iter': 0.08559, 'accuracy': 0.9655, 'precision': 0.66899, 'recall': 0.15584, 'f1': 0.2528, 'auc': 0.7943}
# val: {'epoch': 6, 'time_epoch': 4.02529, 'loss': 0.07865607, 'lr': 0, 'params': 559955, 'time_iter': 0.0312, 'accuracy': 0.98225, 'precision': 0.68182, 'recall': 0.18519, 'f1': 0.29126, 'auc': 0.77482}
# test: {'epoch': 6, 'time_epoch': 4.01862, 'loss': 0.11629495, 'lr': 0, 'params': 559955, 'time_iter': 0.03115, 'accuracy': 0.97228, 'precision': 0.72222, 'recall': 0.2, 'f1': 0.31325, 'auc': 0.74408}
# > Epoch 6: took 96.3s (avg 96.4s) | Best so far: epoch 5	train_loss: 0.1329 train_auc: 0.7622	val_loss: 0.0785 val_auc: 0.8048	test_loss: 0.1213 test_auc: 0.7232
# train: {'epoch': 7, 'time_epoch': 83.89813, 'eta': 8021.39661, 'eta_hours': 2.22817, 'loss': 0.12555693, 'lr': 9.989e-05, 'params': 559955, 'time_iter': 0.08153, 'accuracy': 0.96529, 'precision': 0.62857, 'recall': 0.17857, 'f1': 0.27813, 'auc': 0.79447}
# val: {'epoch': 7, 'time_epoch': 4.10199, 'loss': 0.08270128, 'lr': 0, 'params': 559955, 'time_iter': 0.0318, 'accuracy': 0.9769, 'precision': 0.375, 'recall': 0.25926, 'f1': 0.30657, 'auc': 0.80256}
# test: {'epoch': 7, 'time_epoch': 4.04782, 'loss': 0.12241123, 'lr': 0, 'params': 559955, 'time_iter': 0.03138, 'accuracy': 0.96645, 'precision': 0.44872, 'recall': 0.26923, 'f1': 0.33654, 'auc': 0.76465}
# > Epoch 7: took 92.2s (avg 95.8s) | Best so far: epoch 5	train_loss: 0.1329 train_auc: 0.7622	val_loss: 0.0785 val_auc: 0.8048	test_loss: 0.1213 test_auc: 0.7232
# train: {'epoch': 8, 'time_epoch': 83.39103, 'eta': 7895.80483, 'eta_hours': 2.19328, 'loss': 0.12190616, 'lr': 9.975e-05, 'params': 559955, 'time_iter': 0.08104, 'accuracy': 0.96581, 'precision': 0.62471, 'recall': 0.21753, 'f1': 0.3227, 'auc': 0.80886}
# val: {'epoch': 8, 'time_epoch': 4.03711, 'loss': 0.07240659, 'lr': 0, 'params': 559955, 'time_iter': 0.0313, 'accuracy': 0.98201, 'precision': 0.62963, 'recall': 0.20988, 'f1': 0.31481, 'auc': 0.79874}
# test: {'epoch': 8, 'time_epoch': 3.97683, 'loss': 0.12315128, 'lr': 0, 'params': 559955, 'time_iter': 0.03083, 'accuracy': 0.97082, 'precision': 0.75, 'recall': 0.11538, 'f1': 0.2, 'auc': 0.73138}
# > Epoch 8: took 91.5s (avg 95.4s) | Best so far: epoch 5	train_loss: 0.1329 train_auc: 0.7622	val_loss: 0.0785 val_auc: 0.8048	test_loss: 0.1213 test_auc: 0.7232
# train: {'epoch': 9, 'time_epoch': 81.07653, 'eta': 7757.82272, 'eta_hours': 2.15495, 'loss': 0.11774129, 'lr': 9.956e-05, 'params': 559955, 'time_iter': 0.07879, 'accuracy': 0.96681, 'precision': 0.64957, 'recall': 0.24675, 'f1': 0.35765, 'auc': 0.82517}
# val: {'epoch': 9, 'time_epoch': 3.98509, 'loss': 0.07082476, 'lr': 0, 'params': 559955, 'time_iter': 0.03089, 'accuracy': 0.98249, 'precision': 0.64516, 'recall': 0.24691, 'f1': 0.35714, 'auc': 0.80319}
# test: {'epoch': 9, 'time_epoch': 3.99851, 'loss': 0.11214224, 'lr': 0, 'params': 559955, 'time_iter': 0.031, 'accuracy': 0.97228, 'precision': 0.7, 'recall': 0.21538, 'f1': 0.32941, 'auc': 0.75426}
# > Epoch 9: took 89.2s (avg 94.7s) | Best so far: epoch 5	train_loss: 0.1329 train_auc: 0.7622	val_loss: 0.0785 val_auc: 0.8048	test_loss: 0.1213 test_auc: 0.7232
# train: {'epoch': 10, 'time_epoch': 81.04725, 'eta': 7629.95021, 'eta_hours': 2.11943, 'loss': 0.11631181, 'lr': 9.932e-05, 'params': 559955, 'time_iter': 0.07876, 'accuracy': 0.9673, 'precision': 0.65789, 'recall': 0.2638, 'f1': 0.37659, 'auc': 0.82893}
# val: {'epoch': 10, 'time_epoch': 4.10116, 'loss': 0.07344229, 'lr': 0, 'params': 559955, 'time_iter': 0.03179, 'accuracy': 0.98006, 'precision': 0.4918, 'recall': 0.37037, 'f1': 0.42254, 'auc': 0.82857}
# test: {'epoch': 10, 'time_epoch': 3.97567, 'loss': 0.1213115, 'lr': 0, 'params': 559955, 'time_iter': 0.03082, 'accuracy': 0.96864, 'precision': 0.50847, 'recall': 0.23077, 'f1': 0.31746, 'auc': 0.75612}
# > Epoch 10: took 89.3s (avg 94.2s) | Best so far: epoch 10	train_loss: 0.1163 train_auc: 0.8289	val_loss: 0.0734 val_auc: 0.8286	test_loss: 0.1213 test_auc: 0.7561
# train: {'epoch': 11, 'time_epoch': 81.29629, 'eta': 7511.70818, 'eta_hours': 2.08659, 'loss': 0.11475433, 'lr': 9.902e-05, 'params': 559955, 'time_iter': 0.07901, 'accuracy': 0.96827, 'precision': 0.68359, 'recall': 0.28409, 'f1': 0.40138, 'auc': 0.83344}
# val: {'epoch': 11, 'time_epoch': 4.02009, 'loss': 0.06530162, 'lr': 0, 'params': 559955, 'time_iter': 0.03116, 'accuracy': 0.98274, 'precision': 0.625, 'recall': 0.30864, 'f1': 0.41322, 'auc': 0.84638}
# test: {'epoch': 11, 'time_epoch': 4.05655, 'loss': 0.11221263, 'lr': 0, 'params': 559955, 'time_iter': 0.03145, 'accuracy': 0.97228, 'precision': 0.71053, 'recall': 0.20769, 'f1': 0.32143, 'auc': 0.76959}
# > Epoch 11: took 89.5s (avg 93.8s) | Best so far: epoch 11	train_loss: 0.1148 train_auc: 0.8334	val_loss: 0.0653 val_auc: 0.8464	test_loss: 0.1122 test_auc: 0.7696
# train: {'epoch': 12, 'time_epoch': 82.6026, 'eta': 7407.89232, 'eta_hours': 2.05775, 'loss': 0.11232585, 'lr': 9.867e-05, 'params': 559955, 'time_iter': 0.08027, 'accuracy': 0.96836, 'precision': 0.67207, 'recall': 0.30276, 'f1': 0.41746, 'auc': 0.84346}
# val: {'epoch': 12, 'time_epoch': 4.02235, 'loss': 0.07379817, 'lr': 0, 'params': 559955, 'time_iter': 0.03118, 'accuracy': 0.98274, 'precision': 0.6087, 'recall': 0.34568, 'f1': 0.44094, 'auc': 0.80406}
# test: {'epoch': 12, 'time_epoch': 4.03135, 'loss': 0.11617485, 'lr': 0, 'params': 559955, 'time_iter': 0.03125, 'accuracy': 0.97082, 'precision': 0.57353, 'recall': 0.3, 'f1': 0.39394, 'auc': 0.75323}
# > Epoch 12: took 90.8s (avg 93.6s) | Best so far: epoch 11	train_loss: 0.1148 train_auc: 0.8334	val_loss: 0.0653 val_auc: 0.8464	test_loss: 0.1122 test_auc: 0.7696
# train: {'epoch': 13, 'time_epoch': 81.86919, 'eta': 7302.60172, 'eta_hours': 2.0285, 'loss': 0.11103911, 'lr': 9.826e-05, 'params': 559955, 'time_iter': 0.07956, 'accuracy': 0.96851, 'precision': 0.67626, 'recall': 0.30519, 'f1': 0.42058, 'auc': 0.84905}
# val: {'epoch': 13, 'time_epoch': 4.0082, 'loss': 0.06696882, 'lr': 0, 'params': 559955, 'time_iter': 0.03107, 'accuracy': 0.98298, 'precision': 0.68966, 'recall': 0.24691, 'f1': 0.36364, 'auc': 0.82131}
# test: {'epoch': 13, 'time_epoch': 4.04606, 'loss': 0.11877995, 'lr': 0, 'params': 559955, 'time_iter': 0.03136, 'accuracy': 0.97131, 'precision': 0.6875, 'recall': 0.16923, 'f1': 0.2716, 'auc': 0.75164}
# > Epoch 13: took 90.1s (avg 93.4s) | Best so far: epoch 11	train_loss: 0.1148 train_auc: 0.8334	val_loss: 0.0653 val_auc: 0.8464	test_loss: 0.1122 test_auc: 0.7696
# train: {'epoch': 14, 'time_epoch': 82.29307, 'eta': 7202.83598, 'eta_hours': 2.00079, 'loss': 0.10965385, 'lr': 9.78e-05, 'params': 559955, 'time_iter': 0.07997, 'accuracy': 0.96954, 'precision': 0.7114, 'recall': 0.31412, 'f1': 0.43581, 'auc': 0.85203}
# val: {'epoch': 14, 'time_epoch': 4.00459, 'loss': 0.06952405, 'lr': 0, 'params': 559955, 'time_iter': 0.03104, 'accuracy': 0.98249, 'precision': 0.60465, 'recall': 0.32099, 'f1': 0.41935, 'auc': 0.83073}
# test: {'epoch': 14, 'time_epoch': 3.97358, 'loss': 0.11455065, 'lr': 0, 'params': 559955, 'time_iter': 0.0308, 'accuracy': 0.97058, 'precision': 0.56923, 'recall': 0.28462, 'f1': 0.37949, 'auc': 0.76153}
# > Epoch 14: took 90.4s (avg 93.2s) | Best so far: epoch 11	train_loss: 0.1148 train_auc: 0.8334	val_loss: 0.0653 val_auc: 0.8464	test_loss: 0.1122 test_auc: 0.7696
# train: {'epoch': 15, 'time_epoch': 81.83923, 'eta': 7102.87166, 'eta_hours': 1.97302, 'loss': 0.1073016, 'lr': 9.729e-05, 'params': 559955, 'time_iter': 0.07953, 'accuracy': 0.96976, 'precision': 0.70466, 'recall': 0.33117, 'f1': 0.45058, 'auc': 0.85993}
# val: {'epoch': 15, 'time_epoch': 3.98454, 'loss': 0.07029706, 'lr': 0, 'params': 559955, 'time_iter': 0.03089, 'accuracy': 0.98249, 'precision': 0.59184, 'recall': 0.35802, 'f1': 0.44615, 'auc': 0.81728}
# test: {'epoch': 15, 'time_epoch': 3.98362, 'loss': 0.1152936, 'lr': 0, 'params': 559955, 'time_iter': 0.03088, 'accuracy': 0.96888, 'precision': 0.51471, 'recall': 0.26923, 'f1': 0.35354, 'auc': 0.774}
# > Epoch 15: took 89.9s (avg 93.0s) | Best so far: epoch 11	train_loss: 0.1148 train_auc: 0.8334	val_loss: 0.0653 val_auc: 0.8464	test_loss: 0.1122 test_auc: 0.7696
# train: {'epoch': 16, 'time_epoch': 81.81819, 'eta': 7004.93697, 'eta_hours': 1.94582, 'loss': 0.10664213, 'lr': 9.673e-05, 'params': 559955, 'time_iter': 0.07951, 'accuracy': 0.96924, 'precision': 0.68581, 'recall': 0.32955, 'f1': 0.44518, 'auc': 0.86452}
# val: {'epoch': 16, 'time_epoch': 3.98, 'loss': 0.0746726, 'lr': 0, 'params': 559955, 'time_iter': 0.03085, 'accuracy': 0.98006, 'precision': 0.49206, 'recall': 0.38272, 'f1': 0.43056, 'auc': 0.81271}
# test: {'epoch': 16, 'time_epoch': 3.96606, 'loss': 0.11740721, 'lr': 0, 'params': 559955, 'time_iter': 0.03074, 'accuracy': 0.96888, 'precision': 0.51562, 'recall': 0.25385, 'f1': 0.34021, 'auc': 0.75942}
# > Epoch 16: took 89.9s (avg 92.8s) | Best so far: epoch 11	train_loss: 0.1148 train_auc: 0.8334	val_loss: 0.0653 val_auc: 0.8464	test_loss: 0.1122 test_auc: 0.7696
# train: {'epoch': 17, 'time_epoch': 81.99134, 'eta': 6909.58177, 'eta_hours': 1.91933, 'loss': 0.10466858, 'lr': 9.611e-05, 'params': 559955, 'time_iter': 0.07968, 'accuracy': 0.97046, 'precision': 0.709, 'recall': 0.35795, 'f1': 0.47573, 'auc': 0.86704}
# val: {'epoch': 17, 'time_epoch': 4.0315, 'loss': 0.06972032, 'lr': 0, 'params': 559955, 'time_iter': 0.03125, 'accuracy': 0.98274, 'precision': 0.6087, 'recall': 0.34568, 'f1': 0.44094, 'auc': 0.8317}
# test: {'epoch': 17, 'time_epoch': 4.01327, 'loss': 0.12234893, 'lr': 0, 'params': 559955, 'time_iter': 0.03111, 'accuracy': 0.96888, 'precision': 0.52381, 'recall': 0.16923, 'f1': 0.25581, 'auc': 0.76016}
# > Epoch 17: took 90.2s (avg 92.6s) | Best so far: epoch 11	train_loss: 0.1148 train_auc: 0.8334	val_loss: 0.0653 val_auc: 0.8464	test_loss: 0.1122 test_auc: 0.7696
# train: {'epoch': 18, 'time_epoch': 82.11111, 'eta': 6816.14392, 'eta_hours': 1.89337, 'loss': 0.10441808, 'lr': 9.545e-05, 'params': 559955, 'time_iter': 0.0798, 'accuracy': 0.96967, 'precision': 0.69435, 'recall': 0.33929, 'f1': 0.45583, 'auc': 0.87475}
# val: {'epoch': 18, 'time_epoch': 4.07152, 'loss': 0.06811087, 'lr': 0, 'params': 559955, 'time_iter': 0.03156, 'accuracy': 0.98274, 'precision': 0.6087, 'recall': 0.34568, 'f1': 0.44094, 'auc': 0.8231}
# test: {'epoch': 18, 'time_epoch': 4.00139, 'loss': 0.1130834, 'lr': 0, 'params': 559955, 'time_iter': 0.03102, 'accuracy': 0.96864, 'precision': 0.50704, 'recall': 0.27692, 'f1': 0.35821, 'auc': 0.78062}
# > Epoch 18: took 90.3s (avg 92.5s) | Best so far: epoch 11	train_loss: 0.1148 train_auc: 0.8334	val_loss: 0.0653 val_auc: 0.8464	test_loss: 0.1122 test_auc: 0.7696
# train: {'epoch': 19, 'time_epoch': 82.35401, 'eta': 6724.81032, 'eta_hours': 1.868, 'loss': 0.10155488, 'lr': 9.474e-05, 'params': 559955, 'time_iter': 0.08003, 'accuracy': 0.97082, 'precision': 0.7125, 'recall': 0.37013, 'f1': 0.48718, 'auc': 0.88231}
# val: {'epoch': 19, 'time_epoch': 3.97027, 'loss': 0.06914256, 'lr': 0, 'params': 559955, 'time_iter': 0.03078, 'accuracy': 0.98274, 'precision': 0.67857, 'recall': 0.23457, 'f1': 0.34862, 'auc': 0.81945}
# test: {'epoch': 19, 'time_epoch': 4.01171, 'loss': 0.12228356, 'lr': 0, 'params': 559955, 'time_iter': 0.0311, 'accuracy': 0.96839, 'precision': 0.5, 'recall': 0.11538, 'f1': 0.1875, 'auc': 0.7682}
# > Epoch 19: took 90.5s (avg 92.4s) | Best so far: epoch 11	train_loss: 0.1148 train_auc: 0.8334	val_loss: 0.0653 val_auc: 0.8464	test_loss: 0.1122 test_auc: 0.7696
# train: {'epoch': 20, 'time_epoch': 81.61694, 'eta': 6631.55914, 'eta_hours': 1.8421, 'loss': 0.09992778, 'lr': 9.397e-05, 'params': 559955, 'time_iter': 0.07932, 'accuracy': 0.97103, 'precision': 0.72464, 'recall': 0.36526, 'f1': 0.4857, 'auc': 0.89126}
# val: {'epoch': 20, 'time_epoch': 3.98322, 'loss': 0.0703193, 'lr': 0, 'params': 559955, 'time_iter': 0.03088, 'accuracy': 0.98177, 'precision': 0.56522, 'recall': 0.32099, 'f1': 0.40945, 'auc': 0.81795}
# test: {'epoch': 20, 'time_epoch': 4.08234, 'loss': 0.12142505, 'lr': 0, 'params': 559955, 'time_iter': 0.03165, 'accuracy': 0.96937, 'precision': 0.54, 'recall': 0.20769, 'f1': 0.3, 'auc': 0.7561}
# > Epoch 20: took 89.8s (avg 92.3s) | Best so far: epoch 11	train_loss: 0.1148 train_auc: 0.8334	val_loss: 0.0653 val_auc: 0.8464	test_loss: 0.1122 test_auc: 0.7696
# train: {'epoch': 21, 'time_epoch': 81.42012, 'eta': 6538.66781, 'eta_hours': 1.8163, 'loss': 0.0995549, 'lr': 9.316e-05, 'params': 559955, 'time_iter': 0.07913, 'accuracy': 0.97058, 'precision': 0.7, 'recall': 0.375, 'f1': 0.48837, 'auc': 0.8918}
# val: {'epoch': 21, 'time_epoch': 3.98896, 'loss': 0.07377915, 'lr': 0, 'params': 559955, 'time_iter': 0.03092, 'accuracy': 0.98249, 'precision': 0.60465, 'recall': 0.32099, 'f1': 0.41935, 'auc': 0.81175}
# test: {'epoch': 21, 'time_epoch': 3.96759, 'loss': 0.12220603, 'lr': 0, 'params': 559955, 'time_iter': 0.03076, 'accuracy': 0.96766, 'precision': 0.47541, 'recall': 0.22308, 'f1': 0.30366, 'auc': 0.75635}
# > Epoch 21: took 89.5s (avg 92.2s) | Best so far: epoch 11	train_loss: 0.1148 train_auc: 0.8334	val_loss: 0.0653 val_auc: 0.8464	test_loss: 0.1122 test_auc: 0.7696
# train: {'epoch': 22, 'time_epoch': 81.76676, 'eta': 6447.93447, 'eta_hours': 1.79109, 'loss': 0.09785064, 'lr': 9.23e-05, 'params': 559955, 'time_iter': 0.07946, 'accuracy': 0.97125, 'precision': 0.71536, 'recall': 0.38555, 'f1': 0.50105, 'auc': 0.89657}
# val: {'epoch': 22, 'time_epoch': 4.02619, 'loss': 0.07109711, 'lr': 0, 'params': 559955, 'time_iter': 0.03121, 'accuracy': 0.98225, 'precision': 0.58, 'recall': 0.35802, 'f1': 0.44275, 'auc': 0.82288}
# test: {'epoch': 22, 'time_epoch': 3.99891, 'loss': 0.12138725, 'lr': 0, 'params': 559955, 'time_iter': 0.031, 'accuracy': 0.96985, 'precision': 0.55769, 'recall': 0.22308, 'f1': 0.31868, 'auc': 0.7644}
# > Epoch 22: took 89.9s (avg 92.1s) | Best so far: epoch 11	train_loss: 0.1148 train_auc: 0.8334	val_loss: 0.0653 val_auc: 0.8464	test_loss: 0.1122 test_auc: 0.7696
# train: {'epoch': 23, 'time_epoch': 81.8864, 'eta': 6358.32721, 'eta_hours': 1.7662, 'loss': 0.09663622, 'lr': 9.14e-05, 'params': 559955, 'time_iter': 0.07958, 'accuracy': 0.97149, 'precision': 0.71304, 'recall': 0.39935, 'f1': 0.51197, 'auc': 0.90141}
# val: {'epoch': 23, 'time_epoch': 3.99765, 'loss': 0.0709786, 'lr': 0, 'params': 559955, 'time_iter': 0.03099, 'accuracy': 0.98152, 'precision': 0.55102, 'recall': 0.33333, 'f1': 0.41538, 'auc': 0.83816}
# test: {'epoch': 23, 'time_epoch': 3.99207, 'loss': 0.117155, 'lr': 0, 'params': 559955, 'time_iter': 0.03095, 'accuracy': 0.97034, 'precision': 0.57143, 'recall': 0.24615, 'f1': 0.34409, 'auc': 0.77853}
# > Epoch 23: took 90.0s (avg 92.0s) | Best so far: epoch 11	train_loss: 0.1148 train_auc: 0.8334	val_loss: 0.0653 val_auc: 0.8464	test_loss: 0.1122 test_auc: 0.7696
# train: {'epoch': 24, 'time_epoch': 81.63346, 'eta': 6268.57878, 'eta_hours': 1.74127, 'loss': 0.09436439, 'lr': 9.045e-05, 'params': 559955, 'time_iter': 0.07933, 'accuracy': 0.97231, 'precision': 0.73499, 'recall': 0.40747, 'f1': 0.52428, 'auc': 0.90701}
# val: {'epoch': 24, 'time_epoch': 3.95324, 'loss': 0.07824263, 'lr': 0, 'params': 559955, 'time_iter': 0.03065, 'accuracy': 0.97982, 'precision': 0.48148, 'recall': 0.32099, 'f1': 0.38519, 'auc': 0.82709}
# test: {'epoch': 24, 'time_epoch': 3.94866, 'loss': 0.12719564, 'lr': 0, 'params': 559955, 'time_iter': 0.03061, 'accuracy': 0.96839, 'precision': 0.5, 'recall': 0.19231, 'f1': 0.27778, 'auc': 0.7461}
# > Epoch 24: took 89.7s (avg 91.9s) | Best so far: epoch 11	train_loss: 0.1148 train_auc: 0.8334	val_loss: 0.0653 val_auc: 0.8464	test_loss: 0.1122 test_auc: 0.7696
# train: {'epoch': 25, 'time_epoch': 80.877, 'eta': 6177.30158, 'eta_hours': 1.71592, 'loss': 0.09421213, 'lr': 8.946e-05, 'params': 559955, 'time_iter': 0.0786, 'accuracy': 0.97274, 'precision': 0.74453, 'recall': 0.41396, 'f1': 0.53208, 'auc': 0.90802}
# val: {'epoch': 25, 'time_epoch': 4.0779, 'loss': 0.06982159, 'lr': 0, 'params': 559955, 'time_iter': 0.03161, 'accuracy': 0.98274, 'precision': 0.64706, 'recall': 0.2716, 'f1': 0.38261, 'auc': 0.8316}
# test: {'epoch': 25, 'time_epoch': 3.98906, 'loss': 0.12530078, 'lr': 0, 'params': 559955, 'time_iter': 0.03092, 'accuracy': 0.96961, 'precision': 0.55814, 'recall': 0.18462, 'f1': 0.27746, 'auc': 0.7825}
# > Epoch 25: took 89.1s (avg 91.8s) | Best so far: epoch 11	train_loss: 0.1148 train_auc: 0.8334	val_loss: 0.0653 val_auc: 0.8464	test_loss: 0.1122 test_auc: 0.7696
# train: {'epoch': 26, 'time_epoch': 81.7604, 'eta': 6089.18322, 'eta_hours': 1.69144, 'loss': 0.09174648, 'lr': 8.842e-05, 'params': 559955, 'time_iter': 0.07946, 'accuracy': 0.97289, 'precision': 0.75148, 'recall': 0.41234, 'f1': 0.53249, 'auc': 0.91716}
# val: {'epoch': 26, 'time_epoch': 3.96522, 'loss': 0.07328038, 'lr': 0, 'params': 559955, 'time_iter': 0.03074, 'accuracy': 0.98225, 'precision': 0.60526, 'recall': 0.28395, 'f1': 0.38655, 'auc': 0.83013}
# test: {'epoch': 26, 'time_epoch': 4.06421, 'loss': 0.12654978, 'lr': 0, 'params': 559955, 'time_iter': 0.03151, 'accuracy': 0.96985, 'precision': 0.56, 'recall': 0.21538, 'f1': 0.31111, 'auc': 0.75909}
# > Epoch 26: took 89.9s (avg 91.7s) | Best so far: epoch 11	train_loss: 0.1148 train_auc: 0.8334	val_loss: 0.0653 val_auc: 0.8464	test_loss: 0.1122 test_auc: 0.7696
# train: {'epoch': 27, 'time_epoch': 81.9254, 'eta': 6001.94327, 'eta_hours': 1.66721, 'loss': 0.09231057, 'lr': 8.734e-05, 'params': 559955, 'time_iter': 0.07962, 'accuracy': 0.97289, 'precision': 0.74927, 'recall': 0.41477, 'f1': 0.53396, 'auc': 0.91591}
# val: {'epoch': 27, 'time_epoch': 3.98857, 'loss': 0.07179805, 'lr': 0, 'params': 559955, 'time_iter': 0.03092, 'accuracy': 0.98104, 'precision': 0.52632, 'recall': 0.37037, 'f1': 0.43478, 'auc': 0.83694}
# test: {'epoch': 27, 'time_epoch': 3.95786, 'loss': 0.1253127, 'lr': 0, 'params': 559955, 'time_iter': 0.03068, 'accuracy': 0.96937, 'precision': 0.52381, 'recall': 0.33846, 'f1': 0.41121, 'auc': 0.7884}
# > Epoch 27: took 90.0s (avg 91.6s) | Best so far: epoch 11	train_loss: 0.1148 train_auc: 0.8334	val_loss: 0.0653 val_auc: 0.8464	test_loss: 0.1122 test_auc: 0.7696
# train: {'epoch': 28, 'time_epoch': 81.67, 'eta': 5914.44456, 'eta_hours': 1.6429, 'loss': 0.0913454, 'lr': 8.622e-05, 'params': 559955, 'time_iter': 0.07937, 'accuracy': 0.97274, 'precision': 0.73826, 'recall': 0.42127, 'f1': 0.53643, 'auc': 0.91787}
# val: {'epoch': 28, 'time_epoch': 3.99248, 'loss': 0.06846233, 'lr': 0, 'params': 559955, 'time_iter': 0.03095, 'accuracy': 0.98371, 'precision': 0.68421, 'recall': 0.32099, 'f1': 0.43697, 'auc': 0.83824}
# test: {'epoch': 28, 'time_epoch': 3.96686, 'loss': 0.12380509, 'lr': 0, 'params': 559955, 'time_iter': 0.03075, 'accuracy': 0.96888, 'precision': 0.51515, 'recall': 0.26154, 'f1': 0.34694, 'auc': 0.7735}
# > Epoch 28: took 89.8s (avg 91.6s) | Best so far: epoch 11	train_loss: 0.1148 train_auc: 0.8334	val_loss: 0.0653 val_auc: 0.8464	test_loss: 0.1122 test_auc: 0.7696
# train: {'epoch': 29, 'time_epoch': 81.77618, 'eta': 5827.5822, 'eta_hours': 1.61877, 'loss': 0.08788145, 'lr': 8.506e-05, 'params': 559955, 'time_iter': 0.07947, 'accuracy': 0.97265, 'precision': 0.73184, 'recall': 0.42532, 'f1': 0.53799, 'auc': 0.9262}
# val: {'epoch': 29, 'time_epoch': 3.99328, 'loss': 0.07013773, 'lr': 0, 'params': 559955, 'time_iter': 0.03096, 'accuracy': 0.98371, 'precision': 0.66667, 'recall': 0.34568, 'f1': 0.45528, 'auc': 0.84358}
# test: {'epoch': 29, 'time_epoch': 4.02028, 'loss': 0.12192812, 'lr': 0, 'params': 559955, 'time_iter': 0.03116, 'accuracy': 0.97009, 'precision': 0.5493, 'recall': 0.3, 'f1': 0.38806, 'auc': 0.78772}
# > Epoch 29: took 89.9s (avg 91.5s) | Best so far: epoch 11	train_loss: 0.1148 train_auc: 0.8334	val_loss: 0.0653 val_auc: 0.8464	test_loss: 0.1122 test_auc: 0.7696
# train: {'epoch': 30, 'time_epoch': 81.75193, 'eta': 5740.994, 'eta_hours': 1.59472, 'loss': 0.08917163, 'lr': 8.386e-05, 'params': 559955, 'time_iter': 0.07945, 'accuracy': 0.97365, 'precision': 0.7728, 'recall': 0.41964, 'f1': 0.54392, 'auc': 0.92563}
# val: {'epoch': 30, 'time_epoch': 3.97636, 'loss': 0.07002694, 'lr': 0, 'params': 559955, 'time_iter': 0.03082, 'accuracy': 0.98201, 'precision': 0.55385, 'recall': 0.44444, 'f1': 0.49315, 'auc': 0.85456}
# test: {'epoch': 30, 'time_epoch': 3.96684, 'loss': 0.12926152, 'lr': 0, 'params': 559955, 'time_iter': 0.03075, 'accuracy': 0.96864, 'precision': 0.50526, 'recall': 0.36923, 'f1': 0.42667, 'auc': 0.7676}
# > Epoch 30: took 89.8s (avg 91.5s) | Best so far: epoch 30	train_loss: 0.0892 train_auc: 0.9256	val_loss: 0.0700 val_auc: 0.8546	test_loss: 0.1293 test_auc: 0.7676
# train: {'epoch': 31, 'time_epoch': 81.8977, 'eta': 5655.01783, 'eta_hours': 1.57084, 'loss': 0.08633654, 'lr': 8.263e-05, 'params': 559955, 'time_iter': 0.07959, 'accuracy': 0.97377, 'precision': 0.7617, 'recall': 0.43588, 'f1': 0.55447, 'auc': 0.93074}
# val: {'epoch': 31, 'time_epoch': 4.01536, 'loss': 0.07203656, 'lr': 0, 'params': 559955, 'time_iter': 0.03113, 'accuracy': 0.98371, 'precision': 0.68421, 'recall': 0.32099, 'f1': 0.43697, 'auc': 0.82873}
# test: {'epoch': 31, 'time_epoch': 3.97952, 'loss': 0.13520387, 'lr': 0, 'params': 559955, 'time_iter': 0.03085, 'accuracy': 0.96912, 'precision': 0.52542, 'recall': 0.23846, 'f1': 0.32804, 'auc': 0.75793}
# > Epoch 31: took 90.0s (avg 91.4s) | Best so far: epoch 30	train_loss: 0.0892 train_auc: 0.9256	val_loss: 0.0700 val_auc: 0.8546	test_loss: 0.1293 test_auc: 0.7676
# train: {'epoch': 32, 'time_epoch': 81.53912, 'eta': 5568.56081, 'eta_hours': 1.54682, 'loss': 0.08644392, 'lr': 8.136e-05, 'params': 559955, 'time_iter': 0.07924, 'accuracy': 0.9741, 'precision': 0.77143, 'recall': 0.43831, 'f1': 0.55901, 'auc': 0.93039}
# val: {'epoch': 32, 'time_epoch': 4.03659, 'loss': 0.0755348, 'lr': 0, 'params': 559955, 'time_iter': 0.03129, 'accuracy': 0.98079, 'precision': 0.51389, 'recall': 0.45679, 'f1': 0.48366, 'auc': 0.8471}
# test: {'epoch': 32, 'time_epoch': 3.92918, 'loss': 0.12903548, 'lr': 0, 'params': 559955, 'time_iter': 0.03046, 'accuracy': 0.96742, 'precision': 0.48, 'recall': 0.36923, 'f1': 0.41739, 'auc': 0.77877}
# > Epoch 32: took 89.6s (avg 91.4s) | Best so far: epoch 30	train_loss: 0.0892 train_auc: 0.9256	val_loss: 0.0700 val_auc: 0.8546	test_loss: 0.1293 test_auc: 0.7676
# train: {'epoch': 33, 'time_epoch': 82.13636, 'eta': 5483.55242, 'eta_hours': 1.52321, 'loss': 0.08441704, 'lr': 8.005e-05, 'params': 559955, 'time_iter': 0.07982, 'accuracy': 0.97429, 'precision': 0.76584, 'recall': 0.4513, 'f1': 0.56793, 'auc': 0.93587}
# val: {'epoch': 33, 'time_epoch': 4.08543, 'loss': 0.08021782, 'lr': 0, 'params': 559955, 'time_iter': 0.03167, 'accuracy': 0.97982, 'precision': 0.48214, 'recall': 0.33333, 'f1': 0.39416, 'auc': 0.81869}
# test: {'epoch': 33, 'time_epoch': 3.97572, 'loss': 0.13825283, 'lr': 0, 'params': 559955, 'time_iter': 0.03082, 'accuracy': 0.96499, 'precision': 0.41463, 'recall': 0.26154, 'f1': 0.32075, 'auc': 0.76482}
# > Epoch 33: took 90.3s (avg 91.3s) | Best so far: epoch 30	train_loss: 0.0892 train_auc: 0.9256	val_loss: 0.0700 val_auc: 0.8546	test_loss: 0.1293 test_auc: 0.7676
# train: {'epoch': 34, 'time_epoch': 81.18871, 'eta': 5396.94823, 'eta_hours': 1.49915, 'loss': 0.08334155, 'lr': 7.872e-05, 'params': 559955, 'time_iter': 0.0789, 'accuracy': 0.97447, 'precision': 0.77147, 'recall': 0.45211, 'f1': 0.57011, 'auc': 0.93692}
# val: {'epoch': 34, 'time_epoch': 4.0078, 'loss': 0.07653436, 'lr': 0, 'params': 559955, 'time_iter': 0.03107, 'accuracy': 0.98249, 'precision': 0.61538, 'recall': 0.2963, 'f1': 0.4, 'auc': 0.83269}
# test: {'epoch': 34, 'time_epoch': 4.03922, 'loss': 0.13913527, 'lr': 0, 'params': 559955, 'time_iter': 0.03131, 'accuracy': 0.96888, 'precision': 0.51852, 'recall': 0.21538, 'f1': 0.30435, 'auc': 0.76676}
# > Epoch 34: took 89.4s (avg 91.3s) | Best so far: epoch 30	train_loss: 0.0892 train_auc: 0.9256	val_loss: 0.0700 val_auc: 0.8546	test_loss: 0.1293 test_auc: 0.7676
# train: {'epoch': 35, 'time_epoch': 81.27631, 'eta': 5310.80063, 'eta_hours': 1.47522, 'loss': 0.082729, 'lr': 7.735e-05, 'params': 559955, 'time_iter': 0.07899, 'accuracy': 0.97486, 'precision': 0.77108, 'recall': 0.46753, 'f1': 0.58211, 'auc': 0.94091}
# val: {'epoch': 35, 'time_epoch': 3.97507, 'loss': 0.07279041, 'lr': 0, 'params': 559955, 'time_iter': 0.03081, 'accuracy': 0.98152, 'precision': 0.55102, 'recall': 0.33333, 'f1': 0.41538, 'auc': 0.83746}
# test: {'epoch': 35, 'time_epoch': 3.944, 'loss': 0.13380449, 'lr': 0, 'params': 559955, 'time_iter': 0.03057, 'accuracy': 0.96864, 'precision': 0.50746, 'recall': 0.26154, 'f1': 0.34518, 'auc': 0.77077}
# > Epoch 35: took 89.3s (avg 91.2s) | Best so far: epoch 30	train_loss: 0.0892 train_auc: 0.9256	val_loss: 0.0700 val_auc: 0.8546	test_loss: 0.1293 test_auc: 0.7676
# train: {'epoch': 36, 'time_epoch': 81.84556, 'eta': 5225.88562, 'eta_hours': 1.45163, 'loss': 0.08100449, 'lr': 7.595e-05, 'params': 559955, 'time_iter': 0.07954, 'accuracy': 0.97517, 'precision': 0.77778, 'recall': 0.47159, 'f1': 0.58717, 'auc': 0.9433}
# val: {'epoch': 36, 'time_epoch': 4.00176, 'loss': 0.07395602, 'lr': 0, 'params': 559955, 'time_iter': 0.03102, 'accuracy': 0.98031, 'precision': 0.5, 'recall': 0.34568, 'f1': 0.40876, 'auc': 0.84538}
# test: {'epoch': 36, 'time_epoch': 3.97697, 'loss': 0.13339237, 'lr': 0, 'params': 559955, 'time_iter': 0.03083, 'accuracy': 0.96766, 'precision': 0.47887, 'recall': 0.26154, 'f1': 0.33831, 'auc': 0.77147}
# > Epoch 36: took 90.0s (avg 91.2s) | Best so far: epoch 30	train_loss: 0.0892 train_auc: 0.9256	val_loss: 0.0700 val_auc: 0.8546	test_loss: 0.1293 test_auc: 0.7676
# train: {'epoch': 37, 'time_epoch': 81.54012, 'eta': 5140.63379, 'eta_hours': 1.42795, 'loss': 0.08022798, 'lr': 7.452e-05, 'params': 559955, 'time_iter': 0.07924, 'accuracy': 0.97526, 'precision': 0.77214, 'recall': 0.48133, 'f1': 0.593, 'auc': 0.94643}
# val: {'epoch': 37, 'time_epoch': 3.95244, 'loss': 0.07442052, 'lr': 0, 'params': 559955, 'time_iter': 0.03064, 'accuracy': 0.98201, 'precision': 0.5814, 'recall': 0.30864, 'f1': 0.40323, 'auc': 0.83989}
# test: {'epoch': 37, 'time_epoch': 3.96031, 'loss': 0.13949279, 'lr': 0, 'params': 559955, 'time_iter': 0.0307, 'accuracy': 0.96839, 'precision': 0.5, 'recall': 0.22308, 'f1': 0.30851, 'auc': 0.76436}
# > Epoch 37: took 89.6s (avg 91.2s) | Best so far: epoch 30	train_loss: 0.0892 train_auc: 0.9256	val_loss: 0.0700 val_auc: 0.8546	test_loss: 0.1293 test_auc: 0.7676
# train: {'epoch': 38, 'time_epoch': 81.83213, 'eta': 5056.02905, 'eta_hours': 1.40445, 'loss': 0.08002487, 'lr': 7.307e-05, 'params': 559955, 'time_iter': 0.07953, 'accuracy': 0.97559, 'precision': 0.78562, 'recall': 0.4789, 'f1': 0.59506, 'auc': 0.9444}
# val: {'epoch': 38, 'time_epoch': 4.00461, 'loss': 0.07700289, 'lr': 0, 'params': 559955, 'time_iter': 0.03104, 'accuracy': 0.98152, 'precision': 0.55556, 'recall': 0.30864, 'f1': 0.39683, 'auc': 0.83251}
# test: {'epoch': 38, 'time_epoch': 3.96306, 'loss': 0.14171498, 'lr': 0, 'params': 559955, 'time_iter': 0.03072, 'accuracy': 0.96742, 'precision': 0.46429, 'recall': 0.2, 'f1': 0.27957, 'auc': 0.76086}
# > Epoch 38: took 89.9s (avg 91.1s) | Best so far: epoch 30	train_loss: 0.0892 train_auc: 0.9256	val_loss: 0.0700 val_auc: 0.8546	test_loss: 0.1293 test_auc: 0.7676
# train: {'epoch': 39, 'time_epoch': 81.52572, 'eta': 4971.10332, 'eta_hours': 1.38086, 'loss': 0.07936056, 'lr': 7.159e-05, 'params': 559955, 'time_iter': 0.07923, 'accuracy': 0.97492, 'precision': 0.76954, 'recall': 0.47159, 'f1': 0.5848, 'auc': 0.94846}
# val: {'epoch': 39, 'time_epoch': 4.03703, 'loss': 0.07557899, 'lr': 0, 'params': 559955, 'time_iter': 0.03129, 'accuracy': 0.98177, 'precision': 0.625, 'recall': 0.18519, 'f1': 0.28571, 'auc': 0.83196}
# test: {'epoch': 39, 'time_epoch': 3.96477, 'loss': 0.14248823, 'lr': 0, 'params': 559955, 'time_iter': 0.03073, 'accuracy': 0.96912, 'precision': 0.53061, 'recall': 0.2, 'f1': 0.2905, 'auc': 0.77074}
# > Epoch 39: took 89.7s (avg 91.1s) | Best so far: epoch 30	train_loss: 0.0892 train_auc: 0.9256	val_loss: 0.0700 val_auc: 0.8546	test_loss: 0.1293 test_auc: 0.7676
# train: {'epoch': 40, 'time_epoch': 81.48393, 'eta': 4886.28332, 'eta_hours': 1.3573, 'loss': 0.07735856, 'lr': 7.008e-05, 'params': 559955, 'time_iter': 0.07919, 'accuracy': 0.97523, 'precision': 0.77912, 'recall': 0.4724, 'f1': 0.58818, 'auc': 0.95153}
# val: {'epoch': 40, 'time_epoch': 4.07271, 'loss': 0.07576903, 'lr': 0, 'params': 559955, 'time_iter': 0.03157, 'accuracy': 0.98201, 'precision': 0.58974, 'recall': 0.28395, 'f1': 0.38333, 'auc': 0.83671}
# test: {'epoch': 40, 'time_epoch': 3.98847, 'loss': 0.1431086, 'lr': 0, 'params': 559955, 'time_iter': 0.03092, 'accuracy': 0.96742, 'precision': 0.46667, 'recall': 0.21538, 'f1': 0.29474, 'auc': 0.7748}
# > Epoch 40: took 89.7s (avg 91.1s) | Best so far: epoch 30	train_loss: 0.0892 train_auc: 0.9256	val_loss: 0.0700 val_auc: 0.8546	test_loss: 0.1293 test_auc: 0.7676
# train: {'epoch': 41, 'time_epoch': 81.46248, 'eta': 4801.59254, 'eta_hours': 1.33378, 'loss': 0.0764775, 'lr': 6.856e-05, 'params': 559955, 'time_iter': 0.07917, 'accuracy': 0.97572, 'precision': 0.77721, 'recall': 0.49269, 'f1': 0.60308, 'auc': 0.95117}
# val: {'epoch': 41, 'time_epoch': 4.00653, 'loss': 0.07491492, 'lr': 0, 'params': 559955, 'time_iter': 0.03106, 'accuracy': 0.98177, 'precision': 0.5625, 'recall': 0.33333, 'f1': 0.4186, 'auc': 0.83653}
# test: {'epoch': 41, 'time_epoch': 4.04268, 'loss': 0.1463598, 'lr': 0, 'params': 559955, 'time_iter': 0.03134, 'accuracy': 0.96937, 'precision': 0.5303, 'recall': 0.26923, 'f1': 0.35714, 'auc': 0.76557}
# > Epoch 41: took 89.6s (avg 91.0s) | Best so far: epoch 30	train_loss: 0.0892 train_auc: 0.9256	val_loss: 0.0700 val_auc: 0.8546	test_loss: 0.1293 test_auc: 0.7676
