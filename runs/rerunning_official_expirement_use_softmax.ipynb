# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/torch_scatter-2.1.2-cp310-cp310-linux_x86_64.whl
# /kaggle/input/torch_geometric-2.5.3-py3-none-any.whl
# /kaggle/input/torch_cluster-1.6.3-cp310-cp310-linux_x86_64.whl
# /kaggle/input/torch_spline_conv-1.2.2-cp310-cp310-linux_x86_64.whl
# /kaggle/input/torch_sparse-0.6.18-cp310-cp310-linux_x86_64.whl

# %%
# !git clone https://github.com/rampasek/GraphGPS.git
# Out:
# Cloning into 'GraphGPS'...
#
# remote: Enumerating objects: 526, done.
#
# remote: Counting objects: 100% (316/316), done.
#
# remote: Compressing objects: 100% (91/91), done.
#
# remote: Total 526 (delta 254), reused 225 (delta 225), pack-reused 210 (from 1)
#
# Receiving objects: 100% (526/526), 12.93 MiB | 32.37 MiB/s, done.
#
# Resolving deltas: 100% (336/336), done.

# %%
# %cd /kaggle/working/GraphGPS
# !ls
# Out:
# /kaggle/working/GraphGPS
#
# GraphGPS.png  README.md  final-results.zip  main.py  setup.py  unittests
#
# LICENSE       configs	 graphgps	    run      tests

# %% [markdown]
# ##  installation for slurm if needed using conda

# %%
# # for slurm if needed using conda 
# conda create -n graphgps python=3.10
# conda activate graphgps

# conda install pytorch=1.13 torchvision torchaudio pytorch-cuda=11.7 -c pytorch -c nvidia
# conda install pyg=2.2 -c pyg -c conda-forge
# pip install pyg-lib -f https://data.pyg.org/whl/torch-1.13.0+cu117.html

# # RDKit is required for OGB-LSC PCQM4Mv2 and datasets derived from it.  
# conda install openbabel fsspec rdkit -c conda-forge

# pip install pytorch-lightning yacs torchmetrics
# pip install performer-pytorch
# pip install tensorboardX
# pip install ogb
# pip install wandb

# conda clean --all

# %% [markdown]
# # installation for kaggle

# %%
# Check existing environment
import sys
print("Python version:", sys.version)
import torch
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)

# !pip uninstall -y torch torchvision torchaudio
# !pip install torch==2.0.1+cu118 torchvision==0.15.2+cu118 torchaudio==2.0.2+cu118 --index-url https://download.pytorch.org/whl/cu118

# !pip install torch_geometric

# Optional dependencies:
# !pip install pyg_lib torch_scatter torch_sparse torch_cluster torch_spline_conv -f https://data.pyg.org/whl/torch-2.4.0+cu124.html
# Install other required packages
# !pip install pytorch-lightning yacs torchmetrics
# !pip install performer-pytorch
# !pip install tensorboardX
# !pip install ogb
# !pip install wandb

# Attempt to install RDKit (may have limitations)
# !pip install rdkit-pypi
# !pip install openbabel fsspec
# !pip install  fsspec

# Clean up pip cache (optional)
# !pip cache purge
# Out:
# Python version: 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:45:18) [GCC 12.3.0]
# PyTorch version: 2.4.0
# CUDA available: True
# CUDA version: 12.3
# Found existing installation: torch 2.4.0
# Uninstalling torch-2.4.0:
#   Successfully uninstalled torch-2.4.0
# Found existing installation: torchvision 0.19.0
# Uninstalling torchvision-0.19.0:
#   Successfully uninstalled torchvision-0.19.0
# Found existing installation: torchaudio 2.4.0
# Uninstalling torchaudio-2.4.0:
#   Successfully uninstalled torchaudio-2.4.0
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Collecting torch==2.0.1+cu118
#   Downloading https://download.pytorch.org/whl/cu118/torch-2.0.1%2Bcu118-cp310-cp310-linux_x86_64.whl (2267.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 GB 384.8 kB/s eta 0:00:0000:0100:01
# Collecting torchvision==0.15.2+cu118
#   Downloading https://download.pytorch.org/whl/cu118/torchvision-0.15.2%2Bcu118-cp310-cp310-linux_x86_64.whl (6.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 70.9 MB/s eta 0:00:00:00:0100:01
# Collecting torchaudio==2.0.2+cu118
#   Downloading https://download.pytorch.org/whl/cu118/torchaudio-2.0.2%2Bcu118-cp310-cp310-linux_x86_64.whl (4.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 70.4 MB/s eta 0:00:00:00:01
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch==2.0.1+cu118) (3.15.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch==2.0.1+cu118) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch==2.0.1+cu118) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch==2.0.1+cu118) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch==2.0.1+cu118) (3.1.4)
# Collecting triton==2.0.0 (from torch==2.0.1+cu118)
#   Downloading https://download.pytorch.org/whl/triton-2.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 25.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision==0.15.2+cu118) (1.26.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torchvision==0.15.2+cu118) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision==0.15.2+cu118) (10.3.0)
# Collecting cmake (from triton==2.0.0->torch==2.0.1+cu118)
#   Downloading https://download.pytorch.org/whl/cmake-3.25.0-py2.py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 65.4 MB/s eta 0:00:0000:0100:01
# Collecting lit (from triton==2.0.0->torch==2.0.1+cu118)
#   Downloading https://download.pytorch.org/whl/lit-15.0.7.tar.gz (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.3/132.3 kB 5.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch==2.0.1+cu118) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.15.2+cu118) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.15.2+cu118) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.15.2+cu118) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.15.2+cu118) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch==2.0.1+cu118) (1.3.0)
# Building wheels for collected packages: lit
#   Building wheel for lit (setup.py) ... done
#   Created wheel for lit: filename=lit-15.0.7-py3-none-any.whl size=89987 sha256=e06335e057d0fd746421a6ed41d7074a34f235d167923cea317330317d35076b
#   Stored in directory: /root/.cache/pip/wheels/27/2c/b6/3ed2983b1b44fe0dea1bb35234b09f2c22fb8ebb308679c922
# Successfully built lit
# Installing collected packages: lit, cmake, triton, torch, torchvision, torchaudio
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytorch-lightning 2.4.0 requires torch>=2.1.0, but you have torch 2.0.1+cu118 which is incompatible.
# Successfully installed cmake-3.25.0 lit-15.0.7 torch-2.0.1+cu118 torchaudio-2.0.2+cu118 torchvision-0.15.2+cu118 triton-2.0.0
# Collecting torch_geometric
#   Downloading torch_geometric-2.6.1-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 1.4 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (3.9.5)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (2024.6.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (3.1.4)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (1.26.4)
# Requirement already satisfied: psutil>=5.8.0 in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (5.9.3)
# Requirement already satisfied: pyparsing in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (3.1.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (2.32.3)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (4.66.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch_geometric) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (2024.8.30)
# Downloading torch_geometric-2.6.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 17.1 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: torch_geometric
# Successfully installed torch_geometric-2.6.1
# Looking in links: https://data.pyg.org/whl/torch-2.4.0+cu124.html
# Collecting pyg_lib
#   Downloading https://data.pyg.org/whl/torch-2.4.0%2Bcu124/pyg_lib-0.4.0%2Bpt24cu124-cp310-cp310-linux_x86_64.whl (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 24.3 MB/s eta 0:00:00a 0:00:01
# Collecting torch_scatter
#   Downloading https://data.pyg.org/whl/torch-2.4.0%2Bcu124/torch_scatter-2.1.2%2Bpt24cu124-cp310-cp310-linux_x86_64.whl (10.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 74.3 MB/s eta 0:00:0000:0100:01
# Collecting torch_sparse
#   Downloading https://data.pyg.org/whl/torch-2.4.0%2Bcu124/torch_sparse-0.6.18%2Bpt24cu124-cp310-cp310-linux_x86_64.whl (5.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 62.2 MB/s eta 0:00:00:00:0100:01
# Collecting torch_cluster
#   Downloading https://data.pyg.org/whl/torch-2.4.0%2Bcu124/torch_cluster-1.6.3%2Bpt24cu124-cp310-cp310-linux_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 71.9 MB/s eta 0:00:00:00:01
# Collecting torch_spline_conv
#   Downloading https://data.pyg.org/whl/torch-2.4.0%2Bcu124/torch_spline_conv-1.2.2%2Bpt24cu124-cp310-cp310-linux_x86_64.whl (992 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 992.4/992.4 kB 1.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from torch_sparse) (1.14.1)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in /opt/conda/lib/python3.10/site-packages (from scipy->torch_sparse) (1.26.4)
# Installing collected packages: torch_spline_conv, torch_scatter, pyg_lib, torch_sparse, torch_cluster
# Successfully installed pyg_lib-0.4.0+pt24cu124 torch_cluster-1.6.3+pt24cu124 torch_scatter-2.1.2+pt24cu124 torch_sparse-0.6.18+pt24cu124 torch_spline_conv-1.2.2+pt24cu124
# Requirement already satisfied: pytorch-lightning in /opt/conda/lib/python3.10/site-packages (2.4.0)
# Collecting yacs
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: torchmetrics in /opt/conda/lib/python3.10/site-packages (1.4.2)
# Collecting torch>=2.1.0 (from pytorch-lightning)
#   Downloading torch-2.4.1-cp310-cp310-manylinux1_x86_64.whl.metadata (26 kB)
# Requirement already satisfied: tqdm>=4.57.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (4.66.4)
# Requirement already satisfied: PyYAML>=5.4 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (6.0.2)
# Requirement already satisfied: fsspec>=2022.5.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (2024.6.1)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (21.3)
# Requirement already satisfied: typing-extensions>=4.4.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (4.12.2)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (0.11.7)
# Requirement already satisfied: numpy>1.20.0 in /opt/conda/lib/python3.10/site-packages (from torchmetrics) (1.26.4)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (3.9.5)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from lightning-utilities>=0.10.0->pytorch-lightning) (70.0.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->pytorch-lightning) (3.1.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=2.1.0->pytorch-lightning) (3.15.1)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=2.1.0->pytorch-lightning) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=2.1.0->pytorch-lightning) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=2.1.0->pytorch-lightning) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.0.0 (from torch>=2.1.0->pytorch-lightning)
#   Downloading triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_nvjitlink_cu12-12.6.68-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=2.1.0->pytorch-lightning) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=2.1.0->pytorch-lightning) (1.3.0)
# Requirement already satisfied: idna>=2.0 in /opt/conda/lib/python3.10/site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (3.7)
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Downloading torch-2.4.1-cp310-cp310-manylinux1_x86_64.whl (797.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.1/797.1 MB 1.9 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.1 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 58.8 MB/s eta 0:00:0000:01:00:01
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 57.1 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 31.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 1.8 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 26.0 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 12.3 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 7.5 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 8.8 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 4.4 MB/s eta 0:00:00
# Downloading triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (209.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 7.3 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.6.68-py3-none-manylinux2014_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 62.3 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: yacs, triton, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch
#   Attempting uninstall: triton
#     Found existing installation: triton 2.0.0
#     Uninstalling triton-2.0.0:
#       Successfully uninstalled triton-2.0.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.1+cu118
#     Uninstalling torch-2.0.1+cu118:
#       Successfully uninstalled torch-2.0.1+cu118
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.0.2+cu118 requires torch==2.0.1, but you have torch 2.4.1 which is incompatible.
# torchvision 0.15.2+cu118 requires torch==2.0.1, but you have torch 2.4.1 which is incompatible.
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.6.68 nvidia-nvtx-cu12-12.1.105 torch-2.4.1 triton-3.0.0 yacs-0.1.8
# Collecting performer-pytorch
#   Downloading performer_pytorch-1.1.4-py3-none-any.whl.metadata (763 bytes)
# Collecting einops>=0.3 (from performer-pytorch)
#   Downloading einops-0.8.0-py3-none-any.whl.metadata (12 kB)
# Collecting local-attention>=1.1.1 (from performer-pytorch)
#   Downloading local_attention-1.9.15-py3-none-any.whl.metadata (683 bytes)
# Requirement already satisfied: torch>=1.6 in /opt/conda/lib/python3.10/site-packages (from performer-pytorch) (2.4.1)
# Collecting axial-positional-embedding>=0.1.0 (from performer-pytorch)
#   Downloading axial_positional_embedding-0.2.1.tar.gz (2.6 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.6->performer-pytorch) (12.6.68)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.6->performer-pytorch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.6->performer-pytorch) (1.3.0)
# Downloading performer_pytorch-1.1.4-py3-none-any.whl (13 kB)
# Downloading einops-0.8.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 781.9 kB/s eta 0:00:000:00:01
# Downloading local_attention-1.9.15-py3-none-any.whl (9.0 kB)
# Building wheels for collected packages: axial-positional-embedding
#   Building wheel for axial-positional-embedding (setup.py) ... done
#   Created wheel for axial-positional-embedding: filename=axial_positional_embedding-0.2.1-py3-none-any.whl size=2889 sha256=718f70432a1937c26fa7144a6707428d3faaf113e138a958c7fe4a3cfc32ab19
#   Stored in directory: /root/.cache/pip/wheels/b1/cb/39/7ce7ff2d2fd37cfe1fe7b3a3c43cf410632b2ad3b3f3986d73
# Successfully built axial-positional-embedding
# Installing collected packages: einops, local-attention, axial-positional-embedding, performer-pytorch
# Successfully installed axial-positional-embedding-0.2.1 einops-0.8.0 local-attention-1.9.15 performer-pytorch-1.1.4
# Requirement already satisfied: tensorboardX in /opt/conda/lib/python3.10/site-packages (2.6.2.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from tensorboardX) (1.26.4)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorboardX) (21.3)
# Requirement already satisfied: protobuf>=3.20 in /opt/conda/lib/python3.10/site-packages (from tensorboardX) (3.20.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->tensorboardX) (3.1.2)
# Collecting ogb
#   Downloading ogb-1.3.6-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: torch>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (2.4.1)
# Requirement already satisfied: numpy>=1.16.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (1.26.4)
# Requirement already satisfied: tqdm>=4.29.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (4.66.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (1.2.2)
# Requirement already satisfied: pandas>=0.24.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (2.2.2)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (1.16.0)
# Requirement already satisfied: urllib3>=1.24.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (1.26.18)
# Collecting outdated>=0.2.0 (from ogb)
#   Downloading outdated-0.2.2-py2.py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: setuptools>=44 in /opt/conda/lib/python3.10/site-packages (from outdated>=0.2.0->ogb) (70.0.0)
# Collecting littleutils (from outdated>=0.2.0->ogb)
#   Downloading littleutils-0.2.4-py3-none-any.whl.metadata (679 bytes)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from outdated>=0.2.0->ogb) (2.32.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24.0->ogb) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24.0->ogb) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24.0->ogb) (2024.1)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.20.0->ogb) (1.14.1)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.20.0->ogb) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.20.0->ogb) (3.5.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.6.0->ogb) (12.6.68)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.6.0->ogb) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->outdated>=0.2.0->ogb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->outdated>=0.2.0->ogb) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->outdated>=0.2.0->ogb) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.6.0->ogb) (1.3.0)
# Downloading ogb-1.3.6-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 2.5 MB/s eta 0:00:00
# Downloading outdated-0.2.2-py2.py3-none-any.whl (7.5 kB)
# Downloading littleutils-0.2.4-py3-none-any.whl (8.1 kB)
# Installing collected packages: littleutils, outdated, ogb
# Successfully installed littleutils-0.2.4 ogb-1.3.6 outdated-0.2.2
# Requirement already satisfied: wandb in /opt/conda/lib/python3.10/site-packages (0.18.1)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /opt/conda/lib/python3.10/site-packages (from wandb) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.1.43)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.10/site-packages (from wandb) (3.11.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.20.3)
# Requirement already satisfied: psutil>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from wandb) (6.0.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.32.3)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.14.0)
# Requirement already satisfied: setproctitle in /opt/conda/lib/python3.10/site-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from wandb) (70.0.0)
# Requirement already satisfied: six>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2024.8.30)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.1)
# Collecting rdkit-pypi
#   Downloading rdkit_pypi-2022.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from rdkit-pypi) (1.26.4)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from rdkit-pypi) (10.3.0)
# Downloading rdkit_pypi-2022.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 52.5 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: rdkit-pypi
# Successfully installed rdkit-pypi-2022.9.5
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (2024.6.1)
# Files removed: 184

# %%
import sys
print("Python version:", sys.version)
import torch
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)
# Out:
# Python version: 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:45:18) [GCC 12.3.0]
# PyTorch version: 2.4.0
# CUDA available: True
# CUDA version: 12.3

# %%
import torch_geometric
print("PyG version:", torch_geometric.__version__)

import pytorch_lightning
print("PyTorch Lightning version:", pytorch_lightning.__version__)

import rdkit
print("RDKit version:", rdkit.__version__)
# Out:
# /opt/conda/lib/python3.10/site-packages/torch_geometric/typing.py:68: UserWarning: An issue occurred while importing 'pyg-lib'. Disabling its usage. Stacktrace: /opt/conda/lib/python3.10/site-packages/libpyg.so: undefined symbol: _ZNK5torch8autograd4Node4nameEv
#   warnings.warn(f"An issue occurred while importing 'pyg-lib'. "
# /opt/conda/lib/python3.10/site-packages/torch_geometric/typing.py:86: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: /opt/conda/lib/python3.10/site-packages/torch_scatter/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
#   warnings.warn(f"An issue occurred while importing 'torch-scatter'. "
# /opt/conda/lib/python3.10/site-packages/torch_geometric/typing.py:97: UserWarning: An issue occurred while importing 'torch-cluster'. Disabling its usage. Stacktrace: /opt/conda/lib/python3.10/site-packages/torch_cluster/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
#   warnings.warn(f"An issue occurred while importing 'torch-cluster'. "
# /opt/conda/lib/python3.10/site-packages/torch_geometric/typing.py:113: UserWarning: An issue occurred while importing 'torch-spline-conv'. Disabling its usage. Stacktrace: /opt/conda/lib/python3.10/site-packages/torch_spline_conv/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torch_geometric/typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: /opt/conda/lib/python3.10/site-packages/torch_sparse/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
#   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "
# PyG version: 2.6.1
# PyTorch Lightning version: 2.4.0
# RDKit version: 2022.09.5

# %%
print("Torch version:", torch.__version__)
# Out:
# Torch version: 2.4.0

# %% [markdown]
# # Running their model- GPSConv

# %%
# %cd /kaggle/working/GraphGPS
# !WANDB_MODE=disabled python main.py --cfg configs/GPS/ogbg-molhiv-GPS.yaml

# %% [markdown]
# # Our Model - WeightedGraphGPS

# %%
# %cd /kaggle/working
# !rm -rf /kaggle/working/WeightedGraphGPS

# %%
#clone for our project
# %cd /kaggle/working
# !git clone --branch use_softmax https://github.com/omertalmi5/WeightedGraphGPS.git
# Out:
# /kaggle/working
# Cloning into 'WeightedGraphGPS'...
# remote: Enumerating objects: 765, done.
# remote: Counting objects: 100% (520/520), done.
# remote: Compressing objects: 100% (172/172), done.
# remote: Total 765 (delta 432), reused 348 (delta 348), pack-reused 245 (from 1)
# Receiving objects: 100% (765/765), 13.04 MiB | 29.48 MiB/s, done.
# Resolving deltas: 100% (521/521), done.

# %%
# !pip install wandb
# Out:
# Requirement already satisfied: wandb in /opt/conda/lib/python3.10/site-packages (0.18.1)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /opt/conda/lib/python3.10/site-packages (from wandb) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.1.43)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.10/site-packages (from wandb) (3.11.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.20.3)
# Requirement already satisfied: psutil>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from wandb) (6.0.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.32.3)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.14.0)
# Requirement already satisfied: setproctitle in /opt/conda/lib/python3.10/site-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from wandb) (70.0.0)
# Requirement already satisfied: six>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2024.8.30)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.1)

# %%
# !wandb login 5f1c292fde40243d281618fe88d712346cfe90d7
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
import os
# Set the environment variable
os.environ['USERNAME'] = "omertalmi-tel-aviv-university"

# %%
# %cd /kaggle/working/WeightedGraphGPS
os.environ['BRANCH_NAME']= os.popen('git rev-parse --abbrev-ref HEAD').read().strip()
# !WANDB_MODE=online python main.py --cfg configs/GPS/ogbg-molhiv-GPS.yaml wandb.use True wandb.entity $USERNAME wandb.name $BRANCH_NAME
# Out:
# /kaggle/working/WeightedGraphGPS
# [*] Run ID 0: seed=0, split_index=0
#     Starting now: 2024-09-30 06:37:07.364172
# Downloading http://snap.stanford.edu/ogb/data/graphproppred/csv_mol_download/hiv.zip
# Downloaded 0.00 GB: 100%|█████████████████████████| 3/3 [00:00<00:00,  4.05it/s]
# Extracting ./datasets/hiv.zip
# Processing...
# Loading necessary files...
# This might take a while.
# Processing graphs...
# 100%|██████████████████████████████████| 41127/41127 [00:00<00:00, 61004.03it/s]
# Converting graphs into PyG objects...
# 100%|██████████████████████████████████| 41127/41127 [00:02<00:00, 17993.87it/s]
# Saving...
# Done!
# /opt/conda/lib/python3.10/site-packages/ogb/graphproppred/dataset_pyg.py:68: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.data, self.slices = torch.load(self.processed_paths[0])
# [*] Loaded dataset 'ogbg-molhiv' from 'OGB':
# /opt/conda/lib/python3.10/site-packages/torch_geometric/data/in_memory_dataset.py:300: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
#   Data(edge_index=[2, 2259376], edge_attr=[2259376, 3], x=[1049163, 9], y=[41127, 1], num_nodes=1049163)
#   undirected: True
#   num graphs: 41127
# /opt/conda/lib/python3.10/site-packages/torch_geometric/data/in_memory_dataset.py:300: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. The data of the dataset is already cached, so any modifications to `data` will not be reflected when accessing its elements. Clearing the cache now by removing all elements in `dataset._data_list`. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
#   avg num_nodes/graph: 25
#   num node features: 9
#   num edge features: 3
#   num tasks: 1
#   num classes: 2
# Precomputing Positional Encoding statistics: ['LapPE'] for all graphs...
#   ...estimated to be undirected: True
# 100%|████████████████████████████████████| 41127/41127 [00:55<00:00, 739.29it/s]
# Done! Took 00:00:57.29
# GraphGymModule(
#   (model): GPSModel(
#     (encoder): FeatureEncoder(
#       (node_encoder): Concat2NodeEncoder(
#         (encoder1): AtomEncoder(
#           (atom_embedding_list): ModuleList(
#             (0): Embedding(119, 56)
#             (1): Embedding(5, 56)
#             (2-3): 2 x Embedding(12, 56)
#             (4): Embedding(10, 56)
#             (5-6): 2 x Embedding(6, 56)
#             (7-8): 2 x Embedding(2, 56)
#           )
#         )
#         (encoder2): LapPENodeEncoder(
#           (linear_A): Linear(in_features=2, out_features=16, bias=True)
#           (pe_encoder): Sequential(
#             (0): ReLU()
#             (1): Linear(in_features=16, out_features=8, bias=True)
#             (2): ReLU()
#           )
#         )
#       )
#       (edge_encoder): BondEncoder(
#         (bond_embedding_list): ModuleList(
#           (0): Embedding(5, 64)
#           (1): Embedding(6, 64)
#           (2): Embedding(2, 64)
#         )
#       )
#     )
#     (layers): Sequential(
#       (0): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (gating_conv1): GCNConv(64, 32)
#         (gating_relu): ReLU()
#         (gating_conv2): GCNConv(32, 2)
#         (gating_softmax): Softmax(dim=1)
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (1): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (gating_conv1): GCNConv(64, 32)
#         (gating_relu): ReLU()
#         (gating_conv2): GCNConv(32, 2)
#         (gating_softmax): Softmax(dim=1)
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (2): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (gating_conv1): GCNConv(64, 32)
#         (gating_relu): ReLU()
#         (gating_conv2): GCNConv(32, 2)
#         (gating_softmax): Softmax(dim=1)
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (3): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (gating_conv1): GCNConv(64, 32)
#         (gating_relu): ReLU()
#         (gating_conv2): GCNConv(32, 2)
#         (gating_softmax): Softmax(dim=1)
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (4): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (gating_conv1): GCNConv(64, 32)
#         (gating_relu): ReLU()
#         (gating_conv2): GCNConv(32, 2)
#         (gating_softmax): Softmax(dim=1)
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (5): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (gating_conv1): GCNConv(64, 32)
#         (gating_relu): ReLU()
#         (gating_conv2): GCNConv(32, 2)
#         (gating_softmax): Softmax(dim=1)
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (6): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (gating_conv1): GCNConv(64, 32)
#         (gating_relu): ReLU()
#         (gating_conv2): GCNConv(32, 2)
#         (gating_softmax): Softmax(dim=1)
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (7): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (gating_conv1): GCNConv(64, 32)
#         (gating_relu): ReLU()
#         (gating_conv2): GCNConv(32, 2)
#         (gating_softmax): Softmax(dim=1)
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (8): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (gating_conv1): GCNConv(64, 32)
#         (gating_relu): ReLU()
#         (gating_conv2): GCNConv(32, 2)
#         (gating_softmax): Softmax(dim=1)
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (9): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (gating_conv1): GCNConv(64, 32)
#         (gating_relu): ReLU()
#         (gating_conv2): GCNConv(32, 2)
#         (gating_softmax): Softmax(dim=1)
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#     )
#     (post_mp): SANGraphHead(
#       (FC_layers): ModuleList(
#         (0): Linear(in_features=64, out_features=32, bias=True)
#         (1): Linear(in_features=32, out_features=16, bias=True)
#         (2): Linear(in_features=16, out_features=1, bias=True)
#       )
#       (activation): ReLU()
#     )
#   )
# )
# accelerator: cuda
# benchmark: False
# bn:
#   eps: 1e-05
#   mom: 0.1
# cfg_dest: config.yaml
# custom_metrics: []
# dataset:
#   cache_load: False
#   cache_save: False
#   dir: ./datasets
#   edge_dim: 128
#   edge_encoder: True
#   edge_encoder_bn: False
#   edge_encoder_name: Bond
#   edge_encoder_num_types: 0
#   edge_message_ratio: 0.8
#   edge_negative_sampling_ratio: 1.0
#   edge_train_mode: all
#   encoder: True
#   encoder_bn: True
#   encoder_dim: 128
#   encoder_name: db
#   format: OGB
#   infer_link_label: None
#   label_column: none
#   label_table: none
#   location: local
#   name: ogbg-molhiv
#   node_encoder: True
#   node_encoder_bn: False
#   node_encoder_name: Atom+LapPE
#   node_encoder_num_types: 0
#   remove_feature: False
#   resample_disjoint: False
#   resample_negative: False
#   shuffle_split: True
#   slic_compactness: 10
#   split: [0.8, 0.1, 0.1]
#   split_dir: ./splits
#   split_index: 0
#   split_mode: standard
#   task: graph
#   task_type: classification
#   to_undirected: False
#   transductive: False
#   transform: none
#   tu_simple: True
# devices: 1
# example_arg: example
# example_group:
#   example_arg: example
# gnn:
#   act: relu
#   agg: mean
#   att_final_linear: False
#   att_final_linear_bn: False
#   att_heads: 1
#   batchnorm: True
#   clear_feature: True
#   dim_edge: 64
#   dim_inner: 64
#   dropout: 0.0
#   head: san_graph
#   keep_edge: 0.5
#   l2norm: True
#   layer_type: generalconv
#   layers_mp: 2
#   layers_post_mp: 3
#   layers_pre_mp: 0
#   msg_direction: single
#   normalize_adj: False
#   residual: False
#   self_msg: concat
#   skip_every: 1
#   stage_type: stack
# gpu_mem: False
# graphormer:
#   attention_dropout: 0.0
#   dropout: 0.0
#   embed_dim: 80
#   input_dropout: 0.0
#   mlp_dropout: 0.0
#   num_heads: 4
#   num_layers: 6
#   use_graph_token: True
# gt:
#   attn_dropout: 0.5
#   batch_norm: True
#   bigbird:
#     add_cross_attention: False
#     attention_type: block_sparse
#     block_size: 3
#     chunk_size_feed_forward: 0
#     hidden_act: relu
#     is_decoder: False
#     layer_norm_eps: 1e-06
#     max_position_embeddings: 128
#     num_random_blocks: 3
#     use_bias: False
#   dim_hidden: 64
#   dropout: 0.05
#   full_graph: True
#   gamma: 1e-05
#   layer_norm: False
#   layer_type: CustomGatedGCN+Transformer
#   layers: 10
#   n_heads: 4
#   pna_degrees: []
#   residual: True
# mem:
#   inplace: False
# metric_agg: argmax
# metric_best: auc
# model:
#   edge_decoding: dot
#   graph_pooling: mean
#   loss_fun: cross_entropy
#   match_upper: True
#   size_average: mean
#   thresh: 0.5
#   type: GPSModel
# name_tag:
# num_threads: 6
# num_workers: 0
# optim:
#   base_lr: 0.0001
#   batch_accumulation: 1
#   clip_grad_norm: True
#   clip_grad_norm_value: 1.0
#   lr_decay: 0.1
#   max_epoch: 100
#   min_lr: 0.0
#   momentum: 0.9
#   num_warmup_epochs: 5
#   optimizer: adamW
#   reduce_factor: 0.1
#   schedule_patience: 10
#   scheduler: cosine_with_warmup
#   steps: [30, 60, 90]
#   weight_decay: 1e-05
# out_dir: results/ogbg-molhiv-GPS
# posenc_ElstaticSE:
#   dim_pe: 16
#   enable: False
#   kernel:
#     times: []
#     times_func: range(10)
#   layers: 3
#   model: none
#   n_heads: 4
#   pass_as_var: False
#   post_layers: 0
#   raw_norm_type: none
# posenc_EquivStableLapPE:
#   eigen:
#     eigvec_norm: L2
#     laplacian_norm: sym
#     max_freqs: 10
#   enable: False
#   raw_norm_type: none
# posenc_GraphormerBias:
#   dim_pe: 0
#   enable: False
#   node_degrees_only: False
#   num_in_degrees: None
#   num_out_degrees: None
#   num_spatial_types: None
# posenc_HKdiagSE:
#   dim_pe: 16
#   enable: False
#   kernel:
#     times: []
#     times_func:
#   layers: 3
#   model: none
#   n_heads: 4
#   pass_as_var: False
#   post_layers: 0
#   raw_norm_type: none
# posenc_LapPE:
#   dim_pe: 8
#   eigen:
#     eigvec_norm: L2
#     laplacian_norm: none
#     max_freqs: 8
#   enable: True
#   layers: 2
#   model: DeepSet
#   n_heads: 4
#   pass_as_var: False
#   post_layers: 0
#   raw_norm_type: none
# posenc_RWSE:
#   dim_pe: 16
#   enable: False
#   kernel:
#     times: []
#     times_func:
#   layers: 3
#   model: none
#   n_heads: 4
#   pass_as_var: False
#   post_layers: 0
#   raw_norm_type: none
# posenc_SignNet:
#   dim_pe: 16
#   eigen:
#     eigvec_norm: L2
#     laplacian_norm: sym
#     max_freqs: 10
#   enable: False
#   layers: 3
#   model: none
#   n_heads: 4
#   pass_as_var: False
#   phi_hidden_dim: 64
#   phi_out_dim: 4
#   post_layers: 0
#   raw_norm_type: none
# pretrained:
#   dir:
#   freeze_main: False
#   reset_prediction_head: True
# print: both
# round: 5
# run_dir: results/ogbg-molhiv-GPS/0
# run_id: 0
# run_multiple_splits: []
# seed: 0
# share:
#   dim_in: 9
#   dim_out: 2
#   num_splits: 3
# tensorboard_agg: True
# tensorboard_each_run: False
# train:
#   auto_resume: False
#   batch_size: 32
#   ckpt_best: False
#   ckpt_clean: True
#   ckpt_period: 100
#   enable_ckpt: True
#   epoch_resume: -1
#   eval_period: 1
#   iter_per_epoch: 32
#   mode: custom
#   neighbor_sizes: [20, 15, 10, 5]
#   node_per_graph: 32
#   radius: extend
#   sample_node: False
#   sampler: full_batch
#   skip_train_eval: False
#   walk_length: 4
# val:
#   node_per_graph: 32
#   radius: extend
#   sample_node: False
#   sampler: full_batch
# view_emb: False
# wandb:
#   entity: omertalmi-tel-aviv-university
#   name: use_softmax
#   project: molhiv
#   use: True
# Num parameters: 581405
# Start from epoch 0
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: omertalmi- (omertalmi-tel-aviv-university). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.1
# wandb: Run data is saved locally in /kaggle/working/WeightedGraphGPS/wandb/run-20240930_063820-u9h7h64i
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run use_softmax
# wandb: ⭐️ View project at https://wandb.ai/omertalmi-tel-aviv-university/molhiv
# wandb: 🚀 View run at https://wandb.ai/omertalmi-tel-aviv-university/molhiv/runs/u9h7h64i
# Key posenc_GraphormerBias.num_spatial_types with value <class 'NoneType'> is not a valid type; valid types: {<class 'list'>, <class 'str'>, <class 'bool'>, <class 'int'>, <class 'tuple'>, <class 'float'>}
# Key posenc_GraphormerBias.num_in_degrees with value <class 'NoneType'> is not a valid type; valid types: {<class 'list'>, <class 'str'>, <class 'bool'>, <class 'int'>, <class 'tuple'>, <class 'float'>}
# Key posenc_GraphormerBias.num_out_degrees with value <class 'NoneType'> is not a valid type; valid types: {<class 'list'>, <class 'str'>, <class 'bool'>, <class 'int'>, <class 'tuple'>, <class 'float'>}
# train: {'epoch': 0, 'time_epoch': 122.49277, 'eta': 12126.78413, 'eta_hours': 3.36855, 'loss': 0.85385972, 'lr': 0.0, 'params': 581405, 'time_iter': 0.11904, 'accuracy': 0.03745, 'precision': 0.03745, 'recall': 1.0, 'f1': 0.07219, 'auc': 0.51023}
# ...computing epoch stats took: 0.10s
# val: {'epoch': 0, 'time_epoch': 7.57878, 'loss': 0.86187218, 'lr': 0, 'params': 581405, 'time_iter': 0.05875, 'accuracy': 0.01969, 'precision': 0.01969, 'recall': 1.0, 'f1': 0.03863, 'auc': 0.62356}
# ...computing epoch stats took: 0.01s
# test: {'epoch': 0, 'time_epoch': 7.19613, 'loss': 0.85368947, 'lr': 0, 'params': 581405, 'time_iter': 0.05578, 'accuracy': 0.03161, 'precision': 0.03161, 'recall': 1.0, 'f1': 0.06128, 'auc': 0.6523}
# ...computing epoch stats took: 0.01s
# > Epoch 0: took 137.4s (avg 137.4s) | Best so far: epoch 0	train_loss: 0.8539 train_auc: 0.5102	val_loss: 0.8619 val_auc: 0.6236	test_loss: 0.8537 test_auc: 0.6523
# train: {'epoch': 1, 'time_epoch': 116.99528, 'eta': 11734.91436, 'eta_hours': 3.2597, 'loss': 0.49949476, 'lr': 2e-05, 'params': 581405, 'time_iter': 0.1137, 'accuracy': 0.72378, 'precision': 0.04037, 'recall': 0.28003, 'f1': 0.07057, 'auc': 0.54279}
# ...computing epoch stats took: 0.08s
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 1, 'time_epoch': 6.3727, 'loss': 0.23110675, 'lr': 0, 'params': 581405, 'time_iter': 0.0494, 'accuracy': 0.98031, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.66759}
# ...computing epoch stats took: 0.02s
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# test: {'epoch': 1, 'time_epoch': 6.2779, 'loss': 0.2275489, 'lr': 0, 'params': 581405, 'time_iter': 0.04867, 'accuracy': 0.96839, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.72595}
# ...computing epoch stats took: 0.02s
# > Epoch 1: took 129.8s (avg 133.6s) | Best so far: epoch 1	train_loss: 0.4995 train_auc: 0.5428	val_loss: 0.2311 val_auc: 0.6676	test_loss: 0.2275 test_auc: 0.7259
# train: {'epoch': 2, 'time_epoch': 118.17452, 'eta': 11564.42315, 'eta_hours': 3.21234, 'loss': 0.16628031, 'lr': 4e-05, 'params': 581405, 'time_iter': 0.11484, 'accuracy': 0.96265, 'precision': 0.63636, 'recall': 0.00568, 'f1': 0.01126, 'auc': 0.66001}
# ...computing epoch stats took: 0.09s
# val: {'epoch': 2, 'time_epoch': 6.55356, 'loss': 0.10676223, 'lr': 0, 'params': 581405, 'time_iter': 0.0508, 'accuracy': 0.98152, 'precision': 0.66667, 'recall': 0.12346, 'f1': 0.20833, 'auc': 0.71902}
# ...computing epoch stats took: 0.02s
# test: {'epoch': 2, 'time_epoch': 6.47322, 'loss': 0.13379598, 'lr': 0, 'params': 581405, 'time_iter': 0.05018, 'accuracy': 0.96985, 'precision': 0.63636, 'recall': 0.10769, 'f1': 0.18421, 'auc': 0.708}
# ...computing epoch stats took: 0.02s
# > Epoch 2: took 131.4s (avg 132.9s) | Best so far: epoch 2	train_loss: 0.1663 train_auc: 0.6600	val_loss: 0.1068 val_auc: 0.7190	test_loss: 0.1338 test_auc: 0.7080
# train: {'epoch': 3, 'time_epoch': 117.76025, 'eta': 11410.1478, 'eta_hours': 3.16949, 'loss': 0.13988851, 'lr': 6e-05, 'params': 581405, 'time_iter': 0.11444, 'accuracy': 0.9641, 'precision': 0.65269, 'recall': 0.08847, 'f1': 0.15583, 'auc': 0.7188}
# val: {'epoch': 3, 'time_epoch': 6.44168, 'loss': 0.08493756, 'lr': 0, 'params': 581405, 'time_iter': 0.04994, 'accuracy': 0.98104, 'precision': 0.58824, 'recall': 0.12346, 'f1': 0.20408, 'auc': 0.75667}
# test: {'epoch': 3, 'time_epoch': 6.37541, 'loss': 0.1191511, 'lr': 0, 'params': 581405, 'time_iter': 0.04942, 'accuracy': 0.97107, 'precision': 0.73913, 'recall': 0.13077, 'f1': 0.22222, 'auc': 0.71418}
# > Epoch 3: took 130.7s (avg 132.3s) | Best so far: epoch 3	train_loss: 0.1399 train_auc: 0.7188	val_loss: 0.0849 val_auc: 0.7567	test_loss: 0.1192 test_auc: 0.7142
# train: {'epoch': 4, 'time_epoch': 118.3652, 'eta': 11281.97255, 'eta_hours': 3.13388, 'loss': 0.13443177, 'lr': 8e-05, 'params': 581405, 'time_iter': 0.11503, 'accuracy': 0.96435, 'precision': 0.62241, 'recall': 0.12175, 'f1': 0.20367, 'auc': 0.74504}
# val: {'epoch': 4, 'time_epoch': 6.42833, 'loss': 0.08329685, 'lr': 0, 'params': 581405, 'time_iter': 0.04983, 'accuracy': 0.98177, 'precision': 0.8, 'recall': 0.09877, 'f1': 0.17582, 'auc': 0.78477}
# test: {'epoch': 4, 'time_epoch': 6.31503, 'loss': 0.12843568, 'lr': 0, 'params': 581405, 'time_iter': 0.04895, 'accuracy': 0.96888, 'precision': 0.75, 'recall': 0.02308, 'f1': 0.04478, 'auc': 0.69474}
# > Epoch 4: took 131.3s (avg 132.1s) | Best so far: epoch 4	train_loss: 0.1344 train_auc: 0.7450	val_loss: 0.0833 val_auc: 0.7848	test_loss: 0.1284 test_auc: 0.6947
# train: {'epoch': 5, 'time_epoch': 118.39779, 'eta': 11157.57787, 'eta_hours': 3.09933, 'loss': 0.1308011, 'lr': 0.0001, 'params': 581405, 'time_iter': 0.11506, 'accuracy': 0.96483, 'precision': 0.62136, 'recall': 0.15584, 'f1': 0.24919, 'auc': 0.76388}
# val: {'epoch': 5, 'time_epoch': 6.34522, 'loss': 0.08460977, 'lr': 0, 'params': 581405, 'time_iter': 0.04919, 'accuracy': 0.98031, 'precision': 0.5, 'recall': 0.22222, 'f1': 0.30769, 'auc': 0.77771}
# test: {'epoch': 5, 'time_epoch': 6.30149, 'loss': 0.11981229, 'lr': 0, 'params': 581405, 'time_iter': 0.04885, 'accuracy': 0.96985, 'precision': 0.54412, 'recall': 0.28462, 'f1': 0.37374, 'auc': 0.72938}
# > Epoch 5: took 131.2s (avg 132.0s) | Best so far: epoch 4	train_loss: 0.1344 train_auc: 0.7450	val_loss: 0.0833 val_auc: 0.7848	test_loss: 0.1284 test_auc: 0.6947
# train: {'epoch': 6, 'time_epoch': 117.84257, 'eta': 11027.52011, 'eta_hours': 3.0632, 'loss': 0.12624884, 'lr': 9.997e-05, 'params': 581405, 'time_iter': 0.11452, 'accuracy': 0.96541, 'precision': 0.63277, 'recall': 0.18182, 'f1': 0.28247, 'auc': 0.79053}
# val: {'epoch': 6, 'time_epoch': 6.34428, 'loss': 0.07517654, 'lr': 0, 'params': 581405, 'time_iter': 0.04918, 'accuracy': 0.98152, 'precision': 0.6087, 'recall': 0.17284, 'f1': 0.26923, 'auc': 0.80243}
# test: {'epoch': 6, 'time_epoch': 6.41209, 'loss': 0.11273632, 'lr': 0, 'params': 581405, 'time_iter': 0.04971, 'accuracy': 0.97301, 'precision': 0.74359, 'recall': 0.22308, 'f1': 0.3432, 'auc': 0.75392}
# > Epoch 6: took 130.8s (avg 131.8s) | Best so far: epoch 6	train_loss: 0.1262 train_auc: 0.7905	val_loss: 0.0752 val_auc: 0.8024	test_loss: 0.1127 test_auc: 0.7539
# train: {'epoch': 7, 'time_epoch': 114.86222, 'eta': 10866.24202, 'eta_hours': 3.0184, 'loss': 0.12293621, 'lr': 9.989e-05, 'params': 581405, 'time_iter': 0.11163, 'accuracy': 0.96602, 'precision': 0.65, 'recall': 0.20049, 'f1': 0.30645, 'auc': 0.80005}
# val: {'epoch': 7, 'time_epoch': 6.49412, 'loss': 0.07629077, 'lr': 0, 'params': 581405, 'time_iter': 0.05034, 'accuracy': 0.97909, 'precision': 0.43902, 'recall': 0.22222, 'f1': 0.29508, 'auc': 0.78699}
# test: {'epoch': 7, 'time_epoch': 6.63592, 'loss': 0.11362098, 'lr': 0, 'params': 581405, 'time_iter': 0.05144, 'accuracy': 0.97204, 'precision': 0.64151, 'recall': 0.26154, 'f1': 0.37158, 'auc': 0.7547}
# > Epoch 7: took 128.1s (avg 131.3s) | Best so far: epoch 6	train_loss: 0.1262 train_auc: 0.7905	val_loss: 0.0752 val_auc: 0.8024	test_loss: 0.1127 test_auc: 0.7539
# train: {'epoch': 8, 'time_epoch': 113.97241, 'eta': 10706.28162, 'eta_hours': 2.97397, 'loss': 0.11900429, 'lr': 9.975e-05, 'params': 581405, 'time_iter': 0.11076, 'accuracy': 0.9672, 'precision': 0.67191, 'recall': 0.24269, 'f1': 0.35659, 'auc': 0.8149}
# val: {'epoch': 8, 'time_epoch': 6.05869, 'loss': 0.07825192, 'lr': 0, 'params': 581405, 'time_iter': 0.04697, 'accuracy': 0.97933, 'precision': 0.46296, 'recall': 0.30864, 'f1': 0.37037, 'auc': 0.8092}
# test: {'epoch': 8, 'time_epoch': 6.06537, 'loss': 0.11338415, 'lr': 0, 'params': 581405, 'time_iter': 0.04702, 'accuracy': 0.97058, 'precision': 0.58182, 'recall': 0.24615, 'f1': 0.34595, 'auc': 0.75691}
# > Epoch 8: took 126.3s (avg 130.8s) | Best so far: epoch 8	train_loss: 0.1190 train_auc: 0.8149	val_loss: 0.0783 val_auc: 0.8092	test_loss: 0.1134 test_auc: 0.7569
# train: {'epoch': 9, 'time_epoch': 110.86027, 'eta': 10527.50959, 'eta_hours': 2.92431, 'loss': 0.11660612, 'lr': 9.956e-05, 'params': 581405, 'time_iter': 0.10774, 'accuracy': 0.96778, 'precision': 0.68067, 'recall': 0.26299, 'f1': 0.37939, 'auc': 0.82157}
# val: {'epoch': 9, 'time_epoch': 6.12194, 'loss': 0.07568355, 'lr': 0, 'params': 581405, 'time_iter': 0.04746, 'accuracy': 0.97982, 'precision': 0.47826, 'recall': 0.2716, 'f1': 0.34646, 'auc': 0.80654}
# test: {'epoch': 9, 'time_epoch': 6.06007, 'loss': 0.11222815, 'lr': 0, 'params': 581405, 'time_iter': 0.04698, 'accuracy': 0.97131, 'precision': 0.59677, 'recall': 0.28462, 'f1': 0.38542, 'auc': 0.77831}
# > Epoch 9: took 123.2s (avg 130.0s) | Best so far: epoch 8	train_loss: 0.1190 train_auc: 0.8149	val_loss: 0.0783 val_auc: 0.8092	test_loss: 0.1134 test_auc: 0.7569
# train: {'epoch': 10, 'time_epoch': 111.32816, 'eta': 10364.87079, 'eta_hours': 2.87913, 'loss': 0.11352708, 'lr': 9.932e-05, 'params': 581405, 'time_iter': 0.10819, 'accuracy': 0.96824, 'precision': 0.68226, 'recall': 0.28409, 'f1': 0.40115, 'auc': 0.83877}
# val: {'epoch': 10, 'time_epoch': 6.02382, 'loss': 0.07762946, 'lr': 0, 'params': 581405, 'time_iter': 0.0467, 'accuracy': 0.98104, 'precision': 0.53488, 'recall': 0.28395, 'f1': 0.37097, 'auc': 0.79451}
# test: {'epoch': 10, 'time_epoch': 6.11665, 'loss': 0.11720319, 'lr': 0, 'params': 581405, 'time_iter': 0.04742, 'accuracy': 0.96985, 'precision': 0.56, 'recall': 0.21538, 'f1': 0.31111, 'auc': 0.77925}
# > Epoch 10: took 123.6s (avg 129.4s) | Best so far: epoch 8	train_loss: 0.1190 train_auc: 0.8149	val_loss: 0.0783 val_auc: 0.8092	test_loss: 0.1134 test_auc: 0.7569
# train: {'epoch': 11, 'time_epoch': 110.88648, 'eta': 10207.54481, 'eta_hours': 2.83543, 'loss': 0.11252035, 'lr': 9.902e-05, 'params': 581405, 'time_iter': 0.10776, 'accuracy': 0.96787, 'precision': 0.66541, 'recall': 0.28571, 'f1': 0.39977, 'auc': 0.8411}
# val: {'epoch': 11, 'time_epoch': 6.10693, 'loss': 0.07510994, 'lr': 0, 'params': 581405, 'time_iter': 0.04734, 'accuracy': 0.98249, 'precision': 0.6, 'recall': 0.33333, 'f1': 0.42857, 'auc': 0.82111}
# test: {'epoch': 11, 'time_epoch': 6.15591, 'loss': 0.11232932, 'lr': 0, 'params': 581405, 'time_iter': 0.04772, 'accuracy': 0.97082, 'precision': 0.58333, 'recall': 0.26923, 'f1': 0.36842, 'auc': 0.78565}
# > Epoch 11: took 123.3s (avg 128.9s) | Best so far: epoch 11	train_loss: 0.1125 train_auc: 0.8411	val_loss: 0.0751 val_auc: 0.8211	test_loss: 0.1123 test_auc: 0.7856
# train: {'epoch': 12, 'time_epoch': 111.38118, 'eta': 10060.67404, 'eta_hours': 2.79463, 'loss': 0.11053776, 'lr': 9.867e-05, 'params': 581405, 'time_iter': 0.10824, 'accuracy': 0.96933, 'precision': 0.7061, 'recall': 0.31006, 'f1': 0.43091, 'auc': 0.85002}
# val: {'epoch': 12, 'time_epoch': 6.09362, 'loss': 0.07473743, 'lr': 0, 'params': 581405, 'time_iter': 0.04724, 'accuracy': 0.98274, 'precision': 0.64706, 'recall': 0.2716, 'f1': 0.38261, 'auc': 0.77178}
# test: {'epoch': 12, 'time_epoch': 6.0627, 'loss': 0.11441143, 'lr': 0, 'params': 581405, 'time_iter': 0.047, 'accuracy': 0.97155, 'precision': 0.68571, 'recall': 0.18462, 'f1': 0.29091, 'auc': 0.79669}
# > Epoch 12: took 123.7s (avg 128.5s) | Best so far: epoch 11	train_loss: 0.1125 train_auc: 0.8411	val_loss: 0.0751 val_auc: 0.8211	test_loss: 0.1123 test_auc: 0.7856
# train: {'epoch': 13, 'time_epoch': 111.08849, 'eta': 9917.07528, 'eta_hours': 2.75474, 'loss': 0.10912491, 'lr': 9.826e-05, 'params': 581405, 'time_iter': 0.10796, 'accuracy': 0.96891, 'precision': 0.69981, 'recall': 0.29708, 'f1': 0.41709, 'auc': 0.85696}
# val: {'epoch': 13, 'time_epoch': 6.05296, 'loss': 0.07709331, 'lr': 0, 'params': 581405, 'time_iter': 0.04692, 'accuracy': 0.98177, 'precision': 0.56522, 'recall': 0.32099, 'f1': 0.40945, 'auc': 0.78895}
# test: {'epoch': 13, 'time_epoch': 6.04543, 'loss': 0.11018339, 'lr': 0, 'params': 581405, 'time_iter': 0.04686, 'accuracy': 0.97082, 'precision': 0.58929, 'recall': 0.25385, 'f1': 0.35484, 'auc': 0.80951}
# > Epoch 13: took 123.3s (avg 128.2s) | Best so far: epoch 11	train_loss: 0.1125 train_auc: 0.8411	val_loss: 0.0751 val_auc: 0.8211	test_loss: 0.1123 test_auc: 0.7856
# train: {'epoch': 14, 'time_epoch': 110.62481, 'eta': 9775.1837, 'eta_hours': 2.71533, 'loss': 0.10610275, 'lr': 9.78e-05, 'params': 581405, 'time_iter': 0.10751, 'accuracy': 0.96973, 'precision': 0.70629, 'recall': 0.32792, 'f1': 0.44789, 'auc': 0.867}
# val: {'epoch': 14, 'time_epoch': 6.0359, 'loss': 0.07475712, 'lr': 0, 'params': 581405, 'time_iter': 0.04679, 'accuracy': 0.98201, 'precision': 0.58537, 'recall': 0.2963, 'f1': 0.39344, 'auc': 0.7937}
# test: {'epoch': 14, 'time_epoch': 6.03646, 'loss': 0.11308965, 'lr': 0, 'params': 581405, 'time_iter': 0.04679, 'accuracy': 0.97228, 'precision': 0.64286, 'recall': 0.27692, 'f1': 0.3871, 'auc': 0.79298}
# > Epoch 14: took 122.8s (avg 127.8s) | Best so far: epoch 11	train_loss: 0.1125 train_auc: 0.8411	val_loss: 0.0751 val_auc: 0.8211	test_loss: 0.1123 test_auc: 0.7856
# train: {'epoch': 15, 'time_epoch': 110.70168, 'eta': 9637.60401, 'eta_hours': 2.67711, 'loss': 0.10399431, 'lr': 9.729e-05, 'params': 581405, 'time_iter': 0.10758, 'accuracy': 0.9697, 'precision': 0.69294, 'recall': 0.34253, 'f1': 0.45845, 'auc': 0.87397}
# val: {'epoch': 15, 'time_epoch': 6.20351, 'loss': 0.07635668, 'lr': 0, 'params': 581405, 'time_iter': 0.04809, 'accuracy': 0.98152, 'precision': 0.54902, 'recall': 0.34568, 'f1': 0.42424, 'auc': 0.80759}
# test: {'epoch': 15, 'time_epoch': 6.01923, 'loss': 0.10971914, 'lr': 0, 'params': 581405, 'time_iter': 0.04666, 'accuracy': 0.97204, 'precision': 0.61194, 'recall': 0.31538, 'f1': 0.41624, 'auc': 0.81073}
# > Epoch 15: took 123.1s (avg 127.5s) | Best so far: epoch 11	train_loss: 0.1125 train_auc: 0.8411	val_loss: 0.0751 val_auc: 0.8211	test_loss: 0.1123 test_auc: 0.7856
# train: {'epoch': 16, 'time_epoch': 111.58353, 'eta': 9507.49193, 'eta_hours': 2.64097, 'loss': 0.10315666, 'lr': 9.673e-05, 'params': 581405, 'time_iter': 0.10844, 'accuracy': 0.97034, 'precision': 0.70513, 'recall': 0.35714, 'f1': 0.47414, 'auc': 0.87929}
# val: {'epoch': 16, 'time_epoch': 6.09616, 'loss': 0.07340554, 'lr': 0, 'params': 581405, 'time_iter': 0.04726, 'accuracy': 0.98177, 'precision': 0.56, 'recall': 0.34568, 'f1': 0.42748, 'auc': 0.81602}
# test: {'epoch': 16, 'time_epoch': 6.07152, 'loss': 0.11009305, 'lr': 0, 'params': 581405, 'time_iter': 0.04707, 'accuracy': 0.97082, 'precision': 0.57812, 'recall': 0.28462, 'f1': 0.38144, 'auc': 0.80499}
# > Epoch 16: took 123.9s (avg 127.3s) | Best so far: epoch 11	train_loss: 0.1125 train_auc: 0.8411	val_loss: 0.0751 val_auc: 0.8211	test_loss: 0.1123 test_auc: 0.7856
# train: {'epoch': 17, 'time_epoch': 110.68423, 'eta': 9375.34177, 'eta_hours': 2.60426, 'loss': 0.10154335, 'lr': 9.611e-05, 'params': 581405, 'time_iter': 0.10756, 'accuracy': 0.97079, 'precision': 0.7189, 'recall': 0.3612, 'f1': 0.48082, 'auc': 0.8836}
# val: {'epoch': 17, 'time_epoch': 6.17497, 'loss': 0.08923499, 'lr': 0, 'params': 581405, 'time_iter': 0.04787, 'accuracy': 0.97617, 'precision': 0.38028, 'recall': 0.33333, 'f1': 0.35526, 'auc': 0.76003}
# test: {'epoch': 17, 'time_epoch': 5.99761, 'loss': 0.12607545, 'lr': 0, 'params': 581405, 'time_iter': 0.04649, 'accuracy': 0.9645, 'precision': 0.40476, 'recall': 0.26154, 'f1': 0.31776, 'auc': 0.7758}
# > Epoch 17: took 123.0s (avg 127.0s) | Best so far: epoch 11	train_loss: 0.1125 train_auc: 0.8411	val_loss: 0.0751 val_auc: 0.8211	test_loss: 0.1123 test_auc: 0.7856
# train: {'epoch': 18, 'time_epoch': 113.33531, 'eta': 9256.75318, 'eta_hours': 2.57132, 'loss': 0.10115807, 'lr': 9.545e-05, 'params': 581405, 'time_iter': 0.11014, 'accuracy': 0.97064, 'precision': 0.71661, 'recall': 0.35714, 'f1': 0.47671, 'auc': 0.88726}
# val: {'epoch': 18, 'time_epoch': 6.46844, 'loss': 0.07244269, 'lr': 0, 'params': 581405, 'time_iter': 0.05014, 'accuracy': 0.98322, 'precision': 0.65789, 'recall': 0.30864, 'f1': 0.42017, 'auc': 0.81177}
# test: {'epoch': 18, 'time_epoch': 6.15518, 'loss': 0.11119733, 'lr': 0, 'params': 581405, 'time_iter': 0.04771, 'accuracy': 0.97082, 'precision': 0.59259, 'recall': 0.24615, 'f1': 0.34783, 'auc': 0.80545}
# > Epoch 18: took 126.1s (avg 127.0s) | Best so far: epoch 11	train_loss: 0.1125 train_auc: 0.8411	val_loss: 0.0751 val_auc: 0.8211	test_loss: 0.1123 test_auc: 0.7856
# train: {'epoch': 19, 'time_epoch': 117.18236, 'eta': 9154.07809, 'eta_hours': 2.5428, 'loss': 0.09967453, 'lr': 9.474e-05, 'params': 581405, 'time_iter': 0.11388, 'accuracy': 0.97161, 'precision': 0.73726, 'recall': 0.37581, 'f1': 0.49785, 'auc': 0.88993}
# val: {'epoch': 19, 'time_epoch': 6.34339, 'loss': 0.07455408, 'lr': 0, 'params': 581405, 'time_iter': 0.04917, 'accuracy': 0.98249, 'precision': 0.65517, 'recall': 0.23457, 'f1': 0.34545, 'auc': 0.78037}
# test: {'epoch': 19, 'time_epoch': 6.32829, 'loss': 0.11459963, 'lr': 0, 'params': 581405, 'time_iter': 0.04906, 'accuracy': 0.97082, 'precision': 0.66667, 'recall': 0.15385, 'f1': 0.25, 'auc': 0.79519}
# > Epoch 19: took 130.0s (avg 127.2s) | Best so far: epoch 11	train_loss: 0.1125 train_auc: 0.8411	val_loss: 0.0751 val_auc: 0.8211	test_loss: 0.1123 test_auc: 0.7856
# train: {'epoch': 20, 'time_epoch': 117.97715, 'eta': 9053.0113, 'eta_hours': 2.51473, 'loss': 0.09683106, 'lr': 9.397e-05, 'params': 581405, 'time_iter': 0.11465, 'accuracy': 0.97234, 'precision': 0.74923, 'recall': 0.39286, 'f1': 0.51544, 'auc': 0.89475}
# val: {'epoch': 20, 'time_epoch': 6.34959, 'loss': 0.08665699, 'lr': 0, 'params': 581405, 'time_iter': 0.04922, 'accuracy': 0.97812, 'precision': 0.42105, 'recall': 0.2963, 'f1': 0.34783, 'auc': 0.76341}
# test: {'epoch': 20, 'time_epoch': 6.34163, 'loss': 0.12101972, 'lr': 0, 'params': 581405, 'time_iter': 0.04916, 'accuracy': 0.9662, 'precision': 0.44304, 'recall': 0.26923, 'f1': 0.33493, 'auc': 0.79473}
# > Epoch 20: took 130.8s (avg 127.3s) | Best so far: epoch 11	train_loss: 0.1125 train_auc: 0.8411	val_loss: 0.0751 val_auc: 0.8211	test_loss: 0.1123 test_auc: 0.7856
# train: {'epoch': 21, 'time_epoch': 117.4025, 'eta': 8948.36979, 'eta_hours': 2.48566, 'loss': 0.09483835, 'lr': 9.316e-05, 'params': 581405, 'time_iter': 0.11409, 'accuracy': 0.97192, 'precision': 0.72449, 'recall': 0.40341, 'f1': 0.51825, 'auc': 0.9065}
# val: {'epoch': 21, 'time_epoch': 6.33867, 'loss': 0.08415756, 'lr': 0, 'params': 581405, 'time_iter': 0.04914, 'accuracy': 0.9786, 'precision': 0.44444, 'recall': 0.34568, 'f1': 0.38889, 'auc': 0.78555}
# test: {'epoch': 21, 'time_epoch': 6.33729, 'loss': 0.11794, 'lr': 0, 'params': 581405, 'time_iter': 0.04913, 'accuracy': 0.96937, 'precision': 0.52439, 'recall': 0.33077, 'f1': 0.40566, 'auc': 0.81062}
# > Epoch 21: took 130.2s (avg 127.5s) | Best so far: epoch 11	train_loss: 0.1125 train_auc: 0.8411	val_loss: 0.0751 val_auc: 0.8211	test_loss: 0.1123 test_auc: 0.7856
# train: {'epoch': 22, 'time_epoch': 117.21897, 'eta': 8842.0042, 'eta_hours': 2.45611, 'loss': 0.09496168, 'lr': 9.23e-05, 'params': 581405, 'time_iter': 0.11392, 'accuracy': 0.97265, 'precision': 0.74198, 'recall': 0.41315, 'f1': 0.53076, 'auc': 0.90682}
# val: {'epoch': 22, 'time_epoch': 6.26773, 'loss': 0.07817389, 'lr': 0, 'params': 581405, 'time_iter': 0.04859, 'accuracy': 0.98298, 'precision': 0.61224, 'recall': 0.37037, 'f1': 0.46154, 'auc': 0.7898}
# test: {'epoch': 22, 'time_epoch': 6.27378, 'loss': 0.115942, 'lr': 0, 'params': 581405, 'time_iter': 0.04863, 'accuracy': 0.97034, 'precision': 0.5625, 'recall': 0.27692, 'f1': 0.37113, 'auc': 0.79562}
# > Epoch 22: took 129.9s (avg 127.6s) | Best so far: epoch 11	train_loss: 0.1125 train_auc: 0.8411	val_loss: 0.0751 val_auc: 0.8211	test_loss: 0.1123 test_auc: 0.7856
# train: {'epoch': 23, 'time_epoch': 116.86909, 'eta': 8733.62622, 'eta_hours': 2.42601, 'loss': 0.09238426, 'lr': 9.14e-05, 'params': 581405, 'time_iter': 0.11358, 'accuracy': 0.97255, 'precision': 0.73945, 'recall': 0.41234, 'f1': 0.52944, 'auc': 0.91467}
# val: {'epoch': 23, 'time_epoch': 6.32505, 'loss': 0.07696922, 'lr': 0, 'params': 581405, 'time_iter': 0.04903, 'accuracy': 0.98298, 'precision': 0.64865, 'recall': 0.2963, 'f1': 0.40678, 'auc': 0.77999}
# test: {'epoch': 23, 'time_epoch': 6.2769, 'loss': 0.11554234, 'lr': 0, 'params': 581405, 'time_iter': 0.04866, 'accuracy': 0.97155, 'precision': 0.61404, 'recall': 0.26923, 'f1': 0.37433, 'auc': 0.79147}
# > Epoch 23: took 129.6s (avg 127.7s) | Best so far: epoch 11	train_loss: 0.1125 train_auc: 0.8411	val_loss: 0.0751 val_auc: 0.8211	test_loss: 0.1123 test_auc: 0.7856
# train: {'epoch': 24, 'time_epoch': 118.66401, 'eta': 8629.95371, 'eta_hours': 2.39721, 'loss': 0.09137401, 'lr': 9.045e-05, 'params': 581405, 'time_iter': 0.11532, 'accuracy': 0.97301, 'precision': 0.74784, 'recall': 0.42127, 'f1': 0.53894, 'auc': 0.91862}
# val: {'epoch': 24, 'time_epoch': 6.24303, 'loss': 0.07395968, 'lr': 0, 'params': 581405, 'time_iter': 0.0484, 'accuracy': 0.98371, 'precision': 0.675, 'recall': 0.33333, 'f1': 0.44628, 'auc': 0.80361}
# test: {'epoch': 24, 'time_epoch': 6.30266, 'loss': 0.11579626, 'lr': 0, 'params': 581405, 'time_iter': 0.04886, 'accuracy': 0.9718, 'precision': 0.61667, 'recall': 0.28462, 'f1': 0.38947, 'auc': 0.79371}
# > Epoch 24: took 131.4s (avg 127.8s) | Best so far: epoch 11	train_loss: 0.1125 train_auc: 0.8411	val_loss: 0.0751 val_auc: 0.8211	test_loss: 0.1123 test_auc: 0.7856
# train: {'epoch': 25, 'time_epoch': 116.31425, 'eta': 8518.44023, 'eta_hours': 2.36623, 'loss': 0.09020486, 'lr': 8.946e-05, 'params': 581405, 'time_iter': 0.11304, 'accuracy': 0.97325, 'precision': 0.75581, 'recall': 0.42208, 'f1': 0.54167, 'auc': 0.92142}
# val: {'epoch': 25, 'time_epoch': 6.33115, 'loss': 0.07576631, 'lr': 0, 'params': 581405, 'time_iter': 0.04908, 'accuracy': 0.98152, 'precision': 0.54902, 'recall': 0.34568, 'f1': 0.42424, 'auc': 0.81933}
# test: {'epoch': 25, 'time_epoch': 6.24411, 'loss': 0.11880003, 'lr': 0, 'params': 581405, 'time_iter': 0.0484, 'accuracy': 0.96791, 'precision': 0.4878, 'recall': 0.30769, 'f1': 0.37736, 'auc': 0.80092}
# > Epoch 25: took 129.0s (avg 127.8s) | Best so far: epoch 11	train_loss: 0.1125 train_auc: 0.8411	val_loss: 0.0751 val_auc: 0.8211	test_loss: 0.1123 test_auc: 0.7856
# train: {'epoch': 26, 'time_epoch': 117.01032, 'eta': 8408.45312, 'eta_hours': 2.33568, 'loss': 0.08941721, 'lr': 8.842e-05, 'params': 581405, 'time_iter': 0.11371, 'accuracy': 0.97265, 'precision': 0.72992, 'recall': 0.42776, 'f1': 0.53941, 'auc': 0.92477}
# val: {'epoch': 26, 'time_epoch': 6.40996, 'loss': 0.07733259, 'lr': 0, 'params': 581405, 'time_iter': 0.04969, 'accuracy': 0.98055, 'precision': 0.5082, 'recall': 0.38272, 'f1': 0.43662, 'auc': 0.80464}
# test: {'epoch': 26, 'time_epoch': 6.32509, 'loss': 0.11988753, 'lr': 0, 'params': 581405, 'time_iter': 0.04903, 'accuracy': 0.97034, 'precision': 0.55128, 'recall': 0.33077, 'f1': 0.41346, 'auc': 0.80442}
# > Epoch 26: took 129.9s (avg 127.9s) | Best so far: epoch 11	train_loss: 0.1125 train_auc: 0.8411	val_loss: 0.0751 val_auc: 0.8211	test_loss: 0.1123 test_auc: 0.7856
# train: {'epoch': 27, 'time_epoch': 116.92406, 'eta': 8297.74253, 'eta_hours': 2.30493, 'loss': 0.08752905, 'lr': 8.734e-05, 'params': 581405, 'time_iter': 0.11363, 'accuracy': 0.97344, 'precision': 0.75354, 'recall': 0.43182, 'f1': 0.54902, 'auc': 0.92829}
# val: {'epoch': 27, 'time_epoch': 6.32274, 'loss': 0.07906222, 'lr': 0, 'params': 581405, 'time_iter': 0.04901, 'accuracy': 0.98152, 'precision': 0.55556, 'recall': 0.30864, 'f1': 0.39683, 'auc': 0.78902}
# test: {'epoch': 27, 'time_epoch': 6.32045, 'loss': 0.12159861, 'lr': 0, 'params': 581405, 'time_iter': 0.049, 'accuracy': 0.97082, 'precision': 0.6, 'recall': 0.23077, 'f1': 0.33333, 'auc': 0.8023}
# > Epoch 27: took 129.7s (avg 128.0s) | Best so far: epoch 11	train_loss: 0.1125 train_auc: 0.8411	val_loss: 0.0751 val_auc: 0.8211	test_loss: 0.1123 test_auc: 0.7856
# train: {'epoch': 28, 'time_epoch': 116.51716, 'eta': 8185.60721, 'eta_hours': 2.27378, 'loss': 0.0873277, 'lr': 8.622e-05, 'params': 581405, 'time_iter': 0.11323, 'accuracy': 0.97362, 'precision': 0.75208, 'recall': 0.44075, 'f1': 0.55578, 'auc': 0.92781}
# val: {'epoch': 28, 'time_epoch': 6.25226, 'loss': 0.0826878, 'lr': 0, 'params': 581405, 'time_iter': 0.04847, 'accuracy': 0.97885, 'precision': 0.45833, 'recall': 0.40741, 'f1': 0.43137, 'auc': 0.79988}
# test: {'epoch': 28, 'time_epoch': 6.23595, 'loss': 0.11918915, 'lr': 0, 'params': 581405, 'time_iter': 0.04834, 'accuracy': 0.97034, 'precision': 0.55, 'recall': 0.33846, 'f1': 0.41905, 'auc': 0.81104}
# > Epoch 28: took 129.2s (avg 128.0s) | Best so far: epoch 11	train_loss: 0.1125 train_auc: 0.8411	val_loss: 0.0751 val_auc: 0.8211	test_loss: 0.1123 test_auc: 0.7856
# train: {'epoch': 29, 'time_epoch': 116.62996, 'eta': 8073.44297, 'eta_hours': 2.24262, 'loss': 0.08460478, 'lr': 8.506e-05, 'params': 581405, 'time_iter': 0.11334, 'accuracy': 0.9742, 'precision': 0.7656, 'recall': 0.44805, 'f1': 0.56528, 'auc': 0.93556}
# val: {'epoch': 29, 'time_epoch': 6.27297, 'loss': 0.07412542, 'lr': 0, 'params': 581405, 'time_iter': 0.04863, 'accuracy': 0.98128, 'precision': 0.54, 'recall': 0.33333, 'f1': 0.41221, 'auc': 0.817}
# test: {'epoch': 29, 'time_epoch': 6.26859, 'loss': 0.11851784, 'lr': 0, 'params': 581405, 'time_iter': 0.04859, 'accuracy': 0.97301, 'precision': 0.65079, 'recall': 0.31538, 'f1': 0.42487, 'auc': 0.79727}
# > Epoch 29: took 129.3s (avg 128.1s) | Best so far: epoch 11	train_loss: 0.1125 train_auc: 0.8411	val_loss: 0.0751 val_auc: 0.8211	test_loss: 0.1123 test_auc: 0.7856
# ...
# test: {'epoch': 87, 'time_epoch': 5.97024, 'loss': 0.19955913, 'lr': 0, 'params': 581405, 'time_iter': 0.04628, 'accuracy': 0.96475, 'precision': 0.40741, 'recall': 0.25385, 'f1': 0.3128, 'auc': 0.79953}
# > Epoch 87: took 122.5s (avg 127.1s) | Best so far: epoch 58	train_loss: 0.0549 train_auc: 0.9813	val_loss: 0.0975 val_auc: 0.8297	test_loss: 0.1720 test_auc: 0.8005
# train: {'epoch': 88, 'time_epoch': 109.54328, 'eta': 1259.075, 'eta_hours': 0.34974, 'loss': 0.03872729, 'lr': 3.89e-06, 'params': 581405, 'time_iter': 0.10646, 'accuracy': 0.98666, 'precision': 0.86952, 'recall': 0.75731, 'f1': 0.80954, 'auc': 0.9923}
# val: {'epoch': 88, 'time_epoch': 6.02714, 'loss': 0.12210336, 'lr': 0, 'params': 581405, 'time_iter': 0.04672, 'accuracy': 0.97739, 'precision': 0.42105, 'recall': 0.39506, 'f1': 0.40764, 'auc': 0.80977}
# test: {'epoch': 88, 'time_epoch': 6.42747, 'loss': 0.20319917, 'lr': 0, 'params': 581405, 'time_iter': 0.04983, 'accuracy': 0.96377, 'precision': 0.38554, 'recall': 0.24615, 'f1': 0.30047, 'auc': 0.79847}
# > Epoch 88: took 122.1s (avg 127.1s) | Best so far: epoch 58	train_loss: 0.0549 train_auc: 0.9813	val_loss: 0.0975 val_auc: 0.8297	test_loss: 0.1720 test_auc: 0.8005
# train: {'epoch': 89, 'time_epoch': 114.81203, 'eta': 1144.6526, 'eta_hours': 0.31796, 'loss': 0.04344242, 'lr': 3.27e-06, 'params': 581405, 'time_iter': 0.11158, 'accuracy': 0.98535, 'precision': 0.85311, 'recall': 0.73539, 'f1': 0.78989, 'auc': 0.99078}
# val: {'epoch': 89, 'time_epoch': 6.38261, 'loss': 0.12752515, 'lr': 0, 'params': 581405, 'time_iter': 0.04948, 'accuracy': 0.97885, 'precision': 0.45588, 'recall': 0.38272, 'f1': 0.41611, 'auc': 0.80246}
# test: {'epoch': 89, 'time_epoch': 6.33044, 'loss': 0.21329142, 'lr': 0, 'params': 581405, 'time_iter': 0.04907, 'accuracy': 0.96718, 'precision': 0.45763, 'recall': 0.20769, 'f1': 0.28571, 'auc': 0.80082}
# > Epoch 89: took 127.7s (avg 127.1s) | Best so far: epoch 58	train_loss: 0.0549 train_auc: 0.9813	val_loss: 0.0975 val_auc: 0.8297	test_loss: 0.1720 test_auc: 0.8005
# train: {'epoch': 90, 'time_epoch': 115.99181, 'eta': 1030.33832, 'eta_hours': 0.28621, 'loss': 0.03967129, 'lr': 2.71e-06, 'params': 581405, 'time_iter': 0.11272, 'accuracy': 0.98657, 'precision': 0.87619, 'recall': 0.74675, 'f1': 0.80631, 'auc': 0.99195}
# val: {'epoch': 90, 'time_epoch': 6.25673, 'loss': 0.12276977, 'lr': 0, 'params': 581405, 'time_iter': 0.0485, 'accuracy': 0.97836, 'precision': 0.44444, 'recall': 0.39506, 'f1': 0.4183, 'auc': 0.80887}
# test: {'epoch': 90, 'time_epoch': 6.34348, 'loss': 0.2057494, 'lr': 0, 'params': 581405, 'time_iter': 0.04917, 'accuracy': 0.96572, 'precision': 0.42254, 'recall': 0.23077, 'f1': 0.29851, 'auc': 0.79745}
# > Epoch 90: took 128.7s (avg 127.1s) | Best so far: epoch 58	train_loss: 0.0549 train_auc: 0.9813	val_loss: 0.0975 val_auc: 0.8297	test_loss: 0.1720 test_auc: 0.8005
# train: {'epoch': 91, 'time_epoch': 116.09809, 'eta': 915.99681, 'eta_hours': 0.25444, 'loss': 0.04175358, 'lr': 2.2e-06, 'params': 581405, 'time_iter': 0.11283, 'accuracy': 0.98617, 'precision': 0.86686, 'recall': 0.74513, 'f1': 0.8014, 'auc': 0.99131}
# val: {'epoch': 91, 'time_epoch': 6.02031, 'loss': 0.12355334, 'lr': 0, 'params': 581405, 'time_iter': 0.04667, 'accuracy': 0.9769, 'precision': 0.40789, 'recall': 0.38272, 'f1': 0.3949, 'auc': 0.81522}
# test: {'epoch': 91, 'time_epoch': 5.97017, 'loss': 0.20760099, 'lr': 0, 'params': 581405, 'time_iter': 0.04628, 'accuracy': 0.96645, 'precision': 0.45, 'recall': 0.27692, 'f1': 0.34286, 'auc': 0.79497}
# > Epoch 91: took 128.2s (avg 127.1s) | Best so far: epoch 58	train_loss: 0.0549 train_auc: 0.9813	val_loss: 0.0975 val_auc: 0.8297	test_loss: 0.1720 test_auc: 0.8005
# train: {'epoch': 92, 'time_epoch': 108.75853, 'eta': 801.06508, 'eta_hours': 0.22252, 'loss': 0.03748828, 'lr': 1.74e-06, 'params': 581405, 'time_iter': 0.10569, 'accuracy': 0.98717, 'precision': 0.89397, 'recall': 0.74594, 'f1': 0.81327, 'auc': 0.99292}
# val: {'epoch': 92, 'time_epoch': 5.92929, 'loss': 0.12299231, 'lr': 0, 'params': 581405, 'time_iter': 0.04596, 'accuracy': 0.97812, 'precision': 0.43662, 'recall': 0.38272, 'f1': 0.40789, 'auc': 0.80875}
# test: {'epoch': 92, 'time_epoch': 5.99341, 'loss': 0.20418911, 'lr': 0, 'params': 581405, 'time_iter': 0.04646, 'accuracy': 0.96548, 'precision': 0.42308, 'recall': 0.25385, 'f1': 0.31731, 'auc': 0.79916}
# > Epoch 92: took 120.8s (avg 127.0s) | Best so far: epoch 58	train_loss: 0.0549 train_auc: 0.9813	val_loss: 0.0975 val_auc: 0.8297	test_loss: 0.1720 test_auc: 0.8005
# train: {'epoch': 93, 'time_epoch': 106.92105, 'eta': 686.14742, 'eta_hours': 0.1906, 'loss': 0.03989349, 'lr': 1.33e-06, 'params': 581405, 'time_iter': 0.10391, 'accuracy': 0.98711, 'precision': 0.87899, 'recall': 0.76055, 'f1': 0.81549, 'auc': 0.99064}
# val: {'epoch': 93, 'time_epoch': 6.00362, 'loss': 0.11728244, 'lr': 0, 'params': 581405, 'time_iter': 0.04654, 'accuracy': 0.97958, 'precision': 0.47692, 'recall': 0.38272, 'f1': 0.42466, 'auc': 0.82125}
# test: {'epoch': 93, 'time_epoch': 6.01428, 'loss': 0.20568496, 'lr': 0, 'params': 581405, 'time_iter': 0.04662, 'accuracy': 0.9662, 'precision': 0.44156, 'recall': 0.26154, 'f1': 0.3285, 'auc': 0.79999}
# > Epoch 93: took 119.1s (avg 126.9s) | Best so far: epoch 58	train_loss: 0.0549 train_auc: 0.9813	val_loss: 0.0975 val_auc: 0.8297	test_loss: 0.1720 test_auc: 0.8005
# train: {'epoch': 94, 'time_epoch': 108.09853, 'eta': 571.46007, 'eta_hours': 0.15874, 'loss': 0.03860351, 'lr': 9.8e-07, 'params': 581405, 'time_iter': 0.10505, 'accuracy': 0.98678, 'precision': 0.87139, 'recall': 0.75893, 'f1': 0.81128, 'auc': 0.99224}
# val: {'epoch': 94, 'time_epoch': 6.05071, 'loss': 0.12359771, 'lr': 0, 'params': 581405, 'time_iter': 0.0469, 'accuracy': 0.97715, 'precision': 0.41558, 'recall': 0.39506, 'f1': 0.40506, 'auc': 0.81433}
# test: {'epoch': 94, 'time_epoch': 5.99762, 'loss': 0.2060715, 'lr': 0, 'params': 581405, 'time_iter': 0.04649, 'accuracy': 0.9645, 'precision': 0.40476, 'recall': 0.26154, 'f1': 0.31776, 'auc': 0.7976}
# > Epoch 94: took 120.3s (avg 126.9s) | Best so far: epoch 58	train_loss: 0.0549 train_auc: 0.9813	val_loss: 0.0975 val_auc: 0.8297	test_loss: 0.1720 test_auc: 0.8005
# train: {'epoch': 95, 'time_epoch': 111.19162, 'eta': 457.03888, 'eta_hours': 0.12696, 'loss': 0.03964654, 'lr': 6.8e-07, 'params': 581405, 'time_iter': 0.10806, 'accuracy': 0.98696, 'precision': 0.87073, 'recall': 0.76542, 'f1': 0.81469, 'auc': 0.99087}
# val: {'epoch': 95, 'time_epoch': 6.0708, 'loss': 0.12627939, 'lr': 0, 'params': 581405, 'time_iter': 0.04706, 'accuracy': 0.97812, 'precision': 0.43836, 'recall': 0.39506, 'f1': 0.41558, 'auc': 0.80958}
# test: {'epoch': 95, 'time_epoch': 6.02202, 'loss': 0.20702215, 'lr': 0, 'params': 581405, 'time_iter': 0.04668, 'accuracy': 0.96742, 'precision': 0.47368, 'recall': 0.27692, 'f1': 0.34951, 'auc': 0.80279}
# > Epoch 95: took 123.4s (avg 126.8s) | Best so far: epoch 58	train_loss: 0.0549 train_auc: 0.9813	val_loss: 0.0975 val_auc: 0.8297	test_loss: 0.1720 test_auc: 0.8005
# train: {'epoch': 96, 'time_epoch': 112.73155, 'eta': 342.73189, 'eta_hours': 0.0952, 'loss': 0.03866248, 'lr': 4.4e-07, 'params': 581405, 'time_iter': 0.10955, 'accuracy': 0.98672, 'precision': 0.8684, 'recall': 0.76055, 'f1': 0.8109, 'auc': 0.99289}
# val: {'epoch': 96, 'time_epoch': 6.12351, 'loss': 0.12359804, 'lr': 0, 'params': 581405, 'time_iter': 0.04747, 'accuracy': 0.97933, 'precision': 0.4697, 'recall': 0.38272, 'f1': 0.42177, 'auc': 0.8105}
# test: {'epoch': 96, 'time_epoch': 6.07635, 'loss': 0.2045875, 'lr': 0, 'params': 581405, 'time_iter': 0.0471, 'accuracy': 0.96669, 'precision': 0.45205, 'recall': 0.25385, 'f1': 0.32512, 'auc': 0.7995}
# > Epoch 96: took 125.1s (avg 126.8s) | Best so far: epoch 58	train_loss: 0.0549 train_auc: 0.9813	val_loss: 0.0975 val_auc: 0.8297	test_loss: 0.1720 test_auc: 0.8005
# train: {'epoch': 97, 'time_epoch': 116.39294, 'eta': 228.53179, 'eta_hours': 0.06348, 'loss': 0.0372344, 'lr': 2.5e-07, 'params': 581405, 'time_iter': 0.11311, 'accuracy': 0.98793, 'precision': 0.8891, 'recall': 0.77435, 'f1': 0.82777, 'auc': 0.99263}
# val: {'epoch': 97, 'time_epoch': 6.45399, 'loss': 0.12735577, 'lr': 0, 'params': 581405, 'time_iter': 0.05003, 'accuracy': 0.97788, 'precision': 0.43243, 'recall': 0.39506, 'f1': 0.4129, 'auc': 0.81369}
# test: {'epoch': 97, 'time_epoch': 6.30012, 'loss': 0.21284722, 'lr': 0, 'params': 581405, 'time_iter': 0.04884, 'accuracy': 0.96523, 'precision': 0.41975, 'recall': 0.26154, 'f1': 0.32227, 'auc': 0.79878}
# > Epoch 97: took 129.3s (avg 126.8s) | Best so far: epoch 58	train_loss: 0.0549 train_auc: 0.9813	val_loss: 0.0975 val_auc: 0.8297	test_loss: 0.1720 test_auc: 0.8005
# train: {'epoch': 98, 'time_epoch': 118.0883, 'eta': 114.3045, 'eta_hours': 0.03175, 'loss': 0.03955568, 'lr': 1.1e-07, 'params': 581405, 'time_iter': 0.11476, 'accuracy': 0.9872, 'precision': 0.87791, 'recall': 0.76461, 'f1': 0.81735, 'auc': 0.9916}
# val: {'epoch': 98, 'time_epoch': 6.33795, 'loss': 0.1196251, 'lr': 0, 'params': 581405, 'time_iter': 0.04913, 'accuracy': 0.97909, 'precision': 0.46269, 'recall': 0.38272, 'f1': 0.41892, 'auc': 0.81131}
# test: {'epoch': 98, 'time_epoch': 6.30715, 'loss': 0.20782437, 'lr': 0, 'params': 581405, 'time_iter': 0.04889, 'accuracy': 0.96645, 'precision': 0.44737, 'recall': 0.26154, 'f1': 0.3301, 'auc': 0.80023}
# > Epoch 98: took 130.9s (avg 126.9s) | Best so far: epoch 58	train_loss: 0.0549 train_auc: 0.9813	val_loss: 0.0975 val_auc: 0.8297	test_loss: 0.1720 test_auc: 0.8005
# train: {'epoch': 99, 'time_epoch': 118.54196, 'eta': 0.0, 'eta_hours': 0.0, 'loss': 0.03868764, 'lr': 3e-08, 'params': 581405, 'time_iter': 0.1152, 'accuracy': 0.98641, 'precision': 0.87063, 'recall': 0.74838, 'f1': 0.80489, 'auc': 0.99256}
# val: {'epoch': 99, 'time_epoch': 6.34538, 'loss': 0.11996874, 'lr': 0, 'params': 581405, 'time_iter': 0.04919, 'accuracy': 0.9769, 'precision': 0.40789, 'recall': 0.38272, 'f1': 0.3949, 'auc': 0.81124}
# test: {'epoch': 99, 'time_epoch': 6.30998, 'loss': 0.20370761, 'lr': 0, 'params': 581405, 'time_iter': 0.04891, 'accuracy': 0.9645, 'precision': 0.40476, 'recall': 0.26154, 'f1': 0.31776, 'auc': 0.79783}
# > Epoch 99: took 131.4s (avg 126.9s) | Best so far: epoch 58	train_loss: 0.0549 train_auc: 0.9813	val_loss: 0.0975 val_auc: 0.8297	test_loss: 0.1720 test_auc: 0.8005
# Avg time per epoch: 126.93s
# Total train loop time: 3.53h
# wandb:
# wandb:
# wandb: Run history:
# wandb:       best/epoch ▁▁▂▂▂▂▂▂▂▂▂▂▂▂▂▅▅▅▅▅▅▅▅█████████████████
# wandb:    best/test_auc ▁▄▄▇▇▇▇▇▇▇▇▇▇███████████████████████████
# wandb:   best/test_loss ▄▃▃▁▁▁▁▁▁▁▁▁▁▁▁▄▄▄▄▄▄▄▄▄▄███████████████
# wandb:   best/train_auc ▁▃▄▄▅▅▅▅▅▅▅▅▇▇▇▇▇▇▇▇▇▇▇▇▇███████████████
# wandb:  best/train_loss █▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:     best/val_auc ▁▂▆▇▇███████████████████████████████████
# wandb:    best/val_loss █▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂
# wandb:    test/accuracy ▅▇█▇▇▇█▇▄▇▇▇▅▆▆▄█▆▆▅▆▄▄▆▇▅▅▃▃▂▂▃▃▃▁▃▄▄▄▃
# wandb:         test/auc ▁▄▅▆█▅▇▇▇▇█▇▆▇▇█▇▇▇▆▇▆██▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇
# wandb:       test/epoch ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇█████
# wandb:          test/f1 ▂▁▄▂▇▇▆▇▇▆▅▇█▇█▇▇▆█▇▇▇▅▇▇▆▇▇▇▇▇▆▆▅▅▇▆▆▆▆
# wandb:        test/loss █▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂
# wandb:          test/lr ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:      test/params ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:   test/precision ▆█▅▅▇▆▅▇▆▃▄▆▃▃▃▂▇▃▄▄▃▂▃▂▃▂▃▃▄▂▂▁▄▁▂▂▂▂▁▁
# wandb:      test/recall ▁▃▆▅▆▆▆▆▆▆▇▇▆▆▆▅▇▆▇▇▆▇▅█▇▆▆▅▆▇▆▆▆▆▆▄▆▆▆▆
# wandb:  test/time_epoch ▅▆█▂▂▂▂▃▄▄▄▄▆▂▅▄▄▃▅▄▄▃▃▄▄▁▁▃▃▄▄▄▂▂▁▁▂▂▅▅
# wandb:   test/time_iter █▄▃▄▅▂▂▂▂▃▃▃▃▄▃▂▃▃▃▃▃▃▃▂▂▂▃▃▁▁▂▂▃▁▁▁▃▃▁▃
# wandb:   train/accuracy ▁▆██████████████████████████████████████
# wandb:        train/auc ▁▂▃▄▄▅▅▆▆▆▇▇▇▇▇▇▇▇█▇████████████████████
# wandb:      train/epoch ▁▁▁▁▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇███
# wandb:        train/eta ██▇▇▇▇▆▆▆▆▆▆▆▆▆▅▅▅▅▅▅▅▅▄▄▄▃▃▃▃▂▂▂▂▂▂▁▁▁▁
# wandb:  train/eta_hours ███▇▇▇▇▇▇▆▆▆▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▁▁
# wandb:         train/f1 ▁▂▃▄▃▄▄▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇█████████████
# wandb:       train/loss █▅▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:         train/lr ▂▄████████▇▇▇▇▇▇▆▆▆▅▅▅▅▄▄▃▃▃▃▃▂▂▂▁▁▁▁▁▁▁
# wandb:     train/params ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:  train/precision ▁▁▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇█▇██████████████
# wandb:     train/recall ▁▁▂▂▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▇▆▇▇▇▇████████████
# wandb: train/time_epoch █▆▆▆▆▄▃▃▃▃▄▆▆▅▆▅▆▆▆▃▅▅▅▆▆▅▅▅▅▄▁▁▅▄▄▄▃▅▅▂
# wandb:  train/time_iter █▇█▆▄▄▃▄▃▅█▇▇▇█▇▇▇▃▃▇▇▇█▇▆▆▇▆▇▂▁▁▅▅▄▃▆▂█
# wandb:     val/accuracy ▁███████████████████████████████████████
# wandb:          val/auc ▁▄▆▇▇▇▇▇▆▇▇█▇▆▆█▇▇▇▇▇▇▇▇████▇▇██▇▇▇▇█▇▇▇
# wandb:        val/epoch ▁▁▁▁▂▂▂▂▂▂▂▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▆▇▇█████
# wandb:           val/f1 ▂▁▅▅▆▇▇▇██▇▇▇▇▇▇▇▇█▇█▇▇▇█▇▇▆▇▇▇▇▇▇█▇▇▇▇▇
# wandb:         val/loss █▃▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▂▁▂▂▂▂▂▂▂▂▂▂▂▂▃▃▃▃▃▃▃▃▃
# wandb:           val/lr ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:       val/params ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:    val/precision ▁▇▆▇█▇▅▆█▇▇▇▇▇▆█▇█▇▇▆▆▇▆▇▆▆▅▆▆▅▆▆▅▆▆▅▆▆▆
# wandb:       val/recall ▁▁▁▂▅▅▆▄▆▆▆▆▆▇▆▇▇▆█▇▆▇▆▆▇▇▇▇█▇▇▇▇▇▇▇▇▇▇▇
# wandb:   val/time_epoch █▂▃▂▄▇▆▆▅▅▄▅▅▅▅▂▂▂▂▅▆▄▃▆▃▄▅▄▃▁▃▄▃▄▂▁▂▂▇▆
# wandb:    val/time_iter █▇▆▃▃▂▂▇▆▆▅▆▆▂▅▅▄▅▄▆▂▅▆▄▅▄▁▁▁▁▄▃▂▂▂▂▆▅▂▇
# wandb:
# wandb: Run summary:
# wandb:          best/epoch 58
# wandb:       best/test_auc 0.80051
# wandb:      best/test_loss 0.17198
# wandb:      best/train_auc 0.98128
# wandb:     best/train_loss 0.05493
# wandb:        best/val_auc 0.82967
# wandb:       best/val_loss 0.09746
# wandb:      best_test_perf 0.80051
# wandb:     best_train_perf 0.98128
# wandb:       best_val_perf 0.82967
# wandb: full_epoch_time_avg 126.92811
# wandb: full_epoch_time_sum 12692.81076
# wandb:       test/accuracy 0.9645
# wandb:            test/auc 0.79783
# wandb:          test/epoch 99
# wandb:             test/f1 0.31776
# wandb:           test/loss 0.20371
# wandb:             test/lr 0
# wandb:         test/params 581405
# wandb:      test/precision 0.40476
# wandb:         test/recall 0.26154
# wandb:     test/time_epoch 6.30998
# wandb:      test/time_iter 0.04891
# wandb:      train/accuracy 0.98641
# wandb:           train/auc 0.99256
# wandb:         train/epoch 99
# wandb:           train/eta 0
# wandb:     train/eta_hours 0
# wandb:            train/f1 0.80489
# wandb:          train/loss 0.03869
# wandb:            train/lr 0.0
# wandb:        train/params 581405
# wandb:     train/precision 0.87063
# wandb:        train/recall 0.74838
# wandb:    train/time_epoch 118.54196
# wandb:     train/time_iter 0.1152
# wandb:        val/accuracy 0.9769
# wandb:             val/auc 0.81124
# wandb:           val/epoch 99
# wandb:              val/f1 0.3949
# wandb:            val/loss 0.11997
# wandb:              val/lr 0
# wandb:          val/params 581405
# wandb:       val/precision 0.40789
# wandb:          val/recall 0.38272
# wandb:      val/time_epoch 6.34538
# wandb:       val/time_iter 0.04919
# wandb:
# wandb: 🚀 View run use_softmax at: https://wandb.ai/omertalmi-tel-aviv-university/molhiv/runs/u9h7h64i
# wandb: ⭐️ View project at: https://wandb.ai/omertalmi-tel-aviv-university/molhiv
# wandb: Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240930_063820-u9h7h64i/logs
# Task done, results saved in results/ogbg-molhiv-GPS/0
# 58
# {'epoch': 58, 'time_epoch': 115.09439, 'eta': 4738.75717, 'eta_hours': 1.31632, 'loss': 0.05493275, 'lr': 4.096e-05, 'params': 581405, 'time_iter': 0.11185, 'accuracy': 0.9814, 'precision': 0.82292, 'recall': 0.64123, 'f1': 0.7208, 'auc': 0.98128}
# {'epoch': 58, 'time_epoch': 6.09332, 'loss': 0.17197783, 'lr': 0, 'params': 581405, 'time_iter': 0.04724, 'accuracy': 0.96791, 'precision': 0.48529, 'recall': 0.25385, 'f1': 0.33333, 'auc': 0.80051}
# {'epoch': 58, 'time_epoch': 6.12994, 'loss': 0.09746163, 'lr': 0, 'params': 581405, 'time_iter': 0.04752, 'accuracy': 0.98055, 'precision': 0.5082, 'recall': 0.38272, 'f1': 0.43662, 'auc': 0.82967}
# Results aggregated across runs saved in results/ogbg-molhiv-GPS/agg
# [*] All done: 2024-09-30 10:09:59.315991
