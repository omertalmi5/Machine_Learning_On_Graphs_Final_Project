# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/torch_scatter-2.1.2-cp310-cp310-linux_x86_64.whl
# /kaggle/input/torch_geometric-2.5.3-py3-none-any.whl
# /kaggle/input/torch_cluster-1.6.3-cp310-cp310-linux_x86_64.whl
# /kaggle/input/torch_spline_conv-1.2.2-cp310-cp310-linux_x86_64.whl
# /kaggle/input/torch_sparse-0.6.18-cp310-cp310-linux_x86_64.whl

# %%
# !git clone https://github.com/rampasek/GraphGPS.git
# Out:
# Cloning into 'GraphGPS'...
# remote: Enumerating objects: 526, done.
# remote: Counting objects: 100% (350/350), done.
# remote: Compressing objects: 100% (109/109), done.
# remote: Total 526 (delta 271), reused 241 (delta 241), pack-reused 176 (from 1)
# Receiving objects: 100% (526/526), 12.93 MiB | 21.99 MiB/s, done.
# Resolving deltas: 100% (337/337), done.

# %%
# %cd /kaggle/working/GraphGPS
# !ls
# Out:
# /kaggle/working/GraphGPS
#
# GraphGPS.png  README.md  final-results.zip  main.py  setup.py  unittests
#
# LICENSE       configs	 graphgps	    run      tests

# %% [markdown]
# ##  installation for slurm if needed using conda

# %%
# # for slurm if needed using conda 
# conda create -n graphgps python=3.10
# conda activate graphgps

# conda install pytorch=1.13 torchvision torchaudio pytorch-cuda=11.7 -c pytorch -c nvidia
# conda install pyg=2.2 -c pyg -c conda-forge
# pip install pyg-lib -f https://data.pyg.org/whl/torch-1.13.0+cu117.html

# # RDKit is required for OGB-LSC PCQM4Mv2 and datasets derived from it.  
# conda install openbabel fsspec rdkit -c conda-forge

# pip install pytorch-lightning yacs torchmetrics
# pip install performer-pytorch
# pip install tensorboardX
# pip install ogb
# pip install wandb

# conda clean --all

# %% [markdown]
# # installation for kaggle

# %%
# Check existing environment
import sys
print("Python version:", sys.version)
import torch
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)

# !pip uninstall -y torch torchvision torchaudio
# !pip install torch==2.0.1+cu118 torchvision==0.15.2+cu118 torchaudio==2.0.2+cu118 --index-url https://download.pytorch.org/whl/cu118

# !pip install torch_geometric

# Optional dependencies:
# !pip install pyg_lib torch_scatter torch_sparse torch_cluster torch_spline_conv -f https://data.pyg.org/whl/torch-2.4.0+cu124.html
# Install other required packages
# !pip install pytorch-lightning yacs torchmetrics
# !pip install performer-pytorch
# !pip install tensorboardX
# !pip install ogb
# !pip install wandb

# Attempt to install RDKit (may have limitations)
# !pip install rdkit-pypi
# !pip install openbabel fsspec
# !pip install  fsspec

# Clean up pip cache (optional)
# !pip cache purge
# Out:
# Python version: 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:45:18) [GCC 12.3.0]
# PyTorch version: 2.4.0
# CUDA available: True
# CUDA version: 12.3
# Found existing installation: torch 2.4.0
# Uninstalling torch-2.4.0:
#   Successfully uninstalled torch-2.4.0
# Found existing installation: torchvision 0.19.0
# Uninstalling torchvision-0.19.0:
#   Successfully uninstalled torchvision-0.19.0
# Found existing installation: torchaudio 2.4.0
# Uninstalling torchaudio-2.4.0:
#   Successfully uninstalled torchaudio-2.4.0
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Collecting torch==2.0.1+cu118
#   Downloading https://download.pytorch.org/whl/cu118/torch-2.0.1%2Bcu118-cp310-cp310-linux_x86_64.whl (2267.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 GB 377.1 kB/s eta 0:00:0000:0100:01
# Collecting torchvision==0.15.2+cu118
#   Downloading https://download.pytorch.org/whl/cu118/torchvision-0.15.2%2Bcu118-cp310-cp310-linux_x86_64.whl (6.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 79.2 MB/s eta 0:00:00:00:0100:01
# Collecting torchaudio==2.0.2+cu118
#   Downloading https://download.pytorch.org/whl/cu118/torchaudio-2.0.2%2Bcu118-cp310-cp310-linux_x86_64.whl (4.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 80.9 MB/s eta 0:00:00:00:01
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch==2.0.1+cu118) (3.15.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch==2.0.1+cu118) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch==2.0.1+cu118) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch==2.0.1+cu118) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch==2.0.1+cu118) (3.1.4)
# Collecting triton==2.0.0 (from torch==2.0.1+cu118)
#   Downloading https://download.pytorch.org/whl/triton-2.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 24.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision==0.15.2+cu118) (1.26.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torchvision==0.15.2+cu118) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision==0.15.2+cu118) (10.3.0)
# Collecting cmake (from triton==2.0.0->torch==2.0.1+cu118)
#   Downloading https://download.pytorch.org/whl/cmake-3.25.0-py2.py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 63.6 MB/s eta 0:00:0000:0100:01
# Collecting lit (from triton==2.0.0->torch==2.0.1+cu118)
#   Downloading https://download.pytorch.org/whl/lit-15.0.7.tar.gz (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.3/132.3 kB 9.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch==2.0.1+cu118) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.15.2+cu118) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.15.2+cu118) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.15.2+cu118) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.15.2+cu118) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch==2.0.1+cu118) (1.3.0)
# Building wheels for collected packages: lit
#   Building wheel for lit (setup.py) ... done
#   Created wheel for lit: filename=lit-15.0.7-py3-none-any.whl size=89987 sha256=0daec9c15997870b525db020a60ede9b6e7655b64460150886f99ada89b10bdc
#   Stored in directory: /root/.cache/pip/wheels/27/2c/b6/3ed2983b1b44fe0dea1bb35234b09f2c22fb8ebb308679c922
# Successfully built lit
# Installing collected packages: lit, cmake, triton, torch, torchvision, torchaudio
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytorch-lightning 2.4.0 requires torch>=2.1.0, but you have torch 2.0.1+cu118 which is incompatible.
# Successfully installed cmake-3.25.0 lit-15.0.7 torch-2.0.1+cu118 torchaudio-2.0.2+cu118 torchvision-0.15.2+cu118 triton-2.0.0
# Collecting torch_geometric
#   Downloading torch_geometric-2.6.1-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (3.9.5)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (2024.6.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (3.1.4)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (1.26.4)
# Requirement already satisfied: psutil>=5.8.0 in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (5.9.3)
# Requirement already satisfied: pyparsing in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (3.1.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (2.32.3)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (4.66.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch_geometric) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (2024.8.30)
# Downloading torch_geometric-2.6.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 21.0 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: torch_geometric
# Successfully installed torch_geometric-2.6.1
# Looking in links: https://data.pyg.org/whl/torch-2.4.0+cu124.html
# Collecting pyg_lib
#   Downloading https://data.pyg.org/whl/torch-2.4.0%2Bcu124/pyg_lib-0.4.0%2Bpt24cu124-cp310-cp310-linux_x86_64.whl (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 2.3 MB/s eta 0:00:00a 0:00:010m
# Collecting torch_scatter
#   Downloading https://data.pyg.org/whl/torch-2.4.0%2Bcu124/torch_scatter-2.1.2%2Bpt24cu124-cp310-cp310-linux_x86_64.whl (10.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 86.3 MB/s eta 0:00:0000:0100:01
# Collecting torch_sparse
#   Downloading https://data.pyg.org/whl/torch-2.4.0%2Bcu124/torch_sparse-0.6.18%2Bpt24cu124-cp310-cp310-linux_x86_64.whl (5.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 85.5 MB/s eta 0:00:00:00:01
# Collecting torch_cluster
#   Downloading https://data.pyg.org/whl/torch-2.4.0%2Bcu124/torch_cluster-1.6.3%2Bpt24cu124-cp310-cp310-linux_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 80.5 MB/s eta 0:00:00:00:01
# Collecting torch_spline_conv
#   Downloading https://data.pyg.org/whl/torch-2.4.0%2Bcu124/torch_spline_conv-1.2.2%2Bpt24cu124-cp310-cp310-linux_x86_64.whl (992 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 992.4/992.4 kB 3.4 MB/s eta 0:00:0000:01
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from torch_sparse) (1.14.1)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in /opt/conda/lib/python3.10/site-packages (from scipy->torch_sparse) (1.26.4)
# Installing collected packages: torch_spline_conv, torch_scatter, pyg_lib, torch_sparse, torch_cluster
# Successfully installed pyg_lib-0.4.0+pt24cu124 torch_cluster-1.6.3+pt24cu124 torch_scatter-2.1.2+pt24cu124 torch_sparse-0.6.18+pt24cu124 torch_spline_conv-1.2.2+pt24cu124
# Requirement already satisfied: pytorch-lightning in /opt/conda/lib/python3.10/site-packages (2.4.0)
# Collecting yacs
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: torchmetrics in /opt/conda/lib/python3.10/site-packages (1.4.2)
# Collecting torch>=2.1.0 (from pytorch-lightning)
#   Downloading torch-2.4.1-cp310-cp310-manylinux1_x86_64.whl.metadata (26 kB)
# Requirement already satisfied: tqdm>=4.57.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (4.66.4)
# Requirement already satisfied: PyYAML>=5.4 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (6.0.2)
# Requirement already satisfied: fsspec>=2022.5.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (2024.6.1)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (21.3)
# Requirement already satisfied: typing-extensions>=4.4.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (4.12.2)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (0.11.7)
# Requirement already satisfied: numpy>1.20.0 in /opt/conda/lib/python3.10/site-packages (from torchmetrics) (1.26.4)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (3.9.5)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from lightning-utilities>=0.10.0->pytorch-lightning) (70.0.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->pytorch-lightning) (3.1.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=2.1.0->pytorch-lightning) (3.15.1)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=2.1.0->pytorch-lightning) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=2.1.0->pytorch-lightning) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=2.1.0->pytorch-lightning) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.0.0 (from torch>=2.1.0->pytorch-lightning)
#   Downloading triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_nvjitlink_cu12-12.6.68-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=2.1.0->pytorch-lightning) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=2.1.0->pytorch-lightning) (1.3.0)
# Requirement already satisfied: idna>=2.0 in /opt/conda/lib/python3.10/site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (3.7)
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Downloading torch-2.4.1-cp310-cp310-manylinux1_x86_64.whl (797.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.1/797.1 MB 2.0 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.8 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 80.2 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 75.9 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 43.6 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 2.4 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 6.6 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 13.7 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 8.3 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 8.1 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 6.2 MB/s eta 0:00:00
# Downloading triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (209.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 7.7 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.6.68-py3-none-manylinux2014_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 76.2 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: yacs, triton, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch
#   Attempting uninstall: triton
#     Found existing installation: triton 2.0.0
#     Uninstalling triton-2.0.0:
#       Successfully uninstalled triton-2.0.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.1+cu118
#     Uninstalling torch-2.0.1+cu118:
#       Successfully uninstalled torch-2.0.1+cu118
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.0.2+cu118 requires torch==2.0.1, but you have torch 2.4.1 which is incompatible.
# torchvision 0.15.2+cu118 requires torch==2.0.1, but you have torch 2.4.1 which is incompatible.
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.6.68 nvidia-nvtx-cu12-12.1.105 torch-2.4.1 triton-3.0.0 yacs-0.1.8
# Collecting performer-pytorch
#   Downloading performer_pytorch-1.1.4-py3-none-any.whl.metadata (763 bytes)
# Collecting einops>=0.3 (from performer-pytorch)
#   Downloading einops-0.8.0-py3-none-any.whl.metadata (12 kB)
# Collecting local-attention>=1.1.1 (from performer-pytorch)
#   Downloading local_attention-1.9.15-py3-none-any.whl.metadata (683 bytes)
# Requirement already satisfied: torch>=1.6 in /opt/conda/lib/python3.10/site-packages (from performer-pytorch) (2.4.1)
# Collecting axial-positional-embedding>=0.1.0 (from performer-pytorch)
#   Downloading axial_positional_embedding-0.2.1.tar.gz (2.6 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.6->performer-pytorch) (12.6.68)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.6->performer-pytorch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.6->performer-pytorch) (1.3.0)
# Downloading performer_pytorch-1.1.4-py3-none-any.whl (13 kB)
# Downloading einops-0.8.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 2.9 MB/s eta 0:00:00
# Downloading local_attention-1.9.15-py3-none-any.whl (9.0 kB)
# Building wheels for collected packages: axial-positional-embedding
#   Building wheel for axial-positional-embedding (setup.py) ... done
#   Created wheel for axial-positional-embedding: filename=axial_positional_embedding-0.2.1-py3-none-any.whl size=2889 sha256=3f9053a878c9452a7443e793a9da010850de8bd8e0b3a625116eade2baecc7f2
#   Stored in directory: /root/.cache/pip/wheels/b1/cb/39/7ce7ff2d2fd37cfe1fe7b3a3c43cf410632b2ad3b3f3986d73
# Successfully built axial-positional-embedding
# Installing collected packages: einops, local-attention, axial-positional-embedding, performer-pytorch
# Successfully installed axial-positional-embedding-0.2.1 einops-0.8.0 local-attention-1.9.15 performer-pytorch-1.1.4
# Requirement already satisfied: tensorboardX in /opt/conda/lib/python3.10/site-packages (2.6.2.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from tensorboardX) (1.26.4)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorboardX) (21.3)
# Requirement already satisfied: protobuf>=3.20 in /opt/conda/lib/python3.10/site-packages (from tensorboardX) (3.20.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->tensorboardX) (3.1.2)
# Collecting ogb
#   Downloading ogb-1.3.6-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: torch>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (2.4.1)
# Requirement already satisfied: numpy>=1.16.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (1.26.4)
# Requirement already satisfied: tqdm>=4.29.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (4.66.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (1.2.2)
# Requirement already satisfied: pandas>=0.24.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (2.2.2)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (1.16.0)
# Requirement already satisfied: urllib3>=1.24.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (1.26.18)
# Collecting outdated>=0.2.0 (from ogb)
#   Downloading outdated-0.2.2-py2.py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: setuptools>=44 in /opt/conda/lib/python3.10/site-packages (from outdated>=0.2.0->ogb) (70.0.0)
# Collecting littleutils (from outdated>=0.2.0->ogb)
#   Downloading littleutils-0.2.4-py3-none-any.whl.metadata (679 bytes)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from outdated>=0.2.0->ogb) (2.32.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24.0->ogb) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24.0->ogb) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24.0->ogb) (2024.1)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.20.0->ogb) (1.14.1)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.20.0->ogb) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.20.0->ogb) (3.5.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.6.0->ogb) (12.6.68)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.6.0->ogb) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->outdated>=0.2.0->ogb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->outdated>=0.2.0->ogb) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->outdated>=0.2.0->ogb) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.6.0->ogb) (1.3.0)
# Downloading ogb-1.3.6-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 4.1 MB/s eta 0:00:00
# Downloading outdated-0.2.2-py2.py3-none-any.whl (7.5 kB)
# Downloading littleutils-0.2.4-py3-none-any.whl (8.1 kB)
# Installing collected packages: littleutils, outdated, ogb
# Successfully installed littleutils-0.2.4 ogb-1.3.6 outdated-0.2.2
# Requirement already satisfied: wandb in /opt/conda/lib/python3.10/site-packages (0.18.1)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /opt/conda/lib/python3.10/site-packages (from wandb) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.1.43)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.10/site-packages (from wandb) (3.11.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.20.3)
# Requirement already satisfied: psutil>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from wandb) (6.0.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.32.3)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.14.0)
# Requirement already satisfied: setproctitle in /opt/conda/lib/python3.10/site-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from wandb) (70.0.0)
# Requirement already satisfied: six>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2024.8.30)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.1)
# Collecting rdkit-pypi
#   Downloading rdkit_pypi-2022.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from rdkit-pypi) (1.26.4)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from rdkit-pypi) (10.3.0)
# Downloading rdkit_pypi-2022.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 52.4 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: rdkit-pypi
# Successfully installed rdkit-pypi-2022.9.5
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (2024.6.1)
# Files removed: 184

# %%
import sys
print("Python version:", sys.version)
import torch
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)
# Out:
# Python version: 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:45:18) [GCC 12.3.0]
# PyTorch version: 2.4.0
# CUDA available: True
# CUDA version: 12.3

# %%
import torch_geometric
print("PyG version:", torch_geometric.__version__)

import pytorch_lightning
print("PyTorch Lightning version:", pytorch_lightning.__version__)

import rdkit
print("RDKit version:", rdkit.__version__)
# Out:
# /opt/conda/lib/python3.10/site-packages/torch_geometric/typing.py:68: UserWarning: An issue occurred while importing 'pyg-lib'. Disabling its usage. Stacktrace: /opt/conda/lib/python3.10/site-packages/libpyg.so: undefined symbol: _ZNK5torch8autograd4Node4nameEv
#   warnings.warn(f"An issue occurred while importing 'pyg-lib'. "
# /opt/conda/lib/python3.10/site-packages/torch_geometric/typing.py:86: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: /opt/conda/lib/python3.10/site-packages/torch_scatter/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
#   warnings.warn(f"An issue occurred while importing 'torch-scatter'. "
# /opt/conda/lib/python3.10/site-packages/torch_geometric/typing.py:97: UserWarning: An issue occurred while importing 'torch-cluster'. Disabling its usage. Stacktrace: /opt/conda/lib/python3.10/site-packages/torch_cluster/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
#   warnings.warn(f"An issue occurred while importing 'torch-cluster'. "
# /opt/conda/lib/python3.10/site-packages/torch_geometric/typing.py:113: UserWarning: An issue occurred while importing 'torch-spline-conv'. Disabling its usage. Stacktrace: /opt/conda/lib/python3.10/site-packages/torch_spline_conv/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torch_geometric/typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: /opt/conda/lib/python3.10/site-packages/torch_sparse/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
#   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "
# PyG version: 2.6.1
# PyTorch Lightning version: 2.4.0
# RDKit version: 2022.09.5

# %%
print("Torch version:", torch.__version__)
# Out:
# Torch version: 2.4.0

# %% [markdown]
# # Running their model- GPSConv

# %%
# %cd /kaggle/working/GraphGPS
# !WANDB_MODE=disabled python main.py --cfg configs/GPS/ogbg-molhiv-GPS.yaml

# %% [markdown]
# # Our Model - WeightedGraphGPS

# %%
#clone for our project
# %cd /kaggle/working
# !git clone --branch add_residual https://github.com/omertalmi5/WeightedGraphGPS.git
# Out:
# /kaggle/working
# Cloning into 'WeightedGraphGPS'...
# remote: Enumerating objects: 775, done.
# remote: Counting objects: 100% (530/530), done.
# remote: Compressing objects: 100% (182/182), done.
# remote: Total 775 (delta 440), reused 348 (delta 348), pack-reused 245 (from 1)
# Receiving objects: 100% (775/775), 13.04 MiB | 25.69 MiB/s, done.
# Resolving deltas: 100% (529/529), done.

# %%
# !pip install wandb
# Out:
# Requirement already satisfied: wandb in /opt/conda/lib/python3.10/site-packages (0.18.1)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /opt/conda/lib/python3.10/site-packages (from wandb) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.1.43)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.10/site-packages (from wandb) (3.11.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.20.3)
# Requirement already satisfied: psutil>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from wandb) (6.0.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.32.3)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.14.0)
# Requirement already satisfied: setproctitle in /opt/conda/lib/python3.10/site-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from wandb) (70.0.0)
# Requirement already satisfied: six>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2024.8.30)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.1)

# %%
# !wandb login 5f1c292fde40243d281618fe88d712346cfe90d7
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
import os
# Set the environment variable
os.environ['USERNAME'] = "omertalmi-tel-aviv-university"

# %%
# %cd /kaggle/working/WeightedGraphGPS
os.environ['BRANCH_NAME']= os.popen('git rev-parse --abbrev-ref HEAD').read().strip()
# !WANDB_MODE=online python main.py --cfg configs/GPS/ogbg-molhiv-GPS.yaml wandb.use True wandb.entity $USERNAME wandb.name $BRANCH_NAME
# Out:
# /kaggle/working/WeightedGraphGPS
# [*] Run ID 0: seed=0, split_index=0
#     Starting now: 2024-09-30 16:29:29.740498
# Downloading http://snap.stanford.edu/ogb/data/graphproppred/csv_mol_download/hiv.zip
# Downloaded 0.00 GB: 100%|█████████████████████████| 3/3 [00:03<00:00,  1.00s/it]
# Extracting ./datasets/hiv.zip
# Processing...
# Loading necessary files...
# This might take a while.
# Processing graphs...
# 100%|██████████████████████████████████| 41127/41127 [00:00<00:00, 61804.23it/s]
# Converting graphs into PyG objects...
# 100%|██████████████████████████████████| 41127/41127 [00:02<00:00, 18841.14it/s]
# Saving...
# Done!
# /opt/conda/lib/python3.10/site-packages/ogb/graphproppred/dataset_pyg.py:68: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.data, self.slices = torch.load(self.processed_paths[0])
# [*] Loaded dataset 'ogbg-molhiv' from 'OGB':
# /opt/conda/lib/python3.10/site-packages/torch_geometric/data/in_memory_dataset.py:300: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
#   Data(edge_index=[2, 2259376], edge_attr=[2259376, 3], x=[1049163, 9], y=[41127, 1], num_nodes=1049163)
#   undirected: True
#   num graphs: 41127
# /opt/conda/lib/python3.10/site-packages/torch_geometric/data/in_memory_dataset.py:300: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. The data of the dataset is already cached, so any modifications to `data` will not be reflected when accessing its elements. Clearing the cache now by removing all elements in `dataset._data_list`. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
#   avg num_nodes/graph: 25
#   num node features: 9
#   num edge features: 3
#   num tasks: 1
#   num classes: 2
# Precomputing Positional Encoding statistics: ['LapPE'] for all graphs...
#   ...estimated to be undirected: True
# 100%|████████████████████████████████████| 41127/41127 [00:52<00:00, 789.92it/s]
# Done! Took 00:00:53.62
# GraphGymModule(
#   (model): GPSModel(
#     (encoder): FeatureEncoder(
#       (node_encoder): Concat2NodeEncoder(
#         (encoder1): AtomEncoder(
#           (atom_embedding_list): ModuleList(
#             (0): Embedding(119, 56)
#             (1): Embedding(5, 56)
#             (2-3): 2 x Embedding(12, 56)
#             (4): Embedding(10, 56)
#             (5-6): 2 x Embedding(6, 56)
#             (7-8): 2 x Embedding(2, 56)
#           )
#         )
#         (encoder2): LapPENodeEncoder(
#           (linear_A): Linear(in_features=2, out_features=16, bias=True)
#           (pe_encoder): Sequential(
#             (0): ReLU()
#             (1): Linear(in_features=16, out_features=8, bias=True)
#             (2): ReLU()
#           )
#         )
#       )
#       (edge_encoder): BondEncoder(
#         (bond_embedding_list): ModuleList(
#           (0): Embedding(5, 64)
#           (1): Embedding(6, 64)
#           (2): Embedding(2, 64)
#         )
#       )
#     )
#     (layers): Sequential(
#       (0): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (gating_conv1): GCNConv(64, 32)
#         (gating_relu): ReLU()
#         (gating_conv2): GCNConv(32, 1)
#         (gating_sigmoid): Sigmoid()
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (1): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (gating_conv1): GCNConv(64, 32)
#         (gating_relu): ReLU()
#         (gating_conv2): GCNConv(32, 1)
#         (gating_sigmoid): Sigmoid()
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (2): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (gating_conv1): GCNConv(64, 32)
#         (gating_relu): ReLU()
#         (gating_conv2): GCNConv(32, 1)
#         (gating_sigmoid): Sigmoid()
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (3): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (gating_conv1): GCNConv(64, 32)
#         (gating_relu): ReLU()
#         (gating_conv2): GCNConv(32, 1)
#         (gating_sigmoid): Sigmoid()
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (4): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (gating_conv1): GCNConv(64, 32)
#         (gating_relu): ReLU()
#         (gating_conv2): GCNConv(32, 1)
#         (gating_sigmoid): Sigmoid()
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (5): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (gating_conv1): GCNConv(64, 32)
#         (gating_relu): ReLU()
#         (gating_conv2): GCNConv(32, 1)
#         (gating_sigmoid): Sigmoid()
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (6): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (gating_conv1): GCNConv(64, 32)
#         (gating_relu): ReLU()
#         (gating_conv2): GCNConv(32, 1)
#         (gating_sigmoid): Sigmoid()
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (7): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (gating_conv1): GCNConv(64, 32)
#         (gating_relu): ReLU()
#         (gating_conv2): GCNConv(32, 1)
#         (gating_sigmoid): Sigmoid()
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (8): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (gating_conv1): GCNConv(64, 32)
#         (gating_relu): ReLU()
#         (gating_conv2): GCNConv(32, 1)
#         (gating_sigmoid): Sigmoid()
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (9): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (gating_conv1): GCNConv(64, 32)
#         (gating_relu): ReLU()
#         (gating_conv2): GCNConv(32, 1)
#         (gating_sigmoid): Sigmoid()
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#     )
#     (post_mp): SANGraphHead(
#       (FC_layers): ModuleList(
#         (0): Linear(in_features=64, out_features=32, bias=True)
#         (1): Linear(in_features=32, out_features=16, bias=True)
#         (2): Linear(in_features=16, out_features=1, bias=True)
#       )
#       (activation): ReLU()
#     )
#   )
# )
# accelerator: cuda
# benchmark: False
# bn:
#   eps: 1e-05
#   mom: 0.1
# cfg_dest: config.yaml
# custom_metrics: []
# dataset:
#   cache_load: False
#   cache_save: False
#   dir: ./datasets
#   edge_dim: 128
#   edge_encoder: True
#   edge_encoder_bn: False
#   edge_encoder_name: Bond
#   edge_encoder_num_types: 0
#   edge_message_ratio: 0.8
#   edge_negative_sampling_ratio: 1.0
#   edge_train_mode: all
#   encoder: True
#   encoder_bn: True
#   encoder_dim: 128
#   encoder_name: db
#   format: OGB
#   infer_link_label: None
#   label_column: none
#   label_table: none
#   location: local
#   name: ogbg-molhiv
#   node_encoder: True
#   node_encoder_bn: False
#   node_encoder_name: Atom+LapPE
#   node_encoder_num_types: 0
#   remove_feature: False
#   resample_disjoint: False
#   resample_negative: False
#   shuffle_split: True
#   slic_compactness: 10
#   split: [0.8, 0.1, 0.1]
#   split_dir: ./splits
#   split_index: 0
#   split_mode: standard
#   task: graph
#   task_type: classification
#   to_undirected: False
#   transductive: False
#   transform: none
#   tu_simple: True
# devices: 1
# example_arg: example
# example_group:
#   example_arg: example
# gnn:
#   act: relu
#   agg: mean
#   att_final_linear: False
#   att_final_linear_bn: False
#   att_heads: 1
#   batchnorm: True
#   clear_feature: True
#   dim_edge: 64
#   dim_inner: 64
#   dropout: 0.0
#   head: san_graph
#   keep_edge: 0.5
#   l2norm: True
#   layer_type: generalconv
#   layers_mp: 2
#   layers_post_mp: 3
#   layers_pre_mp: 0
#   msg_direction: single
#   normalize_adj: False
#   residual: False
#   self_msg: concat
#   skip_every: 1
#   stage_type: stack
# gpu_mem: False
# graphormer:
#   attention_dropout: 0.0
#   dropout: 0.0
#   embed_dim: 80
#   input_dropout: 0.0
#   mlp_dropout: 0.0
#   num_heads: 4
#   num_layers: 6
#   use_graph_token: True
# gt:
#   attn_dropout: 0.5
#   batch_norm: True
#   bigbird:
#     add_cross_attention: False
#     attention_type: block_sparse
#     block_size: 3
#     chunk_size_feed_forward: 0
#     hidden_act: relu
#     is_decoder: False
#     layer_norm_eps: 1e-06
#     max_position_embeddings: 128
#     num_random_blocks: 3
#     use_bias: False
#   dim_hidden: 64
#   dropout: 0.05
#   full_graph: True
#   gamma: 1e-05
#   layer_norm: False
#   layer_type: CustomGatedGCN+Transformer
#   layers: 10
#   n_heads: 4
#   pna_degrees: []
#   residual: True
# mem:
#   inplace: False
# metric_agg: argmax
# metric_best: auc
# model:
#   edge_decoding: dot
#   graph_pooling: mean
#   loss_fun: cross_entropy
#   match_upper: True
#   size_average: mean
#   thresh: 0.5
#   type: GPSModel
# name_tag:
# num_threads: 6
# num_workers: 0
# optim:
#   base_lr: 0.0001
#   batch_accumulation: 1
#   clip_grad_norm: True
#   clip_grad_norm_value: 1.0
#   lr_decay: 0.1
#   max_epoch: 100
#   min_lr: 0.0
#   momentum: 0.9
#   num_warmup_epochs: 5
#   optimizer: adamW
#   reduce_factor: 0.1
#   schedule_patience: 10
#   scheduler: cosine_with_warmup
#   steps: [30, 60, 90]
#   weight_decay: 1e-05
# out_dir: results/ogbg-molhiv-GPS
# posenc_ElstaticSE:
#   dim_pe: 16
#   enable: False
#   kernel:
#     times: []
#     times_func: range(10)
#   layers: 3
#   model: none
#   n_heads: 4
#   pass_as_var: False
#   post_layers: 0
#   raw_norm_type: none
# posenc_EquivStableLapPE:
#   eigen:
#     eigvec_norm: L2
#     laplacian_norm: sym
#     max_freqs: 10
#   enable: False
#   raw_norm_type: none
# posenc_GraphormerBias:
#   dim_pe: 0
#   enable: False
#   node_degrees_only: False
#   num_in_degrees: None
#   num_out_degrees: None
#   num_spatial_types: None
# posenc_HKdiagSE:
#   dim_pe: 16
#   enable: False
#   kernel:
#     times: []
#     times_func:
#   layers: 3
#   model: none
#   n_heads: 4
#   pass_as_var: False
#   post_layers: 0
#   raw_norm_type: none
# posenc_LapPE:
#   dim_pe: 8
#   eigen:
#     eigvec_norm: L2
#     laplacian_norm: none
#     max_freqs: 8
#   enable: True
#   layers: 2
#   model: DeepSet
#   n_heads: 4
#   pass_as_var: False
#   post_layers: 0
#   raw_norm_type: none
# posenc_RWSE:
#   dim_pe: 16
#   enable: False
#   kernel:
#     times: []
#     times_func:
#   layers: 3
#   model: none
#   n_heads: 4
#   pass_as_var: False
#   post_layers: 0
#   raw_norm_type: none
# posenc_SignNet:
#   dim_pe: 16
#   eigen:
#     eigvec_norm: L2
#     laplacian_norm: sym
#     max_freqs: 10
#   enable: False
#   layers: 3
#   model: none
#   n_heads: 4
#   pass_as_var: False
#   phi_hidden_dim: 64
#   phi_out_dim: 4
#   post_layers: 0
#   raw_norm_type: none
# pretrained:
#   dir:
#   freeze_main: False
#   reset_prediction_head: True
# print: both
# round: 5
# run_dir: results/ogbg-molhiv-GPS/0
# run_id: 0
# run_multiple_splits: []
# seed: 0
# share:
#   dim_in: 9
#   dim_out: 2
#   num_splits: 3
# tensorboard_agg: True
# tensorboard_each_run: False
# train:
#   auto_resume: False
#   batch_size: 32
#   ckpt_best: False
#   ckpt_clean: True
#   ckpt_period: 100
#   enable_ckpt: True
#   epoch_resume: -1
#   eval_period: 1
#   iter_per_epoch: 32
#   mode: custom
#   neighbor_sizes: [20, 15, 10, 5]
#   node_per_graph: 32
#   radius: extend
#   sample_node: False
#   sampler: full_batch
#   skip_train_eval: False
#   walk_length: 4
# val:
#   node_per_graph: 32
#   radius: extend
#   sample_node: False
#   sampler: full_batch
# view_emb: False
# wandb:
#   entity: omertalmi-tel-aviv-university
#   name: add_residual
#   project: molhiv
#   use: True
# Num parameters: 581095
# Start from epoch 0
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: omertalmi- (omertalmi-tel-aviv-university). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.1
# wandb: Run data is saved locally in /kaggle/working/WeightedGraphGPS/wandb/run-20240930_163041-r1voazyo
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run add_residual
# wandb: ⭐️ View project at https://wandb.ai/omertalmi-tel-aviv-university/molhiv
# wandb: 🚀 View run at https://wandb.ai/omertalmi-tel-aviv-university/molhiv/runs/r1voazyo
# Key posenc_GraphormerBias.num_spatial_types with value <class 'NoneType'> is not a valid type; valid types: {<class 'list'>, <class 'str'>, <class 'bool'>, <class 'int'>, <class 'float'>, <class 'tuple'>}
# Key posenc_GraphormerBias.num_in_degrees with value <class 'NoneType'> is not a valid type; valid types: {<class 'list'>, <class 'str'>, <class 'bool'>, <class 'int'>, <class 'float'>, <class 'tuple'>}
# Key posenc_GraphormerBias.num_out_degrees with value <class 'NoneType'> is not a valid type; valid types: {<class 'list'>, <class 'str'>, <class 'bool'>, <class 'int'>, <class 'float'>, <class 'tuple'>}
# train: {'epoch': 0, 'time_epoch': 112.02714, 'eta': 11090.68673, 'eta_hours': 3.08075, 'loss': 0.70274595, 'lr': 0.0, 'params': 581095, 'time_iter': 0.10887, 'accuracy': 0.11519, 'precision': 0.03841, 'recall': 0.94156, 'f1': 0.07381, 'auc': 0.5079}
# ...computing epoch stats took: 0.09s
# val: {'epoch': 0, 'time_epoch': 6.68572, 'loss': 0.7043007, 'lr': 0, 'params': 581095, 'time_iter': 0.05183, 'accuracy': 0.07853, 'precision': 0.02043, 'recall': 0.97531, 'f1': 0.04002, 'auc': 0.49221}
# ...computing epoch stats took: 0.01s
# test: {'epoch': 0, 'time_epoch': 7.0355, 'loss': 0.70334257, 'lr': 0, 'params': 581095, 'time_iter': 0.05454, 'accuracy': 0.14102, 'precision': 0.03345, 'recall': 0.93846, 'f1': 0.0646, 'auc': 0.48325}
# ...computing epoch stats took: 0.01s
# > Epoch 0: took 125.9s (avg 125.9s) | Best so far: epoch 0	train_loss: 0.7027 train_auc: 0.5079	val_loss: 0.7043 val_auc: 0.4922	test_loss: 0.7033 test_auc: 0.4833
# train: {'epoch': 1, 'time_epoch': 106.39849, 'eta': 10702.85571, 'eta_hours': 2.97302, 'loss': 0.40259422, 'lr': 2e-05, 'params': 581095, 'time_iter': 0.1034, 'accuracy': 0.90453, 'precision': 0.05994, 'recall': 0.10552, 'f1': 0.07645, 'auc': 0.57515}
# ...computing epoch stats took: 0.07s
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 1, 'time_epoch': 5.988, 'loss': 0.17903399, 'lr': 0, 'params': 581095, 'time_iter': 0.04642, 'accuracy': 0.98031, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.70794}
# ...computing epoch stats took: 0.02s
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# test: {'epoch': 1, 'time_epoch': 5.95833, 'loss': 0.18642047, 'lr': 0, 'params': 581095, 'time_iter': 0.04619, 'accuracy': 0.96839, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.72769}
# ...computing epoch stats took: 0.01s
# > Epoch 1: took 118.5s (avg 122.2s) | Best so far: epoch 1	train_loss: 0.4026 train_auc: 0.5752	val_loss: 0.1790 val_auc: 0.7079	test_loss: 0.1864 test_auc: 0.7277
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# train: {'epoch': 2, 'time_epoch': 106.30433, 'eta': 10499.60183, 'eta_hours': 2.91656, 'loss': 0.15765777, 'lr': 4e-05, 'params': 581095, 'time_iter': 0.10331, 'accuracy': 0.96255, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.66685}
# ...computing epoch stats took: 0.05s
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 2, 'time_epoch': 5.93847, 'loss': 0.09004626, 'lr': 0, 'params': 581095, 'time_iter': 0.04603, 'accuracy': 0.98031, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.74219}
# ...computing epoch stats took: 0.01s
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# test: {'epoch': 2, 'time_epoch': 5.96224, 'loss': 0.12051979, 'lr': 0, 'params': 581095, 'time_iter': 0.04622, 'accuracy': 0.96839, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.73379}
# ...computing epoch stats took: 0.01s
# > Epoch 2: took 118.3s (avg 120.9s) | Best so far: epoch 2	train_loss: 0.1577 train_auc: 0.6669	val_loss: 0.0900 val_auc: 0.7422	test_loss: 0.1205 test_auc: 0.7338
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# train: {'epoch': 3, 'time_epoch': 107.13216, 'eta': 10364.69073, 'eta_hours': 2.87908, 'loss': 0.13951161, 'lr': 6e-05, 'params': 581095, 'time_iter': 0.10411, 'accuracy': 0.96255, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.72475}
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 3, 'time_epoch': 5.99704, 'loss': 0.08615395, 'lr': 0, 'params': 581095, 'time_iter': 0.04649, 'accuracy': 0.98031, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.77467}
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# test: {'epoch': 3, 'time_epoch': 5.97331, 'loss': 0.13183593, 'lr': 0, 'params': 581095, 'time_iter': 0.0463, 'accuracy': 0.96839, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.6745}
# > Epoch 3: took 119.2s (avg 120.5s) | Best so far: epoch 3	train_loss: 0.1395 train_auc: 0.7248	val_loss: 0.0862 val_auc: 0.7747	test_loss: 0.1318 test_auc: 0.6745
# train: {'epoch': 4, 'time_epoch': 107.86316, 'eta': 10254.78018, 'eta_hours': 2.84855, 'loss': 0.13577964, 'lr': 8e-05, 'params': 581095, 'time_iter': 0.10482, 'accuracy': 0.96255, 'precision': 0.5, 'recall': 0.00406, 'f1': 0.00805, 'auc': 0.74791}
# val: {'epoch': 4, 'time_epoch': 5.94065, 'loss': 0.07939445, 'lr': 0, 'params': 581095, 'time_iter': 0.04605, 'accuracy': 0.98079, 'precision': 1.0, 'recall': 0.02469, 'f1': 0.04819, 'auc': 0.78813}
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# test: {'epoch': 4, 'time_epoch': 6.02274, 'loss': 0.11702403, 'lr': 0, 'params': 581095, 'time_iter': 0.04669, 'accuracy': 0.96839, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.7607}
# > Epoch 4: took 120.0s (avg 120.4s) | Best so far: epoch 4	train_loss: 0.1358 train_auc: 0.7479	val_loss: 0.0794 val_auc: 0.7881	test_loss: 0.1170 test_auc: 0.7607
# train: {'epoch': 5, 'time_epoch': 107.69815, 'eta': 10142.96703, 'eta_hours': 2.81749, 'loss': 0.13254736, 'lr': 0.0001, 'params': 581095, 'time_iter': 0.10466, 'accuracy': 0.96325, 'precision': 0.56425, 'recall': 0.08198, 'f1': 0.14316, 'auc': 0.76089}
# val: {'epoch': 5, 'time_epoch': 6.01498, 'loss': 0.08380273, 'lr': 0, 'params': 581095, 'time_iter': 0.04663, 'accuracy': 0.98152, 'precision': 0.64706, 'recall': 0.1358, 'f1': 0.22449, 'auc': 0.79249}
# test: {'epoch': 5, 'time_epoch': 6.05239, 'loss': 0.12429158, 'lr': 0, 'params': 581095, 'time_iter': 0.04692, 'accuracy': 0.97009, 'precision': 0.73333, 'recall': 0.08462, 'f1': 0.15172, 'auc': 0.70699}
# > Epoch 5: took 119.9s (avg 120.3s) | Best so far: epoch 5	train_loss: 0.1325 train_auc: 0.7609	val_loss: 0.0838 val_auc: 0.7925	test_loss: 0.1243 test_auc: 0.7070
# train: {'epoch': 6, 'time_epoch': 110.74987, 'eta': 10072.8738, 'eta_hours': 2.79802, 'loss': 0.12671842, 'lr': 9.997e-05, 'params': 581095, 'time_iter': 0.10763, 'accuracy': 0.96535, 'precision': 0.64286, 'recall': 0.16802, 'f1': 0.26641, 'auc': 0.79116}
# val: {'epoch': 6, 'time_epoch': 6.06486, 'loss': 0.07935662, 'lr': 0, 'params': 581095, 'time_iter': 0.04701, 'accuracy': 0.98128, 'precision': 0.66667, 'recall': 0.09877, 'f1': 0.17204, 'auc': 0.79157}
# test: {'epoch': 6, 'time_epoch': 5.98591, 'loss': 0.12252721, 'lr': 0, 'params': 581095, 'time_iter': 0.0464, 'accuracy': 0.96888, 'precision': 0.75, 'recall': 0.02308, 'f1': 0.04478, 'auc': 0.74802}
# > Epoch 6: took 122.9s (avg 120.7s) | Best so far: epoch 5	train_loss: 0.1325 train_auc: 0.7609	val_loss: 0.0838 val_auc: 0.7925	test_loss: 0.1243 test_auc: 0.7070
# train: {'epoch': 7, 'time_epoch': 108.51714, 'eta': 9966.94005, 'eta_hours': 2.76859, 'loss': 0.12290228, 'lr': 9.989e-05, 'params': 581095, 'time_iter': 0.10546, 'accuracy': 0.96584, 'precision': 0.64595, 'recall': 0.19399, 'f1': 0.29838, 'auc': 0.80556}
# val: {'epoch': 7, 'time_epoch': 5.97798, 'loss': 0.07248336, 'lr': 0, 'params': 581095, 'time_iter': 0.04634, 'accuracy': 0.98079, 'precision': 0.52941, 'recall': 0.22222, 'f1': 0.31304, 'auc': 0.81336}
# test: {'epoch': 7, 'time_epoch': 5.96851, 'loss': 0.11220946, 'lr': 0, 'params': 581095, 'time_iter': 0.04627, 'accuracy': 0.97082, 'precision': 0.6, 'recall': 0.23077, 'f1': 0.33333, 'auc': 0.76625}
# > Epoch 7: took 120.6s (avg 120.7s) | Best so far: epoch 7	train_loss: 0.1229 train_auc: 0.8056	val_loss: 0.0725 val_auc: 0.8134	test_loss: 0.1122 test_auc: 0.7662
# train: {'epoch': 8, 'time_epoch': 107.58228, 'eta': 9850.97968, 'eta_hours': 2.73638, 'loss': 0.11974076, 'lr': 9.975e-05, 'params': 581095, 'time_iter': 0.10455, 'accuracy': 0.96608, 'precision': 0.62554, 'recall': 0.23458, 'f1': 0.3412, 'auc': 0.81811}
# val: {'epoch': 8, 'time_epoch': 6.10214, 'loss': 0.0732902, 'lr': 0, 'params': 581095, 'time_iter': 0.0473, 'accuracy': 0.98298, 'precision': 0.61702, 'recall': 0.35802, 'f1': 0.45312, 'auc': 0.81137}
# test: {'epoch': 8, 'time_epoch': 5.97465, 'loss': 0.11228842, 'lr': 0, 'params': 581095, 'time_iter': 0.04632, 'accuracy': 0.96864, 'precision': 0.50617, 'recall': 0.31538, 'f1': 0.38863, 'auc': 0.78265}
# > Epoch 8: took 119.8s (avg 120.6s) | Best so far: epoch 7	train_loss: 0.1229 train_auc: 0.8056	val_loss: 0.0725 val_auc: 0.8134	test_loss: 0.1122 test_auc: 0.7662
# train: {'epoch': 9, 'time_epoch': 106.80826, 'eta': 9729.72879, 'eta_hours': 2.7027, 'loss': 0.11693288, 'lr': 9.956e-05, 'params': 581095, 'time_iter': 0.1038, 'accuracy': 0.96684, 'precision': 0.643, 'recall': 0.25731, 'f1': 0.36754, 'auc': 0.82732}
# val: {'epoch': 9, 'time_epoch': 5.94496, 'loss': 0.07640075, 'lr': 0, 'params': 581095, 'time_iter': 0.04608, 'accuracy': 0.98177, 'precision': 0.61538, 'recall': 0.19753, 'f1': 0.29907, 'auc': 0.79047}
# test: {'epoch': 9, 'time_epoch': 6.01605, 'loss': 0.11892476, 'lr': 0, 'params': 581095, 'time_iter': 0.04664, 'accuracy': 0.96937, 'precision': 0.6, 'recall': 0.09231, 'f1': 0.16, 'auc': 0.76735}
# > Epoch 9: took 118.9s (avg 120.4s) | Best so far: epoch 7	train_loss: 0.1229 train_auc: 0.8056	val_loss: 0.0725 val_auc: 0.8134	test_loss: 0.1122 test_auc: 0.7662
# train: {'epoch': 10, 'time_epoch': 107.01607, 'eta': 9612.78522, 'eta_hours': 2.67022, 'loss': 0.11393319, 'lr': 9.932e-05, 'params': 581095, 'time_iter': 0.104, 'accuracy': 0.96739, 'precision': 0.65619, 'recall': 0.2711, 'f1': 0.38369, 'auc': 0.84114}
# val: {'epoch': 10, 'time_epoch': 5.96183, 'loss': 0.07013004, 'lr': 0, 'params': 581095, 'time_iter': 0.04622, 'accuracy': 0.98201, 'precision': 0.62069, 'recall': 0.22222, 'f1': 0.32727, 'auc': 0.81896}
# test: {'epoch': 10, 'time_epoch': 5.955, 'loss': 0.11622473, 'lr': 0, 'params': 581095, 'time_iter': 0.04616, 'accuracy': 0.97131, 'precision': 0.65789, 'recall': 0.19231, 'f1': 0.29762, 'auc': 0.76731}
# > Epoch 10: took 119.1s (avg 120.3s) | Best so far: epoch 10	train_loss: 0.1139 train_auc: 0.8411	val_loss: 0.0701 val_auc: 0.8190	test_loss: 0.1162 test_auc: 0.7673
# train: {'epoch': 11, 'time_epoch': 106.61203, 'eta': 9494.53327, 'eta_hours': 2.63737, 'loss': 0.11182785, 'lr': 9.902e-05, 'params': 581095, 'time_iter': 0.10361, 'accuracy': 0.96812, 'precision': 0.67167, 'recall': 0.29058, 'f1': 0.40567, 'auc': 0.84825}
# val: {'epoch': 11, 'time_epoch': 6.02235, 'loss': 0.07250713, 'lr': 0, 'params': 581095, 'time_iter': 0.04668, 'accuracy': 0.98347, 'precision': 0.67568, 'recall': 0.30864, 'f1': 0.42373, 'auc': 0.78727}
# test: {'epoch': 11, 'time_epoch': 6.00398, 'loss': 0.11391355, 'lr': 0, 'params': 581095, 'time_iter': 0.04654, 'accuracy': 0.96937, 'precision': 0.53226, 'recall': 0.25385, 'f1': 0.34375, 'auc': 0.76749}
# > Epoch 11: took 118.8s (avg 120.2s) | Best so far: epoch 10	train_loss: 0.1139 train_auc: 0.8411	val_loss: 0.0701 val_auc: 0.8190	test_loss: 0.1162 test_auc: 0.7673
# train: {'epoch': 12, 'time_epoch': 107.2909, 'eta': 9382.61523, 'eta_hours': 2.60628, 'loss': 0.10928302, 'lr': 9.867e-05, 'params': 581095, 'time_iter': 0.10427, 'accuracy': 0.96806, 'precision': 0.66132, 'recall': 0.30114, 'f1': 0.41383, 'auc': 0.85955}
# val: {'epoch': 12, 'time_epoch': 5.94051, 'loss': 0.07062879, 'lr': 0, 'params': 581095, 'time_iter': 0.04605, 'accuracy': 0.98322, 'precision': 0.64286, 'recall': 0.33333, 'f1': 0.43902, 'auc': 0.8092}
# test: {'epoch': 12, 'time_epoch': 5.9587, 'loss': 0.11423966, 'lr': 0, 'params': 581095, 'time_iter': 0.04619, 'accuracy': 0.97058, 'precision': 0.58824, 'recall': 0.23077, 'f1': 0.33149, 'auc': 0.77633}
# > Epoch 12: took 119.3s (avg 120.1s) | Best so far: epoch 10	train_loss: 0.1139 train_auc: 0.8411	val_loss: 0.0701 val_auc: 0.8190	test_loss: 0.1162 test_auc: 0.7673
# train: {'epoch': 13, 'time_epoch': 105.99327, 'eta': 9263.38706, 'eta_hours': 2.57316, 'loss': 0.10863653, 'lr': 9.826e-05, 'params': 581095, 'time_iter': 0.10301, 'accuracy': 0.96885, 'precision': 0.68582, 'recall': 0.31006, 'f1': 0.42705, 'auc': 0.86116}
# val: {'epoch': 13, 'time_epoch': 5.9947, 'loss': 0.07216066, 'lr': 0, 'params': 581095, 'time_iter': 0.04647, 'accuracy': 0.98006, 'precision': 0.4898, 'recall': 0.2963, 'f1': 0.36923, 'auc': 0.82053}
# test: {'epoch': 13, 'time_epoch': 5.95319, 'loss': 0.11264782, 'lr': 0, 'params': 581095, 'time_iter': 0.04615, 'accuracy': 0.96888, 'precision': 0.51724, 'recall': 0.23077, 'f1': 0.31915, 'auc': 0.79207}
# > Epoch 13: took 118.1s (avg 120.0s) | Best so far: epoch 13	train_loss: 0.1086 train_auc: 0.8612	val_loss: 0.0722 val_auc: 0.8205	test_loss: 0.1126 test_auc: 0.7921
# train: {'epoch': 14, 'time_epoch': 105.96936, 'eta': 9145.7881, 'eta_hours': 2.5405, 'loss': 0.10502594, 'lr': 9.78e-05, 'params': 581095, 'time_iter': 0.10298, 'accuracy': 0.96997, 'precision': 0.71034, 'recall': 0.33442, 'f1': 0.45475, 'auc': 0.87299}
# val: {'epoch': 14, 'time_epoch': 5.97075, 'loss': 0.08043286, 'lr': 0, 'params': 581095, 'time_iter': 0.04628, 'accuracy': 0.97885, 'precision': 0.45714, 'recall': 0.39506, 'f1': 0.42384, 'auc': 0.80477}
# test: {'epoch': 14, 'time_epoch': 5.91238, 'loss': 0.11402159, 'lr': 0, 'params': 581095, 'time_iter': 0.04583, 'accuracy': 0.96961, 'precision': 0.52747, 'recall': 0.36923, 'f1': 0.43439, 'auc': 0.78391}
# > Epoch 14: took 118.0s (avg 119.8s) | Best so far: epoch 13	train_loss: 0.1086 train_auc: 0.8612	val_loss: 0.0722 val_auc: 0.8205	test_loss: 0.1126 test_auc: 0.7921
# train: {'epoch': 15, 'time_epoch': 106.68721, 'eta': 9033.41156, 'eta_hours': 2.50928, 'loss': 0.10437687, 'lr': 9.729e-05, 'params': 581095, 'time_iter': 0.10368, 'accuracy': 0.96973, 'precision': 0.69344, 'recall': 0.34334, 'f1': 0.45928, 'auc': 0.8768}
# val: {'epoch': 15, 'time_epoch': 5.95831, 'loss': 0.07514423, 'lr': 0, 'params': 581095, 'time_iter': 0.04619, 'accuracy': 0.98201, 'precision': 0.5814, 'recall': 0.30864, 'f1': 0.40323, 'auc': 0.81561}
# test: {'epoch': 15, 'time_epoch': 5.90512, 'loss': 0.11572367, 'lr': 0, 'params': 581095, 'time_iter': 0.04578, 'accuracy': 0.97155, 'precision': 0.65116, 'recall': 0.21538, 'f1': 0.3237, 'auc': 0.78242}
# > Epoch 15: took 118.7s (avg 119.7s) | Best so far: epoch 13	train_loss: 0.1086 train_auc: 0.8612	val_loss: 0.0722 val_auc: 0.8205	test_loss: 0.1126 test_auc: 0.7921
# train: {'epoch': 16, 'time_epoch': 107.02117, 'eta': 8923.33483, 'eta_hours': 2.4787, 'loss': 0.10229961, 'lr': 9.673e-05, 'params': 581095, 'time_iter': 0.10401, 'accuracy': 0.97076, 'precision': 0.725, 'recall': 0.35308, 'f1': 0.47489, 'auc': 0.8836}
# val: {'epoch': 16, 'time_epoch': 5.93524, 'loss': 0.0738594, 'lr': 0, 'params': 581095, 'time_iter': 0.04601, 'accuracy': 0.98152, 'precision': 0.54717, 'recall': 0.35802, 'f1': 0.43284, 'auc': 0.8254}
# test: {'epoch': 16, 'time_epoch': 5.87923, 'loss': 0.11547067, 'lr': 0, 'params': 581095, 'time_iter': 0.04558, 'accuracy': 0.97082, 'precision': 0.57143, 'recall': 0.30769, 'f1': 0.4, 'auc': 0.76286}
# > Epoch 16: took 119.0s (avg 119.7s) | Best so far: epoch 16	train_loss: 0.1023 train_auc: 0.8836	val_loss: 0.0739 val_auc: 0.8254	test_loss: 0.1155 test_auc: 0.7629
# train: {'epoch': 17, 'time_epoch': 106.36049, 'eta': 8810.58785, 'eta_hours': 2.44739, 'loss': 0.10017241, 'lr': 9.611e-05, 'params': 581095, 'time_iter': 0.10336, 'accuracy': 0.97137, 'precision': 0.73163, 'recall': 0.37175, 'f1': 0.493, 'auc': 0.89136}
# val: {'epoch': 17, 'time_epoch': 6.02576, 'loss': 0.08665868, 'lr': 0, 'params': 581095, 'time_iter': 0.04671, 'accuracy': 0.97447, 'precision': 0.36667, 'recall': 0.40741, 'f1': 0.38596, 'auc': 0.81536}
# test: {'epoch': 17, 'time_epoch': 5.90081, 'loss': 0.12612378, 'lr': 0, 'params': 581095, 'time_iter': 0.04574, 'accuracy': 0.96183, 'precision': 0.392, 'recall': 0.37692, 'f1': 0.38431, 'auc': 0.79597}
# > Epoch 17: took 118.4s (avg 119.6s) | Best so far: epoch 16	train_loss: 0.1023 train_auc: 0.8836	val_loss: 0.0739 val_auc: 0.8254	test_loss: 0.1155 test_auc: 0.7629
# train: {'epoch': 18, 'time_epoch': 106.07859, 'eta': 8697.31137, 'eta_hours': 2.41592, 'loss': 0.09802372, 'lr': 9.545e-05, 'params': 581095, 'time_iter': 0.10309, 'accuracy': 0.97167, 'precision': 0.74038, 'recall': 0.375, 'f1': 0.49784, 'auc': 0.8982}
# val: {'epoch': 18, 'time_epoch': 5.8707, 'loss': 0.07478963, 'lr': 0, 'params': 581095, 'time_iter': 0.04551, 'accuracy': 0.98177, 'precision': 0.56522, 'recall': 0.32099, 'f1': 0.40945, 'auc': 0.80503}
# test: {'epoch': 18, 'time_epoch': 5.94511, 'loss': 0.12010923, 'lr': 0, 'params': 581095, 'time_iter': 0.04609, 'accuracy': 0.97155, 'precision': 0.62745, 'recall': 0.24615, 'f1': 0.35359, 'auc': 0.76906}
# > Epoch 18: took 118.0s (avg 119.5s) | Best so far: epoch 16	train_loss: 0.1023 train_auc: 0.8836	val_loss: 0.0739 val_auc: 0.8254	test_loss: 0.1155 test_auc: 0.7629
# train: {'epoch': 19, 'time_epoch': 106.41784, 'eta': 8586.11164, 'eta_hours': 2.38503, 'loss': 0.09772874, 'lr': 9.474e-05, 'params': 581095, 'time_iter': 0.10342, 'accuracy': 0.97155, 'precision': 0.7327, 'recall': 0.37825, 'f1': 0.49893, 'auc': 0.89912}
# val: {'epoch': 19, 'time_epoch': 5.92811, 'loss': 0.07987769, 'lr': 0, 'params': 581095, 'time_iter': 0.04595, 'accuracy': 0.98225, 'precision': 0.58696, 'recall': 0.33333, 'f1': 0.4252, 'auc': 0.76998}
# test: {'epoch': 19, 'time_epoch': 5.90703, 'loss': 0.12399755, 'lr': 0, 'params': 581095, 'time_iter': 0.04579, 'accuracy': 0.96937, 'precision': 0.53448, 'recall': 0.23846, 'f1': 0.32979, 'auc': 0.75419}
# > Epoch 19: took 118.4s (avg 119.5s) | Best so far: epoch 16	train_loss: 0.1023 train_auc: 0.8836	val_loss: 0.0739 val_auc: 0.8254	test_loss: 0.1155 test_auc: 0.7629
# train: {'epoch': 20, 'time_epoch': 106.08875, 'eta': 8474.12936, 'eta_hours': 2.35392, 'loss': 0.09561664, 'lr': 9.397e-05, 'params': 581095, 'time_iter': 0.1031, 'accuracy': 0.97128, 'precision': 0.72742, 'recall': 0.37256, 'f1': 0.49275, 'auc': 0.90945}
# val: {'epoch': 20, 'time_epoch': 5.92169, 'loss': 0.08656907, 'lr': 0, 'params': 581095, 'time_iter': 0.0459, 'accuracy': 0.97666, 'precision': 0.3913, 'recall': 0.33333, 'f1': 0.36, 'auc': 0.79955}
# test: {'epoch': 20, 'time_epoch': 5.89134, 'loss': 0.1249724, 'lr': 0, 'params': 581095, 'time_iter': 0.04567, 'accuracy': 0.96742, 'precision': 0.47436, 'recall': 0.28462, 'f1': 0.35577, 'auc': 0.76951}
# > Epoch 20: took 118.0s (avg 119.4s) | Best so far: epoch 16	train_loss: 0.1023 train_auc: 0.8836	val_loss: 0.0739 val_auc: 0.8254	test_loss: 0.1155 test_auc: 0.7629
# train: {'epoch': 21, 'time_epoch': 105.93208, 'eta': 8362.12736, 'eta_hours': 2.32281, 'loss': 0.09453359, 'lr': 9.316e-05, 'params': 581095, 'time_iter': 0.10295, 'accuracy': 0.9721, 'precision': 0.73225, 'recall': 0.40179, 'f1': 0.51887, 'auc': 0.90682}
# val: {'epoch': 21, 'time_epoch': 5.99159, 'loss': 0.07595891, 'lr': 0, 'params': 581095, 'time_iter': 0.04645, 'accuracy': 0.98152, 'precision': 0.55102, 'recall': 0.33333, 'f1': 0.41538, 'auc': 0.79581}
# test: {'epoch': 21, 'time_epoch': 5.88073, 'loss': 0.11950202, 'lr': 0, 'params': 581095, 'time_iter': 0.04559, 'accuracy': 0.96888, 'precision': 0.51389, 'recall': 0.28462, 'f1': 0.36634, 'auc': 0.77063}
# > Epoch 21: took 117.9s (avg 119.4s) | Best so far: epoch 16	train_loss: 0.1023 train_auc: 0.8836	val_loss: 0.0739 val_auc: 0.8254	test_loss: 0.1155 test_auc: 0.7629
# train: {'epoch': 22, 'time_epoch': 105.35568, 'eta': 8248.72352, 'eta_hours': 2.29131, 'loss': 0.09333345, 'lr': 9.23e-05, 'params': 581095, 'time_iter': 0.10239, 'accuracy': 0.9724, 'precision': 0.74471, 'recall': 0.40016, 'f1': 0.52059, 'auc': 0.91048}
# val: {'epoch': 22, 'time_epoch': 5.84333, 'loss': 0.07367335, 'lr': 0, 'params': 581095, 'time_iter': 0.0453, 'accuracy': 0.9842, 'precision': 0.72222, 'recall': 0.32099, 'f1': 0.44444, 'auc': 0.80532}
# test: {'epoch': 22, 'time_epoch': 5.90364, 'loss': 0.12170177, 'lr': 0, 'params': 581095, 'time_iter': 0.04576, 'accuracy': 0.97034, 'precision': 0.6, 'recall': 0.18462, 'f1': 0.28235, 'auc': 0.78009}
# > Epoch 22: took 117.2s (avg 119.3s) | Best so far: epoch 16	train_loss: 0.1023 train_auc: 0.8836	val_loss: 0.0739 val_auc: 0.8254	test_loss: 0.1155 test_auc: 0.7629
# train: {'epoch': 23, 'time_epoch': 106.25703, 'eta': 8138.84463, 'eta_hours': 2.26079, 'loss': 0.09096234, 'lr': 9.14e-05, 'params': 581095, 'time_iter': 0.10326, 'accuracy': 0.97356, 'precision': 0.77341, 'recall': 0.41558, 'f1': 0.54065, 'auc': 0.91775}
# val: {'epoch': 23, 'time_epoch': 5.96442, 'loss': 0.07683114, 'lr': 0, 'params': 581095, 'time_iter': 0.04624, 'accuracy': 0.98152, 'precision': 0.55319, 'recall': 0.32099, 'f1': 0.40625, 'auc': 0.79256}
# test: {'epoch': 23, 'time_epoch': 5.92324, 'loss': 0.12510942, 'lr': 0, 'params': 581095, 'time_iter': 0.04592, 'accuracy': 0.97058, 'precision': 0.6, 'recall': 0.20769, 'f1': 0.30857, 'auc': 0.7609}
# > Epoch 23: took 118.3s (avg 119.2s) | Best so far: epoch 16	train_loss: 0.1023 train_auc: 0.8836	val_loss: 0.0739 val_auc: 0.8254	test_loss: 0.1155 test_auc: 0.7629
# train: {'epoch': 24, 'time_epoch': 105.85428, 'eta': 8028.04724, 'eta_hours': 2.23001, 'loss': 0.08986146, 'lr': 9.045e-05, 'params': 581095, 'time_iter': 0.10287, 'accuracy': 0.97362, 'precision': 0.76377, 'recall': 0.42776, 'f1': 0.54839, 'auc': 0.92112}
# val: {'epoch': 24, 'time_epoch': 5.97278, 'loss': 0.07805571, 'lr': 0, 'params': 581095, 'time_iter': 0.0463, 'accuracy': 0.98249, 'precision': 0.58491, 'recall': 0.38272, 'f1': 0.46269, 'auc': 0.79151}
# test: {'epoch': 24, 'time_epoch': 5.91769, 'loss': 0.12503284, 'lr': 0, 'params': 581095, 'time_iter': 0.04587, 'accuracy': 0.96912, 'precision': 0.52308, 'recall': 0.26154, 'f1': 0.34872, 'auc': 0.75898}
# > Epoch 24: took 117.9s (avg 119.2s) | Best so far: epoch 16	train_loss: 0.1023 train_auc: 0.8836	val_loss: 0.0739 val_auc: 0.8254	test_loss: 0.1155 test_auc: 0.7629
# train: {'epoch': 25, 'time_epoch': 106.47894, 'eta': 7919.40794, 'eta_hours': 2.19984, 'loss': 0.08846297, 'lr': 8.946e-05, 'params': 581095, 'time_iter': 0.10348, 'accuracy': 0.97298, 'precision': 0.74326, 'recall': 0.42532, 'f1': 0.54104, 'auc': 0.92427}
# val: {'epoch': 25, 'time_epoch': 5.96251, 'loss': 0.08153791, 'lr': 0, 'params': 581095, 'time_iter': 0.04622, 'accuracy': 0.98152, 'precision': 0.54902, 'recall': 0.34568, 'f1': 0.42424, 'auc': 0.77834}
# test: {'epoch': 25, 'time_epoch': 5.98972, 'loss': 0.12939644, 'lr': 0, 'params': 581095, 'time_iter': 0.04643, 'accuracy': 0.96839, 'precision': 0.5, 'recall': 0.20769, 'f1': 0.29348, 'auc': 0.76578}
# > Epoch 25: took 118.6s (avg 119.1s) | Best so far: epoch 16	train_loss: 0.1023 train_auc: 0.8836	val_loss: 0.0739 val_auc: 0.8254	test_loss: 0.1155 test_auc: 0.7629
# train: {'epoch': 26, 'time_epoch': 105.28458, 'eta': 7807.6995, 'eta_hours': 2.16881, 'loss': 0.08784163, 'lr': 8.842e-05, 'params': 581095, 'time_iter': 0.10232, 'accuracy': 0.97328, 'precision': 0.75543, 'recall': 0.4237, 'f1': 0.5429, 'auc': 0.92927}
# val: {'epoch': 26, 'time_epoch': 6.00258, 'loss': 0.08068388, 'lr': 0, 'params': 581095, 'time_iter': 0.04653, 'accuracy': 0.98177, 'precision': 0.55357, 'recall': 0.38272, 'f1': 0.45255, 'auc': 0.81304}
# test: {'epoch': 26, 'time_epoch': 5.91033, 'loss': 0.12969343, 'lr': 0, 'params': 581095, 'time_iter': 0.04582, 'accuracy': 0.96937, 'precision': 0.53333, 'recall': 0.24615, 'f1': 0.33684, 'auc': 0.79514}
# > Epoch 26: took 117.3s (avg 119.1s) | Best so far: epoch 16	train_loss: 0.1023 train_auc: 0.8836	val_loss: 0.0739 val_auc: 0.8254	test_loss: 0.1155 test_auc: 0.7629
# train: {'epoch': 27, 'time_epoch': 105.74664, 'eta': 7697.63804, 'eta_hours': 2.13823, 'loss': 0.08682194, 'lr': 8.734e-05, 'params': 581095, 'time_iter': 0.10277, 'accuracy': 0.97377, 'precision': 0.75239, 'recall': 0.44643, 'f1': 0.56037, 'auc': 0.93048}
# val: {'epoch': 27, 'time_epoch': 5.88051, 'loss': 0.07642411, 'lr': 0, 'params': 581095, 'time_iter': 0.04559, 'accuracy': 0.98274, 'precision': 0.61905, 'recall': 0.32099, 'f1': 0.42276, 'auc': 0.80455}
# ...
# test: {'epoch': 87, 'time_epoch': 5.95083, 'loss': 0.22066632, 'lr': 0, 'params': 581095, 'time_iter': 0.04613, 'accuracy': 0.96304, 'precision': 0.38542, 'recall': 0.28462, 'f1': 0.32743, 'auc': 0.78327}
# > Epoch 87: took 119.0s (avg 117.9s) | Best so far: epoch 38	train_loss: 0.0719 train_auc: 0.9598	val_loss: 0.0846 val_auc: 0.8289	test_loss: 0.1468 test_auc: 0.7967
# train: {'epoch': 88, 'time_epoch': 104.51595, 'eta': 1164.55278, 'eta_hours': 0.32349, 'loss': 0.04045674, 'lr': 3.89e-06, 'params': 581095, 'time_iter': 0.10157, 'accuracy': 0.98611, 'precision': 0.87224, 'recall': 0.73701, 'f1': 0.79894, 'auc': 0.99137}
# val: {'epoch': 88, 'time_epoch': 5.86616, 'loss': 0.12164598, 'lr': 0, 'params': 581095, 'time_iter': 0.04547, 'accuracy': 0.97763, 'precision': 0.42029, 'recall': 0.35802, 'f1': 0.38667, 'auc': 0.81245}
# test: {'epoch': 88, 'time_epoch': 5.83955, 'loss': 0.22043527, 'lr': 0, 'params': 581095, 'time_iter': 0.04527, 'accuracy': 0.96499, 'precision': 0.4125, 'recall': 0.25385, 'f1': 0.31429, 'auc': 0.78059}
# > Epoch 88: took 116.4s (avg 117.9s) | Best so far: epoch 38	train_loss: 0.0719 train_auc: 0.9598	val_loss: 0.0846 val_auc: 0.8289	test_loss: 0.1468 test_auc: 0.7967
# train: {'epoch': 89, 'time_epoch': 104.46112, 'eta': 1058.52798, 'eta_hours': 0.29404, 'loss': 0.03906247, 'lr': 3.27e-06, 'params': 581095, 'time_iter': 0.10152, 'accuracy': 0.98669, 'precision': 0.87954, 'recall': 0.74675, 'f1': 0.80773, 'auc': 0.99255}
# val: {'epoch': 89, 'time_epoch': 5.96445, 'loss': 0.11913422, 'lr': 0, 'params': 581095, 'time_iter': 0.04624, 'accuracy': 0.9786, 'precision': 0.44776, 'recall': 0.37037, 'f1': 0.40541, 'auc': 0.8153}
# test: {'epoch': 89, 'time_epoch': 5.81624, 'loss': 0.21995189, 'lr': 0, 'params': 581095, 'time_iter': 0.04509, 'accuracy': 0.96402, 'precision': 0.39773, 'recall': 0.26923, 'f1': 0.3211, 'auc': 0.78222}
# > Epoch 89: took 116.4s (avg 117.8s) | Best so far: epoch 38	train_loss: 0.0719 train_auc: 0.9598	val_loss: 0.0846 val_auc: 0.8289	test_loss: 0.1468 test_auc: 0.7967
# train: {'epoch': 90, 'time_epoch': 104.65562, 'eta': 952.55678, 'eta_hours': 0.2646, 'loss': 0.03819611, 'lr': 2.71e-06, 'params': 581095, 'time_iter': 0.10171, 'accuracy': 0.98714, 'precision': 0.88124, 'recall': 0.75893, 'f1': 0.81553, 'auc': 0.99279}
# val: {'epoch': 90, 'time_epoch': 5.84327, 'loss': 0.12549642, 'lr': 0, 'params': 581095, 'time_iter': 0.0453, 'accuracy': 0.97739, 'precision': 0.41892, 'recall': 0.38272, 'f1': 0.4, 'auc': 0.81195}
# test: {'epoch': 90, 'time_epoch': 5.93253, 'loss': 0.22222994, 'lr': 0, 'params': 581095, 'time_iter': 0.04599, 'accuracy': 0.96329, 'precision': 0.3871, 'recall': 0.27692, 'f1': 0.32287, 'auc': 0.78148}
# > Epoch 90: took 116.6s (avg 117.8s) | Best so far: epoch 38	train_loss: 0.0719 train_auc: 0.9598	val_loss: 0.0846 val_auc: 0.8289	test_loss: 0.1468 test_auc: 0.7967
# train: {'epoch': 91, 'time_epoch': 104.75548, 'eta': 846.62286, 'eta_hours': 0.23517, 'loss': 0.0373621, 'lr': 2.2e-06, 'params': 581095, 'time_iter': 0.1018, 'accuracy': 0.98708, 'precision': 0.87746, 'recall': 0.76136, 'f1': 0.8153, 'auc': 0.99301}
# val: {'epoch': 91, 'time_epoch': 5.88299, 'loss': 0.12465917, 'lr': 0, 'params': 581095, 'time_iter': 0.0456, 'accuracy': 0.97836, 'precision': 0.44595, 'recall': 0.40741, 'f1': 0.42581, 'auc': 0.81423}
# test: {'epoch': 91, 'time_epoch': 5.88401, 'loss': 0.22397743, 'lr': 0, 'params': 581095, 'time_iter': 0.04561, 'accuracy': 0.96329, 'precision': 0.3871, 'recall': 0.27692, 'f1': 0.32287, 'auc': 0.78356}
# > Epoch 91: took 116.7s (avg 117.8s) | Best so far: epoch 38	train_loss: 0.0719 train_auc: 0.9598	val_loss: 0.0846 val_auc: 0.8289	test_loss: 0.1468 test_auc: 0.7967
# train: {'epoch': 92, 'time_epoch': 104.96375, 'eta': 740.72996, 'eta_hours': 0.20576, 'loss': 0.0395059, 'lr': 1.74e-06, 'params': 581095, 'time_iter': 0.10201, 'accuracy': 0.98684, 'precision': 0.87371, 'recall': 0.75812, 'f1': 0.81182, 'auc': 0.99136}
# val: {'epoch': 92, 'time_epoch': 5.87277, 'loss': 0.12130169, 'lr': 0, 'params': 581095, 'time_iter': 0.04553, 'accuracy': 0.97763, 'precision': 0.42466, 'recall': 0.38272, 'f1': 0.4026, 'auc': 0.81517}
# test: {'epoch': 92, 'time_epoch': 5.84081, 'loss': 0.2209126, 'lr': 0, 'params': 581095, 'time_iter': 0.04528, 'accuracy': 0.96402, 'precision': 0.4, 'recall': 0.27692, 'f1': 0.32727, 'auc': 0.7852}
# > Epoch 92: took 116.8s (avg 117.8s) | Best so far: epoch 38	train_loss: 0.0719 train_auc: 0.9598	val_loss: 0.0846 val_auc: 0.8289	test_loss: 0.1468 test_auc: 0.7967
# train: {'epoch': 93, 'time_epoch': 104.7816, 'eta': 634.84521, 'eta_hours': 0.17635, 'loss': 0.03842777, 'lr': 1.33e-06, 'params': 581095, 'time_iter': 0.10183, 'accuracy': 0.98681, 'precision': 0.87082, 'recall': 0.76055, 'f1': 0.81196, 'auc': 0.99295}
# val: {'epoch': 93, 'time_epoch': 5.84584, 'loss': 0.12639337, 'lr': 0, 'params': 581095, 'time_iter': 0.04532, 'accuracy': 0.97715, 'precision': 0.41333, 'recall': 0.38272, 'f1': 0.39744, 'auc': 0.81204}
# test: {'epoch': 93, 'time_epoch': 5.9265, 'loss': 0.22082335, 'lr': 0, 'params': 581095, 'time_iter': 0.04594, 'accuracy': 0.96426, 'precision': 0.4023, 'recall': 0.26923, 'f1': 0.32258, 'auc': 0.78285}
# > Epoch 93: took 116.7s (avg 117.8s) | Best so far: epoch 38	train_loss: 0.0719 train_auc: 0.9598	val_loss: 0.0846 val_auc: 0.8289	test_loss: 0.1468 test_auc: 0.7967
# train: {'epoch': 94, 'time_epoch': 104.80306, 'eta': 528.98481, 'eta_hours': 0.14694, 'loss': 0.03986779, 'lr': 9.8e-07, 'params': 581095, 'time_iter': 0.10185, 'accuracy': 0.98632, 'precision': 0.87961, 'recall': 0.73539, 'f1': 0.80106, 'auc': 0.99297}
# val: {'epoch': 94, 'time_epoch': 5.92004, 'loss': 0.12310782, 'lr': 0, 'params': 581095, 'time_iter': 0.04589, 'accuracy': 0.97788, 'precision': 0.42647, 'recall': 0.35802, 'f1': 0.38926, 'auc': 0.8114}
# test: {'epoch': 94, 'time_epoch': 5.91606, 'loss': 0.21976515, 'lr': 0, 'params': 581095, 'time_iter': 0.04586, 'accuracy': 0.96499, 'precision': 0.41667, 'recall': 0.26923, 'f1': 0.3271, 'auc': 0.78452}
# > Epoch 94: took 116.8s (avg 117.8s) | Best so far: epoch 38	train_loss: 0.0719 train_auc: 0.9598	val_loss: 0.0846 val_auc: 0.8289	test_loss: 0.1468 test_auc: 0.7967
# train: {'epoch': 95, 'time_epoch': 105.50545, 'eta': 423.1757, 'eta_hours': 0.11755, 'loss': 0.03882621, 'lr': 6.8e-07, 'params': 581095, 'time_iter': 0.10253, 'accuracy': 0.98696, 'precision': 0.88643, 'recall': 0.74756, 'f1': 0.8111, 'auc': 0.99222}
# val: {'epoch': 95, 'time_epoch': 5.91395, 'loss': 0.12501065, 'lr': 0, 'params': 581095, 'time_iter': 0.04584, 'accuracy': 0.9786, 'precision': 0.44776, 'recall': 0.37037, 'f1': 0.40541, 'auc': 0.81077}
# test: {'epoch': 95, 'time_epoch': 5.83697, 'loss': 0.22325499, 'lr': 0, 'params': 581095, 'time_iter': 0.04525, 'accuracy': 0.96499, 'precision': 0.41463, 'recall': 0.26154, 'f1': 0.32075, 'auc': 0.78196}
# > Epoch 95: took 117.4s (avg 117.8s) | Best so far: epoch 38	train_loss: 0.0719 train_auc: 0.9598	val_loss: 0.0846 val_auc: 0.8289	test_loss: 0.1468 test_auc: 0.7967
# train: {'epoch': 96, 'time_epoch': 104.59033, 'eta': 317.34455, 'eta_hours': 0.08815, 'loss': 0.03662152, 'lr': 4.4e-07, 'params': 581095, 'time_iter': 0.10164, 'accuracy': 0.98754, 'precision': 0.88483, 'recall': 0.76705, 'f1': 0.82174, 'auc': 0.99296}
# val: {'epoch': 96, 'time_epoch': 5.85157, 'loss': 0.12119336, 'lr': 0, 'params': 581095, 'time_iter': 0.04536, 'accuracy': 0.97812, 'precision': 0.43478, 'recall': 0.37037, 'f1': 0.4, 'auc': 0.815}
# test: {'epoch': 96, 'time_epoch': 5.90659, 'loss': 0.22447191, 'lr': 0, 'params': 581095, 'time_iter': 0.04579, 'accuracy': 0.96329, 'precision': 0.38947, 'recall': 0.28462, 'f1': 0.32889, 'auc': 0.78043}
# > Epoch 96: took 116.5s (avg 117.8s) | Best so far: epoch 38	train_loss: 0.0719 train_auc: 0.9598	val_loss: 0.0846 val_auc: 0.8289	test_loss: 0.1468 test_auc: 0.7967
# train: {'epoch': 97, 'time_epoch': 104.68749, 'eta': 211.54071, 'eta_hours': 0.05876, 'loss': 0.03971899, 'lr': 2.5e-07, 'params': 581095, 'time_iter': 0.10174, 'accuracy': 0.98666, 'precision': 0.87091, 'recall': 0.75568, 'f1': 0.80921, 'auc': 0.99151}
# val: {'epoch': 97, 'time_epoch': 5.84424, 'loss': 0.12570108, 'lr': 0, 'params': 581095, 'time_iter': 0.0453, 'accuracy': 0.97642, 'precision': 0.4, 'recall': 0.39506, 'f1': 0.39752, 'auc': 0.81272}
# test: {'epoch': 97, 'time_epoch': 5.83805, 'loss': 0.22673129, 'lr': 0, 'params': 581095, 'time_iter': 0.04526, 'accuracy': 0.96207, 'precision': 0.36735, 'recall': 0.27692, 'f1': 0.31579, 'auc': 0.78214}
# > Epoch 97: took 116.5s (avg 117.8s) | Best so far: epoch 38	train_loss: 0.0719 train_auc: 0.9598	val_loss: 0.0846 val_auc: 0.8289	test_loss: 0.1468 test_auc: 0.7967
# train: {'epoch': 98, 'time_epoch': 104.28946, 'eta': 105.75539, 'eta_hours': 0.02938, 'loss': 0.03894257, 'lr': 1.1e-07, 'params': 581095, 'time_iter': 0.10135, 'accuracy': 0.98733, 'precision': 0.88773, 'recall': 0.75731, 'f1': 0.81735, 'auc': 0.99148}
# val: {'epoch': 98, 'time_epoch': 5.85627, 'loss': 0.12525991, 'lr': 0, 'params': 581095, 'time_iter': 0.0454, 'accuracy': 0.97933, 'precision': 0.46875, 'recall': 0.37037, 'f1': 0.41379, 'auc': 0.80847}
# test: {'epoch': 98, 'time_epoch': 5.8447, 'loss': 0.22400603, 'lr': 0, 'params': 581095, 'time_iter': 0.04531, 'accuracy': 0.96523, 'precision': 0.42169, 'recall': 0.26923, 'f1': 0.32864, 'auc': 0.78255}
# > Epoch 98: took 116.1s (avg 117.7s) | Best so far: epoch 38	train_loss: 0.0719 train_auc: 0.9598	val_loss: 0.0846 val_auc: 0.8289	test_loss: 0.1468 test_auc: 0.7967
# train: {'epoch': 99, 'time_epoch': 104.46555, 'eta': 0.0, 'eta_hours': 0.0, 'loss': 0.03851953, 'lr': 3e-08, 'params': 581095, 'time_iter': 0.10152, 'accuracy': 0.98723, 'precision': 0.8874, 'recall': 0.75487, 'f1': 0.81579, 'auc': 0.99134}
# val: {'epoch': 99, 'time_epoch': 5.86608, 'loss': 0.12296498, 'lr': 0, 'params': 581095, 'time_iter': 0.04547, 'accuracy': 0.97982, 'precision': 0.48387, 'recall': 0.37037, 'f1': 0.41958, 'auc': 0.81639}
# test: {'epoch': 99, 'time_epoch': 6.33997, 'loss': 0.22217117, 'lr': 0, 'params': 581095, 'time_iter': 0.04915, 'accuracy': 0.9645, 'precision': 0.40244, 'recall': 0.25385, 'f1': 0.31132, 'auc': 0.78347}
# > Epoch 99: took 116.8s (avg 117.7s) | Best so far: epoch 38	train_loss: 0.0719 train_auc: 0.9598	val_loss: 0.0846 val_auc: 0.8289	test_loss: 0.1468 test_auc: 0.7967
# Avg time per epoch: 117.73s
# Total train loop time: 3.27h
# wandb:
# wandb:
# wandb: Run history:
# wandb:       best/epoch ▁▂▂▂▂▃▃▃▃▄▄▄▄▄▄▄▄▄▄█████████████████████
# wandb:    best/test_auc ▁▅▅▅▇▄▄▄▄▄▄▄▄███████████████████████████
# wandb:   best/test_loss ▃▃▁▁▂▁▂▂▂▂▂▂▂▂▂▂████████████████████████
# wandb:   best/train_auc ▁▄▄▄▅▆▇▇▇▇▇▇▇▇▇█████████████████████████
# wandb:  best/train_loss █▃▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:     best/val_auc ▁▃▅▆▆▇▇█████████████████████████████████
# wandb:    best/val_loss █▆▂▂▁▂▂▂▂▂▂▂▂▂▂▂▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆
# wandb:    test/accuracy ▁███████████████████████████████████████
# wandb:         test/auc ▁▇▆██▇▇█▇█████████▇▇▇▇███▇██████████████
# wandb:       test/epoch ▁▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▄▅▅▅▆▆▆▆▇▇▇▇▇▇████
# wandb:          test/f1 ▂▁▁▁▄▇▇▇▇█▇█▆▇▇▆▆▇▆▇▇▆▇▇▇▇▆▇▆▇▇▇▇▇▇▇▇▇▇▇
# wandb:        test/loss ▂▁▂▁▁▁▁▁▁▁▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▆▆▆▆▆▇█▇██▇███
# wandb:          test/lr ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:      test/params ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:   test/precision ▁█▇▆▆▆▇▅▆▆▇▆▅▆▆▅▆▆▅▅▅▅▅▅▅▅▅▅▄▅▅▄▅▄▄▅▅▅▅▄
# wandb:      test/recall ▁█▃▅▆▆▇▇▅▅▆▇▇▆▆▇▅▇▇▇▆▅▆▇▇▇▇▅▅▇▇▇▆▇▇▇▇▇▇▇
# wandb:  test/time_epoch ▅▅▇█▆▅▅▅▄▃▄▄▄▄▆▃▂▄▁▂▁▁▃▃▆▂▂▃▁▃▄▁▄▂▄▄▅▄▂▂
# wandb:   test/time_iter ▄▄▄▅▆▄▅▄▃▃▃▃█▄▃▁▂▃▄▂▁▁▂▂▂▃▂▁▂▂▃▁▁▂▃▂▂▄▁▂
# wandb:   train/accuracy ▁▁▂▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▅▅▅▆▆▅▆▆▆▆▆▇▇▇▇▇██████
# wandb:        train/auc ▁▂▃▄▅▅▆▆▆▆▇▇▇▇▇▇▇▇▇█████████████████████
# wandb:      train/epoch ▁▁▁▁▁▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇█
# wandb:        train/eta ████▇▇▇▇▆▆▆▆▆▆▆▆▅▅▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▁▁
# wandb:  train/eta_hours ██▇▇▇▇▇▆▆▆▆▆▆▆▅▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▃▃▃▂▂▂▂▁▁▁
# wandb:         train/f1 ▂▂▁▃▄▅▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇██████████
# wandb:       train/loss █▅▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:         train/lr ▁▄███████▇▇▇▇▇▇▆▆▆▆▆▅▅▅▅▄▄▃▃▃▃▂▂▂▂▂▁▁▁▁▁
# wandb:     train/params ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:  train/precision ▁▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇███▇█████████████████
# wandb:     train/recall ▁▁▃▃▃▄▄▄▅▅▅▅▆▆▆▆▆▆▆▆▇▆▇▇▇▇▇█▇▇██████████
# wandb: train/time_epoch █▃▃▄▄▃▃▃▃▃▂▂█▂▂▆▂▂▂▂▂▁▁▃▃▁▂▂▁▁▁▁▁▁▁▃▁▁▂▁
# wandb:  train/time_iter ▅▅▆▇▇▅▆▅▆▄▄▃▄▂█▂▃▁▃▁▅▂▆▁▂▃▁▁▂▁▁▁▂▃▂▂▂▃▂▂
# wandb:     val/accuracy ▅▅▆█▇▆▇▁▆▇█▆▇▅▄▃▇▇▅▆▃▃▃▄▆▃▃▃▄▂▄▂▃▃▃▂▂▂▂▄
# wandb:          val/auc ▁▅▅▅▇▅▅▆▇▇▅▄▆▆▅▇█▆█▇▇▇▆▆█▇▇▆▇▇▅▆▆▇▆▇▇▇▇▆
# wandb:        val/epoch ▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇███
# wandb:           val/f1 ▁▂▅▄▆█▇██▇██▇▇▇███▇▇▇▇▆██▇▇▇▇▇▇██▇▇▇▇▇▇█
# wandb:         val/loss █▂▁▁▁▁▁▂▁▁▂▂▁▁▂▂▂▂▂▂▂▃▃▃▄▃▃▃▃▄▄▄▄▄▄▅▄▅▅▄
# wandb:           val/lr ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:       val/params ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:    val/precision ▁▁█▆▆▅▄▆▅▅▅▅▆▅▄▅▄▄▅▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄
# wandb:       val/recall █▁▂▃▂▃▃▃▃▃▃▃▃▃▂▃▃▃▄▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃
# wandb:   val/time_epoch █▂▂▃▂▃▃▂▂▂▂▂▃▂▁▁▂▂▁▁▁▂▂▂▂▂▁▂▁▂▁▂▂▁▁▁▁▁▁▁
# wandb:    val/time_iter █▂▃▂▃▃▂▂▂▂▂▂▃▂▄▁▂▁▂▂▂▁▂▂▁▂▁▁▂▁▂▂▂▂▂▁▂▁▂▁
# wandb:
# wandb: Run summary:
# wandb:          best/epoch 38
# wandb:       best/test_auc 0.79668
# wandb:      best/test_loss 0.14684
# wandb:      best/train_auc 0.95978
# wandb:     best/train_loss 0.07188
# wandb:        best/val_auc 0.82894
# wandb:       best/val_loss 0.08461
# wandb:      best_test_perf 0.79668
# wandb:     best_train_perf 0.95978
# wandb:       best_val_perf 0.82894
# wandb: full_epoch_time_avg 117.72587
# wandb: full_epoch_time_sum 11772.58663
# wandb:       test/accuracy 0.9645
# wandb:            test/auc 0.78347
# wandb:          test/epoch 99
# wandb:             test/f1 0.31132
# wandb:           test/loss 0.22217
# wandb:             test/lr 0
# wandb:         test/params 581095
# wandb:      test/precision 0.40244
# wandb:         test/recall 0.25385
# wandb:     test/time_epoch 6.33997
# wandb:      test/time_iter 0.04915
# wandb:      train/accuracy 0.98723
# wandb:           train/auc 0.99134
# wandb:         train/epoch 99
# wandb:           train/eta 0
# wandb:     train/eta_hours 0
# wandb:            train/f1 0.81579
# wandb:          train/loss 0.03852
# wandb:            train/lr 0.0
# wandb:        train/params 581095
# wandb:     train/precision 0.8874
# wandb:        train/recall 0.75487
# wandb:    train/time_epoch 104.46555
# wandb:     train/time_iter 0.10152
# wandb:        val/accuracy 0.97982
# wandb:             val/auc 0.81639
# wandb:           val/epoch 99
# wandb:              val/f1 0.41958
# wandb:            val/loss 0.12296
# wandb:              val/lr 0
# wandb:          val/params 581095
# wandb:       val/precision 0.48387
# wandb:          val/recall 0.37037
# wandb:      val/time_epoch 5.86608
# wandb:       val/time_iter 0.04547
# wandb:
# wandb: 🚀 View run add_residual at: https://wandb.ai/omertalmi-tel-aviv-university/molhiv/runs/r1voazyo
# wandb: ⭐️ View project at: https://wandb.ai/omertalmi-tel-aviv-university/molhiv
# wandb: Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240930_163041-r1voazyo/logs
# Task done, results saved in results/ogbg-molhiv-GPS/0
# 38
# {'epoch': 38, 'time_epoch': 5.98365, 'loss': 0.08460869, 'lr': 0, 'params': 581095, 'time_iter': 0.04638, 'accuracy': 0.98006, 'precision': 0.49206, 'recall': 0.38272, 'f1': 0.43056, 'auc': 0.82894}
# {'epoch': 38, 'time_epoch': 6.05323, 'loss': 0.14684497, 'lr': 0, 'params': 581095, 'time_iter': 0.04692, 'accuracy': 0.96377, 'precision': 0.3956, 'recall': 0.27692, 'f1': 0.32579, 'auc': 0.79668}
# {'epoch': 38, 'time_epoch': 105.72351, 'eta': 6507.92459, 'eta_hours': 1.80776, 'loss': 0.07188116, 'lr': 7.307e-05, 'params': 581095, 'time_iter': 0.10274, 'accuracy': 0.97748, 'precision': 0.79976, 'recall': 0.53166, 'f1': 0.63871, 'auc': 0.95978}
# Results aggregated across runs saved in results/ogbg-molhiv-GPS/agg
# [*] All done: 2024-09-30 19:47:01.723059
