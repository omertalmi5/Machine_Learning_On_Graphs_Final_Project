# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/torch_scatter-2.1.2-cp310-cp310-linux_x86_64.whl
# /kaggle/input/torch_geometric-2.5.3-py3-none-any.whl
# /kaggle/input/torch_cluster-1.6.3-cp310-cp310-linux_x86_64.whl
# /kaggle/input/torch_spline_conv-1.2.2-cp310-cp310-linux_x86_64.whl
# /kaggle/input/torch_sparse-0.6.18-cp310-cp310-linux_x86_64.whl

# %%
# !git clone https://github.com/rampasek/GraphGPS.git
# Out:
# Cloning into 'GraphGPS'...
# remote: Enumerating objects: 526, done.
# remote: Counting objects: 100% (316/316), done.
# remote: Compressing objects: 100% (91/91), done.
# remote: Total 526 (delta 254), reused 225 (delta 225), pack-reused 210 (from 1)
# Receiving objects: 100% (526/526), 12.93 MiB | 34.12 MiB/s, done.
# Resolving deltas: 100% (336/336), done.

# %%
# %cd /kaggle/working/GraphGPS
# !ls
# Out:
# /kaggle/working/GraphGPS
# GraphGPS.png  README.md  final-results.zip  main.py  setup.py  unittests
# LICENSE       configs	 graphgps	    run      tests

# %% [markdown]
# ##  installation for slurm if needed using conda

# %%
# # for slurm if needed using conda 
# conda create -n graphgps python=3.10
# conda activate graphgps

# conda install pytorch=1.13 torchvision torchaudio pytorch-cuda=11.7 -c pytorch -c nvidia
# conda install pyg=2.2 -c pyg -c conda-forge
# pip install pyg-lib -f https://data.pyg.org/whl/torch-1.13.0+cu117.html

# # RDKit is required for OGB-LSC PCQM4Mv2 and datasets derived from it.  
# conda install openbabel fsspec rdkit -c conda-forge

# pip install pytorch-lightning yacs torchmetrics
# pip install performer-pytorch
# pip install tensorboardX
# pip install ogb
# pip install wandb

# conda clean --all

# %% [markdown]
# # installation for kaggle

# %%
# Check existing environment
import sys
print("Python version:", sys.version)
import torch
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)

# !pip uninstall -y torch torchvision torchaudio
# !pip install torch==2.0.1+cu118 torchvision==0.15.2+cu118 torchaudio==2.0.2+cu118 --index-url https://download.pytorch.org/whl/cu118

# !pip install torch_geometric

# Optional dependencies:
# !pip install pyg_lib torch_scatter torch_sparse torch_cluster torch_spline_conv -f https://data.pyg.org/whl/torch-2.4.0+cu124.html
# Install other required packages
# !pip install pytorch-lightning yacs torchmetrics
# !pip install performer-pytorch
# !pip install tensorboardX
# !pip install ogb
# !pip install wandb

# Attempt to install RDKit (may have limitations)
# !pip install rdkit-pypi
# !pip install openbabel fsspec
# !pip install  fsspec

# Clean up pip cache (optional)
# !pip cache purge
# Out:
# Python version: 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:45:18) [GCC 12.3.0]
# PyTorch version: 2.4.0
# CUDA available: True
# CUDA version: 12.3
# Found existing installation: torch 2.4.0
# Uninstalling torch-2.4.0:
#   Successfully uninstalled torch-2.4.0
# Found existing installation: torchvision 0.19.0
# Uninstalling torchvision-0.19.0:
#   Successfully uninstalled torchvision-0.19.0
# Found existing installation: torchaudio 2.4.0
# Uninstalling torchaudio-2.4.0:
#   Successfully uninstalled torchaudio-2.4.0
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Collecting torch==2.0.1+cu118
#   Downloading https://download.pytorch.org/whl/cu118/torch-2.0.1%2Bcu118-cp310-cp310-linux_x86_64.whl (2267.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 GB 374.1 kB/s eta 0:00:0000:0100:01
# Collecting torchvision==0.15.2+cu118
#   Downloading https://download.pytorch.org/whl/cu118/torchvision-0.15.2%2Bcu118-cp310-cp310-linux_x86_64.whl (6.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 80.4 MB/s eta 0:00:00:00:0100:01
# Collecting torchaudio==2.0.2+cu118
#   Downloading https://download.pytorch.org/whl/cu118/torchaudio-2.0.2%2Bcu118-cp310-cp310-linux_x86_64.whl (4.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 76.9 MB/s eta 0:00:00:00:01
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch==2.0.1+cu118) (3.15.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch==2.0.1+cu118) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch==2.0.1+cu118) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch==2.0.1+cu118) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch==2.0.1+cu118) (3.1.4)
# Collecting triton==2.0.0 (from torch==2.0.1+cu118)
#   Downloading https://download.pytorch.org/whl/triton-2.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 24.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision==0.15.2+cu118) (1.26.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torchvision==0.15.2+cu118) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision==0.15.2+cu118) (10.3.0)
# Collecting cmake (from triton==2.0.0->torch==2.0.1+cu118)
#   Downloading https://download.pytorch.org/whl/cmake-3.25.0-py2.py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 54.2 MB/s eta 0:00:0000:0100:01
# Collecting lit (from triton==2.0.0->torch==2.0.1+cu118)
#   Downloading https://download.pytorch.org/whl/lit-15.0.7.tar.gz (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.3/132.3 kB 9.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch==2.0.1+cu118) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.15.2+cu118) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.15.2+cu118) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.15.2+cu118) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.15.2+cu118) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch==2.0.1+cu118) (1.3.0)
# Building wheels for collected packages: lit
#   Building wheel for lit (setup.py) ... done
#   Created wheel for lit: filename=lit-15.0.7-py3-none-any.whl size=89987 sha256=9806610b0a8ab771ef05e5c4c2de0d4e66aa24bdec6ccf4130f6c6c70a5c957e
#   Stored in directory: /root/.cache/pip/wheels/27/2c/b6/3ed2983b1b44fe0dea1bb35234b09f2c22fb8ebb308679c922
# Successfully built lit
# Installing collected packages: lit, cmake, triton, torch, torchvision, torchaudio
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytorch-lightning 2.4.0 requires torch>=2.1.0, but you have torch 2.0.1+cu118 which is incompatible.
# Successfully installed cmake-3.25.0 lit-15.0.7 torch-2.0.1+cu118 torchaudio-2.0.2+cu118 torchvision-0.15.2+cu118 triton-2.0.0
# Collecting torch_geometric
#   Downloading torch_geometric-2.6.0-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (3.9.5)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (2024.6.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (3.1.4)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (1.26.4)
# Requirement already satisfied: psutil>=5.8.0 in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (5.9.3)
# Requirement already satisfied: pyparsing in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (3.1.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (2.32.3)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (4.66.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch_geometric) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (2024.8.30)
# Downloading torch_geometric-2.6.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 16.6 MB/s eta 0:00:00 0:00:01
# Installing collected packages: torch_geometric
# Successfully installed torch_geometric-2.6.0
# Looking in links: https://data.pyg.org/whl/torch-2.4.0+cu124.html
# Collecting pyg_lib
#   Downloading https://data.pyg.org/whl/torch-2.4.0%2Bcu124/pyg_lib-0.4.0%2Bpt24cu124-cp310-cp310-linux_x86_64.whl (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 23.2 MB/s eta 0:00:0000:0100:01
# Collecting torch_scatter
#   Downloading https://data.pyg.org/whl/torch-2.4.0%2Bcu124/torch_scatter-2.1.2%2Bpt24cu124-cp310-cp310-linux_x86_64.whl (10.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 63.6 MB/s eta 0:00:0000:0100:01
# Collecting torch_sparse
#   Downloading https://data.pyg.org/whl/torch-2.4.0%2Bcu124/torch_sparse-0.6.18%2Bpt24cu124-cp310-cp310-linux_x86_64.whl (5.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 65.3 MB/s eta 0:00:00:00:0100:01
# Collecting torch_cluster
#   Downloading https://data.pyg.org/whl/torch-2.4.0%2Bcu124/torch_cluster-1.6.3%2Bpt24cu124-cp310-cp310-linux_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 44.6 MB/s eta 0:00:0000:0100:01
# Collecting torch_spline_conv
#   Downloading https://data.pyg.org/whl/torch-2.4.0%2Bcu124/torch_spline_conv-1.2.2%2Bpt24cu124-cp310-cp310-linux_x86_64.whl (992 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 992.4/992.4 kB 11.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from torch_sparse) (1.14.1)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in /opt/conda/lib/python3.10/site-packages (from scipy->torch_sparse) (1.26.4)
# Installing collected packages: torch_spline_conv, torch_scatter, pyg_lib, torch_sparse, torch_cluster
# Successfully installed pyg_lib-0.4.0+pt24cu124 torch_cluster-1.6.3+pt24cu124 torch_scatter-2.1.2+pt24cu124 torch_sparse-0.6.18+pt24cu124 torch_spline_conv-1.2.2+pt24cu124
# Requirement already satisfied: pytorch-lightning in /opt/conda/lib/python3.10/site-packages (2.4.0)
# Collecting yacs
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: torchmetrics in /opt/conda/lib/python3.10/site-packages (1.4.2)
# Collecting torch>=2.1.0 (from pytorch-lightning)
#   Downloading torch-2.4.1-cp310-cp310-manylinux1_x86_64.whl.metadata (26 kB)
# Requirement already satisfied: tqdm>=4.57.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (4.66.4)
# Requirement already satisfied: PyYAML>=5.4 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (6.0.2)
# Requirement already satisfied: fsspec>=2022.5.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (2024.6.1)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (21.3)
# Requirement already satisfied: typing-extensions>=4.4.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (4.12.2)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (0.11.7)
# Requirement already satisfied: numpy>1.20.0 in /opt/conda/lib/python3.10/site-packages (from torchmetrics) (1.26.4)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (3.9.5)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from lightning-utilities>=0.10.0->pytorch-lightning) (70.0.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->pytorch-lightning) (3.1.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=2.1.0->pytorch-lightning) (3.15.1)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=2.1.0->pytorch-lightning) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=2.1.0->pytorch-lightning) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=2.1.0->pytorch-lightning) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.0.0 (from torch>=2.1.0->pytorch-lightning)
#   Downloading triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_nvjitlink_cu12-12.6.68-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=2.1.0->pytorch-lightning) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=2.1.0->pytorch-lightning) (1.3.0)
# Requirement already satisfied: idna>=2.0 in /opt/conda/lib/python3.10/site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (3.7)
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Downloading torch-2.4.1-cp310-cp310-manylinux1_x86_64.whl (797.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.1/797.1 MB 2.0 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.5 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 71.2 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 55.3 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 42.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.2 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 4.2 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 22.6 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 12.5 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 7.9 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 8.8 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 6.6 MB/s eta 0:00:00
# Downloading triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (209.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 7.2 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.6.68-py3-none-manylinux2014_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 63.2 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: yacs, triton, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch
#   Attempting uninstall: triton
#     Found existing installation: triton 2.0.0
#     Uninstalling triton-2.0.0:
#       Successfully uninstalled triton-2.0.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.1+cu118
#     Uninstalling torch-2.0.1+cu118:
#       Successfully uninstalled torch-2.0.1+cu118
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.0.2+cu118 requires torch==2.0.1, but you have torch 2.4.1 which is incompatible.
# torchvision 0.15.2+cu118 requires torch==2.0.1, but you have torch 2.4.1 which is incompatible.
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.6.68 nvidia-nvtx-cu12-12.1.105 torch-2.4.1 triton-3.0.0 yacs-0.1.8
# Collecting performer-pytorch
#   Downloading performer_pytorch-1.1.4-py3-none-any.whl.metadata (763 bytes)
# Collecting einops>=0.3 (from performer-pytorch)
#   Downloading einops-0.8.0-py3-none-any.whl.metadata (12 kB)
# Collecting local-attention>=1.1.1 (from performer-pytorch)
#   Downloading local_attention-1.9.15-py3-none-any.whl.metadata (683 bytes)
# Requirement already satisfied: torch>=1.6 in /opt/conda/lib/python3.10/site-packages (from performer-pytorch) (2.4.1)
# Collecting axial-positional-embedding>=0.1.0 (from performer-pytorch)
#   Downloading axial_positional_embedding-0.2.1.tar.gz (2.6 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.6->performer-pytorch) (12.6.68)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.6->performer-pytorch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.6->performer-pytorch) (1.3.0)
# Downloading performer_pytorch-1.1.4-py3-none-any.whl (13 kB)
# Downloading einops-0.8.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 1.6 MB/s eta 0:00:00
# Downloading local_attention-1.9.15-py3-none-any.whl (9.0 kB)
# Building wheels for collected packages: axial-positional-embedding
#   Building wheel for axial-positional-embedding (setup.py) ... done
#   Created wheel for axial-positional-embedding: filename=axial_positional_embedding-0.2.1-py3-none-any.whl size=2889 sha256=fb720999f2c913bfc98e346728730f8147a911f6ada8d8a7df72229e4c866653
#   Stored in directory: /root/.cache/pip/wheels/b1/cb/39/7ce7ff2d2fd37cfe1fe7b3a3c43cf410632b2ad3b3f3986d73
# Successfully built axial-positional-embedding
# Installing collected packages: einops, local-attention, axial-positional-embedding, performer-pytorch
# Successfully installed axial-positional-embedding-0.2.1 einops-0.8.0 local-attention-1.9.15 performer-pytorch-1.1.4
# Requirement already satisfied: tensorboardX in /opt/conda/lib/python3.10/site-packages (2.6.2.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from tensorboardX) (1.26.4)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorboardX) (21.3)
# Requirement already satisfied: protobuf>=3.20 in /opt/conda/lib/python3.10/site-packages (from tensorboardX) (3.20.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->tensorboardX) (3.1.2)
# Collecting ogb
#   Downloading ogb-1.3.6-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: torch>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (2.4.1)
# Requirement already satisfied: numpy>=1.16.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (1.26.4)
# Requirement already satisfied: tqdm>=4.29.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (4.66.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (1.2.2)
# Requirement already satisfied: pandas>=0.24.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (2.2.2)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (1.16.0)
# Requirement already satisfied: urllib3>=1.24.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (1.26.18)
# Collecting outdated>=0.2.0 (from ogb)
#   Downloading outdated-0.2.2-py2.py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: setuptools>=44 in /opt/conda/lib/python3.10/site-packages (from outdated>=0.2.0->ogb) (70.0.0)
# Collecting littleutils (from outdated>=0.2.0->ogb)
#   Downloading littleutils-0.2.4-py3-none-any.whl.metadata (679 bytes)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from outdated>=0.2.0->ogb) (2.32.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24.0->ogb) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24.0->ogb) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24.0->ogb) (2024.1)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.20.0->ogb) (1.14.1)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.20.0->ogb) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.20.0->ogb) (3.5.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.6.0->ogb) (12.6.68)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.6.0->ogb) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->outdated>=0.2.0->ogb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->outdated>=0.2.0->ogb) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->outdated>=0.2.0->ogb) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.6.0->ogb) (1.3.0)
# Downloading ogb-1.3.6-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 2.6 MB/s eta 0:00:00
# Downloading outdated-0.2.2-py2.py3-none-any.whl (7.5 kB)
# Downloading littleutils-0.2.4-py3-none-any.whl (8.1 kB)
# Installing collected packages: littleutils, outdated, ogb
# Successfully installed littleutils-0.2.4 ogb-1.3.6 outdated-0.2.2
# Requirement already satisfied: wandb in /opt/conda/lib/python3.10/site-packages (0.18.1)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /opt/conda/lib/python3.10/site-packages (from wandb) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.1.43)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.10/site-packages (from wandb) (3.11.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.20.3)
# Requirement already satisfied: psutil>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from wandb) (6.0.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.32.3)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.14.0)
# Requirement already satisfied: setproctitle in /opt/conda/lib/python3.10/site-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from wandb) (70.0.0)
# Requirement already satisfied: six>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2024.8.30)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.1)
# Collecting rdkit-pypi
#   Downloading rdkit_pypi-2022.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from rdkit-pypi) (1.26.4)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from rdkit-pypi) (10.3.0)
# Downloading rdkit_pypi-2022.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 50.6 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: rdkit-pypi
# Successfully installed rdkit-pypi-2022.9.5
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (2024.6.1)
# Files removed: 184

# %%
import sys
print("Python version:", sys.version)
import torch
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)
# Out:
# Python version: 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:45:18) [GCC 12.3.0]
# PyTorch version: 2.4.0
# CUDA available: True
# CUDA version: 12.3

# %%
import torch_geometric
print("PyG version:", torch_geometric.__version__)

import pytorch_lightning
print("PyTorch Lightning version:", pytorch_lightning.__version__)

import rdkit
print("RDKit version:", rdkit.__version__)
# Out:
# /opt/conda/lib/python3.10/site-packages/torch_geometric/typing.py:68: UserWarning: An issue occurred while importing 'pyg-lib'. Disabling its usage. Stacktrace: /opt/conda/lib/python3.10/site-packages/libpyg.so: undefined symbol: _ZNK5torch8autograd4Node4nameEv
#   warnings.warn(f"An issue occurred while importing 'pyg-lib'. "
# /opt/conda/lib/python3.10/site-packages/torch_geometric/typing.py:86: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: /opt/conda/lib/python3.10/site-packages/torch_scatter/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
#   warnings.warn(f"An issue occurred while importing 'torch-scatter'. "
# /opt/conda/lib/python3.10/site-packages/torch_geometric/typing.py:97: UserWarning: An issue occurred while importing 'torch-cluster'. Disabling its usage. Stacktrace: /opt/conda/lib/python3.10/site-packages/torch_cluster/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
#   warnings.warn(f"An issue occurred while importing 'torch-cluster'. "
# /opt/conda/lib/python3.10/site-packages/torch_geometric/typing.py:113: UserWarning: An issue occurred while importing 'torch-spline-conv'. Disabling its usage. Stacktrace: /opt/conda/lib/python3.10/site-packages/torch_spline_conv/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torch_geometric/typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: /opt/conda/lib/python3.10/site-packages/torch_sparse/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
#   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "
# PyG version: 2.6.0
# PyTorch Lightning version: 2.4.0
# RDKit version: 2022.09.5

# %%
print("Torch version:", torch.__version__)
# Out:
# Torch version: 2.4.0

# %% [markdown]
# # Running their model- GPSConv

# %%
# %cd /kaggle/working/GraphGPS
# !WANDB_MODE=disabled python main.py --cfg configs/GPS/ogbg-molhiv-GPS.yaml
# Out:
# /kaggle/working/GraphGPS
# [*] Run ID 0: seed=0, split_index=0
#     Starting now: 2024-09-24 14:48:36.034400
# Downloading http://snap.stanford.edu/ogb/data/graphproppred/csv_mol_download/hiv.zip
# Downloaded 0.00 GB: 100%|█████████████████████████| 3/3 [00:01<00:00,  2.14it/s]
# Extracting ./datasets/hiv.zip
# Processing...
# Loading necessary files...
# This might take a while.
# Processing graphs...
# 100%|██████████████████████████████████| 41127/41127 [00:00<00:00, 59243.16it/s]
# Converting graphs into PyG objects...
# 100%|██████████████████████████████████| 41127/41127 [00:02<00:00, 16873.60it/s]
# Saving...
# Done!
# /opt/conda/lib/python3.10/site-packages/ogb/graphproppred/dataset_pyg.py:68: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.data, self.slices = torch.load(self.processed_paths[0])
# [*] Loaded dataset 'ogbg-molhiv' from 'OGB':
# /opt/conda/lib/python3.10/site-packages/torch_geometric/data/in_memory_dataset.py:300: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
#   Data(edge_index=[2, 2259376], edge_attr=[2259376, 3], x=[1049163, 9], y=[41127, 1], num_nodes=1049163)
#   undirected: True
#   num graphs: 41127
# /opt/conda/lib/python3.10/site-packages/torch_geometric/data/in_memory_dataset.py:300: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. The data of the dataset is already cached, so any modifications to `data` will not be reflected when accessing its elements. Clearing the cache now by removing all elements in `dataset._data_list`. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
#   avg num_nodes/graph: 25
#   num node features: 9
#   num edge features: 3
#   num tasks: 1
#   num classes: 2
# Precomputing Positional Encoding statistics: ['LapPE'] for all graphs...
#   ...estimated to be undirected: True
# 100%|████████████████████████████████████| 41127/41127 [00:58<00:00, 704.68it/s]
# Done! Took 00:01:00.08
# GraphGymModule(
#   (model): GPSModel(
#     (encoder): FeatureEncoder(
#       (node_encoder): Concat2NodeEncoder(
#         (encoder1): AtomEncoder(
#           (atom_embedding_list): ModuleList(
#             (0): Embedding(119, 56)
#             (1): Embedding(5, 56)
#             (2-3): 2 x Embedding(12, 56)
#             (4): Embedding(10, 56)
#             (5-6): 2 x Embedding(6, 56)
#             (7-8): 2 x Embedding(2, 56)
#           )
#         )
#         (encoder2): LapPENodeEncoder(
#           (linear_A): Linear(in_features=2, out_features=16, bias=True)
#           (pe_encoder): Sequential(
#             (0): ReLU()
#             (1): Linear(in_features=16, out_features=8, bias=True)
#             (2): ReLU()
#           )
#         )
#       )
#       (edge_encoder): BondEncoder(
#         (bond_embedding_list): ModuleList(
#           (0): Embedding(5, 64)
#           (1): Embedding(6, 64)
#           (2): Embedding(2, 64)
#         )
#       )
#     )
#     (layers): Sequential(
#       (0): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (1): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (2): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (3): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (4): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (5): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (6): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (7): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (8): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (9): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#     )
#     (post_mp): SANGraphHead(
#       (FC_layers): ModuleList(
#         (0): Linear(in_features=64, out_features=32, bias=True)
#         (1): Linear(in_features=32, out_features=16, bias=True)
#         (2): Linear(in_features=16, out_features=1, bias=True)
#       )
#       (activation): ReLU()
#     )
#   )
# )
# accelerator: cuda
# benchmark: False
# bn:
#   eps: 1e-05
#   mom: 0.1
# cfg_dest: config.yaml
# custom_metrics: []
# dataset:
#   cache_load: False
#   cache_save: False
#   dir: ./datasets
#   edge_dim: 128
#   edge_encoder: True
#   edge_encoder_bn: False
#   edge_encoder_name: Bond
#   edge_encoder_num_types: 0
#   edge_message_ratio: 0.8
#   edge_negative_sampling_ratio: 1.0
#   edge_train_mode: all
#   encoder: True
#   encoder_bn: True
#   encoder_dim: 128
#   encoder_name: db
#   format: OGB
#   infer_link_label: None
#   label_column: none
#   label_table: none
#   location: local
#   name: ogbg-molhiv
#   node_encoder: True
#   node_encoder_bn: False
#   node_encoder_name: Atom+LapPE
#   node_encoder_num_types: 0
#   remove_feature: False
#   resample_disjoint: False
#   resample_negative: False
#   shuffle_split: True
#   slic_compactness: 10
#   split: [0.8, 0.1, 0.1]
#   split_dir: ./splits
#   split_index: 0
#   split_mode: standard
#   task: graph
#   task_type: classification
#   to_undirected: False
#   transductive: False
#   transform: none
#   tu_simple: True
# devices: 1
# example_arg: example
# example_group:
#   example_arg: example
# gnn:
#   act: relu
#   agg: mean
#   att_final_linear: False
#   att_final_linear_bn: False
#   att_heads: 1
#   batchnorm: True
#   clear_feature: True
#   dim_edge: 64
#   dim_inner: 64
#   dropout: 0.0
#   head: san_graph
#   keep_edge: 0.5
#   l2norm: True
#   layer_type: generalconv
#   layers_mp: 2
#   layers_post_mp: 3
#   layers_pre_mp: 0
#   msg_direction: single
#   normalize_adj: False
#   residual: False
#   self_msg: concat
#   skip_every: 1
#   stage_type: stack
# gpu_mem: False
# graphormer:
#   attention_dropout: 0.0
#   dropout: 0.0
#   embed_dim: 80
#   input_dropout: 0.0
#   mlp_dropout: 0.0
#   num_heads: 4
#   num_layers: 6
#   use_graph_token: True
# gt:
#   attn_dropout: 0.5
#   batch_norm: True
#   bigbird:
#     add_cross_attention: False
#     attention_type: block_sparse
#     block_size: 3
#     chunk_size_feed_forward: 0
#     hidden_act: relu
#     is_decoder: False
#     layer_norm_eps: 1e-06
#     max_position_embeddings: 128
#     num_random_blocks: 3
#     use_bias: False
#   dim_hidden: 64
#   dropout: 0.05
#   full_graph: True
#   gamma: 1e-05
#   layer_norm: False
#   layer_type: CustomGatedGCN+Transformer
#   layers: 10
#   n_heads: 4
#   pna_degrees: []
#   residual: True
# mem:
#   inplace: False
# metric_agg: argmax
# metric_best: auc
# model:
#   edge_decoding: dot
#   graph_pooling: mean
#   loss_fun: cross_entropy
#   match_upper: True
#   size_average: mean
#   thresh: 0.5
#   type: GPSModel
# name_tag:
# num_threads: 6
# num_workers: 0
# optim:
#   base_lr: 0.0001
#   batch_accumulation: 1
#   clip_grad_norm: True
#   clip_grad_norm_value: 1.0
#   lr_decay: 0.1
#   max_epoch: 100
#   min_lr: 0.0
#   momentum: 0.9
#   num_warmup_epochs: 5
#   optimizer: adamW
#   reduce_factor: 0.1
#   schedule_patience: 10
#   scheduler: cosine_with_warmup
#   steps: [30, 60, 90]
#   weight_decay: 1e-05
# out_dir: results/ogbg-molhiv-GPS
# posenc_ElstaticSE:
#   dim_pe: 16
#   enable: False
#   kernel:
#     times: []
#     times_func: range(10)
#   layers: 3
#   model: none
#   n_heads: 4
#   pass_as_var: False
#   post_layers: 0
#   raw_norm_type: none
# posenc_EquivStableLapPE:
#   eigen:
#     eigvec_norm: L2
#     laplacian_norm: sym
#     max_freqs: 10
#   enable: False
#   raw_norm_type: none
# posenc_GraphormerBias:
#   dim_pe: 0
#   enable: False
#   node_degrees_only: False
#   num_in_degrees: None
#   num_out_degrees: None
#   num_spatial_types: None
# posenc_HKdiagSE:
#   dim_pe: 16
#   enable: False
#   kernel:
#     times: []
#     times_func:
#   layers: 3
#   model: none
#   n_heads: 4
#   pass_as_var: False
#   post_layers: 0
#   raw_norm_type: none
# posenc_LapPE:
#   dim_pe: 8
#   eigen:
#     eigvec_norm: L2
#     laplacian_norm: none
#     max_freqs: 8
#   enable: True
#   layers: 2
#   model: DeepSet
#   n_heads: 4
#   pass_as_var: False
#   post_layers: 0
#   raw_norm_type: none
# posenc_RWSE:
#   dim_pe: 16
#   enable: False
#   kernel:
#     times: []
#     times_func:
#   layers: 3
#   model: none
#   n_heads: 4
#   pass_as_var: False
#   post_layers: 0
#   raw_norm_type: none
# posenc_SignNet:
#   dim_pe: 16
#   eigen:
#     eigvec_norm: L2
#     laplacian_norm: sym
#     max_freqs: 10
#   enable: False
#   layers: 3
#   model: none
#   n_heads: 4
#   pass_as_var: False
#   phi_hidden_dim: 64
#   phi_out_dim: 4
#   post_layers: 0
#   raw_norm_type: none
# pretrained:
#   dir:
#   freeze_main: False
#   reset_prediction_head: True
# print: both
# round: 5
# run_dir: results/ogbg-molhiv-GPS/0
# run_id: 0
# run_multiple_splits: []
# seed: 0
# share:
#   dim_in: 9
#   dim_out: 2
#   num_splits: 3
# tensorboard_agg: True
# tensorboard_each_run: False
# train:
#   auto_resume: False
#   batch_size: 32
#   ckpt_best: False
#   ckpt_clean: True
#   ckpt_period: 100
#   enable_ckpt: True
#   epoch_resume: -1
#   eval_period: 1
#   iter_per_epoch: 32
#   mode: custom
#   neighbor_sizes: [20, 15, 10, 5]
#   node_per_graph: 32
#   radius: extend
#   sample_node: False
#   sampler: full_batch
#   skip_train_eval: False
#   walk_length: 4
# val:
#   node_per_graph: 32
#   radius: extend
#   sample_node: False
#   sampler: full_batch
# view_emb: False
# wandb:
#   entity: gtransformers
#   name:
#   project: molhiv
#   use: True
# Num parameters: 559945
# Start from epoch 0
# Key posenc_GraphormerBias.num_spatial_types with value <class 'NoneType'> is not a valid type; valid types: {<class 'list'>, <class 'str'>, <class 'bool'>, <class 'int'>, <class 'float'>, <class 'tuple'>}
# Key posenc_GraphormerBias.num_in_degrees with value <class 'NoneType'> is not a valid type; valid types: {<class 'list'>, <class 'str'>, <class 'bool'>, <class 'int'>, <class 'float'>, <class 'tuple'>}
# Key posenc_GraphormerBias.num_out_degrees with value <class 'NoneType'> is not a valid type; valid types: {<class 'list'>, <class 'str'>, <class 'bool'>, <class 'int'>, <class 'float'>, <class 'tuple'>}
# train: {'epoch': 0, 'time_epoch': 99.38673, 'eta': 9839.2865, 'eta_hours': 2.73314, 'loss': 0.79160294, 'lr': 0.0, 'params': 559945, 'time_iter': 0.09659, 'accuracy': 0.03748, 'precision': 0.03745, 'recall': 1.0, 'f1': 0.07219, 'auc': 0.55785}
# ...computing epoch stats took: 0.10s
# val: {'epoch': 0, 'time_epoch': 5.25705, 'loss': 0.79690719, 'lr': 0, 'params': 559945, 'time_iter': 0.04075, 'accuracy': 0.01969, 'precision': 0.01969, 'recall': 1.0, 'f1': 0.03863, 'auc': 0.53566}
# ...computing epoch stats took: 0.01s
# test: {'epoch': 0, 'time_epoch': 5.7069, 'loss': 0.79430785, 'lr': 0, 'params': 559945, 'time_iter': 0.04424, 'accuracy': 0.03161, 'precision': 0.03161, 'recall': 1.0, 'f1': 0.06128, 'auc': 0.57793}
# ...computing epoch stats took: 0.01s
# > Epoch 0: took 110.5s (avg 110.5s) | Best so far: epoch 0	train_loss: 0.7916 train_auc: 0.5578	val_loss: 0.7969 val_auc: 0.5357	test_loss: 0.7943 test_auc: 0.5779
# train: {'epoch': 1, 'time_epoch': 92.28774, 'eta': 9392.04924, 'eta_hours': 2.6089, 'loss': 0.49233538, 'lr': 2e-05, 'params': 559945, 'time_iter': 0.08969, 'accuracy': 0.76682, 'precision': 0.04673, 'recall': 0.26948, 'f1': 0.07965, 'auc': 0.5597}
# ...computing epoch stats took: 0.09s
# val: {'epoch': 1, 'time_epoch': 4.53555, 'loss': 0.2685116, 'lr': 0, 'params': 559945, 'time_iter': 0.03516, 'accuracy': 0.97617, 'precision': 0.13043, 'recall': 0.03704, 'f1': 0.05769, 'auc': 0.66161}
# ...computing epoch stats took: 0.02s
# test: {'epoch': 1, 'time_epoch': 4.60092, 'loss': 0.26887835, 'lr': 0, 'params': 559945, 'time_iter': 0.03567, 'accuracy': 0.96815, 'precision': 0.46667, 'recall': 0.05385, 'f1': 0.09655, 'auc': 0.66958}
# ...computing epoch stats took: 0.02s
# > Epoch 1: took 101.6s (avg 106.1s) | Best so far: epoch 1	train_loss: 0.4923 train_auc: 0.5597	val_loss: 0.2685 val_auc: 0.6616	test_loss: 0.2689 test_auc: 0.6696
# train: {'epoch': 2, 'time_epoch': 94.42282, 'eta': 9250.47927, 'eta_hours': 2.56958, 'loss': 0.18898395, 'lr': 4e-05, 'params': 559945, 'time_iter': 0.09176, 'accuracy': 0.96231, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.61709}
# ...computing epoch stats took: 0.08s
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 2, 'time_epoch': 4.48908, 'loss': 0.10147719, 'lr': 0, 'params': 559945, 'time_iter': 0.0348, 'accuracy': 0.98031, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.69372}
# ...computing epoch stats took: 0.02s
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# test: {'epoch': 2, 'time_epoch': 4.34649, 'loss': 0.13180921, 'lr': 0, 'params': 559945, 'time_iter': 0.03369, 'accuracy': 0.96839, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.73157}
# ...computing epoch stats took: 0.02s
# > Epoch 2: took 103.4s (avg 105.2s) | Best so far: epoch 2	train_loss: 0.1890 train_auc: 0.6171	val_loss: 0.1015 val_auc: 0.6937	test_loss: 0.1318 test_auc: 0.7316
# train: {'epoch': 3, 'time_epoch': 91.46005, 'eta': 9061.37632, 'eta_hours': 2.51705, 'loss': 0.14630846, 'lr': 6e-05, 'params': 559945, 'time_iter': 0.08888, 'accuracy': 0.96295, 'precision': 0.72414, 'recall': 0.01705, 'f1': 0.03331, 'auc': 0.70101}
# val: {'epoch': 3, 'time_epoch': 4.38038, 'loss': 0.08382278, 'lr': 0, 'params': 559945, 'time_iter': 0.03396, 'accuracy': 0.98177, 'precision': 0.8, 'recall': 0.09877, 'f1': 0.17582, 'auc': 0.76363}
# test: {'epoch': 3, 'time_epoch': 4.34908, 'loss': 0.11734906, 'lr': 0, 'params': 559945, 'time_iter': 0.03371, 'accuracy': 0.96864, 'precision': 0.6, 'recall': 0.02308, 'f1': 0.04444, 'auc': 0.75635}
# > Epoch 3: took 100.3s (avg 104.0s) | Best so far: epoch 3	train_loss: 0.1463 train_auc: 0.7010	val_loss: 0.0838 val_auc: 0.7636	test_loss: 0.1173 test_auc: 0.7563
# train: {'epoch': 4, 'time_epoch': 92.30604, 'eta': 8927.40439, 'eta_hours': 2.47983, 'loss': 0.13807207, 'lr': 8e-05, 'params': 559945, 'time_iter': 0.0897, 'accuracy': 0.96456, 'precision': 0.775, 'recall': 0.07549, 'f1': 0.13757, 'auc': 0.7389}
# val: {'epoch': 4, 'time_epoch': 4.43583, 'loss': 0.08129942, 'lr': 0, 'params': 559945, 'time_iter': 0.03439, 'accuracy': 0.98177, 'precision': 0.66667, 'recall': 0.14815, 'f1': 0.24242, 'auc': 0.78566}
# test: {'epoch': 4, 'time_epoch': 4.36059, 'loss': 0.11505091, 'lr': 0, 'params': 559945, 'time_iter': 0.0338, 'accuracy': 0.9718, 'precision': 0.79167, 'recall': 0.14615, 'f1': 0.24675, 'auc': 0.77235}
# > Epoch 4: took 101.3s (avg 103.4s) | Best so far: epoch 4	train_loss: 0.1381 train_auc: 0.7389	val_loss: 0.0813 val_auc: 0.7857	test_loss: 0.1151 test_auc: 0.7723
# train: {'epoch': 5, 'time_epoch': 93.03054, 'eta': 8818.67153, 'eta_hours': 2.44963, 'loss': 0.13297424, 'lr': 0.0001, 'params': 559945, 'time_iter': 0.09041, 'accuracy': 0.96486, 'precision': 0.68095, 'recall': 0.11607, 'f1': 0.19834, 'auc': 0.76524}
# val: {'epoch': 5, 'time_epoch': 4.33371, 'loss': 0.07584623, 'lr': 0, 'params': 559945, 'time_iter': 0.03359, 'accuracy': 0.98104, 'precision': 0.56, 'recall': 0.17284, 'f1': 0.26415, 'auc': 0.80826}
# test: {'epoch': 5, 'time_epoch': 4.2893, 'loss': 0.11639012, 'lr': 0, 'params': 559945, 'time_iter': 0.03325, 'accuracy': 0.9718, 'precision': 0.65909, 'recall': 0.22308, 'f1': 0.33333, 'auc': 0.75132}
# > Epoch 5: took 101.8s (avg 103.2s) | Best so far: epoch 5	train_loss: 0.1330 train_auc: 0.7652	val_loss: 0.0758 val_auc: 0.8083	test_loss: 0.1164 test_auc: 0.7513
# train: {'epoch': 6, 'time_epoch': 92.37554, 'eta': 8705.72287, 'eta_hours': 2.41826, 'loss': 0.12715544, 'lr': 9.997e-05, 'params': 559945, 'time_iter': 0.08977, 'accuracy': 0.96584, 'precision': 0.68493, 'recall': 0.16234, 'f1': 0.26247, 'auc': 0.79495}
# val: {'epoch': 6, 'time_epoch': 4.43574, 'loss': 0.07836902, 'lr': 0, 'params': 559945, 'time_iter': 0.03439, 'accuracy': 0.98104, 'precision': 0.56522, 'recall': 0.16049, 'f1': 0.25, 'auc': 0.78747}
# test: {'epoch': 6, 'time_epoch': 4.52574, 'loss': 0.11392123, 'lr': 0, 'params': 559945, 'time_iter': 0.03508, 'accuracy': 0.97228, 'precision': 0.73529, 'recall': 0.19231, 'f1': 0.30488, 'auc': 0.76795}
# > Epoch 6: took 101.5s (avg 102.9s) | Best so far: epoch 5	train_loss: 0.1330 train_auc: 0.7652	val_loss: 0.0758 val_auc: 0.8083	test_loss: 0.1164 test_auc: 0.7513
# train: {'epoch': 7, 'time_epoch': 90.02171, 'eta': 8570.84851, 'eta_hours': 2.38079, 'loss': 0.12511893, 'lr': 9.989e-05, 'params': 559945, 'time_iter': 0.08748, 'accuracy': 0.96553, 'precision': 0.64327, 'recall': 0.17857, 'f1': 0.27954, 'auc': 0.79817}
# val: {'epoch': 7, 'time_epoch': 4.32421, 'loss': 0.07849859, 'lr': 0, 'params': 559945, 'time_iter': 0.03352, 'accuracy': 0.98055, 'precision': 0.51724, 'recall': 0.18519, 'f1': 0.27273, 'auc': 0.81868}
# test: {'epoch': 7, 'time_epoch': 4.36617, 'loss': 0.12151835, 'lr': 0, 'params': 559945, 'time_iter': 0.03385, 'accuracy': 0.96985, 'precision': 0.575, 'recall': 0.17692, 'f1': 0.27059, 'auc': 0.75255}
# > Epoch 7: took 98.9s (avg 102.4s) | Best so far: epoch 7	train_loss: 0.1251 train_auc: 0.7982	val_loss: 0.0785 val_auc: 0.8187	test_loss: 0.1215 test_auc: 0.7526
# train: {'epoch': 8, 'time_epoch': 91.13333, 'eta': 8457.18107, 'eta_hours': 2.34922, 'loss': 0.1210451, 'lr': 9.975e-05, 'params': 559945, 'time_iter': 0.08856, 'accuracy': 0.96611, 'precision': 0.63962, 'recall': 0.21753, 'f1': 0.32465, 'auc': 0.81198}
# val: {'epoch': 8, 'time_epoch': 4.36434, 'loss': 0.07291282, 'lr': 0, 'params': 559945, 'time_iter': 0.03383, 'accuracy': 0.98177, 'precision': 0.61538, 'recall': 0.19753, 'f1': 0.29907, 'auc': 0.81797}
# test: {'epoch': 8, 'time_epoch': 4.34013, 'loss': 0.12462511, 'lr': 0, 'params': 559945, 'time_iter': 0.03364, 'accuracy': 0.96888, 'precision': 0.55556, 'recall': 0.07692, 'f1': 0.13514, 'auc': 0.73403}
# > Epoch 8: took 100.0s (avg 102.1s) | Best so far: epoch 7	train_loss: 0.1251 train_auc: 0.7982	val_loss: 0.0785 val_auc: 0.8187	test_loss: 0.1215 test_auc: 0.7526
# train: {'epoch': 9, 'time_epoch': 88.74887, 'eta': 8326.56038, 'eta_hours': 2.31293, 'loss': 0.1176422, 'lr': 9.956e-05, 'params': 559945, 'time_iter': 0.08625, 'accuracy': 0.96717, 'precision': 0.66667, 'recall': 0.24675, 'f1': 0.36019, 'auc': 0.82513}
# val: {'epoch': 9, 'time_epoch': 4.15435, 'loss': 0.0718317, 'lr': 0, 'params': 559945, 'time_iter': 0.0322, 'accuracy': 0.98152, 'precision': 0.61905, 'recall': 0.16049, 'f1': 0.2549, 'auc': 0.81318}
# test: {'epoch': 9, 'time_epoch': 4.1191, 'loss': 0.11337738, 'lr': 0, 'params': 559945, 'time_iter': 0.03193, 'accuracy': 0.97204, 'precision': 0.74194, 'recall': 0.17692, 'f1': 0.28571, 'auc': 0.77412}
# > Epoch 9: took 97.2s (avg 101.7s) | Best so far: epoch 7	train_loss: 0.1251 train_auc: 0.7982	val_loss: 0.0785 val_auc: 0.8187	test_loss: 0.1215 test_auc: 0.7526
# train: {'epoch': 10, 'time_epoch': 88.30879, 'eta': 8199.99207, 'eta_hours': 2.27778, 'loss': 0.1158452, 'lr': 9.932e-05, 'params': 559945, 'time_iter': 0.08582, 'accuracy': 0.96666, 'precision': 0.64033, 'recall': 0.25, 'f1': 0.3596, 'auc': 0.83065}
# val: {'epoch': 10, 'time_epoch': 4.45504, 'loss': 0.07735153, 'lr': 0, 'params': 559945, 'time_iter': 0.03454, 'accuracy': 0.97885, 'precision': 0.45, 'recall': 0.33333, 'f1': 0.38298, 'auc': 0.81122}
# test: {'epoch': 10, 'time_epoch': 4.33842, 'loss': 0.12216294, 'lr': 0, 'params': 559945, 'time_iter': 0.03363, 'accuracy': 0.96888, 'precision': 0.51515, 'recall': 0.26154, 'f1': 0.34694, 'auc': 0.75516}
# > Epoch 10: took 97.3s (avg 101.3s) | Best so far: epoch 7	train_loss: 0.1251 train_auc: 0.7982	val_loss: 0.0785 val_auc: 0.8187	test_loss: 0.1215 test_auc: 0.7526
# train: {'epoch': 11, 'time_epoch': 95.50692, 'eta': 8132.5866, 'eta_hours': 2.25905, 'loss': 0.11518534, 'lr': 9.902e-05, 'params': 559945, 'time_iter': 0.09282, 'accuracy': 0.96769, 'precision': 0.67002, 'recall': 0.27029, 'f1': 0.38519, 'auc': 0.83021}
# val: {'epoch': 11, 'time_epoch': 4.53795, 'loss': 0.06744068, 'lr': 0, 'params': 559945, 'time_iter': 0.03518, 'accuracy': 0.98249, 'precision': 0.68, 'recall': 0.20988, 'f1': 0.32075, 'auc': 0.84298}
# test: {'epoch': 11, 'time_epoch': 4.48362, 'loss': 0.11472062, 'lr': 0, 'params': 559945, 'time_iter': 0.03476, 'accuracy': 0.97155, 'precision': 0.68571, 'recall': 0.18462, 'f1': 0.29091, 'auc': 0.76339}
# > Epoch 11: took 104.7s (avg 101.5s) | Best so far: epoch 11	train_loss: 0.1152 train_auc: 0.8302	val_loss: 0.0674 val_auc: 0.8430	test_loss: 0.1147 test_auc: 0.7634
# train: {'epoch': 12, 'time_epoch': 94.95702, 'eta': 8057.17775, 'eta_hours': 2.2381, 'loss': 0.11262698, 'lr': 9.867e-05, 'params': 559945, 'time_iter': 0.09228, 'accuracy': 0.96839, 'precision': 0.68391, 'recall': 0.28977, 'f1': 0.40707, 'auc': 0.84178}
# val: {'epoch': 12, 'time_epoch': 4.39783, 'loss': 0.07480816, 'lr': 0, 'params': 559945, 'time_iter': 0.03409, 'accuracy': 0.98201, 'precision': 0.57447, 'recall': 0.33333, 'f1': 0.42188, 'auc': 0.80809}
# test: {'epoch': 12, 'time_epoch': 4.36469, 'loss': 0.11711799, 'lr': 0, 'params': 559945, 'time_iter': 0.03383, 'accuracy': 0.96985, 'precision': 0.54054, 'recall': 0.30769, 'f1': 0.39216, 'auc': 0.75185}
# > Epoch 12: took 103.9s (avg 101.7s) | Best so far: epoch 11	train_loss: 0.1152 train_auc: 0.8302	val_loss: 0.0674 val_auc: 0.8430	test_loss: 0.1147 test_auc: 0.7634
# train: {'epoch': 13, 'time_epoch': 90.63953, 'eta': 7952.45461, 'eta_hours': 2.20902, 'loss': 0.11125441, 'lr': 9.826e-05, 'params': 559945, 'time_iter': 0.08809, 'accuracy': 0.96842, 'precision': 0.67837, 'recall': 0.29789, 'f1': 0.41399, 'auc': 0.85116}
# val: {'epoch': 13, 'time_epoch': 4.33654, 'loss': 0.06946938, 'lr': 0, 'params': 559945, 'time_iter': 0.03362, 'accuracy': 0.98249, 'precision': 0.65517, 'recall': 0.23457, 'f1': 0.34545, 'auc': 0.81934}
# test: {'epoch': 13, 'time_epoch': 4.32954, 'loss': 0.12009493, 'lr': 0, 'params': 559945, 'time_iter': 0.03356, 'accuracy': 0.97131, 'precision': 0.73077, 'recall': 0.14615, 'f1': 0.24359, 'auc': 0.75744}
# > Epoch 13: took 99.5s (avg 101.6s) | Best so far: epoch 11	train_loss: 0.1152 train_auc: 0.8302	val_loss: 0.0674 val_auc: 0.8430	test_loss: 0.1147 test_auc: 0.7634
# train: {'epoch': 14, 'time_epoch': 90.50423, 'eta': 7848.84256, 'eta_hours': 2.18023, 'loss': 0.11052585, 'lr': 9.78e-05, 'params': 559945, 'time_iter': 0.08795, 'accuracy': 0.96854, 'precision': 0.67812, 'recall': 0.30438, 'f1': 0.42017, 'auc': 0.84903}
# val: {'epoch': 14, 'time_epoch': 4.27413, 'loss': 0.0676252, 'lr': 0, 'params': 559945, 'time_iter': 0.03313, 'accuracy': 0.98371, 'precision': 0.69444, 'recall': 0.30864, 'f1': 0.42735, 'auc': 0.83832}
# test: {'epoch': 14, 'time_epoch': 4.29668, 'loss': 0.11624428, 'lr': 0, 'params': 559945, 'time_iter': 0.03331, 'accuracy': 0.97058, 'precision': 0.60465, 'recall': 0.2, 'f1': 0.30058, 'auc': 0.76384}
# > Epoch 14: took 99.2s (avg 101.4s) | Best so far: epoch 11	train_loss: 0.1152 train_auc: 0.8302	val_loss: 0.0674 val_auc: 0.8430	test_loss: 0.1147 test_auc: 0.7634
# train: {'epoch': 15, 'time_epoch': 89.12419, 'eta': 7739.6238, 'eta_hours': 2.1499, 'loss': 0.10744502, 'lr': 9.729e-05, 'params': 559945, 'time_iter': 0.08661, 'accuracy': 0.96921, 'precision': 0.69519, 'recall': 0.31656, 'f1': 0.43503, 'auc': 0.85857}
# val: {'epoch': 15, 'time_epoch': 4.26391, 'loss': 0.06953374, 'lr': 0, 'params': 559945, 'time_iter': 0.03305, 'accuracy': 0.98225, 'precision': 0.59524, 'recall': 0.30864, 'f1': 0.4065, 'auc': 0.82598}
# test: {'epoch': 15, 'time_epoch': 4.24729, 'loss': 0.11613011, 'lr': 0, 'params': 559945, 'time_iter': 0.03292, 'accuracy': 0.96961, 'precision': 0.54386, 'recall': 0.23846, 'f1': 0.33155, 'auc': 0.76678}
# > Epoch 15: took 97.8s (avg 101.2s) | Best so far: epoch 11	train_loss: 0.1152 train_auc: 0.8302	val_loss: 0.0674 val_auc: 0.8430	test_loss: 0.1147 test_auc: 0.7634
# train: {'epoch': 16, 'time_epoch': 87.99993, 'eta': 7627.28005, 'eta_hours': 2.11869, 'loss': 0.1061184, 'lr': 9.673e-05, 'params': 559945, 'time_iter': 0.08552, 'accuracy': 0.96939, 'precision': 0.691, 'recall': 0.33036, 'f1': 0.44701, 'auc': 0.86379}
# val: {'epoch': 16, 'time_epoch': 4.31363, 'loss': 0.07099598, 'lr': 0, 'params': 559945, 'time_iter': 0.03344, 'accuracy': 0.98104, 'precision': 0.53191, 'recall': 0.30864, 'f1': 0.39062, 'auc': 0.82388}
# test: {'epoch': 16, 'time_epoch': 4.17798, 'loss': 0.11549615, 'lr': 0, 'params': 559945, 'time_iter': 0.03239, 'accuracy': 0.96961, 'precision': 0.54545, 'recall': 0.23077, 'f1': 0.32432, 'auc': 0.75724}
# > Epoch 16: took 96.7s (avg 100.9s) | Best so far: epoch 11	train_loss: 0.1152 train_auc: 0.8302	val_loss: 0.0674 val_auc: 0.8430	test_loss: 0.1147 test_auc: 0.7634
# train: {'epoch': 17, 'time_epoch': 88.24203, 'eta': 7518.74407, 'eta_hours': 2.08854, 'loss': 0.10353341, 'lr': 9.611e-05, 'params': 559945, 'time_iter': 0.08576, 'accuracy': 0.97018, 'precision': 0.71022, 'recall': 0.34416, 'f1': 0.46364, 'auc': 0.87252}
# val: {'epoch': 17, 'time_epoch': 4.20495, 'loss': 0.07145501, 'lr': 0, 'params': 559945, 'time_iter': 0.0326, 'accuracy': 0.98249, 'precision': 0.65517, 'recall': 0.23457, 'f1': 0.34545, 'auc': 0.82461}
# test: {'epoch': 17, 'time_epoch': 4.20617, 'loss': 0.12142066, 'lr': 0, 'params': 559945, 'time_iter': 0.03261, 'accuracy': 0.96742, 'precision': 0.42857, 'recall': 0.09231, 'f1': 0.1519, 'auc': 0.76591}
# > Epoch 17: took 96.8s (avg 100.7s) | Best so far: epoch 11	train_loss: 0.1152 train_auc: 0.8302	val_loss: 0.0674 val_auc: 0.8430	test_loss: 0.1147 test_auc: 0.7634
# train: {'epoch': 18, 'time_epoch': 87.74239, 'eta': 7410.21425, 'eta_hours': 2.05839, 'loss': 0.10531924, 'lr': 9.545e-05, 'params': 559945, 'time_iter': 0.08527, 'accuracy': 0.96939, 'precision': 0.68971, 'recall': 0.33198, 'f1': 0.44822, 'auc': 0.87275}
# val: {'epoch': 18, 'time_epoch': 4.19536, 'loss': 0.07189074, 'lr': 0, 'params': 559945, 'time_iter': 0.03252, 'accuracy': 0.98177, 'precision': 0.5625, 'recall': 0.33333, 'f1': 0.4186, 'auc': 0.80342}
# test: {'epoch': 18, 'time_epoch': 4.24201, 'loss': 0.11287499, 'lr': 0, 'params': 559945, 'time_iter': 0.03288, 'accuracy': 0.96937, 'precision': 0.53226, 'recall': 0.25385, 'f1': 0.34375, 'auc': 0.7855}
# > Epoch 18: took 96.3s (avg 100.5s) | Best so far: epoch 11	train_loss: 0.1152 train_auc: 0.8302	val_loss: 0.0674 val_auc: 0.8430	test_loss: 0.1147 test_auc: 0.7634
# train: {'epoch': 19, 'time_epoch': 87.8183, 'eta': 7304.06681, 'eta_hours': 2.02891, 'loss': 0.10190497, 'lr': 9.474e-05, 'params': 559945, 'time_iter': 0.08534, 'accuracy': 0.97058, 'precision': 0.71711, 'recall': 0.3539, 'f1': 0.47391, 'auc': 0.88176}
# val: {'epoch': 19, 'time_epoch': 4.21463, 'loss': 0.0706142, 'lr': 0, 'params': 559945, 'time_iter': 0.03267, 'accuracy': 0.98347, 'precision': 0.78261, 'recall': 0.22222, 'f1': 0.34615, 'auc': 0.82183}
# test: {'epoch': 19, 'time_epoch': 4.19578, 'loss': 0.12312086, 'lr': 0, 'params': 559945, 'time_iter': 0.03253, 'accuracy': 0.96864, 'precision': 0.52, 'recall': 0.1, 'f1': 0.16774, 'auc': 0.75458}
# > Epoch 19: took 96.4s (avg 100.2s) | Best so far: epoch 11	train_loss: 0.1152 train_auc: 0.8302	val_loss: 0.0674 val_auc: 0.8430	test_loss: 0.1147 test_auc: 0.7634
# train: {'epoch': 20, 'time_epoch': 86.74689, 'eta': 7195.63448, 'eta_hours': 1.99879, 'loss': 0.09985264, 'lr': 9.397e-05, 'params': 559945, 'time_iter': 0.0843, 'accuracy': 0.97085, 'precision': 0.72562, 'recall': 0.35633, 'f1': 0.47795, 'auc': 0.89014}
# val: {'epoch': 20, 'time_epoch': 4.1682, 'loss': 0.07138232, 'lr': 0, 'params': 559945, 'time_iter': 0.03231, 'accuracy': 0.98152, 'precision': 0.55102, 'recall': 0.33333, 'f1': 0.41538, 'auc': 0.8234}
# test: {'epoch': 20, 'time_epoch': 4.24668, 'loss': 0.1213837, 'lr': 0, 'params': 559945, 'time_iter': 0.03292, 'accuracy': 0.96888, 'precision': 0.51786, 'recall': 0.22308, 'f1': 0.31183, 'auc': 0.75795}
# > Epoch 20: took 95.3s (avg 100.0s) | Best so far: epoch 11	train_loss: 0.1152 train_auc: 0.8302	val_loss: 0.0674 val_auc: 0.8430	test_loss: 0.1147 test_auc: 0.7634
# train: {'epoch': 21, 'time_epoch': 86.56471, 'eta': 7088.52764, 'eta_hours': 1.96904, 'loss': 0.09944539, 'lr': 9.316e-05, 'params': 559945, 'time_iter': 0.08413, 'accuracy': 0.971, 'precision': 0.71517, 'recall': 0.375, 'f1': 0.49201, 'auc': 0.89202}
# val: {'epoch': 21, 'time_epoch': 4.13216, 'loss': 0.07249699, 'lr': 0, 'params': 559945, 'time_iter': 0.03203, 'accuracy': 0.98225, 'precision': 0.58333, 'recall': 0.34568, 'f1': 0.43411, 'auc': 0.82289}
# test: {'epoch': 21, 'time_epoch': 4.10358, 'loss': 0.12539243, 'lr': 0, 'params': 559945, 'time_iter': 0.03181, 'accuracy': 0.96864, 'precision': 0.50909, 'recall': 0.21538, 'f1': 0.3027, 'auc': 0.75092}
# > Epoch 21: took 94.9s (avg 99.8s) | Best so far: epoch 11	train_loss: 0.1152 train_auc: 0.8302	val_loss: 0.0674 val_auc: 0.8430	test_loss: 0.1147 test_auc: 0.7634
# train: {'epoch': 22, 'time_epoch': 86.36325, 'eta': 6982.53261, 'eta_hours': 1.93959, 'loss': 0.09716548, 'lr': 9.23e-05, 'params': 559945, 'time_iter': 0.08393, 'accuracy': 0.97192, 'precision': 0.73913, 'recall': 0.38636, 'f1': 0.50746, 'auc': 0.89986}
# val: {'epoch': 22, 'time_epoch': 4.35793, 'loss': 0.07310305, 'lr': 0, 'params': 559945, 'time_iter': 0.03378, 'accuracy': 0.98177, 'precision': 0.55769, 'recall': 0.35802, 'f1': 0.43609, 'auc': 0.82687}
# test: {'epoch': 22, 'time_epoch': 4.37372, 'loss': 0.12693165, 'lr': 0, 'params': 559945, 'time_iter': 0.0339, 'accuracy': 0.96961, 'precision': 0.55319, 'recall': 0.2, 'f1': 0.29379, 'auc': 0.73012}
# > Epoch 22: took 95.2s (avg 99.6s) | Best so far: epoch 11	train_loss: 0.1152 train_auc: 0.8302	val_loss: 0.0674 val_auc: 0.8430	test_loss: 0.1147 test_auc: 0.7634
# train: {'epoch': 23, 'time_epoch': 84.47702, 'eta': 6872.20048, 'eta_hours': 1.90894, 'loss': 0.0971946, 'lr': 9.14e-05, 'params': 559945, 'time_iter': 0.0821, 'accuracy': 0.97103, 'precision': 0.70915, 'recall': 0.38393, 'f1': 0.49816, 'auc': 0.89732}
# val: {'epoch': 23, 'time_epoch': 4.14005, 'loss': 0.07085496, 'lr': 0, 'params': 559945, 'time_iter': 0.03209, 'accuracy': 0.98177, 'precision': 0.55769, 'recall': 0.35802, 'f1': 0.43609, 'auc': 0.82885}
# test: {'epoch': 23, 'time_epoch': 4.17433, 'loss': 0.11999643, 'lr': 0, 'params': 559945, 'time_iter': 0.03236, 'accuracy': 0.96961, 'precision': 0.55319, 'recall': 0.2, 'f1': 0.29379, 'auc': 0.77354}
# > Epoch 23: took 92.9s (avg 99.3s) | Best so far: epoch 11	train_loss: 0.1152 train_auc: 0.8302	val_loss: 0.0674 val_auc: 0.8430	test_loss: 0.1147 test_auc: 0.7634
# train: {'epoch': 24, 'time_epoch': 84.55197, 'eta': 6764.16164, 'eta_hours': 1.87893, 'loss': 0.09549644, 'lr': 9.045e-05, 'params': 559945, 'time_iter': 0.08217, 'accuracy': 0.97207, 'precision': 0.73676, 'recall': 0.39529, 'f1': 0.51453, 'auc': 0.90186}
# val: {'epoch': 24, 'time_epoch': 4.14227, 'loss': 0.07444056, 'lr': 0, 'params': 559945, 'time_iter': 0.03211, 'accuracy': 0.97958, 'precision': 0.4717, 'recall': 0.30864, 'f1': 0.37313, 'auc': 0.82687}
# test: {'epoch': 24, 'time_epoch': 4.19753, 'loss': 0.12289259, 'lr': 0, 'params': 559945, 'time_iter': 0.03254, 'accuracy': 0.97009, 'precision': 0.5614, 'recall': 0.24615, 'f1': 0.34225, 'auc': 0.75044}
# > Epoch 24: took 93.0s (avg 99.1s) | Best so far: epoch 11	train_loss: 0.1152 train_auc: 0.8302	val_loss: 0.0674 val_auc: 0.8430	test_loss: 0.1147 test_auc: 0.7634
# train: {'epoch': 25, 'time_epoch': 87.39102, 'eta': 6666.00984, 'eta_hours': 1.85167, 'loss': 0.09447321, 'lr': 8.946e-05, 'params': 559945, 'time_iter': 0.08493, 'accuracy': 0.97234, 'precision': 0.7403, 'recall': 0.4026, 'f1': 0.52156, 'auc': 0.90897}
# val: {'epoch': 25, 'time_epoch': 4.12151, 'loss': 0.06933139, 'lr': 0, 'params': 559945, 'time_iter': 0.03195, 'accuracy': 0.98347, 'precision': 0.69697, 'recall': 0.28395, 'f1': 0.40351, 'auc': 0.82374}
# test: {'epoch': 25, 'time_epoch': 4.21659, 'loss': 0.12575965, 'lr': 0, 'params': 559945, 'time_iter': 0.03269, 'accuracy': 0.97058, 'precision': 0.63636, 'recall': 0.16154, 'f1': 0.25767, 'auc': 0.77506}
# > Epoch 25: took 95.9s (avg 98.9s) | Best so far: epoch 11	train_loss: 0.1152 train_auc: 0.8302	val_loss: 0.0674 val_auc: 0.8430	test_loss: 0.1147 test_auc: 0.7634
# train: {'epoch': 26, 'time_epoch': 85.44727, 'eta': 6563.39983, 'eta_hours': 1.82317, 'loss': 0.09288888, 'lr': 8.842e-05, 'params': 559945, 'time_iter': 0.08304, 'accuracy': 0.97225, 'precision': 0.73842, 'recall': 0.40097, 'f1': 0.51973, 'auc': 0.91325}
# val: {'epoch': 26, 'time_epoch': 4.10907, 'loss': 0.07316393, 'lr': 0, 'params': 559945, 'time_iter': 0.03185, 'accuracy': 0.98298, 'precision': 0.63415, 'recall': 0.32099, 'f1': 0.42623, 'auc': 0.81927}
# test: {'epoch': 26, 'time_epoch': 4.13311, 'loss': 0.12460616, 'lr': 0, 'params': 559945, 'time_iter': 0.03204, 'accuracy': 0.96912, 'precision': 0.53488, 'recall': 0.17692, 'f1': 0.2659, 'auc': 0.7565}
# > Epoch 26: took 93.8s (avg 98.7s) | Best so far: epoch 11	train_loss: 0.1152 train_auc: 0.8302	val_loss: 0.0674 val_auc: 0.8430	test_loss: 0.1147 test_auc: 0.7634
# train: {'epoch': 27, 'time_epoch': 84.56807, 'eta': 6459.75492, 'eta_hours': 1.79438, 'loss': 0.09146192, 'lr': 8.734e-05, 'params': 559945, 'time_iter': 0.08218, 'accuracy': 0.97292, 'precision': 0.76434, 'recall': 0.40016, 'f1': 0.52531, 'auc': 0.9181}
# val: {'epoch': 27, 'time_epoch': 4.02419, 'loss': 0.07357533, 'lr': 0, 'params': 559945, 'time_iter': 0.0312, 'accuracy': 0.98055, 'precision': 0.50877, 'recall': 0.35802, 'f1': 0.42029, 'auc': 0.82957}
# test: {'epoch': 27, 'time_epoch': 4.0984, 'loss': 0.12327746, 'lr': 0, 'params': 559945, 'time_iter': 0.03177, 'accuracy': 0.96839, 'precision': 0.5, 'recall': 0.30769, 'f1': 0.38095, 'auc': 0.79097}
# > Epoch 27: took 92.8s (avg 98.5s) | Best so far: epoch 11	train_loss: 0.1152 train_auc: 0.8302	val_loss: 0.0674 val_auc: 0.8430	test_loss: 0.1147 test_auc: 0.7634
# train: {'epoch': 28, 'time_epoch': 85.00764, 'eta': 6358.50184, 'eta_hours': 1.76625, 'loss': 0.09101546, 'lr': 8.622e-05, 'params': 559945, 'time_iter': 0.08261, 'accuracy': 0.97255, 'precision': 0.74227, 'recall': 0.40909, 'f1': 0.52747, 'auc': 0.91931}
# val: {'epoch': 28, 'time_epoch': 4.10415, 'loss': 0.06929696, 'lr': 0, 'params': 559945, 'time_iter': 0.03182, 'accuracy': 0.98274, 'precision': 0.63158, 'recall': 0.2963, 'f1': 0.40336, 'auc': 0.82759}
# test: {'epoch': 28, 'time_epoch': 4.11675, 'loss': 0.12494709, 'lr': 0, 'params': 559945, 'time_iter': 0.03191, 'accuracy': 0.97131, 'precision': 0.63636, 'recall': 0.21538, 'f1': 0.32184, 'auc': 0.77172}
# > Epoch 28: took 93.4s (avg 98.4s) | Best so far: epoch 11	train_loss: 0.1152 train_auc: 0.8302	val_loss: 0.0674 val_auc: 0.8430	test_loss: 0.1147 test_auc: 0.7634
# train: {'epoch': 29, 'time_epoch': 84.43423, 'eta': 6256.99383, 'eta_hours': 1.73805, 'loss': 0.08912623, 'lr': 8.506e-05, 'params': 559945, 'time_iter': 0.08205, 'accuracy': 0.97307, 'precision': 0.75367, 'recall': 0.41721, 'f1': 0.5371, 'auc': 0.92501}
# val: {'epoch': 29, 'time_epoch': 4.08216, 'loss': 0.07292017, 'lr': 0, 'params': 559945, 'time_iter': 0.03164, 'accuracy': 0.98225, 'precision': 0.59524, 'recall': 0.30864, 'f1': 0.4065, 'auc': 0.81692}
# test: {'epoch': 29, 'time_epoch': 4.05822, 'loss': 0.12387831, 'lr': 0, 'params': 559945, 'time_iter': 0.03146, 'accuracy': 0.97009, 'precision': 0.56604, 'recall': 0.23077, 'f1': 0.32787, 'auc': 0.77388}
# > Epoch 29: took 92.7s (avg 98.2s) | Best so far: epoch 11	train_loss: 0.1152 train_auc: 0.8302	val_loss: 0.0674 val_auc: 0.8430	test_loss: 0.1147 test_auc: 0.7634
# train: {'epoch': 30, 'time_epoch': 83.18585, 'eta': 6153.80871, 'eta_hours': 1.70939, 'loss': 0.08847257, 'lr': 8.386e-05, 'params': 559945, 'time_iter': 0.08084, 'accuracy': 0.9735, 'precision': 0.76627, 'recall': 0.42045, 'f1': 0.54298, 'auc': 0.92527}
# val: {'epoch': 30, 'time_epoch': 3.98972, 'loss': 0.08036331, 'lr': 0, 'params': 559945, 'time_iter': 0.03093, 'accuracy': 0.97885, 'precision': 0.45946, 'recall': 0.41975, 'f1': 0.43871, 'auc': 0.82888}
# test: {'epoch': 30, 'time_epoch': 3.97772, 'loss': 0.13436799, 'lr': 0, 'params': 559945, 'time_iter': 0.03084, 'accuracy': 0.96912, 'precision': 0.51852, 'recall': 0.32308, 'f1': 0.3981, 'auc': 0.7663}
# > Epoch 30: took 91.3s (avg 97.9s) | Best so far: epoch 11	train_loss: 0.1152 train_auc: 0.8302	val_loss: 0.0674 val_auc: 0.8430	test_loss: 0.1147 test_auc: 0.7634
# train: {'epoch': 31, 'time_epoch': 83.33798, 'eta': 6052.1968, 'eta_hours': 1.68117, 'loss': 0.08680845, 'lr': 8.263e-05, 'params': 559945, 'time_iter': 0.08099, 'accuracy': 0.97386, 'precision': 0.76271, 'recall': 0.43831, 'f1': 0.5567, 'auc': 0.93109}
# val: {'epoch': 31, 'time_epoch': 4.00569, 'loss': 0.07057568, 'lr': 0, 'params': 559945, 'time_iter': 0.03105, 'accuracy': 0.98347, 'precision': 0.65854, 'recall': 0.33333, 'f1': 0.44262, 'auc': 0.83253}
# test: {'epoch': 31, 'time_epoch': 4.02446, 'loss': 0.13506873, 'lr': 0, 'params': 559945, 'time_iter': 0.0312, 'accuracy': 0.96985, 'precision': 0.56818, 'recall': 0.19231, 'f1': 0.28736, 'auc': 0.75628}
# > Epoch 31: took 91.5s (avg 97.7s) | Best so far: epoch 11	train_loss: 0.1152 train_auc: 0.8302	val_loss: 0.0674 val_auc: 0.8430	test_loss: 0.1147 test_auc: 0.7634
# train: {'epoch': 32, 'time_epoch': 83.35371, 'eta': 5951.72436, 'eta_hours': 1.65326, 'loss': 0.08480755, 'lr': 8.136e-05, 'params': 559945, 'time_iter': 0.081, 'accuracy': 0.9742, 'precision': 0.77554, 'recall': 0.4375, 'f1': 0.55942, 'auc': 0.93512}
# val: {'epoch': 32, 'time_epoch': 4.00228, 'loss': 0.07754602, 'lr': 0, 'params': 559945, 'time_iter': 0.03103, 'accuracy': 0.97885, 'precision': 0.45714, 'recall': 0.39506, 'f1': 0.42384, 'auc': 0.82502}
# ...
# > Epoch 81: took 87.3s (avg 92.7s) | Best so far: epoch 36	train_loss: 0.0803 train_auc: 0.9443	val_loss: 0.0730 val_auc: 0.8487	test_loss: 0.1402 test_auc: 0.7609
# train: {'epoch': 82, 'time_epoch': 79.43492, 'eta': 1432.44038, 'eta_hours': 0.3979, 'loss': 0.04666792, 'lr': 8.6e-06, 'params': 559945, 'time_iter': 0.0772, 'accuracy': 0.98371, 'precision': 0.8501, 'recall': 0.68588, 'f1': 0.75921, 'auc': 0.98861}
# val: {'epoch': 82, 'time_epoch': 3.92739, 'loss': 0.11161285, 'lr': 0, 'params': 559945, 'time_iter': 0.03044, 'accuracy': 0.9786, 'precision': 0.4507, 'recall': 0.39506, 'f1': 0.42105, 'auc': 0.81912}
# test: {'epoch': 82, 'time_epoch': 3.92629, 'loss': 0.20390242, 'lr': 0, 'params': 559945, 'time_iter': 0.03044, 'accuracy': 0.96693, 'precision': 0.45714, 'recall': 0.24615, 'f1': 0.32, 'auc': 0.75967}
# > Epoch 82: took 87.4s (avg 92.6s) | Best so far: epoch 36	train_loss: 0.0803 train_auc: 0.9443	val_loss: 0.0730 val_auc: 0.8487	test_loss: 0.1402 test_auc: 0.7609
# train: {'epoch': 83, 'time_epoch': 79.14091, 'eta': 1347.20389, 'eta_hours': 0.37422, 'loss': 0.04693843, 'lr': 7.7e-06, 'params': 559945, 'time_iter': 0.07691, 'accuracy': 0.98413, 'precision': 0.86373, 'recall': 0.68425, 'f1': 0.76359, 'auc': 0.98787}
# val: {'epoch': 83, 'time_epoch': 4.03832, 'loss': 0.10930492, 'lr': 0, 'params': 559945, 'time_iter': 0.0313, 'accuracy': 0.97836, 'precision': 0.44444, 'recall': 0.39506, 'f1': 0.4183, 'auc': 0.81842}
# test: {'epoch': 83, 'time_epoch': 3.9295, 'loss': 0.20537713, 'lr': 0, 'params': 559945, 'time_iter': 0.03046, 'accuracy': 0.96645, 'precision': 0.43548, 'recall': 0.20769, 'f1': 0.28125, 'auc': 0.75156}
# > Epoch 83: took 87.2s (avg 92.6s) | Best so far: epoch 36	train_loss: 0.0803 train_auc: 0.9443	val_loss: 0.0730 val_auc: 0.8487	test_loss: 0.1402 test_auc: 0.7609
# train: {'epoch': 84, 'time_epoch': 79.74479, 'eta': 1262.21739, 'eta_hours': 0.35062, 'loss': 0.0480641, 'lr': 6.84e-06, 'params': 559945, 'time_iter': 0.0775, 'accuracy': 0.98359, 'precision': 0.8567, 'recall': 0.67451, 'f1': 0.75477, 'auc': 0.98779}
# val: {'epoch': 84, 'time_epoch': 3.9389, 'loss': 0.11271302, 'lr': 0, 'params': 559945, 'time_iter': 0.03053, 'accuracy': 0.97715, 'precision': 0.41558, 'recall': 0.39506, 'f1': 0.40506, 'auc': 0.81888}
# test: {'epoch': 84, 'time_epoch': 4.00376, 'loss': 0.20298194, 'lr': 0, 'params': 559945, 'time_iter': 0.03104, 'accuracy': 0.96402, 'precision': 0.39286, 'recall': 0.25385, 'f1': 0.30841, 'auc': 0.75683}
# > Epoch 84: took 87.8s (avg 92.5s) | Best so far: epoch 36	train_loss: 0.0803 train_auc: 0.9443	val_loss: 0.0730 val_auc: 0.8487	test_loss: 0.1402 test_auc: 0.7609
# train: {'epoch': 85, 'time_epoch': 79.13896, 'eta': 1177.25416, 'eta_hours': 0.32702, 'loss': 0.04620058, 'lr': 6.03e-06, 'params': 559945, 'time_iter': 0.07691, 'accuracy': 0.98383, 'precision': 0.84449, 'recall': 0.69643, 'f1': 0.76335, 'auc': 0.98803}
# val: {'epoch': 85, 'time_epoch': 3.95136, 'loss': 0.11310201, 'lr': 0, 'params': 559945, 'time_iter': 0.03063, 'accuracy': 0.97812, 'precision': 0.43836, 'recall': 0.39506, 'f1': 0.41558, 'auc': 0.81801}
# test: {'epoch': 85, 'time_epoch': 3.96513, 'loss': 0.20917216, 'lr': 0, 'params': 559945, 'time_iter': 0.03074, 'accuracy': 0.96596, 'precision': 0.43421, 'recall': 0.25385, 'f1': 0.32039, 'auc': 0.75285}
# > Epoch 85: took 87.2s (avg 92.4s) | Best so far: epoch 36	train_loss: 0.0803 train_auc: 0.9443	val_loss: 0.0730 val_auc: 0.8487	test_loss: 0.1402 test_auc: 0.7609
# train: {'epoch': 86, 'time_epoch': 80.74715, 'eta': 1092.66514, 'eta_hours': 0.30352, 'loss': 0.04584737, 'lr': 5.26e-06, 'params': 559945, 'time_iter': 0.07847, 'accuracy': 0.98407, 'precision': 0.8505, 'recall': 0.69724, 'f1': 0.76628, 'auc': 0.98906}
# val: {'epoch': 86, 'time_epoch': 3.93472, 'loss': 0.112645, 'lr': 0, 'params': 559945, 'time_iter': 0.0305, 'accuracy': 0.97885, 'precision': 0.45714, 'recall': 0.39506, 'f1': 0.42384, 'auc': 0.81895}
# test: {'epoch': 86, 'time_epoch': 3.93039, 'loss': 0.21120539, 'lr': 0, 'params': 559945, 'time_iter': 0.03047, 'accuracy': 0.96815, 'precision': 0.49254, 'recall': 0.25385, 'f1': 0.33503, 'auc': 0.75384}
# > Epoch 86: took 88.7s (avg 92.4s) | Best so far: epoch 36	train_loss: 0.0803 train_auc: 0.9443	val_loss: 0.0730 val_auc: 0.8487	test_loss: 0.1402 test_auc: 0.7609
# train: {'epoch': 87, 'time_epoch': 80.87967, 'eta': 1008.1815, 'eta_hours': 0.28005, 'loss': 0.04689913, 'lr': 4.55e-06, 'params': 559945, 'time_iter': 0.0786, 'accuracy': 0.98426, 'precision': 0.85069, 'recall': 0.70292, 'f1': 0.76978, 'auc': 0.98712}
# val: {'epoch': 87, 'time_epoch': 3.91397, 'loss': 0.11629158, 'lr': 0, 'params': 559945, 'time_iter': 0.03034, 'accuracy': 0.9769, 'precision': 0.4125, 'recall': 0.40741, 'f1': 0.40994, 'auc': 0.82189}
# test: {'epoch': 87, 'time_epoch': 3.92658, 'loss': 0.20678874, 'lr': 0, 'params': 559945, 'time_iter': 0.03044, 'accuracy': 0.96572, 'precision': 0.43038, 'recall': 0.26154, 'f1': 0.32536, 'auc': 0.75544}
# > Epoch 87: took 88.9s (avg 92.4s) | Best so far: epoch 36	train_loss: 0.0803 train_auc: 0.9443	val_loss: 0.0730 val_auc: 0.8487	test_loss: 0.1402 test_auc: 0.7609
# train: {'epoch': 88, 'time_epoch': 79.59097, 'eta': 923.61957, 'eta_hours': 0.25656, 'loss': 0.04740948, 'lr': 3.89e-06, 'params': 559945, 'time_iter': 0.07735, 'accuracy': 0.98356, 'precision': 0.83576, 'recall': 0.69805, 'f1': 0.76073, 'auc': 0.98731}
# val: {'epoch': 88, 'time_epoch': 4.01149, 'loss': 0.11159222, 'lr': 0, 'params': 559945, 'time_iter': 0.0311, 'accuracy': 0.97812, 'precision': 0.43836, 'recall': 0.39506, 'f1': 0.41558, 'auc': 0.82456}
# test: {'epoch': 88, 'time_epoch': 3.92299, 'loss': 0.20228958, 'lr': 0, 'params': 559945, 'time_iter': 0.03041, 'accuracy': 0.96548, 'precision': 0.42308, 'recall': 0.25385, 'f1': 0.31731, 'auc': 0.75983}
# > Epoch 88: took 87.7s (avg 92.3s) | Best so far: epoch 36	train_loss: 0.0803 train_auc: 0.9443	val_loss: 0.0730 val_auc: 0.8487	test_loss: 0.1402 test_auc: 0.7609
# train: {'epoch': 89, 'time_epoch': 79.60727, 'eta': 839.16991, 'eta_hours': 0.2331, 'loss': 0.04476041, 'lr': 3.27e-06, 'params': 559945, 'time_iter': 0.07736, 'accuracy': 0.98465, 'precision': 0.85742, 'recall': 0.70779, 'f1': 0.77546, 'auc': 0.98944}
# val: {'epoch': 89, 'time_epoch': 3.93118, 'loss': 0.11578975, 'lr': 0, 'params': 559945, 'time_iter': 0.03047, 'accuracy': 0.97593, 'precision': 0.39024, 'recall': 0.39506, 'f1': 0.39264, 'auc': 0.82451}
# test: {'epoch': 89, 'time_epoch': 3.90349, 'loss': 0.20374936, 'lr': 0, 'params': 559945, 'time_iter': 0.03026, 'accuracy': 0.96572, 'precision': 0.43038, 'recall': 0.26154, 'f1': 0.32536, 'auc': 0.75708}
# > Epoch 89: took 87.6s (avg 92.3s) | Best so far: epoch 36	train_loss: 0.0803 train_auc: 0.9443	val_loss: 0.0730 val_auc: 0.8487	test_loss: 0.1402 test_auc: 0.7609
# train: {'epoch': 90, 'time_epoch': 79.5143, 'eta': 754.81749, 'eta_hours': 0.20967, 'loss': 0.04631532, 'lr': 2.71e-06, 'params': 559945, 'time_iter': 0.07727, 'accuracy': 0.98401, 'precision': 0.84881, 'recall': 0.69724, 'f1': 0.7656, 'auc': 0.98761}
# val: {'epoch': 90, 'time_epoch': 3.92588, 'loss': 0.11468021, 'lr': 0, 'params': 559945, 'time_iter': 0.03043, 'accuracy': 0.97788, 'precision': 0.43243, 'recall': 0.39506, 'f1': 0.4129, 'auc': 0.81944}
# test: {'epoch': 90, 'time_epoch': 3.93713, 'loss': 0.20923606, 'lr': 0, 'params': 559945, 'time_iter': 0.03052, 'accuracy': 0.96766, 'precision': 0.47826, 'recall': 0.25385, 'f1': 0.33166, 'auc': 0.75545}
# > Epoch 90: took 87.5s (avg 92.2s) | Best so far: epoch 36	train_loss: 0.0803 train_auc: 0.9443	val_loss: 0.0730 val_auc: 0.8487	test_loss: 0.1402 test_auc: 0.7609
# train: {'epoch': 91, 'time_epoch': 79.4164, 'eta': 670.56173, 'eta_hours': 0.18627, 'loss': 0.04689271, 'lr': 2.2e-06, 'params': 559945, 'time_iter': 0.07718, 'accuracy': 0.98444, 'precision': 0.86585, 'recall': 0.69156, 'f1': 0.76895, 'auc': 0.98772}
# val: {'epoch': 91, 'time_epoch': 3.97001, 'loss': 0.11244858, 'lr': 0, 'params': 559945, 'time_iter': 0.03078, 'accuracy': 0.97715, 'precision': 0.41333, 'recall': 0.38272, 'f1': 0.39744, 'auc': 0.81962}
# test: {'epoch': 91, 'time_epoch': 3.92552, 'loss': 0.20845648, 'lr': 0, 'params': 559945, 'time_iter': 0.03043, 'accuracy': 0.96669, 'precision': 0.44615, 'recall': 0.22308, 'f1': 0.29744, 'auc': 0.7507}
# > Epoch 91: took 87.4s (avg 92.2s) | Best so far: epoch 36	train_loss: 0.0803 train_auc: 0.9443	val_loss: 0.0730 val_auc: 0.8487	test_loss: 0.1402 test_auc: 0.7609
# train: {'epoch': 92, 'time_epoch': 79.69529, 'eta': 586.43104, 'eta_hours': 0.1629, 'loss': 0.04663025, 'lr': 1.74e-06, 'params': 559945, 'time_iter': 0.07745, 'accuracy': 0.98392, 'precision': 0.85327, 'recall': 0.68912, 'f1': 0.76246, 'auc': 0.98868}
# val: {'epoch': 92, 'time_epoch': 3.99999, 'loss': 0.11180739, 'lr': 0, 'params': 559945, 'time_iter': 0.03101, 'accuracy': 0.97715, 'precision': 0.41772, 'recall': 0.40741, 'f1': 0.4125, 'auc': 0.82811}
# test: {'epoch': 92, 'time_epoch': 3.94731, 'loss': 0.20242245, 'lr': 0, 'params': 559945, 'time_iter': 0.0306, 'accuracy': 0.9645, 'precision': 0.40909, 'recall': 0.27692, 'f1': 0.33028, 'auc': 0.76119}
# > Epoch 92: took 87.8s (avg 92.1s) | Best so far: epoch 36	train_loss: 0.0803 train_auc: 0.9443	val_loss: 0.0730 val_auc: 0.8487	test_loss: 0.1402 test_auc: 0.7609
# train: {'epoch': 93, 'time_epoch': 79.50279, 'eta': 502.38243, 'eta_hours': 0.13955, 'loss': 0.04667403, 'lr': 1.33e-06, 'params': 559945, 'time_iter': 0.07726, 'accuracy': 0.98383, 'precision': 0.84047, 'recall': 0.7013, 'f1': 0.7646, 'auc': 0.98735}
# val: {'epoch': 93, 'time_epoch': 4.00612, 'loss': 0.10931275, 'lr': 0, 'params': 559945, 'time_iter': 0.03106, 'accuracy': 0.97788, 'precision': 0.43056, 'recall': 0.38272, 'f1': 0.40523, 'auc': 0.8246}
# test: {'epoch': 93, 'time_epoch': 4.09254, 'loss': 0.20607464, 'lr': 0, 'params': 559945, 'time_iter': 0.03173, 'accuracy': 0.96766, 'precision': 0.47761, 'recall': 0.24615, 'f1': 0.32487, 'auc': 0.75578}
# > Epoch 93: took 87.7s (avg 92.1s) | Best so far: epoch 36	train_loss: 0.0803 train_auc: 0.9443	val_loss: 0.0730 val_auc: 0.8487	test_loss: 0.1402 test_auc: 0.7609
# train: {'epoch': 94, 'time_epoch': 79.13114, 'eta': 418.40995, 'eta_hours': 0.11622, 'loss': 0.04699718, 'lr': 9.8e-07, 'params': 559945, 'time_iter': 0.0769, 'accuracy': 0.98468, 'precision': 0.85756, 'recall': 0.7086, 'f1': 0.776, 'auc': 0.98785}
# val: {'epoch': 94, 'time_epoch': 3.92989, 'loss': 0.11376192, 'lr': 0, 'params': 559945, 'time_iter': 0.03046, 'accuracy': 0.97739, 'precision': 0.42105, 'recall': 0.39506, 'f1': 0.40764, 'auc': 0.8166}
# test: {'epoch': 94, 'time_epoch': 3.96973, 'loss': 0.205383, 'lr': 0, 'params': 559945, 'time_iter': 0.03077, 'accuracy': 0.9662, 'precision': 0.44304, 'recall': 0.26923, 'f1': 0.33493, 'auc': 0.75646}
# > Epoch 94: took 87.2s (avg 92.0s) | Best so far: epoch 36	train_loss: 0.0803 train_auc: 0.9443	val_loss: 0.0730 val_auc: 0.8487	test_loss: 0.1402 test_auc: 0.7609
# train: {'epoch': 95, 'time_epoch': 79.65172, 'eta': 334.56004, 'eta_hours': 0.09293, 'loss': 0.04486075, 'lr': 6.8e-07, 'params': 559945, 'time_iter': 0.07741, 'accuracy': 0.98474, 'precision': 0.87018, 'recall': 0.69643, 'f1': 0.77367, 'auc': 0.98912}
# val: {'epoch': 95, 'time_epoch': 3.94, 'loss': 0.11206172, 'lr': 0, 'params': 559945, 'time_iter': 0.03054, 'accuracy': 0.97788, 'precision': 0.43056, 'recall': 0.38272, 'f1': 0.40523, 'auc': 0.81909}
# test: {'epoch': 95, 'time_epoch': 3.94288, 'loss': 0.20359123, 'lr': 0, 'params': 559945, 'time_iter': 0.03056, 'accuracy': 0.96718, 'precision': 0.46575, 'recall': 0.26154, 'f1': 0.33498, 'auc': 0.75323}
# > Epoch 95: took 87.7s (avg 92.0s) | Best so far: epoch 36	train_loss: 0.0803 train_auc: 0.9443	val_loss: 0.0730 val_auc: 0.8487	test_loss: 0.1402 test_auc: 0.7609
# train: {'epoch': 96, 'time_epoch': 80.512, 'eta': 250.82328, 'eta_hours': 0.06967, 'loss': 0.04456855, 'lr': 4.4e-07, 'params': 559945, 'time_iter': 0.07824, 'accuracy': 0.98392, 'precision': 0.84699, 'recall': 0.69643, 'f1': 0.76437, 'auc': 0.99019}
# val: {'epoch': 96, 'time_epoch': 4.03382, 'loss': 0.11587505, 'lr': 0, 'params': 559945, 'time_iter': 0.03127, 'accuracy': 0.97763, 'precision': 0.42667, 'recall': 0.39506, 'f1': 0.41026, 'auc': 0.81636}
# test: {'epoch': 96, 'time_epoch': 3.93389, 'loss': 0.21622771, 'lr': 0, 'params': 559945, 'time_iter': 0.0305, 'accuracy': 0.96548, 'precision': 0.41429, 'recall': 0.22308, 'f1': 0.29, 'auc': 0.74958}
# > Epoch 96: took 88.6s (avg 91.9s) | Best so far: epoch 36	train_loss: 0.0803 train_auc: 0.9443	val_loss: 0.0730 val_auc: 0.8487	test_loss: 0.1402 test_auc: 0.7609
# train: {'epoch': 97, 'time_epoch': 80.43992, 'eta': 167.15087, 'eta_hours': 0.04643, 'loss': 0.04351739, 'lr': 2.5e-07, 'params': 559945, 'time_iter': 0.07817, 'accuracy': 0.98535, 'precision': 0.87351, 'recall': 0.71185, 'f1': 0.78444, 'auc': 0.98938}
# val: {'epoch': 97, 'time_epoch': 3.94988, 'loss': 0.11406995, 'lr': 0, 'params': 559945, 'time_iter': 0.03062, 'accuracy': 0.97788, 'precision': 0.43056, 'recall': 0.38272, 'f1': 0.40523, 'auc': 0.81962}
# test: {'epoch': 97, 'time_epoch': 3.93053, 'loss': 0.20963331, 'lr': 0, 'params': 559945, 'time_iter': 0.03047, 'accuracy': 0.96669, 'precision': 0.45333, 'recall': 0.26154, 'f1': 0.33171, 'auc': 0.75466}
# > Epoch 97: took 88.5s (avg 91.9s) | Best so far: epoch 36	train_loss: 0.0803 train_auc: 0.9443	val_loss: 0.0730 val_auc: 0.8487	test_loss: 0.1402 test_auc: 0.7609
# train: {'epoch': 98, 'time_epoch': 79.34331, 'eta': 83.53269, 'eta_hours': 0.0232, 'loss': 0.04609321, 'lr': 1.1e-07, 'params': 559945, 'time_iter': 0.07711, 'accuracy': 0.98395, 'precision': 0.84921, 'recall': 0.69481, 'f1': 0.76429, 'auc': 0.98839}
# val: {'epoch': 98, 'time_epoch': 3.93119, 'loss': 0.11229229, 'lr': 0, 'params': 559945, 'time_iter': 0.03047, 'accuracy': 0.97788, 'precision': 0.43243, 'recall': 0.39506, 'f1': 0.4129, 'auc': 0.81799}
# test: {'epoch': 98, 'time_epoch': 4.03648, 'loss': 0.20154865, 'lr': 0, 'params': 559945, 'time_iter': 0.03129, 'accuracy': 0.96669, 'precision': 0.4507, 'recall': 0.24615, 'f1': 0.31841, 'auc': 0.75455}
# > Epoch 98: took 87.4s (avg 91.8s) | Best so far: epoch 36	train_loss: 0.0803 train_auc: 0.9443	val_loss: 0.0730 val_auc: 0.8487	test_loss: 0.1402 test_auc: 0.7609
# train: {'epoch': 99, 'time_epoch': 80.52982, 'eta': 0.0, 'eta_hours': 0.0, 'loss': 0.04409182, 'lr': 3e-08, 'params': 559945, 'time_iter': 0.07826, 'accuracy': 0.98532, 'precision': 0.86897, 'recall': 0.71591, 'f1': 0.78505, 'auc': 0.98938}
# val: {'epoch': 99, 'time_epoch': 3.94743, 'loss': 0.11320602, 'lr': 0, 'params': 559945, 'time_iter': 0.0306, 'accuracy': 0.97836, 'precision': 0.44444, 'recall': 0.39506, 'f1': 0.4183, 'auc': 0.82027}
# test: {'epoch': 99, 'time_epoch': 4.01329, 'loss': 0.20761113, 'lr': 0, 'params': 559945, 'time_iter': 0.03111, 'accuracy': 0.96718, 'precision': 0.46479, 'recall': 0.25385, 'f1': 0.32836, 'auc': 0.75422}
# > Epoch 99: took 88.6s (avg 91.8s) | Best so far: epoch 36	train_loss: 0.0803 train_auc: 0.9443	val_loss: 0.0730 val_auc: 0.8487	test_loss: 0.1402 test_auc: 0.7609
# Avg time per epoch: 91.81s
# Total train loop time: 2.55h
# Task done, results saved in results/ogbg-molhiv-GPS/0
# 36
# {'epoch': 36, 'time_epoch': 89.98691, 'eta': 5579.40447, 'eta_hours': 1.54983, 'loss': 0.08028605, 'lr': 7.595e-05, 'params': 559945, 'time_iter': 0.08745, 'accuracy': 0.97532, 'precision': 0.7815, 'recall': 0.47321, 'f1': 0.58948, 'auc': 0.94434}
# {'epoch': 36, 'time_epoch': 4.20458, 'loss': 0.14022049, 'lr': 0, 'params': 559945, 'time_iter': 0.03259, 'accuracy': 0.96839, 'precision': 0.5, 'recall': 0.23077, 'f1': 0.31579, 'auc': 0.76089}
# {'epoch': 36, 'time_epoch': 4.29505, 'loss': 0.072989, 'lr': 0, 'params': 559945, 'time_iter': 0.03329, 'accuracy': 0.98152, 'precision': 0.54386, 'recall': 0.38272, 'f1': 0.44928, 'auc': 0.84866}
# Results aggregated across runs saved in results/ogbg-molhiv-GPS/agg
# [*] All done: 2024-09-24 17:22:57.170613
