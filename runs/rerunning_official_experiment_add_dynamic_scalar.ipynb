# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/torch_scatter-2.1.2-cp310-cp310-linux_x86_64.whl
# /kaggle/input/torch_geometric-2.5.3-py3-none-any.whl
# /kaggle/input/torch_cluster-1.6.3-cp310-cp310-linux_x86_64.whl
# /kaggle/input/torch_spline_conv-1.2.2-cp310-cp310-linux_x86_64.whl
# /kaggle/input/torch_sparse-0.6.18-cp310-cp310-linux_x86_64.whl

# %%
# !git clone https://github.com/rampasek/GraphGPS.git
# Out:
# Cloning into 'GraphGPS'...
# remote: Enumerating objects: 526, done.
# remote: Counting objects: 100% (316/316), done.
# remote: Compressing objects: 100% (91/91), done.
# remote: Total 526 (delta 254), reused 225 (delta 225), pack-reused 210 (from 1)
# Receiving objects: 100% (526/526), 12.93 MiB | 35.30 MiB/s, done.
# Resolving deltas: 100% (336/336), done.

# %%
# %cd /kaggle/working/GraphGPS
# !ls
# Out:
# /kaggle/working/GraphGPS
# GraphGPS.png  README.md  final-results.zip  main.py  setup.py  unittests
# LICENSE       configs	 graphgps	    run      tests

# %% [markdown]
# ##  installation for slurm if needed using conda

# %%
# # for slurm if needed using conda 
# conda create -n graphgps python=3.10
# conda activate graphgps

# conda install pytorch=1.13 torchvision torchaudio pytorch-cuda=11.7 -c pytorch -c nvidia
# conda install pyg=2.2 -c pyg -c conda-forge
# pip install pyg-lib -f https://data.pyg.org/whl/torch-1.13.0+cu117.html

# # RDKit is required for OGB-LSC PCQM4Mv2 and datasets derived from it.  
# conda install openbabel fsspec rdkit -c conda-forge

# pip install pytorch-lightning yacs torchmetrics
# pip install performer-pytorch
# pip install tensorboardX
# pip install ogb
# pip install wandb

# conda clean --all

# %% [markdown]
# # installation for kaggle

# %%
# Check existing environment
import sys
print("Python version:", sys.version)
import torch
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)

# !pip uninstall -y torch torchvision torchaudio
# !pip install torch==2.0.1+cu118 torchvision==0.15.2+cu118 torchaudio==2.0.2+cu118 --index-url https://download.pytorch.org/whl/cu118

# !pip install torch_geometric

# Optional dependencies:
# !pip install pyg_lib torch_scatter torch_sparse torch_cluster torch_spline_conv -f https://data.pyg.org/whl/torch-2.4.0+cu124.html
# Install other required packages
# !pip install pytorch-lightning yacs torchmetrics
# !pip install performer-pytorch
# !pip install tensorboardX
# !pip install ogb
# !pip install wandb

# Attempt to install RDKit (may have limitations)
# !pip install rdkit-pypi
# !pip install openbabel fsspec
# !pip install  fsspec

# Clean up pip cache (optional)
# !pip cache purge
# Out:
# Python version: 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:45:18) [GCC 12.3.0]
# PyTorch version: 2.4.0
# CUDA available: True
# CUDA version: 12.3
# Found existing installation: torch 2.4.0
# Uninstalling torch-2.4.0:
#   Successfully uninstalled torch-2.4.0
# Found existing installation: torchvision 0.19.0
# Uninstalling torchvision-0.19.0:
#   Successfully uninstalled torchvision-0.19.0
# Found existing installation: torchaudio 2.4.0
# Uninstalling torchaudio-2.4.0:
#   Successfully uninstalled torchaudio-2.4.0
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Collecting torch==2.0.1+cu118
#   Downloading https://download.pytorch.org/whl/cu118/torch-2.0.1%2Bcu118-cp310-cp310-linux_x86_64.whl (2267.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 GB 439.2 kB/s eta 0:00:0000:0100:01
# Collecting torchvision==0.15.2+cu118
#   Downloading https://download.pytorch.org/whl/cu118/torchvision-0.15.2%2Bcu118-cp310-cp310-linux_x86_64.whl (6.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 82.3 MB/s eta 0:00:00:00:0100:01
# Collecting torchaudio==2.0.2+cu118
#   Downloading https://download.pytorch.org/whl/cu118/torchaudio-2.0.2%2Bcu118-cp310-cp310-linux_x86_64.whl (4.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 78.5 MB/s eta 0:00:00:00:01
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch==2.0.1+cu118) (3.15.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch==2.0.1+cu118) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch==2.0.1+cu118) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch==2.0.1+cu118) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch==2.0.1+cu118) (3.1.4)
# Collecting triton==2.0.0 (from torch==2.0.1+cu118)
#   Downloading https://download.pytorch.org/whl/triton-2.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 26.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision==0.15.2+cu118) (1.26.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torchvision==0.15.2+cu118) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision==0.15.2+cu118) (10.3.0)
# Collecting cmake (from triton==2.0.0->torch==2.0.1+cu118)
#   Downloading https://download.pytorch.org/whl/cmake-3.25.0-py2.py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 64.1 MB/s eta 0:00:0000:0100:01
# Collecting lit (from triton==2.0.0->torch==2.0.1+cu118)
#   Downloading https://download.pytorch.org/whl/lit-15.0.7.tar.gz (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.3/132.3 kB 11.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch==2.0.1+cu118) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.15.2+cu118) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.15.2+cu118) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.15.2+cu118) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.15.2+cu118) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch==2.0.1+cu118) (1.3.0)
# Building wheels for collected packages: lit
#   Building wheel for lit (setup.py) ... done
#   Created wheel for lit: filename=lit-15.0.7-py3-none-any.whl size=89987 sha256=0ae993a2708dd27a6cedbe348b7f8023c97965724fa6153b068a08cbf68072f8
#   Stored in directory: /root/.cache/pip/wheels/27/2c/b6/3ed2983b1b44fe0dea1bb35234b09f2c22fb8ebb308679c922
# Successfully built lit
# Installing collected packages: lit, cmake, triton, torch, torchvision, torchaudio
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytorch-lightning 2.4.0 requires torch>=2.1.0, but you have torch 2.0.1+cu118 which is incompatible.
# Successfully installed cmake-3.25.0 lit-15.0.7 torch-2.0.1+cu118 torchaudio-2.0.2+cu118 torchvision-0.15.2+cu118 triton-2.0.0
# Collecting torch_geometric
#   Downloading torch_geometric-2.6.0-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 747.5 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (3.9.5)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (2024.6.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (3.1.4)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (1.26.4)
# Requirement already satisfied: psutil>=5.8.0 in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (5.9.3)
# Requirement already satisfied: pyparsing in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (3.1.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (2.32.3)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (4.66.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch_geometric) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (2024.8.30)
# Downloading torch_geometric-2.6.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 7.6 MB/s eta 0:00:0000:0100:01
# Installing collected packages: torch_geometric
# Successfully installed torch_geometric-2.6.0
# Looking in links: https://data.pyg.org/whl/torch-2.4.0+cu124.html
# Collecting pyg_lib
#   Downloading https://data.pyg.org/whl/torch-2.4.0%2Bcu124/pyg_lib-0.4.0%2Bpt24cu124-cp310-cp310-linux_x86_64.whl (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 22.4 MB/s eta 0:00:0000:0100:01
# Collecting torch_scatter
#   Downloading https://data.pyg.org/whl/torch-2.4.0%2Bcu124/torch_scatter-2.1.2%2Bpt24cu124-cp310-cp310-linux_x86_64.whl (10.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 66.3 MB/s eta 0:00:0000:010:01
# Collecting torch_sparse
#   Downloading https://data.pyg.org/whl/torch-2.4.0%2Bcu124/torch_sparse-0.6.18%2Bpt24cu124-cp310-cp310-linux_x86_64.whl (5.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 11.4 MB/s eta 0:00:0000:0100:01
# Collecting torch_cluster
#   Downloading https://data.pyg.org/whl/torch-2.4.0%2Bcu124/torch_cluster-1.6.3%2Bpt24cu124-cp310-cp310-linux_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 36.0 MB/s eta 0:00:00a 0:00:01
# Collecting torch_spline_conv
#   Downloading https://data.pyg.org/whl/torch-2.4.0%2Bcu124/torch_spline_conv-1.2.2%2Bpt24cu124-cp310-cp310-linux_x86_64.whl (992 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 992.4/992.4 kB 3.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from torch_sparse) (1.14.1)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in /opt/conda/lib/python3.10/site-packages (from scipy->torch_sparse) (1.26.4)
# Installing collected packages: torch_spline_conv, torch_scatter, pyg_lib, torch_sparse, torch_cluster
# Successfully installed pyg_lib-0.4.0+pt24cu124 torch_cluster-1.6.3+pt24cu124 torch_scatter-2.1.2+pt24cu124 torch_sparse-0.6.18+pt24cu124 torch_spline_conv-1.2.2+pt24cu124
# Requirement already satisfied: pytorch-lightning in /opt/conda/lib/python3.10/site-packages (2.4.0)
# Collecting yacs
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: torchmetrics in /opt/conda/lib/python3.10/site-packages (1.4.2)
# Collecting torch>=2.1.0 (from pytorch-lightning)
#   Downloading torch-2.4.1-cp310-cp310-manylinux1_x86_64.whl.metadata (26 kB)
# Requirement already satisfied: tqdm>=4.57.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (4.66.4)
# Requirement already satisfied: PyYAML>=5.4 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (6.0.2)
# Requirement already satisfied: fsspec>=2022.5.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (2024.6.1)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (21.3)
# Requirement already satisfied: typing-extensions>=4.4.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (4.12.2)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (0.11.7)
# Requirement already satisfied: numpy>1.20.0 in /opt/conda/lib/python3.10/site-packages (from torchmetrics) (1.26.4)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (3.9.5)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from lightning-utilities>=0.10.0->pytorch-lightning) (70.0.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->pytorch-lightning) (3.1.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=2.1.0->pytorch-lightning) (3.15.1)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=2.1.0->pytorch-lightning) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=2.1.0->pytorch-lightning) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=2.1.0->pytorch-lightning) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.0.0 (from torch>=2.1.0->pytorch-lightning)
#   Downloading triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_nvjitlink_cu12-12.6.68-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=2.1.0->pytorch-lightning) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=2.1.0->pytorch-lightning) (1.3.0)
# Requirement already satisfied: idna>=2.0 in /opt/conda/lib/python3.10/site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (3.7)
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Downloading torch-2.4.1-cp310-cp310-manylinux1_x86_64.whl (797.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.1/797.1 MB 1.9 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.3 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 17.5 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 16.6 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 16.2 MB/s eta 0:00:00a 0:00:01
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.6 MB/s eta 0:00:0000:0100:05m
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 3.4 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 5.2 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.0 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.0 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 8.6 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 6.8 MB/s eta 0:00:00
# Downloading triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (209.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 7.5 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.6.68-py3-none-manylinux2014_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 56.9 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: yacs, triton, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch
#   Attempting uninstall: triton
#     Found existing installation: triton 2.0.0
#     Uninstalling triton-2.0.0:
#       Successfully uninstalled triton-2.0.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.1+cu118
#     Uninstalling torch-2.0.1+cu118:
#       Successfully uninstalled torch-2.0.1+cu118
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.0.2+cu118 requires torch==2.0.1, but you have torch 2.4.1 which is incompatible.
# torchvision 0.15.2+cu118 requires torch==2.0.1, but you have torch 2.4.1 which is incompatible.
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.6.68 nvidia-nvtx-cu12-12.1.105 torch-2.4.1 triton-3.0.0 yacs-0.1.8
# Collecting performer-pytorch
#   Downloading performer_pytorch-1.1.4-py3-none-any.whl.metadata (763 bytes)
# Collecting einops>=0.3 (from performer-pytorch)
#   Downloading einops-0.8.0-py3-none-any.whl.metadata (12 kB)
# Collecting local-attention>=1.1.1 (from performer-pytorch)
#   Downloading local_attention-1.9.15-py3-none-any.whl.metadata (683 bytes)
# Requirement already satisfied: torch>=1.6 in /opt/conda/lib/python3.10/site-packages (from performer-pytorch) (2.4.1)
# Collecting axial-positional-embedding>=0.1.0 (from performer-pytorch)
#   Downloading axial_positional_embedding-0.2.1.tar.gz (2.6 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.6->performer-pytorch) (12.6.68)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.6->performer-pytorch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.6->performer-pytorch) (1.3.0)
# Downloading performer_pytorch-1.1.4-py3-none-any.whl (13 kB)
# Downloading einops-0.8.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 749.7 kB/s eta 0:00:000:00:01
# Downloading local_attention-1.9.15-py3-none-any.whl (9.0 kB)
# Building wheels for collected packages: axial-positional-embedding
#   Building wheel for axial-positional-embedding (setup.py) ... done
#   Created wheel for axial-positional-embedding: filename=axial_positional_embedding-0.2.1-py3-none-any.whl size=2889 sha256=51e5bb41c32c10e08acda52faf7bd15183f3fa4a058680e228f7fc8d619b758b
#   Stored in directory: /root/.cache/pip/wheels/b1/cb/39/7ce7ff2d2fd37cfe1fe7b3a3c43cf410632b2ad3b3f3986d73
# Successfully built axial-positional-embedding
# Installing collected packages: einops, local-attention, axial-positional-embedding, performer-pytorch
# Successfully installed axial-positional-embedding-0.2.1 einops-0.8.0 local-attention-1.9.15 performer-pytorch-1.1.4
# Requirement already satisfied: tensorboardX in /opt/conda/lib/python3.10/site-packages (2.6.2.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from tensorboardX) (1.26.4)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorboardX) (21.3)
# Requirement already satisfied: protobuf>=3.20 in /opt/conda/lib/python3.10/site-packages (from tensorboardX) (3.20.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->tensorboardX) (3.1.2)
# Collecting ogb
#   Downloading ogb-1.3.6-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: torch>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (2.4.1)
# Requirement already satisfied: numpy>=1.16.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (1.26.4)
# Requirement already satisfied: tqdm>=4.29.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (4.66.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (1.2.2)
# Requirement already satisfied: pandas>=0.24.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (2.2.2)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (1.16.0)
# Requirement already satisfied: urllib3>=1.24.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (1.26.18)
# Collecting outdated>=0.2.0 (from ogb)
#   Downloading outdated-0.2.2-py2.py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: setuptools>=44 in /opt/conda/lib/python3.10/site-packages (from outdated>=0.2.0->ogb) (70.0.0)
# Collecting littleutils (from outdated>=0.2.0->ogb)
#   Downloading littleutils-0.2.4-py3-none-any.whl.metadata (679 bytes)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from outdated>=0.2.0->ogb) (2.32.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24.0->ogb) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24.0->ogb) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24.0->ogb) (2024.1)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.20.0->ogb) (1.14.1)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.20.0->ogb) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.20.0->ogb) (3.5.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.6.0->ogb) (12.6.68)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.6.0->ogb) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->outdated>=0.2.0->ogb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->outdated>=0.2.0->ogb) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->outdated>=0.2.0->ogb) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.6.0->ogb) (1.3.0)
# Downloading ogb-1.3.6-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 1.3 MB/s eta 0:00:00eta 0:00:01
# Downloading outdated-0.2.2-py2.py3-none-any.whl (7.5 kB)
# Downloading littleutils-0.2.4-py3-none-any.whl (8.1 kB)
# Installing collected packages: littleutils, outdated, ogb
# Successfully installed littleutils-0.2.4 ogb-1.3.6 outdated-0.2.2
# Requirement already satisfied: wandb in /opt/conda/lib/python3.10/site-packages (0.18.1)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /opt/conda/lib/python3.10/site-packages (from wandb) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.1.43)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.10/site-packages (from wandb) (3.11.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.20.3)
# Requirement already satisfied: psutil>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from wandb) (6.0.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.32.3)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.14.0)
# Requirement already satisfied: setproctitle in /opt/conda/lib/python3.10/site-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from wandb) (70.0.0)
# Requirement already satisfied: six>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2024.8.30)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.1)
# Collecting rdkit-pypi
#   Downloading rdkit_pypi-2022.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from rdkit-pypi) (1.26.4)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from rdkit-pypi) (10.3.0)
# Downloading rdkit_pypi-2022.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 47.2 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: rdkit-pypi
# Successfully installed rdkit-pypi-2022.9.5
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (2024.6.1)
# Files removed: 184

# %%
import sys
print("Python version:", sys.version)
import torch
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)
# Out:
# Python version: 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:45:18) [GCC 12.3.0]
# PyTorch version: 2.4.0
# CUDA available: True
# CUDA version: 12.3

# %%
import torch_geometric
print("PyG version:", torch_geometric.__version__)

import pytorch_lightning
print("PyTorch Lightning version:", pytorch_lightning.__version__)

import rdkit
print("RDKit version:", rdkit.__version__)
# Out:
# /opt/conda/lib/python3.10/site-packages/torch_geometric/typing.py:68: UserWarning: An issue occurred while importing 'pyg-lib'. Disabling its usage. Stacktrace: /opt/conda/lib/python3.10/site-packages/libpyg.so: undefined symbol: _ZNK5torch8autograd4Node4nameEv
#   warnings.warn(f"An issue occurred while importing 'pyg-lib'. "
# /opt/conda/lib/python3.10/site-packages/torch_geometric/typing.py:86: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: /opt/conda/lib/python3.10/site-packages/torch_scatter/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
#   warnings.warn(f"An issue occurred while importing 'torch-scatter'. "
# /opt/conda/lib/python3.10/site-packages/torch_geometric/typing.py:97: UserWarning: An issue occurred while importing 'torch-cluster'. Disabling its usage. Stacktrace: /opt/conda/lib/python3.10/site-packages/torch_cluster/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
#   warnings.warn(f"An issue occurred while importing 'torch-cluster'. "
# /opt/conda/lib/python3.10/site-packages/torch_geometric/typing.py:113: UserWarning: An issue occurred while importing 'torch-spline-conv'. Disabling its usage. Stacktrace: /opt/conda/lib/python3.10/site-packages/torch_spline_conv/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torch_geometric/typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: /opt/conda/lib/python3.10/site-packages/torch_sparse/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
#   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "
# PyG version: 2.6.0
# PyTorch Lightning version: 2.4.0
# RDKit version: 2022.09.5

# %%
print("Torch version:", torch.__version__)
# Out:
# Torch version: 2.4.0

# %% [markdown]
# # Running their model- GPSConv

# %%
# %cd /kaggle/working/GraphGPS
# !WANDB_MODE=disabled python main.py --cfg configs/GPS/ogbg-molhiv-GPS.yaml

# %% [markdown]
# # Our Model - WeightedGraphGPS

# %%
#clone for our project
# %cd /kaggle/working
# !git clone --branch gating_network https://github.com/omertalmi5/WeightedGraphGPS.git
# Out:
# /kaggle/working
# Cloning into 'WeightedGraphGPS'...
# remote: Enumerating objects: 587, done.
# remote: Counting objects: 100% (379/379), done.
# remote: Compressing objects: 100% (149/149), done.
# remote: Total 587 (delta 305), reused 233 (delta 230), pack-reused 208 (from 1)
# Receiving objects: 100% (587/587), 12.94 MiB | 33.63 MiB/s, done.
# Resolving deltas: 100% (387/387), done.

# %%
# !pip install wandb
# Out:
# Requirement already satisfied: wandb in /opt/conda/lib/python3.10/site-packages (0.18.1)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /opt/conda/lib/python3.10/site-packages (from wandb) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.1.43)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.10/site-packages (from wandb) (3.11.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.20.3)
# Requirement already satisfied: psutil>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from wandb) (6.0.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.32.3)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.14.0)
# Requirement already satisfied: setproctitle in /opt/conda/lib/python3.10/site-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from wandb) (70.0.0)
# Requirement already satisfied: six>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2024.8.30)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.1)

# %%
# !wandb login 5f1c292fde40243d281618fe88d712346cfe90d7
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
import os
# Set the environment variable
os.environ['USERNAME'] = "omertalmi-tel-aviv-university"

# %%
# %cd /kaggle/working/WeightedGraphGPS
# !WANDB_MODE=online python main.py --cfg configs/GPS/ogbg-molhiv-GPS.yaml wandb.use True wandb.entity $USERNAME
# Out:
# /kaggle/working/WeightedGraphGPS
# [*] Run ID 0: seed=0, split_index=0
#     Starting now: 2024-09-25 18:43:43.649289
# Downloading http://snap.stanford.edu/ogb/data/graphproppred/csv_mol_download/hiv.zip
# Downloaded 0.00 GB: 100%|█████████████████████████| 3/3 [00:00<00:00,  3.87it/s]
# Extracting ./datasets/hiv.zip
# Processing...
# Loading necessary files...
# This might take a while.
# Processing graphs...
# 100%|██████████████████████████████████| 41127/41127 [00:00<00:00, 65597.51it/s]
# Converting graphs into PyG objects...
# 100%|██████████████████████████████████| 41127/41127 [00:02<00:00, 18603.59it/s]
# Saving...
# Done!
# /opt/conda/lib/python3.10/site-packages/ogb/graphproppred/dataset_pyg.py:68: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.data, self.slices = torch.load(self.processed_paths[0])
# [*] Loaded dataset 'ogbg-molhiv' from 'OGB':
# /opt/conda/lib/python3.10/site-packages/torch_geometric/data/in_memory_dataset.py:300: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
#   Data(edge_index=[2, 2259376], edge_attr=[2259376, 3], x=[1049163, 9], y=[41127, 1], num_nodes=1049163)
#   undirected: True
#   num graphs: 41127
# /opt/conda/lib/python3.10/site-packages/torch_geometric/data/in_memory_dataset.py:300: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. The data of the dataset is already cached, so any modifications to `data` will not be reflected when accessing its elements. Clearing the cache now by removing all elements in `dataset._data_list`. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
#   avg num_nodes/graph: 25
#   num node features: 9
#   num edge features: 3
#   num tasks: 1
#   num classes: 2
# Precomputing Positional Encoding statistics: ['LapPE'] for all graphs...
#   ...estimated to be undirected: True
# 100%|████████████████████████████████████| 41127/41127 [00:53<00:00, 763.92it/s]
# Done! Took 00:00:55.38
# GraphGymModule(
#   (model): GPSModel(
#     (encoder): FeatureEncoder(
#       (node_encoder): Concat2NodeEncoder(
#         (encoder1): AtomEncoder(
#           (atom_embedding_list): ModuleList(
#             (0): Embedding(119, 56)
#             (1): Embedding(5, 56)
#             (2-3): 2 x Embedding(12, 56)
#             (4): Embedding(10, 56)
#             (5-6): 2 x Embedding(6, 56)
#             (7-8): 2 x Embedding(2, 56)
#           )
#         )
#         (encoder2): LapPENodeEncoder(
#           (linear_A): Linear(in_features=2, out_features=16, bias=True)
#           (pe_encoder): Sequential(
#             (0): ReLU()
#             (1): Linear(in_features=16, out_features=8, bias=True)
#             (2): ReLU()
#           )
#         )
#       )
#       (edge_encoder): BondEncoder(
#         (bond_embedding_list): ModuleList(
#           (0): Embedding(5, 64)
#           (1): Embedding(6, 64)
#           (2): Embedding(2, 64)
#         )
#       )
#     )
#     (layers): Sequential(
#       (0): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (gating_network): Sequential(
#           (0): Linear(in_features=64, out_features=32, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=32, out_features=1, bias=True)
#           (3): Sigmoid()
#         )
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (1): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (gating_network): Sequential(
#           (0): Linear(in_features=64, out_features=32, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=32, out_features=1, bias=True)
#           (3): Sigmoid()
#         )
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (2): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (gating_network): Sequential(
#           (0): Linear(in_features=64, out_features=32, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=32, out_features=1, bias=True)
#           (3): Sigmoid()
#         )
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (3): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (gating_network): Sequential(
#           (0): Linear(in_features=64, out_features=32, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=32, out_features=1, bias=True)
#           (3): Sigmoid()
#         )
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (4): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (gating_network): Sequential(
#           (0): Linear(in_features=64, out_features=32, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=32, out_features=1, bias=True)
#           (3): Sigmoid()
#         )
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (5): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (gating_network): Sequential(
#           (0): Linear(in_features=64, out_features=32, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=32, out_features=1, bias=True)
#           (3): Sigmoid()
#         )
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (6): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (gating_network): Sequential(
#           (0): Linear(in_features=64, out_features=32, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=32, out_features=1, bias=True)
#           (3): Sigmoid()
#         )
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (7): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (gating_network): Sequential(
#           (0): Linear(in_features=64, out_features=32, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=32, out_features=1, bias=True)
#           (3): Sigmoid()
#         )
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (8): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (gating_network): Sequential(
#           (0): Linear(in_features=64, out_features=32, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=32, out_features=1, bias=True)
#           (3): Sigmoid()
#         )
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (9): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (gating_network): Sequential(
#           (0): Linear(in_features=64, out_features=32, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=32, out_features=1, bias=True)
#           (3): Sigmoid()
#         )
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#     )
#     (post_mp): SANGraphHead(
#       (FC_layers): ModuleList(
#         (0): Linear(in_features=64, out_features=32, bias=True)
#         (1): Linear(in_features=32, out_features=16, bias=True)
#         (2): Linear(in_features=16, out_features=1, bias=True)
#       )
#       (activation): ReLU()
#     )
#   )
# )
# accelerator: cuda
# benchmark: False
# bn:
#   eps: 1e-05
#   mom: 0.1
# cfg_dest: config.yaml
# custom_metrics: []
# dataset:
#   cache_load: False
#   cache_save: False
#   dir: ./datasets
#   edge_dim: 128
#   edge_encoder: True
#   edge_encoder_bn: False
#   edge_encoder_name: Bond
#   edge_encoder_num_types: 0
#   edge_message_ratio: 0.8
#   edge_negative_sampling_ratio: 1.0
#   edge_train_mode: all
#   encoder: True
#   encoder_bn: True
#   encoder_dim: 128
#   encoder_name: db
#   format: OGB
#   infer_link_label: None
#   label_column: none
#   label_table: none
#   location: local
#   name: ogbg-molhiv
#   node_encoder: True
#   node_encoder_bn: False
#   node_encoder_name: Atom+LapPE
#   node_encoder_num_types: 0
#   remove_feature: False
#   resample_disjoint: False
#   resample_negative: False
#   shuffle_split: True
#   slic_compactness: 10
#   split: [0.8, 0.1, 0.1]
#   split_dir: ./splits
#   split_index: 0
#   split_mode: standard
#   task: graph
#   task_type: classification
#   to_undirected: False
#   transductive: False
#   transform: none
#   tu_simple: True
# devices: 1
# example_arg: example
# example_group:
#   example_arg: example
# gnn:
#   act: relu
#   agg: mean
#   att_final_linear: False
#   att_final_linear_bn: False
#   att_heads: 1
#   batchnorm: True
#   clear_feature: True
#   dim_edge: 64
#   dim_inner: 64
#   dropout: 0.0
#   head: san_graph
#   keep_edge: 0.5
#   l2norm: True
#   layer_type: generalconv
#   layers_mp: 2
#   layers_post_mp: 3
#   layers_pre_mp: 0
#   msg_direction: single
#   normalize_adj: False
#   residual: False
#   self_msg: concat
#   skip_every: 1
#   stage_type: stack
# gpu_mem: False
# graphormer:
#   attention_dropout: 0.0
#   dropout: 0.0
#   embed_dim: 80
#   input_dropout: 0.0
#   mlp_dropout: 0.0
#   num_heads: 4
#   num_layers: 6
#   use_graph_token: True
# gt:
#   attn_dropout: 0.5
#   batch_norm: True
#   bigbird:
#     add_cross_attention: False
#     attention_type: block_sparse
#     block_size: 3
#     chunk_size_feed_forward: 0
#     hidden_act: relu
#     is_decoder: False
#     layer_norm_eps: 1e-06
#     max_position_embeddings: 128
#     num_random_blocks: 3
#     use_bias: False
#   dim_hidden: 64
#   dropout: 0.05
#   full_graph: True
#   gamma: 1e-05
#   layer_norm: False
#   layer_type: CustomGatedGCN+Transformer
#   layers: 10
#   n_heads: 4
#   pna_degrees: []
#   residual: True
# mem:
#   inplace: False
# metric_agg: argmax
# metric_best: auc
# model:
#   edge_decoding: dot
#   graph_pooling: mean
#   loss_fun: cross_entropy
#   match_upper: True
#   size_average: mean
#   thresh: 0.5
#   type: GPSModel
# name_tag:
# num_threads: 6
# num_workers: 0
# optim:
#   base_lr: 0.0001
#   batch_accumulation: 1
#   clip_grad_norm: True
#   clip_grad_norm_value: 1.0
#   lr_decay: 0.1
#   max_epoch: 100
#   min_lr: 0.0
#   momentum: 0.9
#   num_warmup_epochs: 5
#   optimizer: adamW
#   reduce_factor: 0.1
#   schedule_patience: 10
#   scheduler: cosine_with_warmup
#   steps: [30, 60, 90]
#   weight_decay: 1e-05
# out_dir: results/ogbg-molhiv-GPS
# posenc_ElstaticSE:
#   dim_pe: 16
#   enable: False
#   kernel:
#     times: []
#     times_func: range(10)
#   layers: 3
#   model: none
#   n_heads: 4
#   pass_as_var: False
#   post_layers: 0
#   raw_norm_type: none
# posenc_EquivStableLapPE:
#   eigen:
#     eigvec_norm: L2
#     laplacian_norm: sym
#     max_freqs: 10
#   enable: False
#   raw_norm_type: none
# posenc_GraphormerBias:
#   dim_pe: 0
#   enable: False
#   node_degrees_only: False
#   num_in_degrees: None
#   num_out_degrees: None
#   num_spatial_types: None
# posenc_HKdiagSE:
#   dim_pe: 16
#   enable: False
#   kernel:
#     times: []
#     times_func:
#   layers: 3
#   model: none
#   n_heads: 4
#   pass_as_var: False
#   post_layers: 0
#   raw_norm_type: none
# posenc_LapPE:
#   dim_pe: 8
#   eigen:
#     eigvec_norm: L2
#     laplacian_norm: none
#     max_freqs: 8
#   enable: True
#   layers: 2
#   model: DeepSet
#   n_heads: 4
#   pass_as_var: False
#   post_layers: 0
#   raw_norm_type: none
# posenc_RWSE:
#   dim_pe: 16
#   enable: False
#   kernel:
#     times: []
#     times_func:
#   layers: 3
#   model: none
#   n_heads: 4
#   pass_as_var: False
#   post_layers: 0
#   raw_norm_type: none
# posenc_SignNet:
#   dim_pe: 16
#   eigen:
#     eigvec_norm: L2
#     laplacian_norm: sym
#     max_freqs: 10
#   enable: False
#   layers: 3
#   model: none
#   n_heads: 4
#   pass_as_var: False
#   phi_hidden_dim: 64
#   phi_out_dim: 4
#   post_layers: 0
#   raw_norm_type: none
# pretrained:
#   dir:
#   freeze_main: False
#   reset_prediction_head: True
# print: both
# round: 5
# run_dir: results/ogbg-molhiv-GPS/0
# run_id: 0
# run_multiple_splits: []
# seed: 0
# share:
#   dim_in: 9
#   dim_out: 2
#   num_splits: 3
# tensorboard_agg: True
# tensorboard_each_run: False
# train:
#   auto_resume: False
#   batch_size: 32
#   ckpt_best: False
#   ckpt_clean: True
#   ckpt_period: 100
#   enable_ckpt: True
#   epoch_resume: -1
#   eval_period: 1
#   iter_per_epoch: 32
#   mode: custom
#   neighbor_sizes: [20, 15, 10, 5]
#   node_per_graph: 32
#   radius: extend
#   sample_node: False
#   sampler: full_batch
#   skip_train_eval: False
#   walk_length: 4
# val:
#   node_per_graph: 32
#   radius: extend
#   sample_node: False
#   sampler: full_batch
# view_emb: False
# wandb:
#   entity: omertalmi-tel-aviv-university
#   name:
#   project: molhiv
#   use: True
# Num parameters: 581075
# Start from epoch 0
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: omertalmi- (omertalmi-tel-aviv-university). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.1
# wandb: Run data is saved locally in /kaggle/working/WeightedGraphGPS/wandb/run-20240925_184454-xjtzmmn9
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run ogbg-molhiv.GPS.CustomGatedGCN+Transformer+LapPE.r0
# wandb: ⭐️ View project at https://wandb.ai/omertalmi-tel-aviv-university/molhiv
# wandb: 🚀 View run at https://wandb.ai/omertalmi-tel-aviv-university/molhiv/runs/xjtzmmn9
# Key posenc_GraphormerBias.num_spatial_types with value <class 'NoneType'> is not a valid type; valid types: {<class 'list'>, <class 'str'>, <class 'bool'>, <class 'int'>, <class 'float'>, <class 'tuple'>}
# Key posenc_GraphormerBias.num_in_degrees with value <class 'NoneType'> is not a valid type; valid types: {<class 'list'>, <class 'str'>, <class 'bool'>, <class 'int'>, <class 'float'>, <class 'tuple'>}
# Key posenc_GraphormerBias.num_out_degrees with value <class 'NoneType'> is not a valid type; valid types: {<class 'list'>, <class 'str'>, <class 'bool'>, <class 'int'>, <class 'float'>, <class 'tuple'>}
# train: {'epoch': 0, 'time_epoch': 96.07762, 'eta': 9511.68478, 'eta_hours': 2.64213, 'loss': 0.66800773, 'lr': 0.0, 'params': 581075, 'time_iter': 0.09337, 'accuracy': 0.87666, 'precision': 0.02711, 'recall': 0.06575, 'f1': 0.03839, 'auc': 0.49278}
# ...computing epoch stats took: 0.12s
# val: {'epoch': 0, 'time_epoch': 5.17949, 'loss': 0.67334612, 'lr': 0, 'params': 581075, 'time_iter': 0.04015, 'accuracy': 0.85291, 'precision': 0.01481, 'recall': 0.09877, 'f1': 0.02576, 'auc': 0.49422}
# ...computing epoch stats took: 0.02s
# test: {'epoch': 0, 'time_epoch': 5.4697, 'loss': 0.676691, 'lr': 0, 'params': 581075, 'time_iter': 0.0424, 'accuracy': 0.81741, 'precision': 0.0156, 'recall': 0.07692, 'f1': 0.02594, 'auc': 0.50618}
# ...computing epoch stats took: 0.02s
# > Epoch 0: took 106.9s (avg 106.9s) | Best so far: epoch 0	train_loss: 0.6680 train_auc: 0.4928	val_loss: 0.6733 val_auc: 0.4942	test_loss: 0.6767 test_auc: 0.5062
# train: {'epoch': 1, 'time_epoch': 90.07755, 'eta': 9121.60359, 'eta_hours': 2.53378, 'loss': 0.45163402, 'lr': 2e-05, 'params': 581075, 'time_iter': 0.08754, 'accuracy': 0.96216, 'precision': 0.06667, 'recall': 0.00081, 'f1': 0.0016, 'auc': 0.55896}
# ...computing epoch stats took: 0.07s
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 1, 'time_epoch': 4.27508, 'loss': 0.26765866, 'lr': 0, 'params': 581075, 'time_iter': 0.03314, 'accuracy': 0.98031, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.62486}
# ...computing epoch stats took: 0.02s
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# test: {'epoch': 1, 'time_epoch': 4.28583, 'loss': 0.25741727, 'lr': 0, 'params': 581075, 'time_iter': 0.03322, 'accuracy': 0.96839, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.68751}
# ...computing epoch stats took: 0.02s
# > Epoch 1: took 98.8s (avg 102.8s) | Best so far: epoch 1	train_loss: 0.4516 train_auc: 0.5590	val_loss: 0.2677 val_auc: 0.6249	test_loss: 0.2574 test_auc: 0.6875
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# train: {'epoch': 2, 'time_epoch': 90.44472, 'eta': 8943.39665, 'eta_hours': 2.48428, 'loss': 0.17675653, 'lr': 4e-05, 'params': 581075, 'time_iter': 0.0879, 'accuracy': 0.96255, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.63605}
# ...computing epoch stats took: 0.06s
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 2, 'time_epoch': 4.3296, 'loss': 0.09442957, 'lr': 0, 'params': 581075, 'time_iter': 0.03356, 'accuracy': 0.98031, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.70727}
# ...computing epoch stats took: 0.01s
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# test: {'epoch': 2, 'time_epoch': 4.24615, 'loss': 0.1220007, 'lr': 0, 'params': 581075, 'time_iter': 0.03292, 'accuracy': 0.96839, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.73364}
# ...computing epoch stats took: 0.01s
# > Epoch 2: took 99.1s (avg 101.6s) | Best so far: epoch 2	train_loss: 0.1768 train_auc: 0.6361	val_loss: 0.0944 val_auc: 0.7073	test_loss: 0.1220 test_auc: 0.7336
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# train: {'epoch': 3, 'time_epoch': 90.02784, 'eta': 8799.06575, 'eta_hours': 2.44418, 'loss': 0.14284885, 'lr': 6e-05, 'params': 581075, 'time_iter': 0.08749, 'accuracy': 0.96255, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.71292}
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 3, 'time_epoch': 4.31212, 'loss': 0.08636677, 'lr': 0, 'params': 581075, 'time_iter': 0.03343, 'accuracy': 0.98031, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.73436}
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# test: {'epoch': 3, 'time_epoch': 4.22804, 'loss': 0.12006186, 'lr': 0, 'params': 581075, 'time_iter': 0.03278, 'accuracy': 0.96839, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.72792}
# > Epoch 3: took 98.7s (avg 100.9s) | Best so far: epoch 3	train_loss: 0.1428 train_auc: 0.7129	val_loss: 0.0864 val_auc: 0.7344	test_loss: 0.1201 test_auc: 0.7279
# train: {'epoch': 4, 'time_epoch': 90.77529, 'eta': 8690.65749, 'eta_hours': 2.41407, 'loss': 0.13822298, 'lr': 8e-05, 'params': 581075, 'time_iter': 0.08822, 'accuracy': 0.96304, 'precision': 0.625, 'recall': 0.03247, 'f1': 0.06173, 'auc': 0.73907}
# val: {'epoch': 4, 'time_epoch': 4.30976, 'loss': 0.08527067, 'lr': 0, 'params': 581075, 'time_iter': 0.03341, 'accuracy': 0.98055, 'precision': 0.51613, 'recall': 0.19753, 'f1': 0.28571, 'auc': 0.74428}
# test: {'epoch': 4, 'time_epoch': 4.28537, 'loss': 0.11914687, 'lr': 0, 'params': 581075, 'time_iter': 0.03322, 'accuracy': 0.97082, 'precision': 0.63158, 'recall': 0.18462, 'f1': 0.28571, 'auc': 0.75638}
# > Epoch 4: took 99.5s (avg 100.6s) | Best so far: epoch 4	train_loss: 0.1382 train_auc: 0.7391	val_loss: 0.0853 val_auc: 0.7443	test_loss: 0.1191 test_auc: 0.7564
# train: {'epoch': 5, 'time_epoch': 90.22755, 'eta': 8579.54572, 'eta_hours': 2.38321, 'loss': 0.13374542, 'lr': 0.0001, 'params': 581075, 'time_iter': 0.08768, 'accuracy': 0.9642, 'precision': 0.63235, 'recall': 0.10471, 'f1': 0.17967, 'auc': 0.75985}
# val: {'epoch': 5, 'time_epoch': 4.30076, 'loss': 0.08365758, 'lr': 0, 'params': 581075, 'time_iter': 0.03334, 'accuracy': 0.98055, 'precision': 0.52381, 'recall': 0.1358, 'f1': 0.21569, 'auc': 0.75871}
# test: {'epoch': 5, 'time_epoch': 4.3785, 'loss': 0.11609606, 'lr': 0, 'params': 581075, 'time_iter': 0.03394, 'accuracy': 0.97034, 'precision': 0.6, 'recall': 0.18462, 'f1': 0.28235, 'auc': 0.76029}
# > Epoch 5: took 99.0s (avg 100.3s) | Best so far: epoch 5	train_loss: 0.1337 train_auc: 0.7599	val_loss: 0.0837 val_auc: 0.7587	test_loss: 0.1161 test_auc: 0.7603
# train: {'epoch': 6, 'time_epoch': 90.12297, 'eta': 8473.01138, 'eta_hours': 2.35361, 'loss': 0.12824195, 'lr': 9.997e-05, 'params': 581075, 'time_iter': 0.08758, 'accuracy': 0.96468, 'precision': 0.61667, 'recall': 0.15016, 'f1': 0.24151, 'auc': 0.78671}
# val: {'epoch': 6, 'time_epoch': 4.41171, 'loss': 0.07966368, 'lr': 0, 'params': 581075, 'time_iter': 0.0342, 'accuracy': 0.98152, 'precision': 0.58621, 'recall': 0.20988, 'f1': 0.30909, 'auc': 0.77723}
# test: {'epoch': 6, 'time_epoch': 4.30048, 'loss': 0.1187886, 'lr': 0, 'params': 581075, 'time_iter': 0.03334, 'accuracy': 0.97107, 'precision': 0.64103, 'recall': 0.19231, 'f1': 0.29586, 'auc': 0.74897}
# > Epoch 6: took 99.0s (avg 100.2s) | Best so far: epoch 6	train_loss: 0.1282 train_auc: 0.7867	val_loss: 0.0797 val_auc: 0.7772	test_loss: 0.1188 test_auc: 0.7490
# train: {'epoch': 7, 'time_epoch': 90.50812, 'eta': 8375.00913, 'eta_hours': 2.32639, 'loss': 0.12598079, 'lr': 9.989e-05, 'params': 581075, 'time_iter': 0.08796, 'accuracy': 0.96496, 'precision': 0.61791, 'recall': 0.16802, 'f1': 0.2642, 'auc': 0.7927}
# val: {'epoch': 7, 'time_epoch': 4.28156, 'loss': 0.0801423, 'lr': 0, 'params': 581075, 'time_iter': 0.03319, 'accuracy': 0.98079, 'precision': 0.53125, 'recall': 0.20988, 'f1': 0.30088, 'auc': 0.78756}
# test: {'epoch': 7, 'time_epoch': 4.25648, 'loss': 0.12215943, 'lr': 0, 'params': 581075, 'time_iter': 0.033, 'accuracy': 0.97009, 'precision': 0.62069, 'recall': 0.13846, 'f1': 0.22642, 'auc': 0.74128}
# > Epoch 7: took 99.2s (avg 100.0s) | Best so far: epoch 7	train_loss: 0.1260 train_auc: 0.7927	val_loss: 0.0801 val_auc: 0.7876	test_loss: 0.1222 test_auc: 0.7413
# train: {'epoch': 8, 'time_epoch': 90.83524, 'eta': 8281.97977, 'eta_hours': 2.30055, 'loss': 0.12265158, 'lr': 9.975e-05, 'params': 581075, 'time_iter': 0.08828, 'accuracy': 0.96553, 'precision': 0.63764, 'recall': 0.18425, 'f1': 0.28589, 'auc': 0.80395}
# val: {'epoch': 8, 'time_epoch': 4.27369, 'loss': 0.08222444, 'lr': 0, 'params': 581075, 'time_iter': 0.03313, 'accuracy': 0.97836, 'precision': 0.4, 'recall': 0.19753, 'f1': 0.26446, 'auc': 0.80345}
# test: {'epoch': 8, 'time_epoch': 4.30653, 'loss': 0.11763887, 'lr': 0, 'params': 581075, 'time_iter': 0.03338, 'accuracy': 0.96864, 'precision': 0.50794, 'recall': 0.24615, 'f1': 0.33161, 'auc': 0.75303}
# > Epoch 8: took 99.6s (avg 100.0s) | Best so far: epoch 8	train_loss: 0.1227 train_auc: 0.8040	val_loss: 0.0822 val_auc: 0.8034	test_loss: 0.1176 test_auc: 0.7530
# train: {'epoch': 9, 'time_epoch': 90.18258, 'eta': 8183.51534, 'eta_hours': 2.2732, 'loss': 0.12066028, 'lr': 9.956e-05, 'params': 581075, 'time_iter': 0.08764, 'accuracy': 0.96611, 'precision': 0.63895, 'recall': 0.21834, 'f1': 0.32547, 'auc': 0.81128}
# val: {'epoch': 9, 'time_epoch': 4.22223, 'loss': 0.08506582, 'lr': 0, 'params': 581075, 'time_iter': 0.03273, 'accuracy': 0.97909, 'precision': 0.44444, 'recall': 0.24691, 'f1': 0.31746, 'auc': 0.7778}
# test: {'epoch': 9, 'time_epoch': 4.31425, 'loss': 0.12151171, 'lr': 0, 'params': 581075, 'time_iter': 0.03344, 'accuracy': 0.96791, 'precision': 0.48684, 'recall': 0.28462, 'f1': 0.35922, 'auc': 0.76007}
# > Epoch 9: took 98.9s (avg 99.9s) | Best so far: epoch 8	train_loss: 0.1227 train_auc: 0.8040	val_loss: 0.0822 val_auc: 0.8034	test_loss: 0.1176 test_auc: 0.7530
# train: {'epoch': 10, 'time_epoch': 90.29087, 'eta': 8087.43288, 'eta_hours': 2.24651, 'loss': 0.1172442, 'lr': 9.932e-05, 'params': 581075, 'time_iter': 0.08775, 'accuracy': 0.96635, 'precision': 0.64302, 'recall': 0.22808, 'f1': 0.33673, 'auc': 0.83187}
# val: {'epoch': 10, 'time_epoch': 4.29095, 'loss': 0.07630114, 'lr': 0, 'params': 581075, 'time_iter': 0.03326, 'accuracy': 0.98031, 'precision': 0.5, 'recall': 0.19753, 'f1': 0.28319, 'auc': 0.79238}
# test: {'epoch': 10, 'time_epoch': 4.33372, 'loss': 0.11290433, 'lr': 0, 'params': 581075, 'time_iter': 0.03359, 'accuracy': 0.97082, 'precision': 0.58065, 'recall': 0.27692, 'f1': 0.375, 'auc': 0.76729}
# > Epoch 10: took 99.1s (avg 99.8s) | Best so far: epoch 8	train_loss: 0.1227 train_auc: 0.8040	val_loss: 0.0822 val_auc: 0.8034	test_loss: 0.1176 test_auc: 0.7530
# train: {'epoch': 11, 'time_epoch': 90.39908, 'eta': 7993.10917, 'eta_hours': 2.22031, 'loss': 0.11362129, 'lr': 9.902e-05, 'params': 581075, 'time_iter': 0.08785, 'accuracy': 0.96784, 'precision': 0.67331, 'recall': 0.27435, 'f1': 0.38985, 'auc': 0.84197}
# val: {'epoch': 11, 'time_epoch': 4.24349, 'loss': 0.07514361, 'lr': 0, 'params': 581075, 'time_iter': 0.0329, 'accuracy': 0.98128, 'precision': 0.57143, 'recall': 0.19753, 'f1': 0.29358, 'auc': 0.8147}
# test: {'epoch': 11, 'time_epoch': 4.33092, 'loss': 0.11248277, 'lr': 0, 'params': 581075, 'time_iter': 0.03357, 'accuracy': 0.97131, 'precision': 0.64286, 'recall': 0.20769, 'f1': 0.31395, 'auc': 0.76488}
# > Epoch 11: took 99.1s (avg 99.7s) | Best so far: epoch 11	train_loss: 0.1136 train_auc: 0.8420	val_loss: 0.0751 val_auc: 0.8147	test_loss: 0.1125 test_auc: 0.7649
# train: {'epoch': 12, 'time_epoch': 90.90719, 'eta': 7902.78967, 'eta_hours': 2.19522, 'loss': 0.11186231, 'lr': 9.867e-05, 'params': 581075, 'time_iter': 0.08835, 'accuracy': 0.96781, 'precision': 0.67835, 'recall': 0.26705, 'f1': 0.38323, 'auc': 0.84675}
# val: {'epoch': 12, 'time_epoch': 4.3844, 'loss': 0.08024501, 'lr': 0, 'params': 581075, 'time_iter': 0.03399, 'accuracy': 0.97909, 'precision': 0.43243, 'recall': 0.19753, 'f1': 0.27119, 'auc': 0.79647}
# test: {'epoch': 12, 'time_epoch': 4.3129, 'loss': 0.11518013, 'lr': 0, 'params': 581075, 'time_iter': 0.03343, 'accuracy': 0.97131, 'precision': 0.63043, 'recall': 0.22308, 'f1': 0.32955, 'auc': 0.74663}
# > Epoch 12: took 99.7s (avg 99.7s) | Best so far: epoch 11	train_loss: 0.1136 train_auc: 0.8420	val_loss: 0.0751 val_auc: 0.8147	test_loss: 0.1125 test_auc: 0.7649
# train: {'epoch': 13, 'time_epoch': 90.3342, 'eta': 7808.86646, 'eta_hours': 2.16913, 'loss': 0.10975949, 'lr': 9.826e-05, 'params': 581075, 'time_iter': 0.08779, 'accuracy': 0.96891, 'precision': 0.70213, 'recall': 0.29464, 'f1': 0.41509, 'auc': 0.85285}
# val: {'epoch': 13, 'time_epoch': 4.304, 'loss': 0.07535002, 'lr': 0, 'params': 581075, 'time_iter': 0.03336, 'accuracy': 0.97909, 'precision': 0.4359, 'recall': 0.20988, 'f1': 0.28333, 'auc': 0.80977}
# test: {'epoch': 13, 'time_epoch': 4.28607, 'loss': 0.11672969, 'lr': 0, 'params': 581075, 'time_iter': 0.03323, 'accuracy': 0.97058, 'precision': 0.60465, 'recall': 0.2, 'f1': 0.30058, 'auc': 0.75804}
# > Epoch 13: took 99.1s (avg 99.7s) | Best so far: epoch 11	train_loss: 0.1136 train_auc: 0.8420	val_loss: 0.0751 val_auc: 0.8147	test_loss: 0.1125 test_auc: 0.7649
# train: {'epoch': 14, 'time_epoch': 90.2225, 'eta': 7714.78881, 'eta_hours': 2.143, 'loss': 0.10684651, 'lr': 9.78e-05, 'params': 581075, 'time_iter': 0.08768, 'accuracy': 0.9693, 'precision': 0.69681, 'recall': 0.31899, 'f1': 0.43764, 'auc': 0.86079}
# val: {'epoch': 14, 'time_epoch': 4.25068, 'loss': 0.07621578, 'lr': 0, 'params': 581075, 'time_iter': 0.03295, 'accuracy': 0.97958, 'precision': 0.46512, 'recall': 0.24691, 'f1': 0.32258, 'auc': 0.82678}
# test: {'epoch': 14, 'time_epoch': 4.26866, 'loss': 0.11722097, 'lr': 0, 'params': 581075, 'time_iter': 0.03309, 'accuracy': 0.96815, 'precision': 0.49275, 'recall': 0.26154, 'f1': 0.34171, 'auc': 0.76265}
# > Epoch 14: took 98.9s (avg 99.6s) | Best so far: epoch 14	train_loss: 0.1068 train_auc: 0.8608	val_loss: 0.0762 val_auc: 0.8268	test_loss: 0.1172 test_auc: 0.7627
# train: {'epoch': 15, 'time_epoch': 90.16063, 'eta': 7620.86826, 'eta_hours': 2.11691, 'loss': 0.10535048, 'lr': 9.729e-05, 'params': 581075, 'time_iter': 0.08762, 'accuracy': 0.97, 'precision': 0.70315, 'recall': 0.34416, 'f1': 0.46213, 'auc': 0.86765}
# val: {'epoch': 15, 'time_epoch': 4.36111, 'loss': 0.07422973, 'lr': 0, 'params': 581075, 'time_iter': 0.03381, 'accuracy': 0.98128, 'precision': 0.55263, 'recall': 0.25926, 'f1': 0.35294, 'auc': 0.81671}
# test: {'epoch': 15, 'time_epoch': 4.28669, 'loss': 0.11328792, 'lr': 0, 'params': 581075, 'time_iter': 0.03323, 'accuracy': 0.97009, 'precision': 0.55385, 'recall': 0.27692, 'f1': 0.36923, 'auc': 0.79022}
# > Epoch 15: took 98.9s (avg 99.6s) | Best so far: epoch 14	train_loss: 0.1068 train_auc: 0.8608	val_loss: 0.0762 val_auc: 0.8268	test_loss: 0.1172 test_auc: 0.7627
# train: {'epoch': 16, 'time_epoch': 90.30154, 'eta': 7528.07799, 'eta_hours': 2.09113, 'loss': 0.10320981, 'lr': 9.673e-05, 'params': 581075, 'time_iter': 0.08776, 'accuracy': 0.9704, 'precision': 0.71572, 'recall': 0.3474, 'f1': 0.46776, 'auc': 0.87646}
# val: {'epoch': 16, 'time_epoch': 4.3771, 'loss': 0.07871623, 'lr': 0, 'params': 581075, 'time_iter': 0.03393, 'accuracy': 0.97666, 'precision': 0.39437, 'recall': 0.34568, 'f1': 0.36842, 'auc': 0.83023}
# test: {'epoch': 16, 'time_epoch': 4.27141, 'loss': 0.1252387, 'lr': 0, 'params': 581075, 'time_iter': 0.03311, 'accuracy': 0.96791, 'precision': 0.4875, 'recall': 0.3, 'f1': 0.37143, 'auc': 0.77102}
# > Epoch 16: took 99.1s (avg 99.6s) | Best so far: epoch 16	train_loss: 0.1032 train_auc: 0.8765	val_loss: 0.0787 val_auc: 0.8302	test_loss: 0.1252 test_auc: 0.7710
# train: {'epoch': 17, 'time_epoch': 89.99721, 'eta': 7434.17787, 'eta_hours': 2.06505, 'loss': 0.1017617, 'lr': 9.611e-05, 'params': 581075, 'time_iter': 0.08746, 'accuracy': 0.97113, 'precision': 0.72596, 'recall': 0.36769, 'f1': 0.48815, 'auc': 0.88048}
# val: {'epoch': 17, 'time_epoch': 4.37126, 'loss': 0.07531297, 'lr': 0, 'params': 581075, 'time_iter': 0.03389, 'accuracy': 0.9786, 'precision': 0.43137, 'recall': 0.2716, 'f1': 0.33333, 'auc': 0.81176}
# test: {'epoch': 17, 'time_epoch': 4.25636, 'loss': 0.11393056, 'lr': 0, 'params': 581075, 'time_iter': 0.033, 'accuracy': 0.97082, 'precision': 0.5641, 'recall': 0.33846, 'f1': 0.42308, 'auc': 0.78128}
# > Epoch 17: took 98.8s (avg 99.5s) | Best so far: epoch 16	train_loss: 0.1032 train_auc: 0.8765	val_loss: 0.0787 val_auc: 0.8302	test_loss: 0.1252 test_auc: 0.7710
# train: {'epoch': 18, 'time_epoch': 90.21271, 'eta': 7341.6073, 'eta_hours': 2.03934, 'loss': 0.0998728, 'lr': 9.545e-05, 'params': 581075, 'time_iter': 0.08767, 'accuracy': 0.97091, 'precision': 0.71252, 'recall': 0.37419, 'f1': 0.49069, 'auc': 0.89212}
# val: {'epoch': 18, 'time_epoch': 4.30281, 'loss': 0.07147001, 'lr': 0, 'params': 581075, 'time_iter': 0.03336, 'accuracy': 0.98152, 'precision': 0.55556, 'recall': 0.30864, 'f1': 0.39683, 'auc': 0.83078}
# test: {'epoch': 18, 'time_epoch': 4.34731, 'loss': 0.11544249, 'lr': 0, 'params': 581075, 'time_iter': 0.0337, 'accuracy': 0.96985, 'precision': 0.54054, 'recall': 0.30769, 'f1': 0.39216, 'auc': 0.77588}
# > Epoch 18: took 99.0s (avg 99.5s) | Best so far: epoch 18	train_loss: 0.0999 train_auc: 0.8921	val_loss: 0.0715 val_auc: 0.8308	test_loss: 0.1154 test_auc: 0.7759
# train: {'epoch': 19, 'time_epoch': 90.24853, 'eta': 7249.41579, 'eta_hours': 2.01373, 'loss': 0.10013658, 'lr': 9.474e-05, 'params': 581075, 'time_iter': 0.08771, 'accuracy': 0.97201, 'precision': 0.74722, 'recall': 0.38149, 'f1': 0.5051, 'auc': 0.88631}
# val: {'epoch': 19, 'time_epoch': 4.31883, 'loss': 0.07187955, 'lr': 0, 'params': 581075, 'time_iter': 0.03348, 'accuracy': 0.98152, 'precision': 0.57143, 'recall': 0.24691, 'f1': 0.34483, 'auc': 0.82102}
# test: {'epoch': 19, 'time_epoch': 4.39505, 'loss': 0.11675476, 'lr': 0, 'params': 581075, 'time_iter': 0.03407, 'accuracy': 0.96864, 'precision': 0.50943, 'recall': 0.20769, 'f1': 0.29508, 'auc': 0.77039}
# > Epoch 19: took 99.1s (avg 99.5s) | Best so far: epoch 18	train_loss: 0.0999 train_auc: 0.8921	val_loss: 0.0715 val_auc: 0.8308	test_loss: 0.1154 test_auc: 0.7759
# train: {'epoch': 20, 'time_epoch': 90.28025, 'eta': 7157.52866, 'eta_hours': 1.9882, 'loss': 0.09708753, 'lr': 9.397e-05, 'params': 581075, 'time_iter': 0.08774, 'accuracy': 0.97189, 'precision': 0.74326, 'recall': 0.38068, 'f1': 0.50349, 'auc': 0.8991}
# val: {'epoch': 20, 'time_epoch': 4.27775, 'loss': 0.08905749, 'lr': 0, 'params': 581075, 'time_iter': 0.03316, 'accuracy': 0.97569, 'precision': 0.37975, 'recall': 0.37037, 'f1': 0.375, 'auc': 0.79582}
# test: {'epoch': 20, 'time_epoch': 4.28167, 'loss': 0.13029562, 'lr': 0, 'params': 581075, 'time_iter': 0.03319, 'accuracy': 0.96475, 'precision': 0.42424, 'recall': 0.32308, 'f1': 0.36681, 'auc': 0.74588}
# > Epoch 20: took 99.0s (avg 99.4s) | Best so far: epoch 18	train_loss: 0.0999 train_auc: 0.8921	val_loss: 0.0715 val_auc: 0.8308	test_loss: 0.1154 test_auc: 0.7759
# train: {'epoch': 21, 'time_epoch': 89.49337, 'eta': 7062.99777, 'eta_hours': 1.96194, 'loss': 0.096762, 'lr': 9.316e-05, 'params': 581075, 'time_iter': 0.08697, 'accuracy': 0.97204, 'precision': 0.73353, 'recall': 0.39773, 'f1': 0.51579, 'auc': 0.8996}
# val: {'epoch': 21, 'time_epoch': 4.23552, 'loss': 0.0842877, 'lr': 0, 'params': 581075, 'time_iter': 0.03283, 'accuracy': 0.97544, 'precision': 0.35294, 'recall': 0.2963, 'f1': 0.32215, 'auc': 0.80867}
# test: {'epoch': 21, 'time_epoch': 4.29048, 'loss': 0.12058255, 'lr': 0, 'params': 581075, 'time_iter': 0.03326, 'accuracy': 0.96888, 'precision': 0.5122, 'recall': 0.32308, 'f1': 0.39623, 'auc': 0.78947}
# > Epoch 21: took 98.2s (avg 99.4s) | Best so far: epoch 18	train_loss: 0.0999 train_auc: 0.8921	val_loss: 0.0715 val_auc: 0.8308	test_loss: 0.1154 test_auc: 0.7759
# train: {'epoch': 22, 'time_epoch': 89.46316, 'eta': 6968.80378, 'eta_hours': 1.93578, 'loss': 0.09421465, 'lr': 9.23e-05, 'params': 581075, 'time_iter': 0.08694, 'accuracy': 0.97255, 'precision': 0.74589, 'recall': 0.40503, 'f1': 0.52499, 'auc': 0.90631}
# val: {'epoch': 22, 'time_epoch': 4.25538, 'loss': 0.08246008, 'lr': 0, 'params': 581075, 'time_iter': 0.03299, 'accuracy': 0.97715, 'precision': 0.4058, 'recall': 0.34568, 'f1': 0.37333, 'auc': 0.80982}
# test: {'epoch': 22, 'time_epoch': 4.30778, 'loss': 0.12164912, 'lr': 0, 'params': 581075, 'time_iter': 0.03339, 'accuracy': 0.96791, 'precision': 0.4898, 'recall': 0.36923, 'f1': 0.42105, 'auc': 0.7732}
# > Epoch 22: took 98.2s (avg 99.3s) | Best so far: epoch 18	train_loss: 0.0999 train_auc: 0.8921	val_loss: 0.0715 val_auc: 0.8308	test_loss: 0.1154 test_auc: 0.7759
# train: {'epoch': 23, 'time_epoch': 90.36243, 'eta': 6877.8517, 'eta_hours': 1.91051, 'loss': 0.0941354, 'lr': 9.14e-05, 'params': 581075, 'time_iter': 0.08782, 'accuracy': 0.9724, 'precision': 0.73276, 'recall': 0.41396, 'f1': 0.52905, 'auc': 0.90851}
# val: {'epoch': 23, 'time_epoch': 4.40102, 'loss': 0.07189128, 'lr': 0, 'params': 581075, 'time_iter': 0.03412, 'accuracy': 0.98298, 'precision': 0.60784, 'recall': 0.38272, 'f1': 0.4697, 'auc': 0.82935}
# test: {'epoch': 23, 'time_epoch': 4.42757, 'loss': 0.12298195, 'lr': 0, 'params': 581075, 'time_iter': 0.03432, 'accuracy': 0.96912, 'precision': 0.52632, 'recall': 0.23077, 'f1': 0.32086, 'auc': 0.7804}
# > Epoch 23: took 99.3s (avg 99.3s) | Best so far: epoch 18	train_loss: 0.0999 train_auc: 0.8921	val_loss: 0.0715 val_auc: 0.8308	test_loss: 0.1154 test_auc: 0.7759
# train: {'epoch': 24, 'time_epoch': 91.67486, 'eta': 6790.8841, 'eta_hours': 1.88636, 'loss': 0.09088282, 'lr': 9.045e-05, 'params': 581075, 'time_iter': 0.08909, 'accuracy': 0.97298, 'precision': 0.7511, 'recall': 0.4164, 'f1': 0.53577, 'auc': 0.91775}
# val: {'epoch': 24, 'time_epoch': 4.31393, 'loss': 0.07404882, 'lr': 0, 'params': 581075, 'time_iter': 0.03344, 'accuracy': 0.98104, 'precision': 0.53488, 'recall': 0.28395, 'f1': 0.37097, 'auc': 0.8091}
# test: {'epoch': 24, 'time_epoch': 4.30788, 'loss': 0.12046379, 'lr': 0, 'params': 581075, 'time_iter': 0.03339, 'accuracy': 0.97082, 'precision': 0.56579, 'recall': 0.33077, 'f1': 0.41748, 'auc': 0.77641}
# > Epoch 24: took 100.4s (avg 99.4s) | Best so far: epoch 18	train_loss: 0.0999 train_auc: 0.8921	val_loss: 0.0715 val_auc: 0.8308	test_loss: 0.1154 test_auc: 0.7759
# train: {'epoch': 25, 'time_epoch': 91.08104, 'eta': 6701.86428, 'eta_hours': 1.86163, 'loss': 0.09063733, 'lr': 8.946e-05, 'params': 581075, 'time_iter': 0.08851, 'accuracy': 0.97334, 'precision': 0.76374, 'recall': 0.41721, 'f1': 0.53963, 'auc': 0.91568}
# val: {'epoch': 25, 'time_epoch': 4.3933, 'loss': 0.08304208, 'lr': 0, 'params': 581075, 'time_iter': 0.03406, 'accuracy': 0.97788, 'precision': 0.42188, 'recall': 0.33333, 'f1': 0.37241, 'auc': 0.8036}
# test: {'epoch': 25, 'time_epoch': 4.29884, 'loss': 0.12962095, 'lr': 0, 'params': 581075, 'time_iter': 0.03332, 'accuracy': 0.96548, 'precision': 0.4375, 'recall': 0.32308, 'f1': 0.37168, 'auc': 0.75713}
# > Epoch 25: took 99.9s (avg 99.4s) | Best so far: epoch 18	train_loss: 0.0999 train_auc: 0.8921	val_loss: 0.0715 val_auc: 0.8308	test_loss: 0.1154 test_auc: 0.7759
# train: {'epoch': 26, 'time_epoch': 90.62552, 'eta': 6611.46018, 'eta_hours': 1.83652, 'loss': 0.09054138, 'lr': 8.842e-05, 'params': 581075, 'time_iter': 0.08807, 'accuracy': 0.97313, 'precision': 0.75217, 'recall': 0.42127, 'f1': 0.54006, 'auc': 0.91928}
# val: {'epoch': 26, 'time_epoch': 4.33112, 'loss': 0.0817168, 'lr': 0, 'params': 581075, 'time_iter': 0.03357, 'accuracy': 0.97763, 'precision': 0.41791, 'recall': 0.34568, 'f1': 0.37838, 'auc': 0.82496}
# test: {'epoch': 26, 'time_epoch': 4.2823, 'loss': 0.13519725, 'lr': 0, 'params': 581075, 'time_iter': 0.0332, 'accuracy': 0.96426, 'precision': 0.41237, 'recall': 0.30769, 'f1': 0.35242, 'auc': 0.77133}
# > Epoch 26: took 99.4s (avg 99.4s) | Best so far: epoch 18	train_loss: 0.0999 train_auc: 0.8921	val_loss: 0.0715 val_auc: 0.8308	test_loss: 0.1154 test_auc: 0.7759
# ...
# > Epoch 65: took 97.6s (avg 99.0s) | Best so far: epoch 48	train_loss: 0.0654 train_auc: 0.9695	val_loss: 0.0903 val_auc: 0.8372	test_loss: 0.1660 test_auc: 0.7895
# train: {'epoch': 66, 'time_epoch': 89.3419, 'eta': 2976.74871, 'eta_hours': 0.82687, 'loss': 0.0534747, 'lr': 2.841e-05, 'params': 581075, 'time_iter': 0.08682, 'accuracy': 0.98268, 'precision': 0.84989, 'recall': 0.6526, 'f1': 0.73829, 'auc': 0.98233}
# val: {'epoch': 66, 'time_epoch': 4.33542, 'loss': 0.10719723, 'lr': 0, 'params': 581075, 'time_iter': 0.03361, 'accuracy': 0.97836, 'precision': 0.44118, 'recall': 0.37037, 'f1': 0.40268, 'auc': 0.82144}
# test: {'epoch': 66, 'time_epoch': 4.28095, 'loss': 0.20076219, 'lr': 0, 'params': 581075, 'time_iter': 0.03319, 'accuracy': 0.9645, 'precision': 0.39474, 'recall': 0.23077, 'f1': 0.29126, 'auc': 0.78388}
# > Epoch 66: took 98.1s (avg 99.0s) | Best so far: epoch 48	train_loss: 0.0654 train_auc: 0.9695	val_loss: 0.0903 val_auc: 0.8372	test_loss: 0.1660 test_auc: 0.7895
# train: {'epoch': 67, 'time_epoch': 89.18416, 'eta': 2886.06404, 'eta_hours': 0.80168, 'loss': 0.05121505, 'lr': 2.693e-05, 'params': 581075, 'time_iter': 0.08667, 'accuracy': 0.98304, 'precision': 0.84886, 'recall': 0.66558, 'f1': 0.74613, 'auc': 0.98444}
# val: {'epoch': 67, 'time_epoch': 4.30393, 'loss': 0.10546698, 'lr': 0, 'params': 581075, 'time_iter': 0.03336, 'accuracy': 0.97788, 'precision': 0.41935, 'recall': 0.32099, 'f1': 0.36364, 'auc': 0.82186}
# test: {'epoch': 67, 'time_epoch': 4.36616, 'loss': 0.19289643, 'lr': 0, 'params': 581075, 'time_iter': 0.03385, 'accuracy': 0.9645, 'precision': 0.4, 'recall': 0.24615, 'f1': 0.30476, 'auc': 0.78969}
# > Epoch 67: took 98.0s (avg 99.0s) | Best so far: epoch 48	train_loss: 0.0654 train_auc: 0.9695	val_loss: 0.0903 val_auc: 0.8372	test_loss: 0.1660 test_auc: 0.7895
# train: {'epoch': 68, 'time_epoch': 89.15861, 'eta': 2795.41138, 'eta_hours': 0.7765, 'loss': 0.04918439, 'lr': 2.548e-05, 'params': 581075, 'time_iter': 0.08665, 'accuracy': 0.98274, 'precision': 0.84086, 'recall': 0.66477, 'f1': 0.74252, 'auc': 0.98689}
# val: {'epoch': 68, 'time_epoch': 4.2513, 'loss': 0.1054527, 'lr': 0, 'params': 581075, 'time_iter': 0.03296, 'accuracy': 0.97666, 'precision': 0.4026, 'recall': 0.38272, 'f1': 0.39241, 'auc': 0.82601}
# test: {'epoch': 68, 'time_epoch': 4.32616, 'loss': 0.19156792, 'lr': 0, 'params': 581075, 'time_iter': 0.03354, 'accuracy': 0.96183, 'precision': 0.35484, 'recall': 0.25385, 'f1': 0.29596, 'auc': 0.78485}
# > Epoch 68: took 97.9s (avg 98.9s) | Best so far: epoch 48	train_loss: 0.0654 train_auc: 0.9695	val_loss: 0.0903 val_auc: 0.8372	test_loss: 0.1660 test_auc: 0.7895
# train: {'epoch': 69, 'time_epoch': 89.50258, 'eta': 2704.94883, 'eta_hours': 0.75137, 'loss': 0.04971793, 'lr': 2.405e-05, 'params': 581075, 'time_iter': 0.08698, 'accuracy': 0.98319, 'precision': 0.85926, 'recall': 0.65909, 'f1': 0.74598, 'auc': 0.98665}
# val: {'epoch': 69, 'time_epoch': 4.21908, 'loss': 0.10455362, 'lr': 0, 'params': 581075, 'time_iter': 0.03271, 'accuracy': 0.98006, 'precision': 0.4918, 'recall': 0.37037, 'f1': 0.42254, 'auc': 0.82265}
# test: {'epoch': 69, 'time_epoch': 4.20504, 'loss': 0.19939148, 'lr': 0, 'params': 581075, 'time_iter': 0.0326, 'accuracy': 0.96426, 'precision': 0.37313, 'recall': 0.19231, 'f1': 0.25381, 'auc': 0.78394}
# > Epoch 69: took 98.1s (avg 98.9s) | Best so far: epoch 48	train_loss: 0.0654 train_auc: 0.9695	val_loss: 0.0903 val_auc: 0.8372	test_loss: 0.1660 test_auc: 0.7895
# train: {'epoch': 70, 'time_epoch': 89.60492, 'eta': 2614.55512, 'eta_hours': 0.72627, 'loss': 0.04912806, 'lr': 2.265e-05, 'params': 581075, 'time_iter': 0.08708, 'accuracy': 0.9838, 'precision': 0.8746, 'recall': 0.66234, 'f1': 0.75381, 'auc': 0.98728}
# val: {'epoch': 70, 'time_epoch': 4.27637, 'loss': 0.10871908, 'lr': 0, 'params': 581075, 'time_iter': 0.03315, 'accuracy': 0.97812, 'precision': 0.43077, 'recall': 0.34568, 'f1': 0.38356, 'auc': 0.82345}
# test: {'epoch': 70, 'time_epoch': 4.29385, 'loss': 0.20701677, 'lr': 0, 'params': 581075, 'time_iter': 0.03329, 'accuracy': 0.9645, 'precision': 0.39474, 'recall': 0.23077, 'f1': 0.29126, 'auc': 0.78395}
# > Epoch 70: took 98.3s (avg 98.9s) | Best so far: epoch 48	train_loss: 0.0654 train_auc: 0.9695	val_loss: 0.0903 val_auc: 0.8372	test_loss: 0.1660 test_auc: 0.7895
# train: {'epoch': 71, 'time_epoch': 91.07439, 'eta': 2524.75478, 'eta_hours': 0.70132, 'loss': 0.05029188, 'lr': 2.128e-05, 'params': 581075, 'time_iter': 0.08851, 'accuracy': 0.98356, 'precision': 0.86407, 'recall': 0.66558, 'f1': 0.75195, 'auc': 0.98541}
# val: {'epoch': 71, 'time_epoch': 4.29521, 'loss': 0.10757034, 'lr': 0, 'params': 581075, 'time_iter': 0.0333, 'accuracy': 0.9769, 'precision': 0.39706, 'recall': 0.33333, 'f1': 0.36242, 'auc': 0.82025}
# test: {'epoch': 71, 'time_epoch': 4.22868, 'loss': 0.20371441, 'lr': 0, 'params': 581075, 'time_iter': 0.03278, 'accuracy': 0.96475, 'precision': 0.39726, 'recall': 0.22308, 'f1': 0.28571, 'auc': 0.78181}
# > Epoch 71: took 99.7s (avg 98.9s) | Best so far: epoch 48	train_loss: 0.0654 train_auc: 0.9695	val_loss: 0.0903 val_auc: 0.8372	test_loss: 0.1660 test_auc: 0.7895
# train: {'epoch': 72, 'time_epoch': 89.56632, 'eta': 2434.36176, 'eta_hours': 0.67621, 'loss': 0.04739451, 'lr': 1.995e-05, 'params': 581075, 'time_iter': 0.08704, 'accuracy': 0.98401, 'precision': 0.86467, 'recall': 0.67938, 'f1': 0.76091, 'auc': 0.98776}
# val: {'epoch': 72, 'time_epoch': 4.2787, 'loss': 0.11079984, 'lr': 0, 'params': 581075, 'time_iter': 0.03317, 'accuracy': 0.97812, 'precision': 0.42857, 'recall': 0.33333, 'f1': 0.375, 'auc': 0.81935}
# test: {'epoch': 72, 'time_epoch': 4.26519, 'loss': 0.20799543, 'lr': 0, 'params': 581075, 'time_iter': 0.03306, 'accuracy': 0.9645, 'precision': 0.38571, 'recall': 0.20769, 'f1': 0.27, 'auc': 0.7772}
# > Epoch 72: took 98.2s (avg 98.9s) | Best so far: epoch 48	train_loss: 0.0654 train_auc: 0.9695	val_loss: 0.0903 val_auc: 0.8372	test_loss: 0.1660 test_auc: 0.7895
# train: {'epoch': 73, 'time_epoch': 89.54869, 'eta': 2343.98489, 'eta_hours': 0.65111, 'loss': 0.04583494, 'lr': 1.864e-05, 'params': 581075, 'time_iter': 0.08702, 'accuracy': 0.98404, 'precision': 0.86481, 'recall': 0.68019, 'f1': 0.76147, 'auc': 0.98863}
# val: {'epoch': 73, 'time_epoch': 4.23519, 'loss': 0.1119395, 'lr': 0, 'params': 581075, 'time_iter': 0.03283, 'accuracy': 0.97958, 'precision': 0.4717, 'recall': 0.30864, 'f1': 0.37313, 'auc': 0.82213}
# test: {'epoch': 73, 'time_epoch': 4.3442, 'loss': 0.2159279, 'lr': 0, 'params': 581075, 'time_iter': 0.03368, 'accuracy': 0.96499, 'precision': 0.40541, 'recall': 0.23077, 'f1': 0.29412, 'auc': 0.77748}
# > Epoch 73: took 98.3s (avg 98.9s) | Best so far: epoch 48	train_loss: 0.0654 train_auc: 0.9695	val_loss: 0.0903 val_auc: 0.8372	test_loss: 0.1660 test_auc: 0.7895
# train: {'epoch': 74, 'time_epoch': 90.1642, 'eta': 2253.83527, 'eta_hours': 0.62607, 'loss': 0.04697319, 'lr': 1.737e-05, 'params': 581075, 'time_iter': 0.08762, 'accuracy': 0.98462, 'precision': 0.86667, 'recall': 0.69643, 'f1': 0.77228, 'auc': 0.98716}
# val: {'epoch': 74, 'time_epoch': 4.24688, 'loss': 0.11209259, 'lr': 0, 'params': 581075, 'time_iter': 0.03292, 'accuracy': 0.98006, 'precision': 0.49123, 'recall': 0.34568, 'f1': 0.4058, 'auc': 0.81721}
# test: {'epoch': 74, 'time_epoch': 4.28166, 'loss': 0.2112293, 'lr': 0, 'params': 581075, 'time_iter': 0.03319, 'accuracy': 0.96499, 'precision': 0.41026, 'recall': 0.24615, 'f1': 0.30769, 'auc': 0.77856}
# > Epoch 74: took 98.8s (avg 98.9s) | Best so far: epoch 48	train_loss: 0.0654 train_auc: 0.9695	val_loss: 0.0903 val_auc: 0.8372	test_loss: 0.1660 test_auc: 0.7895
# train: {'epoch': 75, 'time_epoch': 90.19512, 'eta': 2163.69503, 'eta_hours': 0.60103, 'loss': 0.04672325, 'lr': 1.614e-05, 'params': 581075, 'time_iter': 0.08765, 'accuracy': 0.9841, 'precision': 0.84789, 'recall': 0.7013, 'f1': 0.76766, 'auc': 0.98745}
# val: {'epoch': 75, 'time_epoch': 4.2311, 'loss': 0.10782809, 'lr': 0, 'params': 581075, 'time_iter': 0.0328, 'accuracy': 0.97885, 'precision': 0.44828, 'recall': 0.32099, 'f1': 0.3741, 'auc': 0.82546}
# test: {'epoch': 75, 'time_epoch': 4.27234, 'loss': 0.20514827, 'lr': 0, 'params': 581075, 'time_iter': 0.03312, 'accuracy': 0.96548, 'precision': 0.43182, 'recall': 0.29231, 'f1': 0.34862, 'auc': 0.78295}
# > Epoch 75: took 98.8s (avg 98.9s) | Best so far: epoch 48	train_loss: 0.0654 train_auc: 0.9695	val_loss: 0.0903 val_auc: 0.8372	test_loss: 0.1660 test_auc: 0.7895
# train: {'epoch': 76, 'time_epoch': 88.82107, 'eta': 2073.14293, 'eta_hours': 0.57587, 'loss': 0.04485433, 'lr': 1.494e-05, 'params': 581075, 'time_iter': 0.08632, 'accuracy': 0.98486, 'precision': 0.8577, 'recall': 0.71429, 'f1': 0.77945, 'auc': 0.98947}
# val: {'epoch': 76, 'time_epoch': 4.26562, 'loss': 0.11312041, 'lr': 0, 'params': 581075, 'time_iter': 0.03307, 'accuracy': 0.97812, 'precision': 0.42857, 'recall': 0.33333, 'f1': 0.375, 'auc': 0.8245}
# test: {'epoch': 76, 'time_epoch': 4.24099, 'loss': 0.20997422, 'lr': 0, 'params': 581075, 'time_iter': 0.03288, 'accuracy': 0.96353, 'precision': 0.3913, 'recall': 0.27692, 'f1': 0.32432, 'auc': 0.78242}
# > Epoch 76: took 97.5s (avg 98.9s) | Best so far: epoch 48	train_loss: 0.0654 train_auc: 0.9695	val_loss: 0.0903 val_auc: 0.8372	test_loss: 0.1660 test_auc: 0.7895
# train: {'epoch': 77, 'time_epoch': 89.54172, 'eta': 1982.83848, 'eta_hours': 0.55079, 'loss': 0.04534104, 'lr': 1.378e-05, 'params': 581075, 'time_iter': 0.08702, 'accuracy': 0.98465, 'precision': 0.8668, 'recall': 0.69724, 'f1': 0.77283, 'auc': 0.98887}
# val: {'epoch': 77, 'time_epoch': 4.27284, 'loss': 0.11630618, 'lr': 0, 'params': 581075, 'time_iter': 0.03312, 'accuracy': 0.97739, 'precision': 0.40909, 'recall': 0.33333, 'f1': 0.36735, 'auc': 0.82548}
# test: {'epoch': 77, 'time_epoch': 4.27338, 'loss': 0.21584491, 'lr': 0, 'params': 581075, 'time_iter': 0.03313, 'accuracy': 0.9645, 'precision': 0.40698, 'recall': 0.26923, 'f1': 0.32407, 'auc': 0.78548}
# > Epoch 77: took 98.2s (avg 98.9s) | Best so far: epoch 48	train_loss: 0.0654 train_auc: 0.9695	val_loss: 0.0903 val_auc: 0.8372	test_loss: 0.1660 test_auc: 0.7895
# train: {'epoch': 78, 'time_epoch': 90.79229, 'eta': 1892.88577, 'eta_hours': 0.5258, 'loss': 0.04560974, 'lr': 1.266e-05, 'params': 581075, 'time_iter': 0.08823, 'accuracy': 0.98426, 'precision': 0.85558, 'recall': 0.69724, 'f1': 0.76834, 'auc': 0.98957}
# val: {'epoch': 78, 'time_epoch': 4.33627, 'loss': 0.11909603, 'lr': 0, 'params': 581075, 'time_iter': 0.03361, 'accuracy': 0.97763, 'precision': 0.42029, 'recall': 0.35802, 'f1': 0.38667, 'auc': 0.81958}
# test: {'epoch': 78, 'time_epoch': 4.24409, 'loss': 0.21440045, 'lr': 0, 'params': 581075, 'time_iter': 0.0329, 'accuracy': 0.9611, 'precision': 0.34375, 'recall': 0.25385, 'f1': 0.29204, 'auc': 0.79057}
# > Epoch 78: took 99.5s (avg 98.9s) | Best so far: epoch 48	train_loss: 0.0654 train_auc: 0.9695	val_loss: 0.0903 val_auc: 0.8372	test_loss: 0.1660 test_auc: 0.7895
# train: {'epoch': 79, 'time_epoch': 89.55815, 'eta': 1802.60354, 'eta_hours': 0.50072, 'loss': 0.0450285, 'lr': 1.158e-05, 'params': 581075, 'time_iter': 0.08703, 'accuracy': 0.9845, 'precision': 0.85956, 'recall': 0.70049, 'f1': 0.77191, 'auc': 0.98971}
# val: {'epoch': 79, 'time_epoch': 4.30815, 'loss': 0.11739176, 'lr': 0, 'params': 581075, 'time_iter': 0.0334, 'accuracy': 0.97788, 'precision': 0.42647, 'recall': 0.35802, 'f1': 0.38926, 'auc': 0.81891}
# test: {'epoch': 79, 'time_epoch': 4.23761, 'loss': 0.22436404, 'lr': 0, 'params': 581075, 'time_iter': 0.03285, 'accuracy': 0.96256, 'precision': 0.34211, 'recall': 0.2, 'f1': 0.25243, 'auc': 0.78448}
# > Epoch 79: took 98.2s (avg 98.9s) | Best so far: epoch 48	train_loss: 0.0654 train_auc: 0.9695	val_loss: 0.0903 val_auc: 0.8372	test_loss: 0.1660 test_auc: 0.7895
# train: {'epoch': 80, 'time_epoch': 89.4568, 'eta': 1712.31541, 'eta_hours': 0.47564, 'loss': 0.04462267, 'lr': 1.054e-05, 'params': 581075, 'time_iter': 0.08694, 'accuracy': 0.98556, 'precision': 0.87512, 'recall': 0.71672, 'f1': 0.78804, 'auc': 0.9874}
# val: {'epoch': 80, 'time_epoch': 4.20916, 'loss': 0.11482913, 'lr': 0, 'params': 581075, 'time_iter': 0.03263, 'accuracy': 0.97812, 'precision': 0.42373, 'recall': 0.30864, 'f1': 0.35714, 'auc': 0.82591}
# test: {'epoch': 80, 'time_epoch': 4.33697, 'loss': 0.22239685, 'lr': 0, 'params': 581075, 'time_iter': 0.03362, 'accuracy': 0.96426, 'precision': 0.38961, 'recall': 0.23077, 'f1': 0.28986, 'auc': 0.78085}
# > Epoch 80: took 98.1s (avg 98.9s) | Best so far: epoch 48	train_loss: 0.0654 train_auc: 0.9695	val_loss: 0.0903 val_auc: 0.8372	test_loss: 0.1660 test_auc: 0.7895
# train: {'epoch': 81, 'time_epoch': 89.47561, 'eta': 1622.05168, 'eta_hours': 0.45057, 'loss': 0.04492286, 'lr': 9.55e-06, 'params': 581075, 'time_iter': 0.08695, 'accuracy': 0.98477, 'precision': 0.86368, 'recall': 0.70455, 'f1': 0.77604, 'auc': 0.98944}
# val: {'epoch': 81, 'time_epoch': 4.31733, 'loss': 0.1108881, 'lr': 0, 'params': 581075, 'time_iter': 0.03347, 'accuracy': 0.97909, 'precision': 0.46032, 'recall': 0.35802, 'f1': 0.40278, 'auc': 0.82569}
# test: {'epoch': 81, 'time_epoch': 4.2848, 'loss': 0.21622995, 'lr': 0, 'params': 581075, 'time_iter': 0.03322, 'accuracy': 0.96353, 'precision': 0.38095, 'recall': 0.24615, 'f1': 0.29907, 'auc': 0.78051}
# > Epoch 81: took 98.2s (avg 98.9s) | Best so far: epoch 48	train_loss: 0.0654 train_auc: 0.9695	val_loss: 0.0903 val_auc: 0.8372	test_loss: 0.1660 test_auc: 0.7895
# train: {'epoch': 82, 'time_epoch': 89.18428, 'eta': 1531.74728, 'eta_hours': 0.42549, 'loss': 0.04461026, 'lr': 8.6e-06, 'params': 581075, 'time_iter': 0.08667, 'accuracy': 0.98547, 'precision': 0.87106, 'recall': 0.71834, 'f1': 0.78737, 'auc': 0.98843}
# val: {'epoch': 82, 'time_epoch': 4.23421, 'loss': 0.11538429, 'lr': 0, 'params': 581075, 'time_iter': 0.03282, 'accuracy': 0.97958, 'precision': 0.47458, 'recall': 0.34568, 'f1': 0.4, 'auc': 0.82403}
# test: {'epoch': 82, 'time_epoch': 4.2319, 'loss': 0.22361183, 'lr': 0, 'params': 581075, 'time_iter': 0.03281, 'accuracy': 0.96377, 'precision': 0.37975, 'recall': 0.23077, 'f1': 0.28708, 'auc': 0.78662}
# > Epoch 82: took 97.8s (avg 98.9s) | Best so far: epoch 48	train_loss: 0.0654 train_auc: 0.9695	val_loss: 0.0903 val_auc: 0.8372	test_loss: 0.1660 test_auc: 0.7895
# train: {'epoch': 83, 'time_epoch': 90.05202, 'eta': 1441.63483, 'eta_hours': 0.40045, 'loss': 0.04358497, 'lr': 7.7e-06, 'params': 581075, 'time_iter': 0.08751, 'accuracy': 0.98541, 'precision': 0.87154, 'recall': 0.71591, 'f1': 0.7861, 'auc': 0.99015}
# val: {'epoch': 83, 'time_epoch': 4.31323, 'loss': 0.11691297, 'lr': 0, 'params': 581075, 'time_iter': 0.03344, 'accuracy': 0.97617, 'precision': 0.38356, 'recall': 0.34568, 'f1': 0.36364, 'auc': 0.81902}
# test: {'epoch': 83, 'time_epoch': 4.2193, 'loss': 0.20993027, 'lr': 0, 'params': 581075, 'time_iter': 0.03271, 'accuracy': 0.96329, 'precision': 0.38462, 'recall': 0.26923, 'f1': 0.31674, 'auc': 0.78544}
# > Epoch 83: took 98.7s (avg 98.8s) | Best so far: epoch 48	train_loss: 0.0654 train_auc: 0.9695	val_loss: 0.0903 val_auc: 0.8372	test_loss: 0.1660 test_auc: 0.7895
# train: {'epoch': 84, 'time_epoch': 89.16724, 'eta': 1351.36767, 'eta_hours': 0.37538, 'loss': 0.04380977, 'lr': 6.84e-06, 'params': 581075, 'time_iter': 0.08665, 'accuracy': 0.98495, 'precision': 0.86305, 'recall': 0.71104, 'f1': 0.77971, 'auc': 0.99026}
# val: {'epoch': 84, 'time_epoch': 4.25172, 'loss': 0.11431723, 'lr': 0, 'params': 581075, 'time_iter': 0.03296, 'accuracy': 0.97739, 'precision': 0.41429, 'recall': 0.35802, 'f1': 0.38411, 'auc': 0.81939}
# test: {'epoch': 84, 'time_epoch': 4.25459, 'loss': 0.20776672, 'lr': 0, 'params': 581075, 'time_iter': 0.03298, 'accuracy': 0.96329, 'precision': 0.37931, 'recall': 0.25385, 'f1': 0.30415, 'auc': 0.78509}
# > Epoch 84: took 97.8s (avg 98.8s) | Best so far: epoch 48	train_loss: 0.0654 train_auc: 0.9695	val_loss: 0.0903 val_auc: 0.8372	test_loss: 0.1660 test_auc: 0.7895
