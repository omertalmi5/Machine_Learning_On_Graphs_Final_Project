# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/torch_scatter-2.1.2-cp310-cp310-linux_x86_64.whl
# /kaggle/input/torch_geometric-2.5.3-py3-none-any.whl
# /kaggle/input/torch_cluster-1.6.3-cp310-cp310-linux_x86_64.whl
# /kaggle/input/torch_spline_conv-1.2.2-cp310-cp310-linux_x86_64.whl
# /kaggle/input/torch_sparse-0.6.18-cp310-cp310-linux_x86_64.whl

# %%
# !git clone https://github.com/rampasek/GraphGPS.git
# Out:
# Cloning into 'GraphGPS'...
# remote: Enumerating objects: 526, done.
# remote: Counting objects: 100% (316/316), done.
# remote: Compressing objects: 100% (91/91), done.
# remote: Total 526 (delta 254), reused 225 (delta 225), pack-reused 210 (from 1)
# Receiving objects: 100% (526/526), 12.93 MiB | 30.36 MiB/s, done.
# Resolving deltas: 100% (336/336), done.

# %%
# %cd /kaggle/working/GraphGPS
# !ls
# Out:
# /kaggle/working/GraphGPS
# GraphGPS.png  README.md  final-results.zip  main.py  setup.py  unittests
# LICENSE       configs	 graphgps	    run      tests

# %% [markdown]
# ##  installation for slurm if needed using conda

# %%
# # for slurm if needed using conda 
# conda create -n graphgps python=3.10
# conda activate graphgps

# conda install pytorch=1.13 torchvision torchaudio pytorch-cuda=11.7 -c pytorch -c nvidia
# conda install pyg=2.2 -c pyg -c conda-forge
# pip install pyg-lib -f https://data.pyg.org/whl/torch-1.13.0+cu117.html

# # RDKit is required for OGB-LSC PCQM4Mv2 and datasets derived from it.  
# conda install openbabel fsspec rdkit -c conda-forge

# pip install pytorch-lightning yacs torchmetrics
# pip install performer-pytorch
# pip install tensorboardX
# pip install ogb
# pip install wandb

# conda clean --all

# %% [markdown]
# # installation for kaggle

# %%
# Check existing environment
import sys
print("Python version:", sys.version)
import torch
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)

# !pip uninstall -y torch torchvision torchaudio
# !pip install torch==2.0.1+cu118 torchvision==0.15.2+cu118 torchaudio==2.0.2+cu118 --index-url https://download.pytorch.org/whl/cu118

# !pip install torch_geometric

# Optional dependencies:
# !pip install pyg_lib torch_scatter torch_sparse torch_cluster torch_spline_conv -f https://data.pyg.org/whl/torch-2.4.0+cu124.html
# Install other required packages
# !pip install pytorch-lightning yacs torchmetrics
# !pip install performer-pytorch
# !pip install tensorboardX
# !pip install ogb
# !pip install wandb

# Attempt to install RDKit (may have limitations)
# !pip install rdkit-pypi
# !pip install openbabel fsspec
# !pip install  fsspec

# Clean up pip cache (optional)
# !pip cache purge
# Out:
# Python version: 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:45:18) [GCC 12.3.0]
# PyTorch version: 2.4.0
# CUDA available: True
# CUDA version: 12.3
# Found existing installation: torch 2.4.0
# Uninstalling torch-2.4.0:
#   Successfully uninstalled torch-2.4.0
# Found existing installation: torchvision 0.19.0
# Uninstalling torchvision-0.19.0:
#   Successfully uninstalled torchvision-0.19.0
# Found existing installation: torchaudio 2.4.0
# Uninstalling torchaudio-2.4.0:
#   Successfully uninstalled torchaudio-2.4.0
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Collecting torch==2.0.1+cu118
#   Downloading https://download.pytorch.org/whl/cu118/torch-2.0.1%2Bcu118-cp310-cp310-linux_x86_64.whl (2267.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 GB ? eta 0:00:00a 0:00:0100:01
# Collecting torchvision==0.15.2+cu118
#   Downloading https://download.pytorch.org/whl/cu118/torchvision-0.15.2%2Bcu118-cp310-cp310-linux_x86_64.whl (6.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 81.6 MB/s eta 0:00:00:00:01
# Collecting torchaudio==2.0.2+cu118
#   Downloading https://download.pytorch.org/whl/cu118/torchaudio-2.0.2%2Bcu118-cp310-cp310-linux_x86_64.whl (4.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 84.9 MB/s eta 0:00:00:00:01
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch==2.0.1+cu118) (3.15.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch==2.0.1+cu118) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch==2.0.1+cu118) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch==2.0.1+cu118) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch==2.0.1+cu118) (3.1.4)
# Collecting triton==2.0.0 (from torch==2.0.1+cu118)
#   Downloading https://download.pytorch.org/whl/triton-2.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 25.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision==0.15.2+cu118) (1.26.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torchvision==0.15.2+cu118) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision==0.15.2+cu118) (10.3.0)
# Collecting cmake (from triton==2.0.0->torch==2.0.1+cu118)
#   Downloading https://download.pytorch.org/whl/cmake-3.25.0-py2.py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 58.4 MB/s eta 0:00:0000:0100:01
# Collecting lit (from triton==2.0.0->torch==2.0.1+cu118)
#   Downloading https://download.pytorch.org/whl/lit-15.0.7.tar.gz (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.3/132.3 kB 8.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch==2.0.1+cu118) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.15.2+cu118) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.15.2+cu118) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.15.2+cu118) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.15.2+cu118) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch==2.0.1+cu118) (1.3.0)
# Building wheels for collected packages: lit
#   Building wheel for lit (setup.py) ... done
#   Created wheel for lit: filename=lit-15.0.7-py3-none-any.whl size=89987 sha256=6fd948f066d56e644f87959a0e473463a19e2af19948b64e48036dde3d36d890
#   Stored in directory: /root/.cache/pip/wheels/27/2c/b6/3ed2983b1b44fe0dea1bb35234b09f2c22fb8ebb308679c922
# Successfully built lit
# Installing collected packages: lit, cmake, triton, torch, torchvision, torchaudio
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytorch-lightning 2.4.0 requires torch>=2.1.0, but you have torch 2.0.1+cu118 which is incompatible.
# Successfully installed cmake-3.25.0 lit-15.0.7 torch-2.0.1+cu118 torchaudio-2.0.2+cu118 torchvision-0.15.2+cu118 triton-2.0.0
# Collecting torch_geometric
#   Downloading torch_geometric-2.6.0-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (3.9.5)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (2024.6.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (3.1.4)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (1.26.4)
# Requirement already satisfied: psutil>=5.8.0 in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (5.9.3)
# Requirement already satisfied: pyparsing in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (3.1.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (2.32.3)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (4.66.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch_geometric) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (2024.8.30)
# Downloading torch_geometric-2.6.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 18.8 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: torch_geometric
# Successfully installed torch_geometric-2.6.0
# Looking in links: https://data.pyg.org/whl/torch-2.4.0+cu124.html
# Collecting pyg_lib
#   Downloading https://data.pyg.org/whl/torch-2.4.0%2Bcu124/pyg_lib-0.4.0%2Bpt24cu124-cp310-cp310-linux_x86_64.whl (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 21.2 MB/s eta 0:00:0000:0100:01
# Collecting torch_scatter
#   Downloading https://data.pyg.org/whl/torch-2.4.0%2Bcu124/torch_scatter-2.1.2%2Bpt24cu124-cp310-cp310-linux_x86_64.whl (10.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 95.0 MB/s eta 0:00:0000:0100:01
# Collecting torch_sparse
#   Downloading https://data.pyg.org/whl/torch-2.4.0%2Bcu124/torch_sparse-0.6.18%2Bpt24cu124-cp310-cp310-linux_x86_64.whl (5.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 91.7 MB/s eta 0:00:00:00:01
# Collecting torch_cluster
#   Downloading https://data.pyg.org/whl/torch-2.4.0%2Bcu124/torch_cluster-1.6.3%2Bpt24cu124-cp310-cp310-linux_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 82.1 MB/s eta 0:00:00:00:01
# Collecting torch_spline_conv
#   Downloading https://data.pyg.org/whl/torch-2.4.0%2Bcu124/torch_spline_conv-1.2.2%2Bpt24cu124-cp310-cp310-linux_x86_64.whl (992 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 992.4/992.4 kB 44.5 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from torch_sparse) (1.14.1)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in /opt/conda/lib/python3.10/site-packages (from scipy->torch_sparse) (1.26.4)
# Installing collected packages: torch_spline_conv, torch_scatter, pyg_lib, torch_sparse, torch_cluster
# Successfully installed pyg_lib-0.4.0+pt24cu124 torch_cluster-1.6.3+pt24cu124 torch_scatter-2.1.2+pt24cu124 torch_sparse-0.6.18+pt24cu124 torch_spline_conv-1.2.2+pt24cu124
# Requirement already satisfied: pytorch-lightning in /opt/conda/lib/python3.10/site-packages (2.4.0)
# Collecting yacs
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: torchmetrics in /opt/conda/lib/python3.10/site-packages (1.4.2)
# Collecting torch>=2.1.0 (from pytorch-lightning)
#   Downloading torch-2.4.1-cp310-cp310-manylinux1_x86_64.whl.metadata (26 kB)
# Requirement already satisfied: tqdm>=4.57.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (4.66.4)
# Requirement already satisfied: PyYAML>=5.4 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (6.0.2)
# Requirement already satisfied: fsspec>=2022.5.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (2024.6.1)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (21.3)
# Requirement already satisfied: typing-extensions>=4.4.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (4.12.2)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (0.11.7)
# Requirement already satisfied: numpy>1.20.0 in /opt/conda/lib/python3.10/site-packages (from torchmetrics) (1.26.4)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (3.9.5)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from lightning-utilities>=0.10.0->pytorch-lightning) (70.0.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->pytorch-lightning) (3.1.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=2.1.0->pytorch-lightning) (3.15.1)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=2.1.0->pytorch-lightning) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=2.1.0->pytorch-lightning) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=2.1.0->pytorch-lightning) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.0.0 (from torch>=2.1.0->pytorch-lightning)
#   Downloading triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_nvjitlink_cu12-12.6.68-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=2.1.0->pytorch-lightning) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=2.1.0->pytorch-lightning) (1.3.0)
# Requirement already satisfied: idna>=2.0 in /opt/conda/lib/python3.10/site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (3.7)
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Downloading torch-2.4.1-cp310-cp310-manylinux1_x86_64.whl (797.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.1/797.1 MB 2.4 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.5 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 12.9 MB/s eta 0:00:00:00:010:01
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 12.4 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 5.7 MB/s eta 0:00:00:00:01
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.4 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 3.5 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 31.0 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 13.8 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 8.2 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 9.2 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 5.3 MB/s eta 0:00:00
# Downloading triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (209.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 7.8 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.6.68-py3-none-manylinux2014_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 75.7 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: yacs, triton, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch
#   Attempting uninstall: triton
#     Found existing installation: triton 2.0.0
#     Uninstalling triton-2.0.0:
#       Successfully uninstalled triton-2.0.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.1+cu118
#     Uninstalling torch-2.0.1+cu118:
#       Successfully uninstalled torch-2.0.1+cu118
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.0.2+cu118 requires torch==2.0.1, but you have torch 2.4.1 which is incompatible.
# torchvision 0.15.2+cu118 requires torch==2.0.1, but you have torch 2.4.1 which is incompatible.
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.6.68 nvidia-nvtx-cu12-12.1.105 torch-2.4.1 triton-3.0.0 yacs-0.1.8
# Collecting performer-pytorch
#   Downloading performer_pytorch-1.1.4-py3-none-any.whl.metadata (763 bytes)
# Collecting einops>=0.3 (from performer-pytorch)
#   Downloading einops-0.8.0-py3-none-any.whl.metadata (12 kB)
# Collecting local-attention>=1.1.1 (from performer-pytorch)
#   Downloading local_attention-1.9.15-py3-none-any.whl.metadata (683 bytes)
# Requirement already satisfied: torch>=1.6 in /opt/conda/lib/python3.10/site-packages (from performer-pytorch) (2.4.1)
# Collecting axial-positional-embedding>=0.1.0 (from performer-pytorch)
#   Downloading axial_positional_embedding-0.2.1.tar.gz (2.6 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.6->performer-pytorch) (12.6.68)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.6->performer-pytorch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.6->performer-pytorch) (1.3.0)
# Downloading performer_pytorch-1.1.4-py3-none-any.whl (13 kB)
# Downloading einops-0.8.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 1.8 MB/s eta 0:00:00
# Downloading local_attention-1.9.15-py3-none-any.whl (9.0 kB)
# Building wheels for collected packages: axial-positional-embedding
#   Building wheel for axial-positional-embedding (setup.py) ... done
#   Created wheel for axial-positional-embedding: filename=axial_positional_embedding-0.2.1-py3-none-any.whl size=2889 sha256=cb7e924c395c251c818ac61c40455ac8ae9383181c4283bad48b16f70b34fb36
#   Stored in directory: /root/.cache/pip/wheels/b1/cb/39/7ce7ff2d2fd37cfe1fe7b3a3c43cf410632b2ad3b3f3986d73
# Successfully built axial-positional-embedding
# Installing collected packages: einops, local-attention, axial-positional-embedding, performer-pytorch
# Successfully installed axial-positional-embedding-0.2.1 einops-0.8.0 local-attention-1.9.15 performer-pytorch-1.1.4
# Requirement already satisfied: tensorboardX in /opt/conda/lib/python3.10/site-packages (2.6.2.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from tensorboardX) (1.26.4)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorboardX) (21.3)
# Requirement already satisfied: protobuf>=3.20 in /opt/conda/lib/python3.10/site-packages (from tensorboardX) (3.20.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->tensorboardX) (3.1.2)
# Collecting ogb
#   Downloading ogb-1.3.6-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: torch>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (2.4.1)
# Requirement already satisfied: numpy>=1.16.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (1.26.4)
# Requirement already satisfied: tqdm>=4.29.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (4.66.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (1.2.2)
# Requirement already satisfied: pandas>=0.24.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (2.2.2)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (1.16.0)
# Requirement already satisfied: urllib3>=1.24.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (1.26.18)
# Collecting outdated>=0.2.0 (from ogb)
#   Downloading outdated-0.2.2-py2.py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: setuptools>=44 in /opt/conda/lib/python3.10/site-packages (from outdated>=0.2.0->ogb) (70.0.0)
# Collecting littleutils (from outdated>=0.2.0->ogb)
#   Downloading littleutils-0.2.4-py3-none-any.whl.metadata (679 bytes)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from outdated>=0.2.0->ogb) (2.32.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24.0->ogb) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24.0->ogb) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24.0->ogb) (2024.1)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.20.0->ogb) (1.14.1)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.20.0->ogb) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.20.0->ogb) (3.5.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.6.0->ogb) (12.6.68)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.6.0->ogb) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->outdated>=0.2.0->ogb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->outdated>=0.2.0->ogb) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->outdated>=0.2.0->ogb) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.6.0->ogb) (1.3.0)
# Downloading ogb-1.3.6-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 1.1 MB/s eta 0:00:00-:--:--
# Downloading outdated-0.2.2-py2.py3-none-any.whl (7.5 kB)
# Downloading littleutils-0.2.4-py3-none-any.whl (8.1 kB)
# Installing collected packages: littleutils, outdated, ogb
# Successfully installed littleutils-0.2.4 ogb-1.3.6 outdated-0.2.2
# Requirement already satisfied: wandb in /opt/conda/lib/python3.10/site-packages (0.18.1)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /opt/conda/lib/python3.10/site-packages (from wandb) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.1.43)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.10/site-packages (from wandb) (3.11.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.20.3)
# Requirement already satisfied: psutil>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from wandb) (6.0.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.32.3)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.14.0)
# Requirement already satisfied: setproctitle in /opt/conda/lib/python3.10/site-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from wandb) (70.0.0)
# Requirement already satisfied: six>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2024.8.30)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.1)
# Collecting rdkit-pypi
#   Downloading rdkit_pypi-2022.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from rdkit-pypi) (1.26.4)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from rdkit-pypi) (10.3.0)
# Downloading rdkit_pypi-2022.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 60.3 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: rdkit-pypi
# Successfully installed rdkit-pypi-2022.9.5
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (2024.6.1)
# Files removed: 184

# %%
import sys
print("Python version:", sys.version)
import torch
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)
# Out:
# Python version: 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:45:18) [GCC 12.3.0]
# PyTorch version: 2.4.0
# CUDA available: True
# CUDA version: 12.3

# %%
import torch_geometric
print("PyG version:", torch_geometric.__version__)

import pytorch_lightning
print("PyTorch Lightning version:", pytorch_lightning.__version__)

import rdkit
print("RDKit version:", rdkit.__version__)
# Out:
# /opt/conda/lib/python3.10/site-packages/torch_geometric/typing.py:68: UserWarning: An issue occurred while importing 'pyg-lib'. Disabling its usage. Stacktrace: /opt/conda/lib/python3.10/site-packages/libpyg.so: undefined symbol: _ZNK5torch8autograd4Node4nameEv
#   warnings.warn(f"An issue occurred while importing 'pyg-lib'. "
# /opt/conda/lib/python3.10/site-packages/torch_geometric/typing.py:86: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: /opt/conda/lib/python3.10/site-packages/torch_scatter/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
#   warnings.warn(f"An issue occurred while importing 'torch-scatter'. "
# /opt/conda/lib/python3.10/site-packages/torch_geometric/typing.py:97: UserWarning: An issue occurred while importing 'torch-cluster'. Disabling its usage. Stacktrace: /opt/conda/lib/python3.10/site-packages/torch_cluster/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
#   warnings.warn(f"An issue occurred while importing 'torch-cluster'. "
# /opt/conda/lib/python3.10/site-packages/torch_geometric/typing.py:113: UserWarning: An issue occurred while importing 'torch-spline-conv'. Disabling its usage. Stacktrace: /opt/conda/lib/python3.10/site-packages/torch_spline_conv/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torch_geometric/typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: /opt/conda/lib/python3.10/site-packages/torch_sparse/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
#   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "
# PyG version: 2.6.0
# PyTorch Lightning version: 2.4.0
# RDKit version: 2022.09.5

# %%
print("Torch version:", torch.__version__)
# Out:
# Torch version: 2.4.0

# %% [markdown]
# # Running their model- GPSConv

# %%
# %cd /kaggle/working/GraphGPS
# !WANDB_MODE=disabled python main.py --cfg configs/GPS/ogbg-molhiv-GPS.yaml

# %% [markdown]
# # Our Model - WeightedGraphGPS

# %%
# %cd /kaggle/working
# !rm -rf WeightedGraphGPS
# Out:
# /kaggle/working

# %%
#clone for our project
# %cd /kaggle/working
# !git clone --branch cross_attention https://github.com/omertalmi5/WeightedGraphGPS.git
# Out:
# /kaggle/working
# Cloning into 'WeightedGraphGPS'...
# remote: Enumerating objects: 632, done.
# remote: Counting objects: 100% (424/424), done.
# remote: Compressing objects: 100% (141/141), done.
# remote: Total 632 (delta 336), reused 304 (delta 283), pack-reused 208 (from 1)
# Receiving objects: 100% (632/632), 12.96 MiB | 28.29 MiB/s, done.
# Resolving deltas: 100% (418/418), done.

# %%
# !pip install wandb
# Out:
# Requirement already satisfied: wandb in /opt/conda/lib/python3.10/site-packages (0.18.1)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /opt/conda/lib/python3.10/site-packages (from wandb) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.1.43)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.10/site-packages (from wandb) (3.11.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.20.3)
# Requirement already satisfied: psutil>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from wandb) (6.0.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.32.3)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.14.0)
# Requirement already satisfied: setproctitle in /opt/conda/lib/python3.10/site-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from wandb) (70.0.0)
# Requirement already satisfied: six>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2024.8.30)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.1)

# %%
# !wandb login 5f1c292fde40243d281618fe88d712346cfe90d7
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
import os
# Set the environment variable
os.environ['USERNAME'] = "omertalmi-tel-aviv-university"

# %%
# %cd /kaggle/working/WeightedGraphGPS
# !WANDB_MODE=online python main.py --cfg configs/GPS/ogbg-molhiv-GPS.yaml wandb.use True wandb.entity $USERNAME
# Out:
# /kaggle/working/WeightedGraphGPS
# [*] Run ID 0: seed=0, split_index=0
#     Starting now: 2024-09-26 07:58:43.187069
# Downloading http://snap.stanford.edu/ogb/data/graphproppred/csv_mol_download/hiv.zip
# Downloaded 0.00 GB: 100%|█████████████████████████| 3/3 [00:00<00:00,  4.38it/s]
# Extracting ./datasets/hiv.zip
# Processing...
# Loading necessary files...
# This might take a while.
# Processing graphs...
# 100%|██████████████████████████████████| 41127/41127 [00:00<00:00, 63670.39it/s]
# Converting graphs into PyG objects...
# 100%|██████████████████████████████████| 41127/41127 [00:02<00:00, 18613.56it/s]
# Saving...
# Done!
# /opt/conda/lib/python3.10/site-packages/ogb/graphproppred/dataset_pyg.py:68: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.data, self.slices = torch.load(self.processed_paths[0])
# [*] Loaded dataset 'ogbg-molhiv' from 'OGB':
# /opt/conda/lib/python3.10/site-packages/torch_geometric/data/in_memory_dataset.py:300: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
#   Data(edge_index=[2, 2259376], edge_attr=[2259376, 3], x=[1049163, 9], y=[41127, 1], num_nodes=1049163)
#   undirected: True
#   num graphs: 41127
# /opt/conda/lib/python3.10/site-packages/torch_geometric/data/in_memory_dataset.py:300: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. The data of the dataset is already cached, so any modifications to `data` will not be reflected when accessing its elements. Clearing the cache now by removing all elements in `dataset._data_list`. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
#   avg num_nodes/graph: 25
#   num node features: 9
#   num edge features: 3
#   num tasks: 1
#   num classes: 2
# Precomputing Positional Encoding statistics: ['LapPE'] for all graphs...
#   ...estimated to be undirected: True
# 100%|████████████████████████████████████| 41127/41127 [00:53<00:00, 775.73it/s]
# Done! Took 00:00:54.61
# GraphGymModule(
#   (model): GPSModel(
#     (encoder): FeatureEncoder(
#       (node_encoder): Concat2NodeEncoder(
#         (encoder1): AtomEncoder(
#           (atom_embedding_list): ModuleList(
#             (0): Embedding(119, 56)
#             (1): Embedding(5, 56)
#             (2-3): 2 x Embedding(12, 56)
#             (4): Embedding(10, 56)
#             (5-6): 2 x Embedding(6, 56)
#             (7-8): 2 x Embedding(2, 56)
#           )
#         )
#         (encoder2): LapPENodeEncoder(
#           (linear_A): Linear(in_features=2, out_features=16, bias=True)
#           (pe_encoder): Sequential(
#             (0): ReLU()
#             (1): Linear(in_features=16, out_features=8, bias=True)
#             (2): ReLU()
#           )
#         )
#       )
#       (edge_encoder): BondEncoder(
#         (bond_embedding_list): ModuleList(
#           (0): Embedding(5, 64)
#           (1): Embedding(6, 64)
#           (2): Embedding(2, 64)
#         )
#       )
#     )
#     (layers): Sequential(
#       (0): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#         (cross_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm_cross_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_cross_attn): Dropout(p=0.05, inplace=False)
#       )
#       (1): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#         (cross_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm_cross_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_cross_attn): Dropout(p=0.05, inplace=False)
#       )
#       (2): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#         (cross_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm_cross_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_cross_attn): Dropout(p=0.05, inplace=False)
#       )
#       (3): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#         (cross_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm_cross_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_cross_attn): Dropout(p=0.05, inplace=False)
#       )
#       (4): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#         (cross_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm_cross_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_cross_attn): Dropout(p=0.05, inplace=False)
#       )
#       (5): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#         (cross_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm_cross_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_cross_attn): Dropout(p=0.05, inplace=False)
#       )
#       (6): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#         (cross_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm_cross_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_cross_attn): Dropout(p=0.05, inplace=False)
#       )
#       (7): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#         (cross_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm_cross_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_cross_attn): Dropout(p=0.05, inplace=False)
#       )
#       (8): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#         (cross_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm_cross_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_cross_attn): Dropout(p=0.05, inplace=False)
#       )
#       (9): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#         (cross_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm_cross_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_cross_attn): Dropout(p=0.05, inplace=False)
#       )
#     )
#     (post_mp): SANGraphHead(
#       (FC_layers): ModuleList(
#         (0): Linear(in_features=64, out_features=32, bias=True)
#         (1): Linear(in_features=32, out_features=16, bias=True)
#         (2): Linear(in_features=16, out_features=1, bias=True)
#       )
#       (activation): ReLU()
#     )
#   )
# )
# accelerator: cuda
# benchmark: False
# bn:
#   eps: 1e-05
#   mom: 0.1
# cfg_dest: config.yaml
# custom_metrics: []
# dataset:
#   cache_load: False
#   cache_save: False
#   dir: ./datasets
#   edge_dim: 128
#   edge_encoder: True
#   edge_encoder_bn: False
#   edge_encoder_name: Bond
#   edge_encoder_num_types: 0
#   edge_message_ratio: 0.8
#   edge_negative_sampling_ratio: 1.0
#   edge_train_mode: all
#   encoder: True
#   encoder_bn: True
#   encoder_dim: 128
#   encoder_name: db
#   format: OGB
#   infer_link_label: None
#   label_column: none
#   label_table: none
#   location: local
#   name: ogbg-molhiv
#   node_encoder: True
#   node_encoder_bn: False
#   node_encoder_name: Atom+LapPE
#   node_encoder_num_types: 0
#   remove_feature: False
#   resample_disjoint: False
#   resample_negative: False
#   shuffle_split: True
#   slic_compactness: 10
#   split: [0.8, 0.1, 0.1]
#   split_dir: ./splits
#   split_index: 0
#   split_mode: standard
#   task: graph
#   task_type: classification
#   to_undirected: False
#   transductive: False
#   transform: none
#   tu_simple: True
# devices: 1
# example_arg: example
# example_group:
#   example_arg: example
# gnn:
#   act: relu
#   agg: mean
#   att_final_linear: False
#   att_final_linear_bn: False
#   att_heads: 1
#   batchnorm: True
#   clear_feature: True
#   dim_edge: 64
#   dim_inner: 64
#   dropout: 0.0
#   head: san_graph
#   keep_edge: 0.5
#   l2norm: True
#   layer_type: generalconv
#   layers_mp: 2
#   layers_post_mp: 3
#   layers_pre_mp: 0
#   msg_direction: single
#   normalize_adj: False
#   residual: False
#   self_msg: concat
#   skip_every: 1
#   stage_type: stack
# gpu_mem: False
# graphormer:
#   attention_dropout: 0.0
#   dropout: 0.0
#   embed_dim: 80
#   input_dropout: 0.0
#   mlp_dropout: 0.0
#   num_heads: 4
#   num_layers: 6
#   use_graph_token: True
# gt:
#   attn_dropout: 0.5
#   batch_norm: True
#   bigbird:
#     add_cross_attention: False
#     attention_type: block_sparse
#     block_size: 3
#     chunk_size_feed_forward: 0
#     hidden_act: relu
#     is_decoder: False
#     layer_norm_eps: 1e-06
#     max_position_embeddings: 128
#     num_random_blocks: 3
#     use_bias: False
#   dim_hidden: 64
#   dropout: 0.05
#   full_graph: True
#   gamma: 1e-05
#   layer_norm: False
#   layer_type: CustomGatedGCN+Transformer
#   layers: 10
#   n_heads: 4
#   pna_degrees: []
#   residual: True
# mem:
#   inplace: False
# metric_agg: argmax
# metric_best: auc
# model:
#   edge_decoding: dot
#   graph_pooling: mean
#   loss_fun: cross_entropy
#   match_upper: True
#   size_average: mean
#   thresh: 0.5
#   type: GPSModel
# name_tag:
# num_threads: 6
# num_workers: 0
# optim:
#   base_lr: 0.0001
#   batch_accumulation: 1
#   clip_grad_norm: True
#   clip_grad_norm_value: 1.0
#   lr_decay: 0.1
#   max_epoch: 100
#   min_lr: 0.0
#   momentum: 0.9
#   num_warmup_epochs: 5
#   optimizer: adamW
#   reduce_factor: 0.1
#   schedule_patience: 10
#   scheduler: cosine_with_warmup
#   steps: [30, 60, 90]
#   weight_decay: 1e-05
# out_dir: results/ogbg-molhiv-GPS
# posenc_ElstaticSE:
#   dim_pe: 16
#   enable: False
#   kernel:
#     times: []
#     times_func: range(10)
#   layers: 3
#   model: none
#   n_heads: 4
#   pass_as_var: False
#   post_layers: 0
#   raw_norm_type: none
# posenc_EquivStableLapPE:
#   eigen:
#     eigvec_norm: L2
#     laplacian_norm: sym
#     max_freqs: 10
#   enable: False
#   raw_norm_type: none
# posenc_GraphormerBias:
#   dim_pe: 0
#   enable: False
#   node_degrees_only: False
#   num_in_degrees: None
#   num_out_degrees: None
#   num_spatial_types: None
# posenc_HKdiagSE:
#   dim_pe: 16
#   enable: False
#   kernel:
#     times: []
#     times_func:
#   layers: 3
#   model: none
#   n_heads: 4
#   pass_as_var: False
#   post_layers: 0
#   raw_norm_type: none
# posenc_LapPE:
#   dim_pe: 8
#   eigen:
#     eigvec_norm: L2
#     laplacian_norm: none
#     max_freqs: 8
#   enable: True
#   layers: 2
#   model: DeepSet
#   n_heads: 4
#   pass_as_var: False
#   post_layers: 0
#   raw_norm_type: none
# posenc_RWSE:
#   dim_pe: 16
#   enable: False
#   kernel:
#     times: []
#     times_func:
#   layers: 3
#   model: none
#   n_heads: 4
#   pass_as_var: False
#   post_layers: 0
#   raw_norm_type: none
# posenc_SignNet:
#   dim_pe: 16
#   eigen:
#     eigvec_norm: L2
#     laplacian_norm: sym
#     max_freqs: 10
#   enable: False
#   layers: 3
#   model: none
#   n_heads: 4
#   pass_as_var: False
#   phi_hidden_dim: 64
#   phi_out_dim: 4
#   post_layers: 0
#   raw_norm_type: none
# pretrained:
#   dir:
#   freeze_main: False
#   reset_prediction_head: True
# print: both
# round: 5
# run_dir: results/ogbg-molhiv-GPS/0
# run_id: 0
# run_multiple_splits: []
# seed: 0
# share:
#   dim_in: 9
#   dim_out: 2
#   num_splits: 3
# tensorboard_agg: True
# tensorboard_each_run: False
# train:
#   auto_resume: False
#   batch_size: 32
#   ckpt_best: False
#   ckpt_clean: True
#   ckpt_period: 100
#   enable_ckpt: True
#   epoch_resume: -1
#   eval_period: 1
#   iter_per_epoch: 32
#   mode: custom
#   neighbor_sizes: [20, 15, 10, 5]
#   node_per_graph: 32
#   radius: extend
#   sample_node: False
#   sampler: full_batch
#   skip_train_eval: False
#   walk_length: 4
# val:
#   node_per_graph: 32
#   radius: extend
#   sample_node: False
#   sampler: full_batch
# view_emb: False
# wandb:
#   entity: omertalmi-tel-aviv-university
#   name:
#   project: molhiv
#   use: True
# Num parameters: 727625
# Start from epoch 0
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: omertalmi- (omertalmi-tel-aviv-university). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.1
# wandb: Run data is saved locally in /kaggle/working/WeightedGraphGPS/wandb/run-20240926_075953-naomnkmr
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run ogbg-molhiv.GPS.CustomGatedGCN+Transformer+LapPE.r0
# wandb: ⭐️ View project at https://wandb.ai/omertalmi-tel-aviv-university/molhiv
# wandb: 🚀 View run at https://wandb.ai/omertalmi-tel-aviv-university/molhiv/runs/naomnkmr
# Key posenc_GraphormerBias.num_spatial_types with value <class 'NoneType'> is not a valid type; valid types: {<class 'list'>, <class 'str'>, <class 'bool'>, <class 'tuple'>, <class 'int'>, <class 'float'>}
# Key posenc_GraphormerBias.num_in_degrees with value <class 'NoneType'> is not a valid type; valid types: {<class 'list'>, <class 'str'>, <class 'bool'>, <class 'tuple'>, <class 'int'>, <class 'float'>}
# Key posenc_GraphormerBias.num_out_degrees with value <class 'NoneType'> is not a valid type; valid types: {<class 'list'>, <class 'str'>, <class 'bool'>, <class 'tuple'>, <class 'int'>, <class 'float'>}
# train: {'epoch': 0, 'time_epoch': 123.67626, 'eta': 12243.9499, 'eta_hours': 3.4011, 'loss': 0.61891712, 'lr': 0.0, 'params': 727625, 'time_iter': 0.12019, 'accuracy': 0.96237, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.45365}
# ...computing epoch stats took: 0.12s
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 0, 'time_epoch': 7.19298, 'loss': 0.61701019, 'lr': 0, 'params': 727625, 'time_iter': 0.05576, 'accuracy': 0.98031, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.33798}
# ...computing epoch stats took: 0.02s
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# test: {'epoch': 0, 'time_epoch': 7.2245, 'loss': 0.61972089, 'lr': 0, 'params': 727625, 'time_iter': 0.056, 'accuracy': 0.96839, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.33639}
# ...computing epoch stats took: 0.01s
# > Epoch 0: took 138.3s (avg 138.3s) | Best so far: epoch 0	train_loss: 0.6189 train_auc: 0.4536	val_loss: 0.6170 val_auc: 0.3380	test_loss: 0.6197 test_auc: 0.3364
# train: {'epoch': 1, 'time_epoch': 118.22578, 'eta': 11853.20007, 'eta_hours': 3.29256, 'loss': 0.44016045, 'lr': 2e-05, 'params': 727625, 'time_iter': 0.11489, 'accuracy': 0.96252, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.56752}
# ...computing epoch stats took: 0.07s
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 1, 'time_epoch': 6.36994, 'loss': 0.24386442, 'lr': 0, 'params': 727625, 'time_iter': 0.04938, 'accuracy': 0.98031, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.70102}
# ...computing epoch stats took: 0.01s
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# test: {'epoch': 1, 'time_epoch': 6.37839, 'loss': 0.23995121, 'lr': 0, 'params': 727625, 'time_iter': 0.04944, 'accuracy': 0.96839, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.71741}
# ...computing epoch stats took: 0.01s
# > Epoch 1: took 131.1s (avg 134.7s) | Best so far: epoch 1	train_loss: 0.4402 train_auc: 0.5675	val_loss: 0.2439 val_auc: 0.7010	test_loss: 0.2400 test_auc: 0.7174
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# train: {'epoch': 2, 'time_epoch': 117.56218, 'eta': 11622.6764, 'eta_hours': 3.22852, 'loss': 0.17595448, 'lr': 4e-05, 'params': 727625, 'time_iter': 0.11425, 'accuracy': 0.96255, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.6403}
# ...computing epoch stats took: 0.05s
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 2, 'time_epoch': 6.35483, 'loss': 0.09442583, 'lr': 0, 'params': 727625, 'time_iter': 0.04926, 'accuracy': 0.98031, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.73891}
# ...computing epoch stats took: 0.01s
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# test: {'epoch': 2, 'time_epoch': 6.35905, 'loss': 0.12653178, 'lr': 0, 'params': 727625, 'time_iter': 0.04929, 'accuracy': 0.96839, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.71195}
# ...computing epoch stats took: 0.01s
# > Epoch 2: took 130.4s (avg 133.3s) | Best so far: epoch 2	train_loss: 0.1760 train_auc: 0.6403	val_loss: 0.0944 val_auc: 0.7389	test_loss: 0.1265 test_auc: 0.7119
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# train: {'epoch': 3, 'time_epoch': 117.17311, 'eta': 11439.2958, 'eta_hours': 3.17758, 'loss': 0.14159307, 'lr': 6e-05, 'params': 727625, 'time_iter': 0.11387, 'accuracy': 0.96255, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.72113}
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 3, 'time_epoch': 6.34361, 'loss': 0.081842, 'lr': 0, 'params': 727625, 'time_iter': 0.04918, 'accuracy': 0.98031, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.76523}
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# test: {'epoch': 3, 'time_epoch': 6.36484, 'loss': 0.11894517, 'lr': 0, 'params': 727625, 'time_iter': 0.04934, 'accuracy': 0.96839, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.72137}
# > Epoch 3: took 130.0s (avg 132.4s) | Best so far: epoch 3	train_loss: 0.1416 train_auc: 0.7211	val_loss: 0.0818 val_auc: 0.7652	test_loss: 0.1189 test_auc: 0.7214
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# train: {'epoch': 4, 'time_epoch': 116.92794, 'eta': 11277.73997, 'eta_hours': 3.13271, 'loss': 0.13725056, 'lr': 8e-05, 'params': 727625, 'time_iter': 0.11363, 'accuracy': 0.96255, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.73614}
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 4, 'time_epoch': 6.42221, 'loss': 0.08680194, 'lr': 0, 'params': 727625, 'time_iter': 0.04978, 'accuracy': 0.98031, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.71867}
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# test: {'epoch': 4, 'time_epoch': 6.43773, 'loss': 0.12236014, 'lr': 0, 'params': 727625, 'time_iter': 0.0499, 'accuracy': 0.96839, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.70134}
# > Epoch 4: took 129.9s (avg 131.9s) | Best so far: epoch 3	train_loss: 0.1416 train_auc: 0.7211	val_loss: 0.0818 val_auc: 0.7652	test_loss: 0.1189 test_auc: 0.7214
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# train: {'epoch': 5, 'time_epoch': 117.59091, 'eta': 11141.44676, 'eta_hours': 3.09485, 'loss': 0.13393582, 'lr': 0.0001, 'params': 727625, 'time_iter': 0.11428, 'accuracy': 0.96255, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.75572}
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 5, 'time_epoch': 6.46442, 'loss': 0.07957824, 'lr': 0, 'params': 727625, 'time_iter': 0.05011, 'accuracy': 0.98031, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.77588}
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# test: {'epoch': 5, 'time_epoch': 6.39671, 'loss': 0.11623625, 'lr': 0, 'params': 727625, 'time_iter': 0.04959, 'accuracy': 0.96839, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.74093}
# > Epoch 5: took 130.6s (avg 131.7s) | Best so far: epoch 5	train_loss: 0.1339 train_auc: 0.7557	val_loss: 0.0796 val_auc: 0.7759	test_loss: 0.1162 test_auc: 0.7409
# train: {'epoch': 6, 'time_epoch': 118.03076, 'eta': 11016.34068, 'eta_hours': 3.06009, 'loss': 0.13131583, 'lr': 9.997e-05, 'params': 727625, 'time_iter': 0.1147, 'accuracy': 0.96277, 'precision': 1.0, 'recall': 0.00568, 'f1': 0.0113, 'auc': 0.76727}
# val: {'epoch': 6, 'time_epoch': 6.4337, 'loss': 0.07967485, 'lr': 0, 'params': 727625, 'time_iter': 0.04987, 'accuracy': 0.98104, 'precision': 0.6, 'recall': 0.11111, 'f1': 0.1875, 'auc': 0.77936}
# test: {'epoch': 6, 'time_epoch': 6.38373, 'loss': 0.11744636, 'lr': 0, 'params': 727625, 'time_iter': 0.04949, 'accuracy': 0.97155, 'precision': 0.84211, 'recall': 0.12308, 'f1': 0.21477, 'auc': 0.72828}
# > Epoch 6: took 131.0s (avg 131.6s) | Best so far: epoch 6	train_loss: 0.1313 train_auc: 0.7673	val_loss: 0.0797 val_auc: 0.7794	test_loss: 0.1174 test_auc: 0.7283
# train: {'epoch': 7, 'time_epoch': 117.30036, 'eta': 10884.60383, 'eta_hours': 3.0235, 'loss': 0.12736573, 'lr': 9.989e-05, 'params': 727625, 'time_iter': 0.11399, 'accuracy': 0.9645, 'precision': 0.63559, 'recall': 0.12175, 'f1': 0.20436, 'auc': 0.79028}
# val: {'epoch': 7, 'time_epoch': 6.4093, 'loss': 0.07709967, 'lr': 0, 'params': 727625, 'time_iter': 0.04968, 'accuracy': 0.98152, 'precision': 0.61905, 'recall': 0.16049, 'f1': 0.2549, 'auc': 0.75033}
# test: {'epoch': 7, 'time_epoch': 6.4015, 'loss': 0.12354451, 'lr': 0, 'params': 727625, 'time_iter': 0.04962, 'accuracy': 0.97058, 'precision': 0.84615, 'recall': 0.08462, 'f1': 0.15385, 'auc': 0.71403}
# > Epoch 7: took 130.3s (avg 131.4s) | Best so far: epoch 6	train_loss: 0.1313 train_auc: 0.7673	val_loss: 0.0797 val_auc: 0.7794	test_loss: 0.1174 test_auc: 0.7283
# train: {'epoch': 8, 'time_epoch': 117.523, 'eta': 10758.32623, 'eta_hours': 2.98842, 'loss': 0.12570132, 'lr': 9.975e-05, 'params': 727625, 'time_iter': 0.11421, 'accuracy': 0.9648, 'precision': 0.59158, 'recall': 0.19399, 'f1': 0.29218, 'auc': 0.79124}
# val: {'epoch': 8, 'time_epoch': 6.34435, 'loss': 0.07316322, 'lr': 0, 'params': 727625, 'time_iter': 0.04918, 'accuracy': 0.98006, 'precision': 0.48649, 'recall': 0.22222, 'f1': 0.30508, 'auc': 0.81857}
# test: {'epoch': 8, 'time_epoch': 6.396, 'loss': 0.10707175, 'lr': 0, 'params': 727625, 'time_iter': 0.04958, 'accuracy': 0.9718, 'precision': 0.64583, 'recall': 0.23846, 'f1': 0.34831, 'auc': 0.7796}
# > Epoch 8: took 130.4s (avg 131.3s) | Best so far: epoch 8	train_loss: 0.1257 train_auc: 0.7912	val_loss: 0.0732 val_auc: 0.8186	test_loss: 0.1071 test_auc: 0.7796
# train: {'epoch': 9, 'time_epoch': 117.80278, 'eta': 10636.3176, 'eta_hours': 2.95453, 'loss': 0.12269337, 'lr': 9.956e-05, 'params': 727625, 'time_iter': 0.11448, 'accuracy': 0.96596, 'precision': 0.6267, 'recall': 0.22484, 'f1': 0.33094, 'auc': 0.80096}
# val: {'epoch': 9, 'time_epoch': 6.34729, 'loss': 0.07507161, 'lr': 0, 'params': 727625, 'time_iter': 0.0492, 'accuracy': 0.98079, 'precision': 0.53125, 'recall': 0.20988, 'f1': 0.30088, 'auc': 0.80402}
# test: {'epoch': 9, 'time_epoch': 6.41533, 'loss': 0.11149713, 'lr': 0, 'params': 727625, 'time_iter': 0.04973, 'accuracy': 0.97277, 'precision': 0.65, 'recall': 0.3, 'f1': 0.41053, 'auc': 0.74909}
# > Epoch 9: took 130.7s (avg 131.3s) | Best so far: epoch 8	train_loss: 0.1257 train_auc: 0.7912	val_loss: 0.0732 val_auc: 0.8186	test_loss: 0.1071 test_auc: 0.7796
# train: {'epoch': 10, 'time_epoch': 117.83937, 'eta': 10515.36973, 'eta_hours': 2.92094, 'loss': 0.12211392, 'lr': 9.932e-05, 'params': 727625, 'time_iter': 0.11452, 'accuracy': 0.96663, 'precision': 0.64629, 'recall': 0.24026, 'f1': 0.3503, 'auc': 0.79848}
# val: {'epoch': 10, 'time_epoch': 6.31115, 'loss': 0.07751124, 'lr': 0, 'params': 727625, 'time_iter': 0.04892, 'accuracy': 0.97471, 'precision': 0.36782, 'recall': 0.39506, 'f1': 0.38095, 'auc': 0.82992}
# test: {'epoch': 10, 'time_epoch': 6.29789, 'loss': 0.11521729, 'lr': 0, 'params': 727625, 'time_iter': 0.04882, 'accuracy': 0.96718, 'precision': 0.47312, 'recall': 0.33846, 'f1': 0.39462, 'auc': 0.76818}
# > Epoch 10: took 130.6s (avg 131.2s) | Best so far: epoch 10	train_loss: 0.1221 train_auc: 0.7985	val_loss: 0.0775 val_auc: 0.8299	test_loss: 0.1152 test_auc: 0.7682
# train: {'epoch': 11, 'time_epoch': 116.78495, 'eta': 10387.20752, 'eta_hours': 2.88534, 'loss': 0.11960168, 'lr': 9.902e-05, 'params': 727625, 'time_iter': 0.11349, 'accuracy': 0.96638, 'precision': 0.64126, 'recall': 0.23214, 'f1': 0.34088, 'auc': 0.81695}
# val: {'epoch': 11, 'time_epoch': 6.36816, 'loss': 0.07606692, 'lr': 0, 'params': 727625, 'time_iter': 0.04937, 'accuracy': 0.98201, 'precision': 0.57778, 'recall': 0.32099, 'f1': 0.4127, 'auc': 0.78621}
# test: {'epoch': 11, 'time_epoch': 6.44828, 'loss': 0.11205312, 'lr': 0, 'params': 727625, 'time_iter': 0.04999, 'accuracy': 0.97277, 'precision': 0.63636, 'recall': 0.32308, 'f1': 0.42857, 'auc': 0.75906}
# > Epoch 11: took 129.7s (avg 131.1s) | Best so far: epoch 10	train_loss: 0.1221 train_auc: 0.7985	val_loss: 0.0775 val_auc: 0.8299	test_loss: 0.1152 test_auc: 0.7682
# train: {'epoch': 12, 'time_epoch': 116.77061, 'eta': 10260.69966, 'eta_hours': 2.85019, 'loss': 0.11862463, 'lr': 9.867e-05, 'params': 727625, 'time_iter': 0.11348, 'accuracy': 0.96626, 'precision': 0.63034, 'recall': 0.23945, 'f1': 0.34706, 'auc': 0.82492}
# val: {'epoch': 12, 'time_epoch': 6.49675, 'loss': 0.07611774, 'lr': 0, 'params': 727625, 'time_iter': 0.05036, 'accuracy': 0.97982, 'precision': 0.475, 'recall': 0.23457, 'f1': 0.31405, 'auc': 0.82358}
# test: {'epoch': 12, 'time_epoch': 6.47723, 'loss': 0.111154, 'lr': 0, 'params': 727625, 'time_iter': 0.05021, 'accuracy': 0.9718, 'precision': 0.63462, 'recall': 0.25385, 'f1': 0.36264, 'auc': 0.76348}
# > Epoch 12: took 129.9s (avg 131.0s) | Best so far: epoch 10	train_loss: 0.1221 train_auc: 0.7985	val_loss: 0.0775 val_auc: 0.8299	test_loss: 0.1152 test_auc: 0.7682
# train: {'epoch': 13, 'time_epoch': 117.09997, 'eta': 10137.6061, 'eta_hours': 2.816, 'loss': 0.11653014, 'lr': 9.826e-05, 'params': 727625, 'time_iter': 0.1138, 'accuracy': 0.96702, 'precision': 0.65281, 'recall': 0.25487, 'f1': 0.36661, 'auc': 0.82784}
# val: {'epoch': 13, 'time_epoch': 6.39106, 'loss': 0.07701047, 'lr': 0, 'params': 727625, 'time_iter': 0.04954, 'accuracy': 0.9786, 'precision': 0.44444, 'recall': 0.34568, 'f1': 0.38889, 'auc': 0.82449}
# test: {'epoch': 13, 'time_epoch': 6.37521, 'loss': 0.11490235, 'lr': 0, 'params': 727625, 'time_iter': 0.04942, 'accuracy': 0.96815, 'precision': 0.49383, 'recall': 0.30769, 'f1': 0.37915, 'auc': 0.76925}
# > Epoch 13: took 130.0s (avg 130.9s) | Best so far: epoch 10	train_loss: 0.1221 train_auc: 0.7985	val_loss: 0.0775 val_auc: 0.8299	test_loss: 0.1152 test_auc: 0.7682
# train: {'epoch': 14, 'time_epoch': 116.92876, 'eta': 10014.34145, 'eta_hours': 2.78176, 'loss': 0.115589, 'lr': 9.78e-05, 'params': 727625, 'time_iter': 0.11363, 'accuracy': 0.96724, 'precision': 0.65339, 'recall': 0.26623, 'f1': 0.37832, 'auc': 0.83453}
# val: {'epoch': 14, 'time_epoch': 6.32474, 'loss': 0.06887324, 'lr': 0, 'params': 727625, 'time_iter': 0.04903, 'accuracy': 0.98177, 'precision': 0.57895, 'recall': 0.2716, 'f1': 0.36975, 'auc': 0.83429}
# test: {'epoch': 14, 'time_epoch': 6.34865, 'loss': 0.11416387, 'lr': 0, 'params': 727625, 'time_iter': 0.04921, 'accuracy': 0.97155, 'precision': 0.60656, 'recall': 0.28462, 'f1': 0.38743, 'auc': 0.76906}
# > Epoch 14: took 129.7s (avg 130.8s) | Best so far: epoch 14	train_loss: 0.1156 train_auc: 0.8345	val_loss: 0.0689 val_auc: 0.8343	test_loss: 0.1142 test_auc: 0.7691
# train: {'epoch': 15, 'time_epoch': 117.27647, 'eta': 9893.69427, 'eta_hours': 2.74825, 'loss': 0.11321697, 'lr': 9.729e-05, 'params': 727625, 'time_iter': 0.11397, 'accuracy': 0.96836, 'precision': 0.6785, 'recall': 0.29464, 'f1': 0.41087, 'auc': 0.83835}
# val: {'epoch': 15, 'time_epoch': 6.31625, 'loss': 0.07063941, 'lr': 0, 'params': 727625, 'time_iter': 0.04896, 'accuracy': 0.98055, 'precision': 0.51515, 'recall': 0.20988, 'f1': 0.29825, 'auc': 0.81436}
# test: {'epoch': 15, 'time_epoch': 6.31968, 'loss': 0.10954828, 'lr': 0, 'params': 727625, 'time_iter': 0.04899, 'accuracy': 0.97204, 'precision': 0.65957, 'recall': 0.23846, 'f1': 0.35028, 'auc': 0.78693}
# > Epoch 15: took 130.0s (avg 130.8s) | Best so far: epoch 14	train_loss: 0.1156 train_auc: 0.8345	val_loss: 0.0689 val_auc: 0.8343	test_loss: 0.1142 test_auc: 0.7691
# train: {'epoch': 16, 'time_epoch': 117.14032, 'eta': 9772.77894, 'eta_hours': 2.71466, 'loss': 0.11205608, 'lr': 9.673e-05, 'params': 727625, 'time_iter': 0.11384, 'accuracy': 0.96879, 'precision': 0.69159, 'recall': 0.30032, 'f1': 0.41879, 'auc': 0.84515}
# val: {'epoch': 16, 'time_epoch': 6.32043, 'loss': 0.07741379, 'lr': 0, 'params': 727625, 'time_iter': 0.049, 'accuracy': 0.97958, 'precision': 0.46939, 'recall': 0.28395, 'f1': 0.35385, 'auc': 0.82549}
# test: {'epoch': 16, 'time_epoch': 6.35251, 'loss': 0.11014521, 'lr': 0, 'params': 727625, 'time_iter': 0.04924, 'accuracy': 0.97009, 'precision': 0.5493, 'recall': 0.3, 'f1': 0.38806, 'auc': 0.78715}
# > Epoch 16: took 129.9s (avg 130.7s) | Best so far: epoch 14	train_loss: 0.1156 train_auc: 0.8345	val_loss: 0.0689 val_auc: 0.8343	test_loss: 0.1142 test_auc: 0.7691
# train: {'epoch': 17, 'time_epoch': 116.93126, 'eta': 9651.33066, 'eta_hours': 2.68093, 'loss': 0.11067599, 'lr': 9.611e-05, 'params': 727625, 'time_iter': 0.11364, 'accuracy': 0.96863, 'precision': 0.67794, 'recall': 0.30925, 'f1': 0.42475, 'auc': 0.84782}
# val: {'epoch': 17, 'time_epoch': 6.39429, 'loss': 0.06937196, 'lr': 0, 'params': 727625, 'time_iter': 0.04957, 'accuracy': 0.98128, 'precision': 0.56667, 'recall': 0.20988, 'f1': 0.30631, 'auc': 0.81647}
# test: {'epoch': 17, 'time_epoch': 6.45891, 'loss': 0.11082191, 'lr': 0, 'params': 727625, 'time_iter': 0.05007, 'accuracy': 0.97131, 'precision': 0.65, 'recall': 0.2, 'f1': 0.30588, 'auc': 0.77014}
# > Epoch 17: took 129.9s (avg 130.7s) | Best so far: epoch 14	train_loss: 0.1156 train_auc: 0.8345	val_loss: 0.0689 val_auc: 0.8343	test_loss: 0.1142 test_auc: 0.7691
# train: {'epoch': 18, 'time_epoch': 116.81243, 'eta': 9529.85124, 'eta_hours': 2.64718, 'loss': 0.10851725, 'lr': 9.545e-05, 'params': 727625, 'time_iter': 0.11352, 'accuracy': 0.96906, 'precision': 0.67953, 'recall': 0.32873, 'f1': 0.44311, 'auc': 0.85684}
# val: {'epoch': 18, 'time_epoch': 6.30913, 'loss': 0.0698535, 'lr': 0, 'params': 727625, 'time_iter': 0.04891, 'accuracy': 0.98249, 'precision': 0.62162, 'recall': 0.28395, 'f1': 0.38983, 'auc': 0.82272}
# test: {'epoch': 18, 'time_epoch': 6.39623, 'loss': 0.1166067, 'lr': 0, 'params': 727625, 'time_iter': 0.04958, 'accuracy': 0.97107, 'precision': 0.60784, 'recall': 0.23846, 'f1': 0.34254, 'auc': 0.77057}
# > Epoch 18: took 129.6s (avg 130.6s) | Best so far: epoch 14	train_loss: 0.1156 train_auc: 0.8345	val_loss: 0.0689 val_auc: 0.8343	test_loss: 0.1142 test_auc: 0.7691
# train: {'epoch': 19, 'time_epoch': 117.30555, 'eta': 9410.81104, 'eta_hours': 2.61411, 'loss': 0.10749144, 'lr': 9.474e-05, 'params': 727625, 'time_iter': 0.114, 'accuracy': 0.96988, 'precision': 0.69983, 'recall': 0.34253, 'f1': 0.45995, 'auc': 0.86008}
# val: {'epoch': 19, 'time_epoch': 6.35789, 'loss': 0.06860614, 'lr': 0, 'params': 727625, 'time_iter': 0.04929, 'accuracy': 0.98201, 'precision': 0.57143, 'recall': 0.34568, 'f1': 0.43077, 'auc': 0.83284}
# test: {'epoch': 19, 'time_epoch': 6.40376, 'loss': 0.11196615, 'lr': 0, 'params': 727625, 'time_iter': 0.04964, 'accuracy': 0.96912, 'precision': 0.51724, 'recall': 0.34615, 'f1': 0.41475, 'auc': 0.80113}
# > Epoch 19: took 130.2s (avg 130.6s) | Best so far: epoch 14	train_loss: 0.1156 train_auc: 0.8345	val_loss: 0.0689 val_auc: 0.8343	test_loss: 0.1142 test_auc: 0.7691
# train: {'epoch': 20, 'time_epoch': 116.07528, 'eta': 9287.30784, 'eta_hours': 2.57981, 'loss': 0.10716706, 'lr': 9.397e-05, 'params': 727625, 'time_iter': 0.1128, 'accuracy': 0.96991, 'precision': 0.69836, 'recall': 0.34578, 'f1': 0.46254, 'auc': 0.85901}
# val: {'epoch': 20, 'time_epoch': 6.34888, 'loss': 0.06778855, 'lr': 0, 'params': 727625, 'time_iter': 0.04922, 'accuracy': 0.98177, 'precision': 0.57143, 'recall': 0.2963, 'f1': 0.39024, 'auc': 0.85029}
# test: {'epoch': 20, 'time_epoch': 6.35142, 'loss': 0.11518041, 'lr': 0, 'params': 727625, 'time_iter': 0.04924, 'accuracy': 0.96912, 'precision': 0.52542, 'recall': 0.23846, 'f1': 0.32804, 'auc': 0.78313}
# > Epoch 20: took 128.9s (avg 130.5s) | Best so far: epoch 20	train_loss: 0.1072 train_auc: 0.8590	val_loss: 0.0678 val_auc: 0.8503	test_loss: 0.1152 test_auc: 0.7831
# train: {'epoch': 21, 'time_epoch': 116.18266, 'eta': 9164.86063, 'eta_hours': 2.54579, 'loss': 0.10471847, 'lr': 9.316e-05, 'params': 727625, 'time_iter': 0.11291, 'accuracy': 0.97116, 'precision': 0.73862, 'recall': 0.35552, 'f1': 0.48, 'auc': 0.86483}
# val: {'epoch': 21, 'time_epoch': 6.3466, 'loss': 0.06866973, 'lr': 0, 'params': 727625, 'time_iter': 0.0492, 'accuracy': 0.98274, 'precision': 0.61905, 'recall': 0.32099, 'f1': 0.42276, 'auc': 0.83775}
# test: {'epoch': 21, 'time_epoch': 6.2842, 'loss': 0.11558178, 'lr': 0, 'params': 727625, 'time_iter': 0.04871, 'accuracy': 0.97009, 'precision': 0.55556, 'recall': 0.26923, 'f1': 0.36269, 'auc': 0.77616}
# > Epoch 21: took 128.9s (avg 130.5s) | Best so far: epoch 20	train_loss: 0.1072 train_auc: 0.8590	val_loss: 0.0678 val_auc: 0.8503	test_loss: 0.1152 test_auc: 0.7831
# train: {'epoch': 22, 'time_epoch': 115.67851, 'eta': 9041.27036, 'eta_hours': 2.51146, 'loss': 0.10373007, 'lr': 9.23e-05, 'params': 727625, 'time_iter': 0.11242, 'accuracy': 0.97049, 'precision': 0.7088, 'recall': 0.35958, 'f1': 0.47711, 'auc': 0.87467}
# val: {'epoch': 22, 'time_epoch': 6.42818, 'loss': 0.06636317, 'lr': 0, 'params': 727625, 'time_iter': 0.04983, 'accuracy': 0.98274, 'precision': 0.61364, 'recall': 0.33333, 'f1': 0.432, 'auc': 0.83977}
# test: {'epoch': 22, 'time_epoch': 6.27643, 'loss': 0.11210662, 'lr': 0, 'params': 727625, 'time_iter': 0.04865, 'accuracy': 0.97034, 'precision': 0.55405, 'recall': 0.31538, 'f1': 0.40196, 'auc': 0.78955}
# > Epoch 22: took 128.5s (avg 130.4s) | Best so far: epoch 20	train_loss: 0.1072 train_auc: 0.8590	val_loss: 0.0678 val_auc: 0.8503	test_loss: 0.1152 test_auc: 0.7831
# ...
# train: {'epoch': 74, 'time_epoch': 113.8826, 'eta': 2898.9678, 'eta_hours': 0.80527, 'loss': 0.06865418, 'lr': 1.737e-05, 'params': 727625, 'time_iter': 0.11067, 'accuracy': 0.97842, 'precision': 0.81907, 'recall': 0.54383, 'f1': 0.65366, 'auc': 0.96758}
# val: {'epoch': 74, 'time_epoch': 6.31168, 'loss': 0.08792205, 'lr': 0, 'params': 727625, 'time_iter': 0.04893, 'accuracy': 0.97715, 'precision': 0.41558, 'recall': 0.39506, 'f1': 0.40506, 'auc': 0.82272}
# test: {'epoch': 74, 'time_epoch': 6.26743, 'loss': 0.15994583, 'lr': 0, 'params': 727625, 'time_iter': 0.04858, 'accuracy': 0.96329, 'precision': 0.36709, 'recall': 0.22308, 'f1': 0.27751, 'auc': 0.77317}
# > Epoch 74: took 126.6s (avg 128.8s) | Best so far: epoch 20	train_loss: 0.1072 train_auc: 0.8590	val_loss: 0.0678 val_auc: 0.8503	test_loss: 0.1152 test_auc: 0.7831
# train: {'epoch': 75, 'time_epoch': 113.92803, 'eta': 2782.36782, 'eta_hours': 0.77288, 'loss': 0.06655187, 'lr': 1.614e-05, 'params': 727625, 'time_iter': 0.11072, 'accuracy': 0.97875, 'precision': 0.8184, 'recall': 0.55601, 'f1': 0.66216, 'auc': 0.97135}
# val: {'epoch': 75, 'time_epoch': 6.29811, 'loss': 0.0862057, 'lr': 0, 'params': 727625, 'time_iter': 0.04882, 'accuracy': 0.98031, 'precision': 0.5, 'recall': 0.40741, 'f1': 0.44898, 'auc': 0.82058}
# test: {'epoch': 75, 'time_epoch': 6.22736, 'loss': 0.16430515, 'lr': 0, 'params': 727625, 'time_iter': 0.04827, 'accuracy': 0.96523, 'precision': 0.40299, 'recall': 0.20769, 'f1': 0.27411, 'auc': 0.77039}
# > Epoch 75: took 126.6s (avg 128.7s) | Best so far: epoch 20	train_loss: 0.1072 train_auc: 0.8590	val_loss: 0.0678 val_auc: 0.8503	test_loss: 0.1152 test_auc: 0.7831
# train: {'epoch': 76, 'time_epoch': 114.20885, 'eta': 2665.92112, 'eta_hours': 0.74053, 'loss': 0.06816067, 'lr': 1.494e-05, 'params': 727625, 'time_iter': 0.11099, 'accuracy': 0.97848, 'precision': 0.81643, 'recall': 0.5487, 'f1': 0.65631, 'auc': 0.96873}
# val: {'epoch': 76, 'time_epoch': 6.24299, 'loss': 0.0870695, 'lr': 0, 'params': 727625, 'time_iter': 0.0484, 'accuracy': 0.97982, 'precision': 0.48649, 'recall': 0.44444, 'f1': 0.46452, 'auc': 0.82311}
# test: {'epoch': 76, 'time_epoch': 6.26397, 'loss': 0.16657828, 'lr': 0, 'params': 727625, 'time_iter': 0.04856, 'accuracy': 0.96402, 'precision': 0.39286, 'recall': 0.25385, 'f1': 0.30841, 'auc': 0.77603}
# > Epoch 76: took 126.8s (avg 128.7s) | Best so far: epoch 20	train_loss: 0.1072 train_auc: 0.8590	val_loss: 0.0678 val_auc: 0.8503	test_loss: 0.1152 test_auc: 0.7831
# train: {'epoch': 77, 'time_epoch': 114.55186, 'eta': 2549.62855, 'eta_hours': 0.70823, 'loss': 0.06620633, 'lr': 1.378e-05, 'params': 727625, 'time_iter': 0.11132, 'accuracy': 0.97836, 'precision': 0.80588, 'recall': 0.55601, 'f1': 0.65802, 'auc': 0.9711}
# val: {'epoch': 77, 'time_epoch': 6.24897, 'loss': 0.09016301, 'lr': 0, 'params': 727625, 'time_iter': 0.04844, 'accuracy': 0.97812, 'precision': 0.43662, 'recall': 0.38272, 'f1': 0.40789, 'auc': 0.81571}
# test: {'epoch': 77, 'time_epoch': 6.29778, 'loss': 0.16576656, 'lr': 0, 'params': 727625, 'time_iter': 0.04882, 'accuracy': 0.96402, 'precision': 0.39024, 'recall': 0.24615, 'f1': 0.30189, 'auc': 0.77183}
# > Epoch 77: took 127.2s (avg 128.7s) | Best so far: epoch 20	train_loss: 0.1072 train_auc: 0.8590	val_loss: 0.0678 val_auc: 0.8503	test_loss: 0.1152 test_auc: 0.7831
# train: {'epoch': 78, 'time_epoch': 117.2514, 'eta': 2434.09765, 'eta_hours': 0.67614, 'loss': 0.06659915, 'lr': 1.266e-05, 'params': 727625, 'time_iter': 0.11395, 'accuracy': 0.9786, 'precision': 0.80841, 'recall': 0.56169, 'f1': 0.66284, 'auc': 0.97099}
# val: {'epoch': 78, 'time_epoch': 6.38678, 'loss': 0.09085885, 'lr': 0, 'params': 727625, 'time_iter': 0.04951, 'accuracy': 0.97739, 'precision': 0.41892, 'recall': 0.38272, 'f1': 0.4, 'auc': 0.81732}
# test: {'epoch': 78, 'time_epoch': 6.37254, 'loss': 0.16503765, 'lr': 0, 'params': 727625, 'time_iter': 0.0494, 'accuracy': 0.96548, 'precision': 0.43023, 'recall': 0.28462, 'f1': 0.34259, 'auc': 0.77144}
# > Epoch 78: took 130.1s (avg 128.7s) | Best so far: epoch 20	train_loss: 0.1072 train_auc: 0.8590	val_loss: 0.0678 val_auc: 0.8503	test_loss: 0.1152 test_auc: 0.7831
# train: {'epoch': 79, 'time_epoch': 118.11933, 'eta': 2318.74072, 'eta_hours': 0.64409, 'loss': 0.06568591, 'lr': 1.158e-05, 'params': 727625, 'time_iter': 0.11479, 'accuracy': 0.97936, 'precision': 0.82491, 'recall': 0.56981, 'f1': 0.67403, 'auc': 0.9699}
# val: {'epoch': 79, 'time_epoch': 6.43057, 'loss': 0.08778933, 'lr': 0, 'params': 727625, 'time_iter': 0.04985, 'accuracy': 0.97958, 'precision': 0.47761, 'recall': 0.39506, 'f1': 0.43243, 'auc': 0.8161}
# test: {'epoch': 79, 'time_epoch': 6.36431, 'loss': 0.16304152, 'lr': 0, 'params': 727625, 'time_iter': 0.04934, 'accuracy': 0.96596, 'precision': 0.42857, 'recall': 0.23077, 'f1': 0.3, 'auc': 0.77098}
# > Epoch 79: took 131.1s (avg 128.8s) | Best so far: epoch 20	train_loss: 0.1072 train_auc: 0.8590	val_loss: 0.0678 val_auc: 0.8503	test_loss: 0.1152 test_auc: 0.7831
# train: {'epoch': 80, 'time_epoch': 118.61883, 'eta': 2203.43275, 'eta_hours': 0.61206, 'loss': 0.06613095, 'lr': 1.054e-05, 'params': 727625, 'time_iter': 0.11528, 'accuracy': 0.97924, 'precision': 0.82256, 'recall': 0.56818, 'f1': 0.67211, 'auc': 0.96913}
# val: {'epoch': 80, 'time_epoch': 6.63555, 'loss': 0.09280568, 'lr': 0, 'params': 727625, 'time_iter': 0.05144, 'accuracy': 0.97763, 'precision': 0.4321, 'recall': 0.4321, 'f1': 0.4321, 'auc': 0.81393}
# test: {'epoch': 80, 'time_epoch': 6.70365, 'loss': 0.16348127, 'lr': 0, 'params': 727625, 'time_iter': 0.05197, 'accuracy': 0.96548, 'precision': 0.43182, 'recall': 0.29231, 'f1': 0.34862, 'auc': 0.7727}
# > Epoch 80: took 132.1s (avg 128.8s) | Best so far: epoch 20	train_loss: 0.1072 train_auc: 0.8590	val_loss: 0.0678 val_auc: 0.8503	test_loss: 0.1152 test_auc: 0.7831
# train: {'epoch': 81, 'time_epoch': 125.35523, 'eta': 2089.52274, 'eta_hours': 0.58042, 'loss': 0.06548047, 'lr': 9.55e-06, 'params': 727625, 'time_iter': 0.12182, 'accuracy': 0.97915, 'precision': 0.82193, 'recall': 0.56575, 'f1': 0.67019, 'auc': 0.97169}
# val: {'epoch': 81, 'time_epoch': 6.52237, 'loss': 0.09025392, 'lr': 0, 'params': 727625, 'time_iter': 0.05056, 'accuracy': 0.9769, 'precision': 0.41026, 'recall': 0.39506, 'f1': 0.40252, 'auc': 0.82767}
# test: {'epoch': 81, 'time_epoch': 6.4981, 'loss': 0.16877012, 'lr': 0, 'params': 727625, 'time_iter': 0.05037, 'accuracy': 0.96499, 'precision': 0.4186, 'recall': 0.27692, 'f1': 0.33333, 'auc': 0.77492}
# > Epoch 81: took 138.5s (avg 128.9s) | Best so far: epoch 20	train_loss: 0.1072 train_auc: 0.8590	val_loss: 0.0678 val_auc: 0.8503	test_loss: 0.1152 test_auc: 0.7831
# train: {'epoch': 82, 'time_epoch': 123.24298, 'eta': 1974.90432, 'eta_hours': 0.54858, 'loss': 0.0630272, 'lr': 8.6e-06, 'params': 727625, 'time_iter': 0.11977, 'accuracy': 0.97985, 'precision': 0.8244, 'recall': 0.58685, 'f1': 0.68563, 'auc': 0.97361}
# val: {'epoch': 82, 'time_epoch': 6.68183, 'loss': 0.09588046, 'lr': 0, 'params': 727625, 'time_iter': 0.0518, 'accuracy': 0.9752, 'precision': 0.39806, 'recall': 0.50617, 'f1': 0.44565, 'auc': 0.82792}
# test: {'epoch': 82, 'time_epoch': 6.60778, 'loss': 0.17421704, 'lr': 0, 'params': 727625, 'time_iter': 0.05122, 'accuracy': 0.95988, 'precision': 0.33945, 'recall': 0.28462, 'f1': 0.30962, 'auc': 0.78273}
# > Epoch 82: took 136.7s (avg 129.0s) | Best so far: epoch 20	train_loss: 0.1072 train_auc: 0.8590	val_loss: 0.0678 val_auc: 0.8503	test_loss: 0.1152 test_auc: 0.7831
# train: {'epoch': 83, 'time_epoch': 122.20728, 'eta': 1859.88327, 'eta_hours': 0.51663, 'loss': 0.06501501, 'lr': 7.7e-06, 'params': 727625, 'time_iter': 0.11876, 'accuracy': 0.97915, 'precision': 0.81236, 'recall': 0.5763, 'f1': 0.67426, 'auc': 0.97255}
# val: {'epoch': 83, 'time_epoch': 6.46339, 'loss': 0.08998504, 'lr': 0, 'params': 727625, 'time_iter': 0.0501, 'accuracy': 0.97885, 'precision': 0.45588, 'recall': 0.38272, 'f1': 0.41611, 'auc': 0.82339}
# test: {'epoch': 83, 'time_epoch': 6.46279, 'loss': 0.169533, 'lr': 0, 'params': 727625, 'time_iter': 0.0501, 'accuracy': 0.96669, 'precision': 0.44928, 'recall': 0.23846, 'f1': 0.31156, 'auc': 0.78385}
# > Epoch 83: took 135.3s (avg 129.1s) | Best so far: epoch 20	train_loss: 0.1072 train_auc: 0.8590	val_loss: 0.0678 val_auc: 0.8503	test_loss: 0.1152 test_auc: 0.7831
# train: {'epoch': 84, 'time_epoch': 122.14877, 'eta': 1744.68282, 'eta_hours': 0.48463, 'loss': 0.06379689, 'lr': 6.84e-06, 'params': 727625, 'time_iter': 0.11871, 'accuracy': 0.97948, 'precision': 0.82497, 'recall': 0.57386, 'f1': 0.67688, 'auc': 0.97345}
# val: {'epoch': 84, 'time_epoch': 6.46921, 'loss': 0.09242123, 'lr': 0, 'params': 727625, 'time_iter': 0.05015, 'accuracy': 0.97666, 'precision': 0.41935, 'recall': 0.48148, 'f1': 0.44828, 'auc': 0.82577}
# test: {'epoch': 84, 'time_epoch': 6.53051, 'loss': 0.16619386, 'lr': 0, 'params': 727625, 'time_iter': 0.05062, 'accuracy': 0.96353, 'precision': 0.4, 'recall': 0.30769, 'f1': 0.34783, 'auc': 0.78166}
# > Epoch 84: took 135.3s (avg 129.2s) | Best so far: epoch 20	train_loss: 0.1072 train_auc: 0.8590	val_loss: 0.0678 val_auc: 0.8503	test_loss: 0.1152 test_auc: 0.7831
# train: {'epoch': 85, 'time_epoch': 121.43083, 'eta': 1629.2039, 'eta_hours': 0.45256, 'loss': 0.0637385, 'lr': 6.03e-06, 'params': 727625, 'time_iter': 0.11801, 'accuracy': 0.97927, 'precision': 0.80488, 'recall': 0.58929, 'f1': 0.68041, 'auc': 0.97378}
# val: {'epoch': 85, 'time_epoch': 6.47709, 'loss': 0.08700011, 'lr': 0, 'params': 727625, 'time_iter': 0.05021, 'accuracy': 0.97763, 'precision': 0.42466, 'recall': 0.38272, 'f1': 0.4026, 'auc': 0.82595}
# test: {'epoch': 85, 'time_epoch': 6.50827, 'loss': 0.16177058, 'lr': 0, 'params': 727625, 'time_iter': 0.05045, 'accuracy': 0.96475, 'precision': 0.40964, 'recall': 0.26154, 'f1': 0.31925, 'auc': 0.77923}
# > Epoch 85: took 134.6s (avg 129.2s) | Best so far: epoch 20	train_loss: 0.1072 train_auc: 0.8590	val_loss: 0.0678 val_auc: 0.8503	test_loss: 0.1152 test_auc: 0.7831
# train: {'epoch': 86, 'time_epoch': 121.79501, 'eta': 1513.64257, 'eta_hours': 0.42046, 'loss': 0.06516218, 'lr': 5.26e-06, 'params': 727625, 'time_iter': 0.11836, 'accuracy': 0.979, 'precision': 0.82012, 'recall': 0.5625, 'f1': 0.66731, 'auc': 0.97192}
# val: {'epoch': 86, 'time_epoch': 6.64129, 'loss': 0.09378391, 'lr': 0, 'params': 727625, 'time_iter': 0.05148, 'accuracy': 0.97496, 'precision': 0.38298, 'recall': 0.44444, 'f1': 0.41143, 'auc': 0.8182}
# test: {'epoch': 86, 'time_epoch': 6.48487, 'loss': 0.16307949, 'lr': 0, 'params': 727625, 'time_iter': 0.05027, 'accuracy': 0.96377, 'precision': 0.4, 'recall': 0.29231, 'f1': 0.33778, 'auc': 0.77207}
# > Epoch 86: took 135.1s (avg 129.3s) | Best so far: epoch 20	train_loss: 0.1072 train_auc: 0.8590	val_loss: 0.0678 val_auc: 0.8503	test_loss: 0.1152 test_auc: 0.7831
# train: {'epoch': 87, 'time_epoch': 123.11159, 'eta': 1398.1191, 'eta_hours': 0.38837, 'loss': 0.06218147, 'lr': 4.55e-06, 'params': 727625, 'time_iter': 0.11964, 'accuracy': 0.97958, 'precision': 0.81891, 'recall': 0.5836, 'f1': 0.68152, 'auc': 0.97523}
# val: {'epoch': 87, 'time_epoch': 6.66752, 'loss': 0.09367278, 'lr': 0, 'params': 727625, 'time_iter': 0.05169, 'accuracy': 0.97666, 'precision': 0.40964, 'recall': 0.41975, 'f1': 0.41463, 'auc': 0.82213}
# test: {'epoch': 87, 'time_epoch': 6.42097, 'loss': 0.17380236, 'lr': 0, 'params': 727625, 'time_iter': 0.04977, 'accuracy': 0.9628, 'precision': 0.37363, 'recall': 0.26154, 'f1': 0.30769, 'auc': 0.77802}
# > Epoch 87: took 136.3s (avg 129.4s) | Best so far: epoch 20	train_loss: 0.1072 train_auc: 0.8590	val_loss: 0.0678 val_auc: 0.8503	test_loss: 0.1152 test_auc: 0.7831
# train: {'epoch': 88, 'time_epoch': 122.62107, 'eta': 1282.36448, 'eta_hours': 0.35621, 'loss': 0.06301578, 'lr': 3.89e-06, 'params': 727625, 'time_iter': 0.11917, 'accuracy': 0.97939, 'precision': 0.81839, 'recall': 0.57792, 'f1': 0.67745, 'auc': 0.97584}
# val: {'epoch': 88, 'time_epoch': 6.566, 'loss': 0.0896448, 'lr': 0, 'params': 727625, 'time_iter': 0.0509, 'accuracy': 0.9786, 'precision': 0.4507, 'recall': 0.39506, 'f1': 0.42105, 'auc': 0.82181}
# test: {'epoch': 88, 'time_epoch': 6.60866, 'loss': 0.16929227, 'lr': 0, 'params': 727625, 'time_iter': 0.05123, 'accuracy': 0.96523, 'precision': 0.41975, 'recall': 0.26154, 'f1': 0.32227, 'auc': 0.78101}
# > Epoch 88: took 135.9s (avg 129.4s) | Best so far: epoch 20	train_loss: 0.1072 train_auc: 0.8590	val_loss: 0.0678 val_auc: 0.8503	test_loss: 0.1152 test_auc: 0.7831
# train: {'epoch': 89, 'time_epoch': 123.09937, 'eta': 1166.51042, 'eta_hours': 0.32403, 'loss': 0.06420312, 'lr': 3.27e-06, 'params': 727625, 'time_iter': 0.11963, 'accuracy': 0.97964, 'precision': 0.82523, 'recall': 0.57873, 'f1': 0.68034, 'auc': 0.97331}
# val: {'epoch': 89, 'time_epoch': 7.00365, 'loss': 0.09188759, 'lr': 0, 'params': 727625, 'time_iter': 0.05429, 'accuracy': 0.97885, 'precision': 0.46154, 'recall': 0.44444, 'f1': 0.45283, 'auc': 0.82348}
# test: {'epoch': 89, 'time_epoch': 6.64361, 'loss': 0.17362854, 'lr': 0, 'params': 727625, 'time_iter': 0.0515, 'accuracy': 0.96426, 'precision': 0.4023, 'recall': 0.26923, 'f1': 0.32258, 'auc': 0.7818}
# > Epoch 89: took 136.9s (avg 129.5s) | Best so far: epoch 20	train_loss: 0.1072 train_auc: 0.8590	val_loss: 0.0678 val_auc: 0.8503	test_loss: 0.1152 test_auc: 0.7831
# ^C
# Traceback (most recent call last):
#   File "/kaggle/working/WeightedGraphGPS/main.py", line 166, in <module>
#     train_dict[cfg.train.mode](loggers, loaders, model, optimizer,
#   File "/kaggle/working/WeightedGraphGPS/graphgps/train/custom_train.py", line 121, in custom_train
#     train_epoch(loggers[0], loaders[0], model, optimizer, scheduler,
#   File "/kaggle/working/WeightedGraphGPS/graphgps/train/custom_train.py", line 23, in train_epoch
#     pred, true = model(batch)
#   File "/opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/torch_geometric/graphgym/model_builder.py", line 24, in forward
#     return self.model(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/kaggle/working/WeightedGraphGPS/graphgps/network/gps_model.py", line 107, in forward
#     batch = module(batch)
#   File "/opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/torch/nn/modules/container.py", line 219, in forward
#     input = module(input)
#   File "/opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1553, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1562, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/kaggle/working/WeightedGraphGPS/graphgps/layer/gps_layer.py", line 231, in forward
#     h_local_dense, mask = to_dense_batch(h_local, batch.batch)
#   File "/opt/conda/lib/python3.10/site-packages/torch_geometric/experimental.py", line 117, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/conda/lib/python3.10/site-packages/torch_geometric/utils/_to_dense_batch.py", line 111, in to_dense_batch
#     dynamic_shapes_disabled = is_experimental_mode_enabled(
#   File "/opt/conda/lib/python3.10/site-packages/torch_geometric/experimental.py", line 34, in is_experimental_mode_enabled
#     return all([__experimental_flag__[option] for option in options])
# KeyboardInterrupt

# %%
# !zip /kaggle/working/results_cross_attention.zip /kaggle/working/WeightedGraphGPS
# Out:
#   adding: kaggle/working/WeightedGraphGPS/ (stored 0%)
