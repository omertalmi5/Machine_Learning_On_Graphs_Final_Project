# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/torch_scatter-2.1.2-cp310-cp310-linux_x86_64.whl
# /kaggle/input/torch_geometric-2.5.3-py3-none-any.whl
# /kaggle/input/torch_cluster-1.6.3-cp310-cp310-linux_x86_64.whl
# /kaggle/input/torch_spline_conv-1.2.2-cp310-cp310-linux_x86_64.whl
# /kaggle/input/torch_sparse-0.6.18-cp310-cp310-linux_x86_64.whl

# %%
# !git clone https://github.com/rampasek/GraphGPS.git
# Out:
# Cloning into 'GraphGPS'...
# remote: Enumerating objects: 526, done.
# remote: Counting objects: 100% (350/350), done.
# remote: Compressing objects: 100% (109/109), done.
# remote: Total 526 (delta 271), reused 241 (delta 241), pack-reused 176 (from 1)
# Receiving objects: 100% (526/526), 12.93 MiB | 38.48 MiB/s, done.
# Resolving deltas: 100% (337/337), done.

# %%
# %cd /kaggle/working/GraphGPS
# !ls
# Out:
# /kaggle/working/GraphGPS
#
# GraphGPS.png  README.md  final-results.zip  main.py  setup.py  unittests
#
# LICENSE       configs	 graphgps	    run      tests

# %% [markdown]
# ##  installation for slurm if needed using conda

# %%
# # for slurm if needed using conda 
# conda create -n graphgps python=3.10
# conda activate graphgps

# conda install pytorch=1.13 torchvision torchaudio pytorch-cuda=11.7 -c pytorch -c nvidia
# conda install pyg=2.2 -c pyg -c conda-forge
# pip install pyg-lib -f https://data.pyg.org/whl/torch-1.13.0+cu117.html

# # RDKit is required for OGB-LSC PCQM4Mv2 and datasets derived from it.  
# conda install openbabel fsspec rdkit -c conda-forge

# pip install pytorch-lightning yacs torchmetrics
# pip install performer-pytorch
# pip install tensorboardX
# pip install ogb
# pip install wandb

# conda clean --all

# %% [markdown]
# # installation for kaggle

# %%
# Check existing environment
import sys
print("Python version:", sys.version)
import torch
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)

# !pip uninstall -y torch torchvision torchaudio
# !pip install torch==2.0.1+cu118 torchvision==0.15.2+cu118 torchaudio==2.0.2+cu118 --index-url https://download.pytorch.org/whl/cu118

# !pip install torch_geometric

# Optional dependencies:
# !pip install pyg_lib torch_scatter torch_sparse torch_cluster torch_spline_conv -f https://data.pyg.org/whl/torch-2.4.0+cu124.html
# Install other required packages
# !pip install pytorch-lightning yacs torchmetrics
# !pip install performer-pytorch
# !pip install tensorboardX
# !pip install ogb
# !pip install wandb

# Attempt to install RDKit (may have limitations)
# !pip install rdkit-pypi
# !pip install openbabel fsspec
# !pip install  fsspec

# Clean up pip cache (optional)
# !pip cache purge
# Out:
# Python version: 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:45:18) [GCC 12.3.0]
# PyTorch version: 2.4.0
# CUDA available: True
# CUDA version: 12.3
# Found existing installation: torch 2.4.0
# Uninstalling torch-2.4.0:
#   Successfully uninstalled torch-2.4.0
# Found existing installation: torchvision 0.19.0
# Uninstalling torchvision-0.19.0:
#   Successfully uninstalled torchvision-0.19.0
# Found existing installation: torchaudio 2.4.0
# Uninstalling torchaudio-2.4.0:
#   Successfully uninstalled torchaudio-2.4.0
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Collecting torch==2.0.1+cu118
#   Downloading https://download.pytorch.org/whl/cu118/torch-2.0.1%2Bcu118-cp310-cp310-linux_x86_64.whl (2267.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 GB ? eta 0:00:00a 0:00:0100:01
# Collecting torchvision==0.15.2+cu118
#   Downloading https://download.pytorch.org/whl/cu118/torchvision-0.15.2%2Bcu118-cp310-cp310-linux_x86_64.whl (6.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 59.0 MB/s eta 0:00:0000:01:00:01
# Collecting torchaudio==2.0.2+cu118
#   Downloading https://download.pytorch.org/whl/cu118/torchaudio-2.0.2%2Bcu118-cp310-cp310-linux_x86_64.whl (4.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 85.1 MB/s eta 0:00:00:00:01
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch==2.0.1+cu118) (3.15.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch==2.0.1+cu118) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch==2.0.1+cu118) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch==2.0.1+cu118) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch==2.0.1+cu118) (3.1.4)
# Collecting triton==2.0.0 (from torch==2.0.1+cu118)
#   Downloading https://download.pytorch.org/whl/triton-2.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 21.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision==0.15.2+cu118) (1.26.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torchvision==0.15.2+cu118) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision==0.15.2+cu118) (10.3.0)
# Collecting cmake (from triton==2.0.0->torch==2.0.1+cu118)
#   Downloading https://download.pytorch.org/whl/cmake-3.25.0-py2.py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 49.7 MB/s eta 0:00:0000:0100:01
# Collecting lit (from triton==2.0.0->torch==2.0.1+cu118)
#   Downloading https://download.pytorch.org/whl/lit-15.0.7.tar.gz (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.3/132.3 kB 8.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch==2.0.1+cu118) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.15.2+cu118) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.15.2+cu118) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.15.2+cu118) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision==0.15.2+cu118) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch==2.0.1+cu118) (1.3.0)
# Building wheels for collected packages: lit
#   Building wheel for lit (setup.py) ... done
#   Created wheel for lit: filename=lit-15.0.7-py3-none-any.whl size=89987 sha256=fdb2da9be18bbdfc4b60c792c433c5ce5939f7b0307e3b90f0f4d048cddc4127
#   Stored in directory: /root/.cache/pip/wheels/27/2c/b6/3ed2983b1b44fe0dea1bb35234b09f2c22fb8ebb308679c922
# Successfully built lit
# Installing collected packages: lit, cmake, triton, torch, torchvision, torchaudio
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytorch-lightning 2.4.0 requires torch>=2.1.0, but you have torch 2.0.1+cu118 which is incompatible.
# Successfully installed cmake-3.25.0 lit-15.0.7 torch-2.0.1+cu118 torchaudio-2.0.2+cu118 torchvision-0.15.2+cu118 triton-2.0.0
# Collecting torch_geometric
#   Downloading torch_geometric-2.6.1-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (3.9.5)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (2024.6.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (3.1.4)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (1.26.4)
# Requirement already satisfied: psutil>=5.8.0 in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (5.9.3)
# Requirement already satisfied: pyparsing in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (3.1.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (2.32.3)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from torch_geometric) (4.66.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->torch_geometric) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch_geometric) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torch_geometric) (2024.8.30)
# Downloading torch_geometric-2.6.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 23.1 MB/s eta 0:00:0000:01
# Installing collected packages: torch_geometric
# Successfully installed torch_geometric-2.6.1
# Looking in links: https://data.pyg.org/whl/torch-2.4.0+cu124.html
# Collecting pyg_lib
#   Downloading https://data.pyg.org/whl/torch-2.4.0%2Bcu124/pyg_lib-0.4.0%2Bpt24cu124-cp310-cp310-linux_x86_64.whl (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 8.6 MB/s eta 0:00:0000:0100:01
# Collecting torch_scatter
#   Downloading https://data.pyg.org/whl/torch-2.4.0%2Bcu124/torch_scatter-2.1.2%2Bpt24cu124-cp310-cp310-linux_x86_64.whl (10.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 12.8 MB/s eta 0:00:0000:0100:01
# Collecting torch_sparse
#   Downloading https://data.pyg.org/whl/torch-2.4.0%2Bcu124/torch_sparse-0.6.18%2Bpt24cu124-cp310-cp310-linux_x86_64.whl (5.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 18.5 MB/s eta 0:00:0000:0100:01
# Collecting torch_cluster
#   Downloading https://data.pyg.org/whl/torch-2.4.0%2Bcu124/torch_cluster-1.6.3%2Bpt24cu124-cp310-cp310-linux_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 24.0 MB/s eta 0:00:0000:0100:01
# Collecting torch_spline_conv
#   Downloading https://data.pyg.org/whl/torch-2.4.0%2Bcu124/torch_spline_conv-1.2.2%2Bpt24cu124-cp310-cp310-linux_x86_64.whl (992 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 992.4/992.4 kB 17.7 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from torch_sparse) (1.14.1)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in /opt/conda/lib/python3.10/site-packages (from scipy->torch_sparse) (1.26.4)
# Installing collected packages: torch_spline_conv, torch_scatter, pyg_lib, torch_sparse, torch_cluster
# Successfully installed pyg_lib-0.4.0+pt24cu124 torch_cluster-1.6.3+pt24cu124 torch_scatter-2.1.2+pt24cu124 torch_sparse-0.6.18+pt24cu124 torch_spline_conv-1.2.2+pt24cu124
# Requirement already satisfied: pytorch-lightning in /opt/conda/lib/python3.10/site-packages (2.4.0)
# Collecting yacs
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: torchmetrics in /opt/conda/lib/python3.10/site-packages (1.4.2)
# Collecting torch>=2.1.0 (from pytorch-lightning)
#   Downloading torch-2.4.1-cp310-cp310-manylinux1_x86_64.whl.metadata (26 kB)
# Requirement already satisfied: tqdm>=4.57.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (4.66.4)
# Requirement already satisfied: PyYAML>=5.4 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (6.0.2)
# Requirement already satisfied: fsspec>=2022.5.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (2024.6.1)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (21.3)
# Requirement already satisfied: typing-extensions>=4.4.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (4.12.2)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /opt/conda/lib/python3.10/site-packages (from pytorch-lightning) (0.11.7)
# Requirement already satisfied: numpy>1.20.0 in /opt/conda/lib/python3.10/site-packages (from torchmetrics) (1.26.4)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (3.9.5)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from lightning-utilities>=0.10.0->pytorch-lightning) (70.0.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->pytorch-lightning) (3.1.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=2.1.0->pytorch-lightning) (3.15.1)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=2.1.0->pytorch-lightning) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=2.1.0->pytorch-lightning) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=2.1.0->pytorch-lightning) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.0.0 (from torch>=2.1.0->pytorch-lightning)
#   Downloading triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.1.0->pytorch-lightning)
#   Downloading nvidia_nvjitlink_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=2.1.0->pytorch-lightning) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=2.1.0->pytorch-lightning) (1.3.0)
# Requirement already satisfied: idna>=2.0 in /opt/conda/lib/python3.10/site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (3.7)
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Downloading torch-2.4.1-cp310-cp310-manylinux1_x86_64.whl (797.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.1/797.1 MB 2.0 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.7 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 87.9 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 71.5 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 43.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 10.1 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 29.2 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 13.1 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.4 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 2.1 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 6.4 MB/s eta 0:00:00
# Downloading triton-3.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (209.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 7.7 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 76.8 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: yacs, triton, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch
#   Attempting uninstall: triton
#     Found existing installation: triton 2.0.0
#     Uninstalling triton-2.0.0:
#       Successfully uninstalled triton-2.0.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.1+cu118
#     Uninstalling torch-2.0.1+cu118:
#       Successfully uninstalled torch-2.0.1+cu118
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.0.2+cu118 requires torch==2.0.1, but you have torch 2.4.1 which is incompatible.
# torchvision 0.15.2+cu118 requires torch==2.0.1, but you have torch 2.4.1 which is incompatible.
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.6.77 nvidia-nvtx-cu12-12.1.105 torch-2.4.1 triton-3.0.0 yacs-0.1.8
# Collecting performer-pytorch
#   Downloading performer_pytorch-1.1.4-py3-none-any.whl.metadata (763 bytes)
# Collecting einops>=0.3 (from performer-pytorch)
#   Downloading einops-0.8.0-py3-none-any.whl.metadata (12 kB)
# Collecting local-attention>=1.1.1 (from performer-pytorch)
#   Downloading local_attention-1.9.15-py3-none-any.whl.metadata (683 bytes)
# Requirement already satisfied: torch>=1.6 in /opt/conda/lib/python3.10/site-packages (from performer-pytorch) (2.4.1)
# Collecting axial-positional-embedding>=0.1.0 (from performer-pytorch)
#   Downloading axial_positional_embedding-0.2.1.tar.gz (2.6 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6->performer-pytorch) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.6->performer-pytorch) (12.6.77)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.6->performer-pytorch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.6->performer-pytorch) (1.3.0)
# Downloading performer_pytorch-1.1.4-py3-none-any.whl (13 kB)
# Downloading einops-0.8.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 1.9 MB/s eta 0:00:00
# Downloading local_attention-1.9.15-py3-none-any.whl (9.0 kB)
# Building wheels for collected packages: axial-positional-embedding
#   Building wheel for axial-positional-embedding (setup.py) ... done
#   Created wheel for axial-positional-embedding: filename=axial_positional_embedding-0.2.1-py3-none-any.whl size=2889 sha256=384637bee43dc9017b1be54ba863f18e9fbd226b4abf7ebbbf2bd878cb8e9eb9
#   Stored in directory: /root/.cache/pip/wheels/b1/cb/39/7ce7ff2d2fd37cfe1fe7b3a3c43cf410632b2ad3b3f3986d73
# Successfully built axial-positional-embedding
# Installing collected packages: einops, local-attention, axial-positional-embedding, performer-pytorch
# Successfully installed axial-positional-embedding-0.2.1 einops-0.8.0 local-attention-1.9.15 performer-pytorch-1.1.4
# Requirement already satisfied: tensorboardX in /opt/conda/lib/python3.10/site-packages (2.6.2.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from tensorboardX) (1.26.4)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorboardX) (21.3)
# Requirement already satisfied: protobuf>=3.20 in /opt/conda/lib/python3.10/site-packages (from tensorboardX) (3.20.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->tensorboardX) (3.1.2)
# Collecting ogb
#   Downloading ogb-1.3.6-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: torch>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (2.4.1)
# Requirement already satisfied: numpy>=1.16.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (1.26.4)
# Requirement already satisfied: tqdm>=4.29.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (4.66.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (1.2.2)
# Requirement already satisfied: pandas>=0.24.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (2.2.2)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (1.16.0)
# Requirement already satisfied: urllib3>=1.24.0 in /opt/conda/lib/python3.10/site-packages (from ogb) (1.26.18)
# Collecting outdated>=0.2.0 (from ogb)
#   Downloading outdated-0.2.2-py2.py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: setuptools>=44 in /opt/conda/lib/python3.10/site-packages (from outdated>=0.2.0->ogb) (70.0.0)
# Collecting littleutils (from outdated>=0.2.0->ogb)
#   Downloading littleutils-0.2.4-py3-none-any.whl.metadata (679 bytes)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from outdated>=0.2.0->ogb) (2.32.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24.0->ogb) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24.0->ogb) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.24.0->ogb) (2024.1)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.20.0->ogb) (1.14.1)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.20.0->ogb) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.20.0->ogb) (3.5.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->ogb) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.6.0->ogb) (12.6.77)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.6.0->ogb) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->outdated>=0.2.0->ogb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->outdated>=0.2.0->ogb) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->outdated>=0.2.0->ogb) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.6.0->ogb) (1.3.0)
# Downloading ogb-1.3.6-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 2.3 MB/s eta 0:00:00
# Downloading outdated-0.2.2-py2.py3-none-any.whl (7.5 kB)
# Downloading littleutils-0.2.4-py3-none-any.whl (8.1 kB)
# Installing collected packages: littleutils, outdated, ogb
# Successfully installed littleutils-0.2.4 ogb-1.3.6 outdated-0.2.2
# Requirement already satisfied: wandb in /opt/conda/lib/python3.10/site-packages (0.18.1)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /opt/conda/lib/python3.10/site-packages (from wandb) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.1.43)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.10/site-packages (from wandb) (3.11.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.20.3)
# Requirement already satisfied: psutil>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from wandb) (6.0.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.32.3)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.14.0)
# Requirement already satisfied: setproctitle in /opt/conda/lib/python3.10/site-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from wandb) (70.0.0)
# Requirement already satisfied: six>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2024.8.30)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.1)
# Collecting rdkit-pypi
#   Downloading rdkit_pypi-2022.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from rdkit-pypi) (1.26.4)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from rdkit-pypi) (10.3.0)
# Downloading rdkit_pypi-2022.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 59.0 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: rdkit-pypi
# Successfully installed rdkit-pypi-2022.9.5
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (2024.6.1)
# Files removed: 184

# %%
import sys
print("Python version:", sys.version)
import torch
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)
# Out:
# Python version: 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:45:18) [GCC 12.3.0]
# PyTorch version: 2.4.0
# CUDA available: True
# CUDA version: 12.3

# %%
import torch_geometric
print("PyG version:", torch_geometric.__version__)

import pytorch_lightning
print("PyTorch Lightning version:", pytorch_lightning.__version__)

import rdkit
print("RDKit version:", rdkit.__version__)
# Out:
# /opt/conda/lib/python3.10/site-packages/torch_geometric/typing.py:68: UserWarning: An issue occurred while importing 'pyg-lib'. Disabling its usage. Stacktrace: /opt/conda/lib/python3.10/site-packages/libpyg.so: undefined symbol: _ZNK5torch8autograd4Node4nameEv
#   warnings.warn(f"An issue occurred while importing 'pyg-lib'. "
# /opt/conda/lib/python3.10/site-packages/torch_geometric/typing.py:86: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: /opt/conda/lib/python3.10/site-packages/torch_scatter/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
#   warnings.warn(f"An issue occurred while importing 'torch-scatter'. "
# /opt/conda/lib/python3.10/site-packages/torch_geometric/typing.py:97: UserWarning: An issue occurred while importing 'torch-cluster'. Disabling its usage. Stacktrace: /opt/conda/lib/python3.10/site-packages/torch_cluster/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
#   warnings.warn(f"An issue occurred while importing 'torch-cluster'. "
# /opt/conda/lib/python3.10/site-packages/torch_geometric/typing.py:113: UserWarning: An issue occurred while importing 'torch-spline-conv'. Disabling its usage. Stacktrace: /opt/conda/lib/python3.10/site-packages/torch_spline_conv/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torch_geometric/typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: /opt/conda/lib/python3.10/site-packages/torch_sparse/_version_cuda.so: undefined symbol: _ZN5torch3jit17parseSchemaOrNameERKSsb
#   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "
# PyG version: 2.6.1
# PyTorch Lightning version: 2.4.0
# RDKit version: 2022.09.5

# %%
print("Torch version:", torch.__version__)
# Out:
# Torch version: 2.4.0

# %% [markdown]
# # Running their model- GPSConv

# %%
# %cd /kaggle/working/GraphGPS
# !WANDB_MODE=disabled python main.py --cfg configs/GPS/ogbg-molhiv-GPS.yaml

# %% [markdown]
# # Our Model - WeightedGraphGPS

# %%
#clone for our project
# %cd /kaggle/working
# !git clone --branch use_softmax https://github.com/omertalmi5/WeightedGraphGPS.git
# Out:
# /kaggle/working
# Cloning into 'WeightedGraphGPS'...
# remote: Enumerating objects: 867, done.
# remote: Counting objects: 100% (622/622), done.
# remote: Compressing objects: 100% (264/264), done.
# remote: Total 867 (delta 513), reused 370 (delta 358), pack-reused 245 (from 1)
# Receiving objects: 100% (867/867), 13.06 MiB | 33.36 MiB/s, done.
# Resolving deltas: 100% (602/602), done.

# %%
# !pip install wandb
# Out:
# Requirement already satisfied: wandb in /opt/conda/lib/python3.10/site-packages (0.18.1)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /opt/conda/lib/python3.10/site-packages (from wandb) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.1.43)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.10/site-packages (from wandb) (3.11.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.20.3)
# Requirement already satisfied: psutil>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from wandb) (6.0.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.32.3)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.14.0)
# Requirement already satisfied: setproctitle in /opt/conda/lib/python3.10/site-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from wandb) (70.0.0)
# Requirement already satisfied: six>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2024.8.30)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.1)

# %%
# !wandb login 5f1c292fde40243d281618fe88d712346cfe90d7
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
import os
# Set the environment variable
os.environ['USERNAME'] = "omertalmi-tel-aviv-university"

# %%
# %cd /kaggle/working/WeightedGraphGPS
os.environ['BRANCH_NAME']= os.popen('git rev-parse --abbrev-ref HEAD').read().strip()
# !WANDB_MODE=online python main.py --cfg configs/GPS/ogbg-molhiv-GPS.yaml wandb.use True wandb.entity $USERNAME wandb.name $BRANCH_NAME
# Out:
# /kaggle/working/WeightedGraphGPS
# [*] Run ID 0: seed=0, split_index=0
#     Starting now: 2024-10-02 06:16:52.306885
# Downloading http://snap.stanford.edu/ogb/data/graphproppred/csv_mol_download/hiv.zip
# Downloaded 0.00 GB: 100%|█████████████████████████| 3/3 [00:00<00:00, 10.81it/s]
# Extracting ./datasets/hiv.zip
# Processing...
# Loading necessary files...
# This might take a while.
# Processing graphs...
# 100%|██████████████████████████████████| 41127/41127 [00:00<00:00, 64891.46it/s]
# Converting graphs into PyG objects...
# 100%|██████████████████████████████████| 41127/41127 [00:02<00:00, 18134.17it/s]
# Saving...
# Done!
# /opt/conda/lib/python3.10/site-packages/ogb/graphproppred/dataset_pyg.py:68: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.data, self.slices = torch.load(self.processed_paths[0])
# [*] Loaded dataset 'ogbg-molhiv' from 'OGB':
# /opt/conda/lib/python3.10/site-packages/torch_geometric/data/in_memory_dataset.py:300: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
#   Data(edge_index=[2, 2259376], edge_attr=[2259376, 3], x=[1049163, 9], y=[41127, 1], num_nodes=1049163)
#   undirected: True
#   num graphs: 41127
# /opt/conda/lib/python3.10/site-packages/torch_geometric/data/in_memory_dataset.py:300: UserWarning: It is not recommended to directly access the internal storage format `data` of an 'InMemoryDataset'. The data of the dataset is already cached, so any modifications to `data` will not be reflected when accessing its elements. Clearing the cache now by removing all elements in `dataset._data_list`. If you are absolutely certain what you are doing, access the internal storage via `InMemoryDataset._data` instead to suppress this warning. Alternatively, you can access stacked individual attributes of every graph via `dataset.{attr_name}`.
#   warnings.warn(msg)
#   avg num_nodes/graph: 25
#   num node features: 9
#   num edge features: 3
#   num tasks: 1
#   num classes: 2
# Precomputing Positional Encoding statistics: ['LapPE'] for all graphs...
#   ...estimated to be undirected: True
# 100%|████████████████████████████████████| 41127/41127 [00:50<00:00, 816.74it/s]
# Done! Took 00:00:51.90
# GraphGymModule(
#   (model): GPSModel(
#     (encoder): FeatureEncoder(
#       (node_encoder): Concat2NodeEncoder(
#         (encoder1): AtomEncoder(
#           (atom_embedding_list): ModuleList(
#             (0): Embedding(119, 56)
#             (1): Embedding(5, 56)
#             (2-3): 2 x Embedding(12, 56)
#             (4): Embedding(10, 56)
#             (5-6): 2 x Embedding(6, 56)
#             (7-8): 2 x Embedding(2, 56)
#           )
#         )
#         (encoder2): LapPENodeEncoder(
#           (linear_A): Linear(in_features=2, out_features=16, bias=True)
#           (pe_encoder): Sequential(
#             (0): ReLU()
#             (1): Linear(in_features=16, out_features=8, bias=True)
#             (2): ReLU()
#           )
#         )
#       )
#       (edge_encoder): BondEncoder(
#         (bond_embedding_list): ModuleList(
#           (0): Embedding(5, 64)
#           (1): Embedding(6, 64)
#           (2): Embedding(2, 64)
#         )
#       )
#     )
#     (layers): Sequential(
#       (0): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (gating_conv1): GCNConv(64, 32)
#         (gating_relu): ReLU()
#         (gating_conv2): GCNConv(32, 2)
#         (gating_softmax): Softmax(dim=1)
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (1): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (gating_conv1): GCNConv(64, 32)
#         (gating_relu): ReLU()
#         (gating_conv2): GCNConv(32, 2)
#         (gating_softmax): Softmax(dim=1)
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (2): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (gating_conv1): GCNConv(64, 32)
#         (gating_relu): ReLU()
#         (gating_conv2): GCNConv(32, 2)
#         (gating_softmax): Softmax(dim=1)
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (3): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (gating_conv1): GCNConv(64, 32)
#         (gating_relu): ReLU()
#         (gating_conv2): GCNConv(32, 2)
#         (gating_softmax): Softmax(dim=1)
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (4): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (gating_conv1): GCNConv(64, 32)
#         (gating_relu): ReLU()
#         (gating_conv2): GCNConv(32, 2)
#         (gating_softmax): Softmax(dim=1)
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (5): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (gating_conv1): GCNConv(64, 32)
#         (gating_relu): ReLU()
#         (gating_conv2): GCNConv(32, 2)
#         (gating_softmax): Softmax(dim=1)
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (6): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (gating_conv1): GCNConv(64, 32)
#         (gating_relu): ReLU()
#         (gating_conv2): GCNConv(32, 2)
#         (gating_softmax): Softmax(dim=1)
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (7): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (gating_conv1): GCNConv(64, 32)
#         (gating_relu): ReLU()
#         (gating_conv2): GCNConv(32, 2)
#         (gating_softmax): Softmax(dim=1)
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (8): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (gating_conv1): GCNConv(64, 32)
#         (gating_relu): ReLU()
#         (gating_conv2): GCNConv(32, 2)
#         (gating_softmax): Softmax(dim=1)
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#       (9): GPSLayer(
#         summary: dim_h=64, local_gnn_type=CustomGatedGCN, global_model_type=Transformer, heads=4
#         (gating_conv1): GCNConv(64, 32)
#         (gating_relu): ReLU()
#         (gating_conv2): GCNConv(32, 2)
#         (gating_softmax): Softmax(dim=1)
#         (local_model): GatedGCNLayer()
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=64, out_features=64, bias=True)
#         )
#         (norm1_local): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (norm1_attn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (dropout_local): Dropout(p=0.05, inplace=False)
#         (dropout_attn): Dropout(p=0.05, inplace=False)
#         (ff_linear1): Linear(in_features=64, out_features=128, bias=True)
#         (ff_linear2): Linear(in_features=128, out_features=64, bias=True)
#         (act_fn_ff): ReLU()
#         (norm2): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (ff_dropout1): Dropout(p=0.05, inplace=False)
#         (ff_dropout2): Dropout(p=0.05, inplace=False)
#       )
#     )
#     (post_mp): SANGraphHead(
#       (FC_layers): ModuleList(
#         (0): Linear(in_features=64, out_features=32, bias=True)
#         (1): Linear(in_features=32, out_features=16, bias=True)
#         (2): Linear(in_features=16, out_features=1, bias=True)
#       )
#       (activation): ReLU()
#     )
#   )
# )
# accelerator: cuda
# benchmark: False
# bn:
#   eps: 1e-05
#   mom: 0.1
# cfg_dest: config.yaml
# custom_metrics: []
# dataset:
#   cache_load: False
#   cache_save: False
#   dir: ./datasets
#   edge_dim: 128
#   edge_encoder: True
#   edge_encoder_bn: False
#   edge_encoder_name: Bond
#   edge_encoder_num_types: 0
#   edge_message_ratio: 0.8
#   edge_negative_sampling_ratio: 1.0
#   edge_train_mode: all
#   encoder: True
#   encoder_bn: True
#   encoder_dim: 128
#   encoder_name: db
#   format: OGB
#   infer_link_label: None
#   label_column: none
#   label_table: none
#   location: local
#   name: ogbg-molhiv
#   node_encoder: True
#   node_encoder_bn: False
#   node_encoder_name: Atom+LapPE
#   node_encoder_num_types: 0
#   remove_feature: False
#   resample_disjoint: False
#   resample_negative: False
#   shuffle_split: True
#   slic_compactness: 10
#   split: [0.8, 0.1, 0.1]
#   split_dir: ./splits
#   split_index: 0
#   split_mode: standard
#   task: graph
#   task_type: classification
#   to_undirected: False
#   transductive: False
#   transform: none
#   tu_simple: True
# devices: 1
# example_arg: example
# example_group:
#   example_arg: example
# gnn:
#   act: relu
#   agg: mean
#   att_final_linear: False
#   att_final_linear_bn: False
#   att_heads: 1
#   batchnorm: True
#   clear_feature: True
#   dim_edge: 64
#   dim_inner: 64
#   dropout: 0.0
#   head: san_graph
#   keep_edge: 0.5
#   l2norm: True
#   layer_type: generalconv
#   layers_mp: 2
#   layers_post_mp: 3
#   layers_pre_mp: 0
#   msg_direction: single
#   normalize_adj: False
#   residual: False
#   self_msg: concat
#   skip_every: 1
#   stage_type: stack
# gpu_mem: False
# graphormer:
#   attention_dropout: 0.0
#   dropout: 0.0
#   embed_dim: 80
#   input_dropout: 0.0
#   mlp_dropout: 0.0
#   num_heads: 4
#   num_layers: 6
#   use_graph_token: True
# gt:
#   attn_dropout: 0.5
#   batch_norm: True
#   bigbird:
#     add_cross_attention: False
#     attention_type: block_sparse
#     block_size: 3
#     chunk_size_feed_forward: 0
#     hidden_act: relu
#     is_decoder: False
#     layer_norm_eps: 1e-06
#     max_position_embeddings: 128
#     num_random_blocks: 3
#     use_bias: False
#   dim_hidden: 64
#   dropout: 0.05
#   full_graph: True
#   gamma: 1e-05
#   layer_norm: False
#   layer_type: CustomGatedGCN+Transformer
#   layers: 10
#   n_heads: 4
#   pna_degrees: []
#   residual: True
# mem:
#   inplace: False
# metric_agg: argmax
# metric_best: auc
# model:
#   edge_decoding: dot
#   graph_pooling: mean
#   loss_fun: cross_entropy
#   match_upper: True
#   size_average: mean
#   thresh: 0.5
#   type: GPSModel
# name_tag:
# num_threads: 6
# num_workers: 0
# optim:
#   base_lr: 0.0001
#   batch_accumulation: 1
#   clip_grad_norm: True
#   clip_grad_norm_value: 1.0
#   lr_decay: 0.1
#   max_epoch: 100
#   min_lr: 0.0
#   momentum: 0.9
#   num_warmup_epochs: 5
#   optimizer: adamW
#   reduce_factor: 0.1
#   schedule_patience: 10
#   scheduler: cosine_with_warmup
#   steps: [30, 60, 90]
#   weight_decay: 1e-05
# out_dir: results/ogbg-molhiv-GPS
# posenc_ElstaticSE:
#   dim_pe: 16
#   enable: False
#   kernel:
#     times: []
#     times_func: range(10)
#   layers: 3
#   model: none
#   n_heads: 4
#   pass_as_var: False
#   post_layers: 0
#   raw_norm_type: none
# posenc_EquivStableLapPE:
#   eigen:
#     eigvec_norm: L2
#     laplacian_norm: sym
#     max_freqs: 10
#   enable: False
#   raw_norm_type: none
# posenc_GraphormerBias:
#   dim_pe: 0
#   enable: False
#   node_degrees_only: False
#   num_in_degrees: None
#   num_out_degrees: None
#   num_spatial_types: None
# posenc_HKdiagSE:
#   dim_pe: 16
#   enable: False
#   kernel:
#     times: []
#     times_func:
#   layers: 3
#   model: none
#   n_heads: 4
#   pass_as_var: False
#   post_layers: 0
#   raw_norm_type: none
# posenc_LapPE:
#   dim_pe: 8
#   eigen:
#     eigvec_norm: L2
#     laplacian_norm: none
#     max_freqs: 8
#   enable: True
#   layers: 2
#   model: DeepSet
#   n_heads: 4
#   pass_as_var: False
#   post_layers: 0
#   raw_norm_type: none
# posenc_RWSE:
#   dim_pe: 16
#   enable: False
#   kernel:
#     times: []
#     times_func:
#   layers: 3
#   model: none
#   n_heads: 4
#   pass_as_var: False
#   post_layers: 0
#   raw_norm_type: none
# posenc_SignNet:
#   dim_pe: 16
#   eigen:
#     eigvec_norm: L2
#     laplacian_norm: sym
#     max_freqs: 10
#   enable: False
#   layers: 3
#   model: none
#   n_heads: 4
#   pass_as_var: False
#   phi_hidden_dim: 64
#   phi_out_dim: 4
#   post_layers: 0
#   raw_norm_type: none
# pretrained:
#   dir:
#   freeze_main: False
#   reset_prediction_head: True
# print: both
# round: 5
# run_dir: results/ogbg-molhiv-GPS/0
# run_id: 0
# run_multiple_splits: []
# seed: 0
# share:
#   dim_in: 9
#   dim_out: 2
#   num_splits: 3
# tensorboard_agg: True
# tensorboard_each_run: False
# train:
#   auto_resume: False
#   batch_size: 32
#   ckpt_best: False
#   ckpt_clean: True
#   ckpt_period: 100
#   enable_ckpt: True
#   epoch_resume: -1
#   eval_period: 1
#   iter_per_epoch: 32
#   mode: custom
#   neighbor_sizes: [20, 15, 10, 5]
#   node_per_graph: 32
#   radius: extend
#   sample_node: False
#   sampler: full_batch
#   skip_train_eval: False
#   walk_length: 4
# val:
#   node_per_graph: 32
#   radius: extend
#   sample_node: False
#   sampler: full_batch
# view_emb: False
# wandb:
#   entity: omertalmi-tel-aviv-university
#   name: use_softmax
#   project: molhiv
#   use: True
# Num parameters: 581405
# Start from epoch 0
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: omertalmi- (omertalmi-tel-aviv-university). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.1
# wandb: Run data is saved locally in /kaggle/working/WeightedGraphGPS/wandb/run-20241002_061759-hr4kpctq
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run use_softmax
# wandb: ⭐️ View project at https://wandb.ai/omertalmi-tel-aviv-university/molhiv
# wandb: 🚀 View run at https://wandb.ai/omertalmi-tel-aviv-university/molhiv/runs/hr4kpctq
# Key posenc_GraphormerBias.num_spatial_types with value <class 'NoneType'> is not a valid type; valid types: {<class 'list'>, <class 'str'>, <class 'bool'>, <class 'float'>, <class 'int'>, <class 'tuple'>}
# Key posenc_GraphormerBias.num_in_degrees with value <class 'NoneType'> is not a valid type; valid types: {<class 'list'>, <class 'str'>, <class 'bool'>, <class 'float'>, <class 'int'>, <class 'tuple'>}
# Key posenc_GraphormerBias.num_out_degrees with value <class 'NoneType'> is not a valid type; valid types: {<class 'list'>, <class 'str'>, <class 'bool'>, <class 'float'>, <class 'int'>, <class 'tuple'>}
# train: {'epoch': 0, 'time_epoch': 113.17946, 'eta': 11204.7665, 'eta_hours': 3.11244, 'loss': 0.85385972, 'lr': 0.0, 'params': 581405, 'time_iter': 0.10999, 'accuracy': 0.03745, 'precision': 0.03745, 'recall': 1.0, 'f1': 0.07219, 'auc': 0.51023}
# ...computing epoch stats took: 0.09s
# val: {'epoch': 0, 'time_epoch': 6.63276, 'loss': 0.86187218, 'lr': 0, 'params': 581405, 'time_iter': 0.05142, 'accuracy': 0.01969, 'precision': 0.01969, 'recall': 1.0, 'f1': 0.03863, 'auc': 0.62356}
# ...computing epoch stats took: 0.01s
# test: {'epoch': 0, 'time_epoch': 7.10765, 'loss': 0.85368947, 'lr': 0, 'params': 581405, 'time_iter': 0.0551, 'accuracy': 0.03161, 'precision': 0.03161, 'recall': 1.0, 'f1': 0.06128, 'auc': 0.6523}
# ...computing epoch stats took: 0.01s
# > Epoch 0: took 127.1s (avg 127.1s) | Best so far: epoch 0	train_loss: 0.8539 train_auc: 0.5102	val_loss: 0.8619 val_auc: 0.6236	test_loss: 0.8537 test_auc: 0.6523
# train: {'epoch': 1, 'time_epoch': 107.98839, 'eta': 10837.22464, 'eta_hours': 3.01034, 'loss': 0.49964468, 'lr': 2e-05, 'params': 581405, 'time_iter': 0.10494, 'accuracy': 0.72387, 'precision': 0.04049, 'recall': 0.28084, 'f1': 0.07078, 'auc': 0.5431}
# ...computing epoch stats took: 0.08s
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# val: {'epoch': 1, 'time_epoch': 5.91961, 'loss': 0.23174926, 'lr': 0, 'params': 581405, 'time_iter': 0.04589, 'accuracy': 0.98031, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.66361}
# ...computing epoch stats took: 0.02s
# test: {'epoch': 1, 'time_epoch': 5.95194, 'loss': 0.22772611, 'lr': 0, 'params': 581405, 'time_iter': 0.04614, 'accuracy': 0.96791, 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': 0.72696}
# ...computing epoch stats took: 0.01s
# > Epoch 1: took 120.0s (avg 123.5s) | Best so far: epoch 1	train_loss: 0.4996 train_auc: 0.5431	val_loss: 0.2317 val_auc: 0.6636	test_loss: 0.2277 test_auc: 0.7270
# train: {'epoch': 2, 'time_epoch': 108.95869, 'eta': 10674.09157, 'eta_hours': 2.96503, 'loss': 0.16624667, 'lr': 4e-05, 'params': 581405, 'time_iter': 0.10589, 'accuracy': 0.96265, 'precision': 0.57895, 'recall': 0.00893, 'f1': 0.01759, 'auc': 0.65854}
# ...computing epoch stats took: 0.07s
# val: {'epoch': 2, 'time_epoch': 5.89862, 'loss': 0.09644746, 'lr': 0, 'params': 581405, 'time_iter': 0.04573, 'accuracy': 0.98128, 'precision': 0.66667, 'recall': 0.09877, 'f1': 0.17204, 'auc': 0.73005}
# ...computing epoch stats took: 0.01s
# test: {'epoch': 2, 'time_epoch': 5.95258, 'loss': 0.12602271, 'lr': 0, 'params': 581405, 'time_iter': 0.04614, 'accuracy': 0.97009, 'precision': 0.76923, 'recall': 0.07692, 'f1': 0.13986, 'auc': 0.71038}
# ...computing epoch stats took: 0.01s
# > Epoch 2: took 120.9s (avg 122.7s) | Best so far: epoch 2	train_loss: 0.1662 train_auc: 0.6585	val_loss: 0.0964 val_auc: 0.7300	test_loss: 0.1260 test_auc: 0.7104
# train: {'epoch': 3, 'time_epoch': 108.06782, 'eta': 10516.66474, 'eta_hours': 2.9213, 'loss': 0.14021849, 'lr': 6e-05, 'params': 581405, 'time_iter': 0.10502, 'accuracy': 0.96423, 'precision': 0.65714, 'recall': 0.09334, 'f1': 0.16347, 'auc': 0.70989}
# val: {'epoch': 3, 'time_epoch': 5.89434, 'loss': 0.0839267, 'lr': 0, 'params': 581405, 'time_iter': 0.04569, 'accuracy': 0.98201, 'precision': 0.70588, 'recall': 0.14815, 'f1': 0.2449, 'auc': 0.7781}
# test: {'epoch': 3, 'time_epoch': 5.94577, 'loss': 0.11956598, 'lr': 0, 'params': 581405, 'time_iter': 0.04609, 'accuracy': 0.97155, 'precision': 0.74074, 'recall': 0.15385, 'f1': 0.25478, 'auc': 0.70175}
# > Epoch 3: took 120.0s (avg 122.0s) | Best so far: epoch 3	train_loss: 0.1402 train_auc: 0.7099	val_loss: 0.0839 val_auc: 0.7781	test_loss: 0.1196 test_auc: 0.7017
# train: {'epoch': 4, 'time_epoch': 108.26874, 'eta': 10382.79907, 'eta_hours': 2.88411, 'loss': 0.13379434, 'lr': 8e-05, 'params': 581405, 'time_iter': 0.10522, 'accuracy': 0.96456, 'precision': 0.62992, 'recall': 0.12987, 'f1': 0.21534, 'auc': 0.75235}
# val: {'epoch': 4, 'time_epoch': 5.93119, 'loss': 0.08333246, 'lr': 0, 'params': 581405, 'time_iter': 0.04598, 'accuracy': 0.98055, 'precision': 0.54545, 'recall': 0.07407, 'f1': 0.13043, 'auc': 0.80541}
# test: {'epoch': 4, 'time_epoch': 5.89786, 'loss': 0.13148276, 'lr': 0, 'params': 581405, 'time_iter': 0.04572, 'accuracy': 0.96742, 'precision': 0.3, 'recall': 0.02308, 'f1': 0.04286, 'auc': 0.66467}
# > Epoch 4: took 120.2s (avg 121.7s) | Best so far: epoch 4	train_loss: 0.1338 train_auc: 0.7523	val_loss: 0.0833 val_auc: 0.8054	test_loss: 0.1315 test_auc: 0.6647
# train: {'epoch': 5, 'time_epoch': 107.22351, 'eta': 10241.09033, 'eta_hours': 2.84475, 'loss': 0.13012461, 'lr': 0.0001, 'params': 581405, 'time_iter': 0.1042, 'accuracy': 0.96477, 'precision': 0.61371, 'recall': 0.1599, 'f1': 0.2537, 'auc': 0.76904}
# val: {'epoch': 5, 'time_epoch': 6.0049, 'loss': 0.07891214, 'lr': 0, 'params': 581405, 'time_iter': 0.04655, 'accuracy': 0.98079, 'precision': 0.53125, 'recall': 0.20988, 'f1': 0.30088, 'auc': 0.78754}
# test: {'epoch': 5, 'time_epoch': 5.88813, 'loss': 0.11774384, 'lr': 0, 'params': 581405, 'time_iter': 0.04564, 'accuracy': 0.97131, 'precision': 0.625, 'recall': 0.23077, 'f1': 0.33708, 'auc': 0.74303}
# > Epoch 5: took 119.3s (avg 121.3s) | Best so far: epoch 4	train_loss: 0.1338 train_auc: 0.7523	val_loss: 0.0833 val_auc: 0.8054	test_loss: 0.1315 test_auc: 0.6647
# train: {'epoch': 6, 'time_epoch': 107.30333, 'eta': 10110.29499, 'eta_hours': 2.80842, 'loss': 0.12598078, 'lr': 9.997e-05, 'params': 581405, 'time_iter': 0.10428, 'accuracy': 0.96611, 'precision': 0.66572, 'recall': 0.19075, 'f1': 0.29653, 'auc': 0.79108}
# val: {'epoch': 6, 'time_epoch': 5.92082, 'loss': 0.07721499, 'lr': 0, 'params': 581405, 'time_iter': 0.0459, 'accuracy': 0.98177, 'precision': 0.63636, 'recall': 0.17284, 'f1': 0.27184, 'auc': 0.78949}
# test: {'epoch': 6, 'time_epoch': 5.96907, 'loss': 0.11442363, 'lr': 0, 'params': 581405, 'time_iter': 0.04627, 'accuracy': 0.97301, 'precision': 0.74359, 'recall': 0.22308, 'f1': 0.3432, 'auc': 0.75666}
# > Epoch 6: took 119.3s (avg 121.0s) | Best so far: epoch 4	train_loss: 0.1338 train_auc: 0.7523	val_loss: 0.0833 val_auc: 0.8054	test_loss: 0.1315 test_auc: 0.6647
# train: {'epoch': 7, 'time_epoch': 106.59083, 'eta': 9977.17886, 'eta_hours': 2.77144, 'loss': 0.12413219, 'lr': 9.989e-05, 'params': 581405, 'time_iter': 0.10359, 'accuracy': 0.96602, 'precision': 0.64844, 'recall': 0.20211, 'f1': 0.30817, 'auc': 0.79169}
# val: {'epoch': 7, 'time_epoch': 5.93689, 'loss': 0.07764397, 'lr': 0, 'params': 581405, 'time_iter': 0.04602, 'accuracy': 0.98031, 'precision': 0.5, 'recall': 0.19753, 'f1': 0.28319, 'auc': 0.7958}
# test: {'epoch': 7, 'time_epoch': 5.91421, 'loss': 0.11747978, 'lr': 0, 'params': 581405, 'time_iter': 0.04585, 'accuracy': 0.97107, 'precision': 0.64103, 'recall': 0.19231, 'f1': 0.29586, 'auc': 0.74394}
# > Epoch 7: took 118.6s (avg 120.7s) | Best so far: epoch 4	train_loss: 0.1338 train_auc: 0.7523	val_loss: 0.0833 val_auc: 0.8054	test_loss: 0.1315 test_auc: 0.6647
# train: {'epoch': 8, 'time_epoch': 107.38156, 'eta': 9857.95244, 'eta_hours': 2.73832, 'loss': 0.11892942, 'lr': 9.975e-05, 'params': 581405, 'time_iter': 0.10436, 'accuracy': 0.96702, 'precision': 0.67213, 'recall': 0.23295, 'f1': 0.34599, 'auc': 0.81523}
# val: {'epoch': 8, 'time_epoch': 6.00588, 'loss': 0.075768, 'lr': 0, 'params': 581405, 'time_iter': 0.04656, 'accuracy': 0.98274, 'precision': 0.61364, 'recall': 0.33333, 'f1': 0.432, 'auc': 0.80098}
# test: {'epoch': 8, 'time_epoch': 5.92147, 'loss': 0.11391603, 'lr': 0, 'params': 581405, 'time_iter': 0.0459, 'accuracy': 0.97204, 'precision': 0.65306, 'recall': 0.24615, 'f1': 0.35754, 'auc': 0.75822}
# > Epoch 8: took 119.4s (avg 120.5s) | Best so far: epoch 4	train_loss: 0.1338 train_auc: 0.7523	val_loss: 0.0833 val_auc: 0.8054	test_loss: 0.1315 test_auc: 0.6647
# train: {'epoch': 9, 'time_epoch': 106.58493, 'eta': 9733.92537, 'eta_hours': 2.70387, 'loss': 0.11785247, 'lr': 9.956e-05, 'params': 581405, 'time_iter': 0.10358, 'accuracy': 0.96757, 'precision': 0.68456, 'recall': 0.24838, 'f1': 0.3645, 'auc': 0.82043}
# val: {'epoch': 9, 'time_epoch': 5.91499, 'loss': 0.07534977, 'lr': 0, 'params': 581405, 'time_iter': 0.04585, 'accuracy': 0.97982, 'precision': 0.47727, 'recall': 0.25926, 'f1': 0.336, 'auc': 0.82581}
# test: {'epoch': 9, 'time_epoch': 5.88637, 'loss': 0.11589819, 'lr': 0, 'params': 581405, 'time_iter': 0.04563, 'accuracy': 0.97131, 'precision': 0.625, 'recall': 0.23077, 'f1': 0.33708, 'auc': 0.76033}
# > Epoch 9: took 118.5s (avg 120.3s) | Best so far: epoch 9	train_loss: 0.1179 train_auc: 0.8204	val_loss: 0.0753 val_auc: 0.8258	test_loss: 0.1159 test_auc: 0.7603
# train: {'epoch': 10, 'time_epoch': 106.89766, 'eta': 9615.59987, 'eta_hours': 2.671, 'loss': 0.11484861, 'lr': 9.932e-05, 'params': 581405, 'time_iter': 0.10388, 'accuracy': 0.96787, 'precision': 0.68116, 'recall': 0.26705, 'f1': 0.38367, 'auc': 0.82763}
# val: {'epoch': 10, 'time_epoch': 5.98559, 'loss': 0.07609758, 'lr': 0, 'params': 581405, 'time_iter': 0.0464, 'accuracy': 0.98128, 'precision': 0.54762, 'recall': 0.28395, 'f1': 0.37398, 'auc': 0.79566}
# test: {'epoch': 10, 'time_epoch': 5.93731, 'loss': 0.11882868, 'lr': 0, 'params': 581405, 'time_iter': 0.04603, 'accuracy': 0.97034, 'precision': 0.59091, 'recall': 0.2, 'f1': 0.29885, 'auc': 0.74694}
# > Epoch 10: took 119.0s (avg 120.2s) | Best so far: epoch 9	train_loss: 0.1179 train_auc: 0.8204	val_loss: 0.0753 val_auc: 0.8258	test_loss: 0.1159 test_auc: 0.7603
# train: {'epoch': 11, 'time_epoch': 110.62104, 'eta': 9526.48374, 'eta_hours': 2.64625, 'loss': 0.11284776, 'lr': 9.902e-05, 'params': 581405, 'time_iter': 0.1075, 'accuracy': 0.96827, 'precision': 0.688, 'recall': 0.27922, 'f1': 0.39723, 'auc': 0.83786}
# val: {'epoch': 11, 'time_epoch': 5.92733, 'loss': 0.07097906, 'lr': 0, 'params': 581405, 'time_iter': 0.04595, 'accuracy': 0.98347, 'precision': 0.69697, 'recall': 0.28395, 'f1': 0.40351, 'auc': 0.82726}
# test: {'epoch': 11, 'time_epoch': 5.98532, 'loss': 0.11153662, 'lr': 0, 'params': 581405, 'time_iter': 0.0464, 'accuracy': 0.97155, 'precision': 0.63265, 'recall': 0.23846, 'f1': 0.34637, 'auc': 0.78204}
# > Epoch 11: took 122.7s (avg 120.4s) | Best so far: epoch 11	train_loss: 0.1128 train_auc: 0.8379	val_loss: 0.0710 val_auc: 0.8273	test_loss: 0.1115 test_auc: 0.7820
# train: {'epoch': 12, 'time_epoch': 107.43855, 'eta': 9412.76097, 'eta_hours': 2.61466, 'loss': 0.11021617, 'lr': 9.867e-05, 'params': 581405, 'time_iter': 0.10441, 'accuracy': 0.96897, 'precision': 0.6972, 'recall': 0.30276, 'f1': 0.42218, 'auc': 0.8469}
# val: {'epoch': 12, 'time_epoch': 5.92465, 'loss': 0.0722565, 'lr': 0, 'params': 581405, 'time_iter': 0.04593, 'accuracy': 0.98322, 'precision': 0.67647, 'recall': 0.28395, 'f1': 0.4, 'auc': 0.78866}
# test: {'epoch': 12, 'time_epoch': 5.95982, 'loss': 0.11463375, 'lr': 0, 'params': 581405, 'time_iter': 0.0462, 'accuracy': 0.97204, 'precision': 0.68293, 'recall': 0.21538, 'f1': 0.32749, 'auc': 0.77686}
# > Epoch 12: took 119.5s (avg 120.3s) | Best so far: epoch 11	train_loss: 0.1128 train_auc: 0.8379	val_loss: 0.0710 val_auc: 0.8273	test_loss: 0.1115 test_auc: 0.7820
# train: {'epoch': 13, 'time_epoch': 107.4537, 'eta': 9300.02903, 'eta_hours': 2.58334, 'loss': 0.1093943, 'lr': 9.826e-05, 'params': 581405, 'time_iter': 0.10443, 'accuracy': 0.9693, 'precision': 0.70404, 'recall': 0.31088, 'f1': 0.43131, 'auc': 0.85252}
# val: {'epoch': 13, 'time_epoch': 5.88493, 'loss': 0.07817124, 'lr': 0, 'params': 581405, 'time_iter': 0.04562, 'accuracy': 0.98079, 'precision': 0.52174, 'recall': 0.2963, 'f1': 0.37795, 'auc': 0.77266}
# test: {'epoch': 13, 'time_epoch': 5.8702, 'loss': 0.11726108, 'lr': 0, 'params': 581405, 'time_iter': 0.04551, 'accuracy': 0.96766, 'precision': 0.47541, 'recall': 0.22308, 'f1': 0.30366, 'auc': 0.78795}
# > Epoch 13: took 119.3s (avg 120.3s) | Best so far: epoch 11	train_loss: 0.1128 train_auc: 0.8379	val_loss: 0.0710 val_auc: 0.8273	test_loss: 0.1115 test_auc: 0.7820
# train: {'epoch': 14, 'time_epoch': 108.87731, 'eta': 9196.06797, 'eta_hours': 2.55446, 'loss': 0.10742843, 'lr': 9.78e-05, 'params': 581405, 'time_iter': 0.10581, 'accuracy': 0.97006, 'precision': 0.72252, 'recall': 0.32549, 'f1': 0.4488, 'auc': 0.85925}
# val: {'epoch': 14, 'time_epoch': 5.93641, 'loss': 0.07526763, 'lr': 0, 'params': 581405, 'time_iter': 0.04602, 'accuracy': 0.97982, 'precision': 0.48387, 'recall': 0.37037, 'f1': 0.41958, 'auc': 0.80826}
# test: {'epoch': 14, 'time_epoch': 5.93384, 'loss': 0.11665985, 'lr': 0, 'params': 581405, 'time_iter': 0.046, 'accuracy': 0.96937, 'precision': 0.52778, 'recall': 0.29231, 'f1': 0.37624, 'auc': 0.76459}
# > Epoch 14: took 120.9s (avg 120.3s) | Best so far: epoch 11	train_loss: 0.1128 train_auc: 0.8379	val_loss: 0.0710 val_auc: 0.8273	test_loss: 0.1115 test_auc: 0.7820
# train: {'epoch': 15, 'time_epoch': 106.80558, 'eta': 9080.61581, 'eta_hours': 2.52239, 'loss': 0.10510929, 'lr': 9.729e-05, 'params': 581405, 'time_iter': 0.1038, 'accuracy': 0.96997, 'precision': 0.70678, 'recall': 0.33847, 'f1': 0.45774, 'auc': 0.87047}
# val: {'epoch': 15, 'time_epoch': 5.9933, 'loss': 0.07405534, 'lr': 0, 'params': 581405, 'time_iter': 0.04646, 'accuracy': 0.98006, 'precision': 0.49153, 'recall': 0.35802, 'f1': 0.41429, 'auc': 0.81845}
# test: {'epoch': 15, 'time_epoch': 5.91643, 'loss': 0.11234129, 'lr': 0, 'params': 581405, 'time_iter': 0.04586, 'accuracy': 0.97131, 'precision': 0.58571, 'recall': 0.31538, 'f1': 0.41, 'auc': 0.78867}
# > Epoch 15: took 118.9s (avg 120.2s) | Best so far: epoch 11	train_loss: 0.1128 train_auc: 0.8379	val_loss: 0.0710 val_auc: 0.8273	test_loss: 0.1115 test_auc: 0.7820
# train: {'epoch': 16, 'time_epoch': 107.32355, 'eta': 8968.70979, 'eta_hours': 2.49131, 'loss': 0.10336019, 'lr': 9.673e-05, 'params': 581405, 'time_iter': 0.1043, 'accuracy': 0.97079, 'precision': 0.71961, 'recall': 0.36039, 'f1': 0.48026, 'auc': 0.8769}
# val: {'epoch': 16, 'time_epoch': 5.93674, 'loss': 0.07380471, 'lr': 0, 'params': 581405, 'time_iter': 0.04602, 'accuracy': 0.98201, 'precision': 0.57447, 'recall': 0.33333, 'f1': 0.42188, 'auc': 0.82022}
# test: {'epoch': 16, 'time_epoch': 5.97735, 'loss': 0.11173697, 'lr': 0, 'params': 581405, 'time_iter': 0.04634, 'accuracy': 0.97058, 'precision': 0.56923, 'recall': 0.28462, 'f1': 0.37949, 'auc': 0.79768}
# > Epoch 16: took 119.4s (avg 120.2s) | Best so far: epoch 11	train_loss: 0.1128 train_auc: 0.8379	val_loss: 0.0710 val_auc: 0.8273	test_loss: 0.1115 test_auc: 0.7820
# train: {'epoch': 17, 'time_epoch': 106.63149, 'eta': 8854.16021, 'eta_hours': 2.45949, 'loss': 0.10127107, 'lr': 9.611e-05, 'params': 581405, 'time_iter': 0.10363, 'accuracy': 0.97088, 'precision': 0.72026, 'recall': 0.36364, 'f1': 0.48328, 'auc': 0.88771}
# val: {'epoch': 17, 'time_epoch': 5.93389, 'loss': 0.09216816, 'lr': 0, 'params': 581405, 'time_iter': 0.046, 'accuracy': 0.9718, 'precision': 0.31183, 'recall': 0.35802, 'f1': 0.33333, 'auc': 0.81288}
# test: {'epoch': 17, 'time_epoch': 5.93234, 'loss': 0.13058485, 'lr': 0, 'params': 581405, 'time_iter': 0.04599, 'accuracy': 0.96183, 'precision': 0.36082, 'recall': 0.26923, 'f1': 0.30837, 'auc': 0.77103}
# > Epoch 17: took 118.6s (avg 120.1s) | Best so far: epoch 11	train_loss: 0.1128 train_auc: 0.8379	val_loss: 0.0710 val_auc: 0.8273	test_loss: 0.1115 test_auc: 0.7820
# train: {'epoch': 18, 'time_epoch': 107.56001, 'eta': 8744.40256, 'eta_hours': 2.429, 'loss': 0.1005746, 'lr': 9.545e-05, 'params': 581405, 'time_iter': 0.10453, 'accuracy': 0.97113, 'precision': 0.73422, 'recall': 0.35877, 'f1': 0.48201, 'auc': 0.88931}
# val: {'epoch': 18, 'time_epoch': 6.04088, 'loss': 0.07151548, 'lr': 0, 'params': 581405, 'time_iter': 0.04683, 'accuracy': 0.98274, 'precision': 0.6087, 'recall': 0.34568, 'f1': 0.44094, 'auc': 0.83859}
# test: {'epoch': 18, 'time_epoch': 5.99847, 'loss': 0.1184454, 'lr': 0, 'params': 581405, 'time_iter': 0.0465, 'accuracy': 0.97034, 'precision': 0.59091, 'recall': 0.2, 'f1': 0.29885, 'auc': 0.79609}
# > Epoch 18: took 119.7s (avg 120.1s) | Best so far: epoch 18	train_loss: 0.1006 train_auc: 0.8893	val_loss: 0.0715 val_auc: 0.8386	test_loss: 0.1184 test_auc: 0.7961
# train: {'epoch': 19, 'time_epoch': 111.28085, 'eta': 8649.74803, 'eta_hours': 2.40271, 'loss': 0.09942776, 'lr': 9.474e-05, 'params': 581405, 'time_iter': 0.10814, 'accuracy': 0.97143, 'precision': 0.72813, 'recall': 0.37825, 'f1': 0.49786, 'auc': 0.89265}
# val: {'epoch': 19, 'time_epoch': 5.94873, 'loss': 0.07164879, 'lr': 0, 'params': 581405, 'time_iter': 0.04611, 'accuracy': 0.98444, 'precision': 0.7931, 'recall': 0.28395, 'f1': 0.41818, 'auc': 0.80656}
# test: {'epoch': 19, 'time_epoch': 5.96997, 'loss': 0.1153547, 'lr': 0, 'params': 581405, 'time_iter': 0.04628, 'accuracy': 0.97204, 'precision': 0.74194, 'recall': 0.17692, 'f1': 0.28571, 'auc': 0.78779}
# > Epoch 19: took 123.3s (avg 120.2s) | Best so far: epoch 18	train_loss: 0.1006 train_auc: 0.8893	val_loss: 0.0715 val_auc: 0.8386	test_loss: 0.1184 test_auc: 0.7961
# train: {'epoch': 20, 'time_epoch': 107.67026, 'eta': 8539.92735, 'eta_hours': 2.3722, 'loss': 0.09730832, 'lr': 9.397e-05, 'params': 581405, 'time_iter': 0.10464, 'accuracy': 0.97152, 'precision': 0.73083, 'recall': 0.37906, 'f1': 0.4992, 'auc': 0.89633}
# val: {'epoch': 20, 'time_epoch': 5.99088, 'loss': 0.08659968, 'lr': 0, 'params': 581405, 'time_iter': 0.04644, 'accuracy': 0.97885, 'precision': 0.44643, 'recall': 0.30864, 'f1': 0.36496, 'auc': 0.7888}
# test: {'epoch': 20, 'time_epoch': 5.93159, 'loss': 0.12384041, 'lr': 0, 'params': 581405, 'time_iter': 0.04598, 'accuracy': 0.96645, 'precision': 0.43548, 'recall': 0.20769, 'f1': 0.28125, 'auc': 0.78275}
# > Epoch 20: took 119.7s (avg 120.2s) | Best so far: epoch 18	train_loss: 0.1006 train_auc: 0.8893	val_loss: 0.0715 val_auc: 0.8386	test_loss: 0.1184 test_auc: 0.7961
# train: {'epoch': 21, 'time_epoch': 106.46841, 'eta': 8426.04106, 'eta_hours': 2.34057, 'loss': 0.0949999, 'lr': 9.316e-05, 'params': 581405, 'time_iter': 0.10347, 'accuracy': 0.97189, 'precision': 0.72279, 'recall': 0.40422, 'f1': 0.51848, 'auc': 0.90539}
# val: {'epoch': 21, 'time_epoch': 6.04883, 'loss': 0.0850245, 'lr': 0, 'params': 581405, 'time_iter': 0.04689, 'accuracy': 0.9786, 'precision': 0.45205, 'recall': 0.40741, 'f1': 0.42857, 'auc': 0.77617}
# test: {'epoch': 21, 'time_epoch': 5.88426, 'loss': 0.12177129, 'lr': 0, 'params': 581405, 'time_iter': 0.04561, 'accuracy': 0.96888, 'precision': 0.51087, 'recall': 0.36154, 'f1': 0.42342, 'auc': 0.80025}
# > Epoch 21: took 118.5s (avg 120.1s) | Best so far: epoch 18	train_loss: 0.1006 train_auc: 0.8893	val_loss: 0.0715 val_auc: 0.8386	test_loss: 0.1184 test_auc: 0.7961
# train: {'epoch': 22, 'time_epoch': 106.6024, 'eta': 8313.24838, 'eta_hours': 2.30924, 'loss': 0.09452146, 'lr': 9.23e-05, 'params': 581405, 'time_iter': 0.1036, 'accuracy': 0.97289, 'precision': 0.75758, 'recall': 0.40584, 'f1': 0.52854, 'auc': 0.90822}
# val: {'epoch': 22, 'time_epoch': 5.95061, 'loss': 0.07285079, 'lr': 0, 'params': 581405, 'time_iter': 0.04613, 'accuracy': 0.98298, 'precision': 0.62222, 'recall': 0.34568, 'f1': 0.44444, 'auc': 0.83458}
# test: {'epoch': 22, 'time_epoch': 6.1198, 'loss': 0.11697849, 'lr': 0, 'params': 581405, 'time_iter': 0.04744, 'accuracy': 0.96985, 'precision': 0.54286, 'recall': 0.29231, 'f1': 0.38, 'auc': 0.78238}
# > Epoch 22: took 118.8s (avg 120.1s) | Best so far: epoch 18	train_loss: 0.1006 train_auc: 0.8893	val_loss: 0.0715 val_auc: 0.8386	test_loss: 0.1184 test_auc: 0.7961
# train: {'epoch': 23, 'time_epoch': 107.67846, 'eta': 8204.37906, 'eta_hours': 2.27899, 'loss': 0.09153249, 'lr': 9.14e-05, 'params': 581405, 'time_iter': 0.10464, 'accuracy': 0.97341, 'precision': 0.76923, 'recall': 0.41396, 'f1': 0.53826, 'auc': 0.91382}
# val: {'epoch': 23, 'time_epoch': 6.02349, 'loss': 0.07833264, 'lr': 0, 'params': 581405, 'time_iter': 0.04669, 'accuracy': 0.98177, 'precision': 0.57143, 'recall': 0.2963, 'f1': 0.39024, 'auc': 0.79563}
# test: {'epoch': 23, 'time_epoch': 5.93218, 'loss': 0.12181138, 'lr': 0, 'params': 581405, 'time_iter': 0.04599, 'accuracy': 0.96912, 'precision': 0.52632, 'recall': 0.23077, 'f1': 0.32086, 'auc': 0.78805}
# > Epoch 23: took 119.8s (avg 120.1s) | Best so far: epoch 18	train_loss: 0.1006 train_auc: 0.8893	val_loss: 0.0715 val_auc: 0.8386	test_loss: 0.1184 test_auc: 0.7961
# train: {'epoch': 24, 'time_epoch': 106.98837, 'eta': 8093.53475, 'eta_hours': 2.2482, 'loss': 0.091709, 'lr': 9.045e-05, 'params': 581405, 'time_iter': 0.10397, 'accuracy': 0.9735, 'precision': 0.76549, 'recall': 0.42127, 'f1': 0.54346, 'auc': 0.91739}
# val: {'epoch': 24, 'time_epoch': 5.94583, 'loss': 0.07749019, 'lr': 0, 'params': 581405, 'time_iter': 0.04609, 'accuracy': 0.98347, 'precision': 0.68571, 'recall': 0.2963, 'f1': 0.41379, 'auc': 0.76649}
# test: {'epoch': 24, 'time_epoch': 5.95429, 'loss': 0.1200624, 'lr': 0, 'params': 581405, 'time_iter': 0.04616, 'accuracy': 0.97058, 'precision': 0.60976, 'recall': 0.19231, 'f1': 0.2924, 'auc': 0.77191}
# > Epoch 24: took 119.0s (avg 120.0s) | Best so far: epoch 18	train_loss: 0.1006 train_auc: 0.8893	val_loss: 0.0715 val_auc: 0.8386	test_loss: 0.1184 test_auc: 0.7961
# train: {'epoch': 25, 'time_epoch': 107.92822, 'eta': 7985.662, 'eta_hours': 2.21824, 'loss': 0.08823824, 'lr': 8.946e-05, 'params': 581405, 'time_iter': 0.10489, 'accuracy': 0.97319, 'precision': 0.75964, 'recall': 0.41558, 'f1': 0.53725, 'auc': 0.92792}
# val: {'epoch': 25, 'time_epoch': 5.93363, 'loss': 0.07733236, 'lr': 0, 'params': 581405, 'time_iter': 0.046, 'accuracy': 0.98031, 'precision': 0.5, 'recall': 0.33333, 'f1': 0.4, 'auc': 0.81771}
# test: {'epoch': 25, 'time_epoch': 5.89019, 'loss': 0.12224354, 'lr': 0, 'params': 581405, 'time_iter': 0.04566, 'accuracy': 0.97034, 'precision': 0.57143, 'recall': 0.24615, 'f1': 0.34409, 'auc': 0.7878}
# > Epoch 25: took 119.9s (avg 120.0s) | Best so far: epoch 18	train_loss: 0.1006 train_auc: 0.8893	val_loss: 0.0715 val_auc: 0.8386	test_loss: 0.1184 test_auc: 0.7961
# train: {'epoch': 26, 'time_epoch': 106.75741, 'eta': 7874.61962, 'eta_hours': 2.18739, 'loss': 0.0876942, 'lr': 8.842e-05, 'params': 581405, 'time_iter': 0.10375, 'accuracy': 0.97356, 'precision': 0.76006, 'recall': 0.42938, 'f1': 0.54876, 'auc': 0.92753}
# val: {'epoch': 26, 'time_epoch': 5.97627, 'loss': 0.07687277, 'lr': 0, 'params': 581405, 'time_iter': 0.04633, 'accuracy': 0.98177, 'precision': 0.56, 'recall': 0.34568, 'f1': 0.42748, 'auc': 0.81072}
# test: {'epoch': 26, 'time_epoch': 5.88567, 'loss': 0.12031001, 'lr': 0, 'params': 581405, 'time_iter': 0.04563, 'accuracy': 0.97131, 'precision': 0.58108, 'recall': 0.33077, 'f1': 0.42157, 'auc': 0.7995}
# > Epoch 26: took 118.8s (avg 120.0s) | Best so far: epoch 18	train_loss: 0.1006 train_auc: 0.8893	val_loss: 0.0715 val_auc: 0.8386	test_loss: 0.1184 test_auc: 0.7961
# train: {'epoch': 27, 'time_epoch': 106.79725, 'eta': 7763.98575, 'eta_hours': 2.15666, 'loss': 0.08706448, 'lr': 8.734e-05, 'params': 581405, 'time_iter': 0.10379, 'accuracy': 0.97395, 'precision': 0.76978, 'recall': 0.43425, 'f1': 0.55527, 'auc': 0.92782}
# val: {'epoch': 27, 'time_epoch': 5.89762, 'loss': 0.07736662, 'lr': 0, 'params': 581405, 'time_iter': 0.04572, 'accuracy': 0.98128, 'precision': 0.53704, 'recall': 0.35802, 'f1': 0.42963, 'auc': 0.82356}
# test: {'epoch': 27, 'time_epoch': 6.02487, 'loss': 0.1238749, 'lr': 0, 'params': 581405, 'time_iter': 0.0467, 'accuracy': 0.97204, 'precision': 0.61905, 'recall': 0.3, 'f1': 0.40415, 'auc': 0.78822}
# > Epoch 27: took 118.9s (avg 119.9s) | Best so far: epoch 18	train_loss: 0.1006 train_auc: 0.8893	val_loss: 0.0715 val_auc: 0.8386	test_loss: 0.1184 test_auc: 0.7961
# train: {'epoch': 28, 'time_epoch': 110.34722, 'eta': 7662.30778, 'eta_hours': 2.12842, 'loss': 0.08768698, 'lr': 8.622e-05, 'params': 581405, 'time_iter': 0.10724, 'accuracy': 0.97325, 'precision': 0.74719, 'recall': 0.43182, 'f1': 0.54733, 'auc': 0.92859}
# val: {'epoch': 28, 'time_epoch': 6.00261, 'loss': 0.08151721, 'lr': 0, 'params': 581405, 'time_iter': 0.04653, 'accuracy': 0.97836, 'precision': 0.44118, 'recall': 0.37037, 'f1': 0.40268, 'auc': 0.83282}
# test: {'epoch': 28, 'time_epoch': 5.96774, 'loss': 0.12993249, 'lr': 0, 'params': 581405, 'time_iter': 0.04626, 'accuracy': 0.96645, 'precision': 0.45122, 'recall': 0.28462, 'f1': 0.34906, 'auc': 0.80086}
# > Epoch 28: took 122.5s (avg 120.0s) | Best so far: epoch 18	train_loss: 0.1006 train_auc: 0.8893	val_loss: 0.0715 val_auc: 0.8386	test_loss: 0.1184 test_auc: 0.7961
# train: {'epoch': 29, 'time_epoch': 107.95955, 'eta': 7554.48065, 'eta_hours': 2.09847, 'loss': 0.08391907, 'lr': 8.506e-05, 'params': 581405, 'time_iter': 0.10492, 'accuracy': 0.97465, 'precision': 0.7741, 'recall': 0.45617, 'f1': 0.57406, 'auc': 0.93535}
# val: {'epoch': 29, 'time_epoch': 5.91733, 'loss': 0.07271574, 'lr': 0, 'params': 581405, 'time_iter': 0.04587, 'accuracy': 0.98274, 'precision': 0.6087, 'recall': 0.34568, 'f1': 0.44094, 'auc': 0.82058}
# test: {'epoch': 29, 'time_epoch': 5.87987, 'loss': 0.12415907, 'lr': 0, 'params': 581405, 'time_iter': 0.04558, 'accuracy': 0.97155, 'precision': 0.60656, 'recall': 0.28462, 'f1': 0.38743, 'auc': 0.77563}
# > Epoch 29: took 119.9s (avg 120.0s) | Best so far: epoch 18	train_loss: 0.1006 train_auc: 0.8893	val_loss: 0.0715 val_auc: 0.8386	test_loss: 0.1184 test_auc: 0.7961
# train: {'epoch': 30, 'time_epoch': 106.23203, 'eta': 7442.79984, 'eta_hours': 2.06744, 'loss': 0.08127208, 'lr': 8.386e-05, 'params': 581405, 'time_iter': 0.10324, 'accuracy': 0.97559, 'precision': 0.79263, 'recall': 0.47159, 'f1': 0.59135, 'auc': 0.94275}
# ...
# test: {'epoch': 87, 'time_epoch': 5.86106, 'loss': 0.2202217, 'lr': 0, 'params': 581405, 'time_iter': 0.04543, 'accuracy': 0.96572, 'precision': 0.43373, 'recall': 0.27692, 'f1': 0.33803, 'auc': 0.77035}
# > Epoch 87: took 118.3s (avg 119.1s) | Best so far: epoch 18	train_loss: 0.1006 train_auc: 0.8893	val_loss: 0.0715 val_auc: 0.8386	test_loss: 0.1184 test_auc: 0.7961
# train: {'epoch': 88, 'time_epoch': 105.41878, 'eta': 1178.6907, 'eta_hours': 0.32741, 'loss': 0.0391708, 'lr': 3.89e-06, 'params': 581405, 'time_iter': 0.10245, 'accuracy': 0.98702, 'precision': 0.87512, 'recall': 0.76218, 'f1': 0.81475, 'auc': 0.99266}
# val: {'epoch': 88, 'time_epoch': 5.90067, 'loss': 0.12911926, 'lr': 0, 'params': 581405, 'time_iter': 0.04574, 'accuracy': 0.97642, 'precision': 0.4, 'recall': 0.39506, 'f1': 0.39752, 'auc': 0.8032}
# test: {'epoch': 88, 'time_epoch': 5.85712, 'loss': 0.21873193, 'lr': 0, 'params': 581405, 'time_iter': 0.0454, 'accuracy': 0.96523, 'precision': 0.42697, 'recall': 0.29231, 'f1': 0.34703, 'auc': 0.77309}
# > Epoch 88: took 117.3s (avg 119.1s) | Best so far: epoch 18	train_loss: 0.1006 train_auc: 0.8893	val_loss: 0.0715 val_auc: 0.8386	test_loss: 0.1184 test_auc: 0.7961
# train: {'epoch': 89, 'time_epoch': 105.99481, 'eta': 1071.40823, 'eta_hours': 0.29761, 'loss': 0.04099827, 'lr': 3.27e-06, 'params': 581405, 'time_iter': 0.10301, 'accuracy': 0.98571, 'precision': 0.8608, 'recall': 0.73782, 'f1': 0.79458, 'auc': 0.99161}
# val: {'epoch': 89, 'time_epoch': 5.87921, 'loss': 0.12928266, 'lr': 0, 'params': 581405, 'time_iter': 0.04558, 'accuracy': 0.97982, 'precision': 0.48387, 'recall': 0.37037, 'f1': 0.41958, 'auc': 0.80755}
# test: {'epoch': 89, 'time_epoch': 5.81388, 'loss': 0.22997693, 'lr': 0, 'params': 581405, 'time_iter': 0.04507, 'accuracy': 0.96718, 'precision': 0.46575, 'recall': 0.26154, 'f1': 0.33498, 'auc': 0.77761}
# > Epoch 89: took 117.8s (avg 119.1s) | Best so far: epoch 18	train_loss: 0.1006 train_auc: 0.8893	val_loss: 0.0715 val_auc: 0.8386	test_loss: 0.1184 test_auc: 0.7961
# train: {'epoch': 90, 'time_epoch': 105.86466, 'eta': 964.1412, 'eta_hours': 0.26782, 'loss': 0.0397317, 'lr': 2.71e-06, 'params': 581405, 'time_iter': 0.10288, 'accuracy': 0.98693, 'precision': 0.87268, 'recall': 0.76218, 'f1': 0.81369, 'auc': 0.99212}
# val: {'epoch': 90, 'time_epoch': 5.80628, 'loss': 0.12853473, 'lr': 0, 'params': 581405, 'time_iter': 0.04501, 'accuracy': 0.97812, 'precision': 0.43662, 'recall': 0.38272, 'f1': 0.40789, 'auc': 0.805}
# test: {'epoch': 90, 'time_epoch': 5.85374, 'loss': 0.22190005, 'lr': 0, 'params': 581405, 'time_iter': 0.04538, 'accuracy': 0.96693, 'precision': 0.46512, 'recall': 0.30769, 'f1': 0.37037, 'auc': 0.77206}
# > Epoch 90: took 117.7s (avg 119.1s) | Best so far: epoch 18	train_loss: 0.1006 train_auc: 0.8893	val_loss: 0.0715 val_auc: 0.8386	test_loss: 0.1184 test_auc: 0.7961
# train: {'epoch': 91, 'time_epoch': 106.08892, 'eta': 856.92415, 'eta_hours': 0.23803, 'loss': 0.04019148, 'lr': 2.2e-06, 'params': 581405, 'time_iter': 0.1031, 'accuracy': 0.98611, 'precision': 0.8744, 'recall': 0.73458, 'f1': 0.79841, 'auc': 0.99273}
# val: {'epoch': 91, 'time_epoch': 5.8731, 'loss': 0.13067134, 'lr': 0, 'params': 581405, 'time_iter': 0.04553, 'accuracy': 0.97885, 'precision': 0.45833, 'recall': 0.40741, 'f1': 0.43137, 'auc': 0.80239}
# test: {'epoch': 91, 'time_epoch': 5.86453, 'loss': 0.22245805, 'lr': 0, 'params': 581405, 'time_iter': 0.04546, 'accuracy': 0.96669, 'precision': 0.45679, 'recall': 0.28462, 'f1': 0.35071, 'auc': 0.77126}
# > Epoch 91: took 118.0s (avg 119.1s) | Best so far: epoch 18	train_loss: 0.1006 train_auc: 0.8893	val_loss: 0.0715 val_auc: 0.8386	test_loss: 0.1184 test_auc: 0.7961
# train: {'epoch': 92, 'time_epoch': 105.63907, 'eta': 749.6975, 'eta_hours': 0.20825, 'loss': 0.03954873, 'lr': 1.74e-06, 'params': 581405, 'time_iter': 0.10266, 'accuracy': 0.98626, 'precision': 0.87428, 'recall': 0.73945, 'f1': 0.80123, 'auc': 0.99188}
# val: {'epoch': 92, 'time_epoch': 5.81854, 'loss': 0.12213326, 'lr': 0, 'params': 581405, 'time_iter': 0.0451, 'accuracy': 0.97933, 'precision': 0.46774, 'recall': 0.35802, 'f1': 0.40559, 'auc': 0.8065}
# test: {'epoch': 92, 'time_epoch': 5.78805, 'loss': 0.21843718, 'lr': 0, 'params': 581405, 'time_iter': 0.04487, 'accuracy': 0.96718, 'precision': 0.46914, 'recall': 0.29231, 'f1': 0.36019, 'auc': 0.77346}
# > Epoch 92: took 117.4s (avg 119.1s) | Best so far: epoch 18	train_loss: 0.1006 train_auc: 0.8893	val_loss: 0.0715 val_auc: 0.8386	test_loss: 0.1184 test_auc: 0.7961
# train: {'epoch': 93, 'time_epoch': 105.97656, 'eta': 642.52617, 'eta_hours': 0.17848, 'loss': 0.03739114, 'lr': 1.33e-06, 'params': 581405, 'time_iter': 0.10299, 'accuracy': 0.98726, 'precision': 0.88241, 'recall': 0.76136, 'f1': 0.81743, 'auc': 0.99205}
# val: {'epoch': 93, 'time_epoch': 5.84648, 'loss': 0.12600977, 'lr': 0, 'params': 581405, 'time_iter': 0.04532, 'accuracy': 0.97812, 'precision': 0.43662, 'recall': 0.38272, 'f1': 0.40789, 'auc': 0.81068}
# test: {'epoch': 93, 'time_epoch': 5.79432, 'loss': 0.22651931, 'lr': 0, 'params': 581405, 'time_iter': 0.04492, 'accuracy': 0.96669, 'precision': 0.45679, 'recall': 0.28462, 'f1': 0.35071, 'auc': 0.7765}
# > Epoch 93: took 117.7s (avg 119.0s) | Best so far: epoch 18	train_loss: 0.1006 train_auc: 0.8893	val_loss: 0.0715 val_auc: 0.8386	test_loss: 0.1184 test_auc: 0.7961
# train: {'epoch': 94, 'time_epoch': 105.85239, 'eta': 535.37346, 'eta_hours': 0.14871, 'loss': 0.03794146, 'lr': 9.8e-07, 'params': 581405, 'time_iter': 0.10287, 'accuracy': 0.98705, 'precision': 0.87593, 'recall': 0.76218, 'f1': 0.8151, 'auc': 0.99243}
# val: {'epoch': 94, 'time_epoch': 5.8345, 'loss': 0.12977172, 'lr': 0, 'params': 581405, 'time_iter': 0.04523, 'accuracy': 0.9769, 'precision': 0.41463, 'recall': 0.41975, 'f1': 0.41718, 'auc': 0.80479}
# test: {'epoch': 94, 'time_epoch': 5.84154, 'loss': 0.22140244, 'lr': 0, 'params': 581405, 'time_iter': 0.04528, 'accuracy': 0.96475, 'precision': 0.41573, 'recall': 0.28462, 'f1': 0.3379, 'auc': 0.77044}
# > Epoch 94: took 117.7s (avg 119.0s) | Best so far: epoch 18	train_loss: 0.1006 train_auc: 0.8893	val_loss: 0.0715 val_auc: 0.8386	test_loss: 0.1184 test_auc: 0.7961
# train: {'epoch': 95, 'time_epoch': 106.04922, 'eta': 428.25604, 'eta_hours': 0.11896, 'loss': 0.03803292, 'lr': 6.8e-07, 'params': 581405, 'time_iter': 0.10306, 'accuracy': 0.98657, 'precision': 0.86372, 'recall': 0.76136, 'f1': 0.80932, 'auc': 0.99277}
# val: {'epoch': 95, 'time_epoch': 5.89554, 'loss': 0.12608158, 'lr': 0, 'params': 581405, 'time_iter': 0.0457, 'accuracy': 0.97812, 'precision': 0.43284, 'recall': 0.35802, 'f1': 0.39189, 'auc': 0.80526}
# test: {'epoch': 95, 'time_epoch': 5.80899, 'loss': 0.22164495, 'lr': 0, 'params': 581405, 'time_iter': 0.04503, 'accuracy': 0.96669, 'precision': 0.45333, 'recall': 0.26154, 'f1': 0.33171, 'auc': 0.77253}
# > Epoch 95: took 117.9s (avg 119.0s) | Best so far: epoch 18	train_loss: 0.1006 train_auc: 0.8893	val_loss: 0.0715 val_auc: 0.8386	test_loss: 0.1184 test_auc: 0.7961
# train: {'epoch': 96, 'time_epoch': 105.50203, 'eta': 321.14372, 'eta_hours': 0.08921, 'loss': 0.03919173, 'lr': 4.4e-07, 'params': 581405, 'time_iter': 0.10253, 'accuracy': 0.98657, 'precision': 0.87908, 'recall': 0.74351, 'f1': 0.80563, 'auc': 0.99251}
# val: {'epoch': 96, 'time_epoch': 5.86296, 'loss': 0.1309312, 'lr': 0, 'params': 581405, 'time_iter': 0.04545, 'accuracy': 0.98006, 'precision': 0.49206, 'recall': 0.38272, 'f1': 0.43056, 'auc': 0.8052}
# test: {'epoch': 96, 'time_epoch': 5.84308, 'loss': 0.23109535, 'lr': 0, 'params': 581405, 'time_iter': 0.0453, 'accuracy': 0.96766, 'precision': 0.47826, 'recall': 0.25385, 'f1': 0.33166, 'auc': 0.77374}
# > Epoch 96: took 117.3s (avg 119.0s) | Best so far: epoch 18	train_loss: 0.1006 train_auc: 0.8893	val_loss: 0.0715 val_auc: 0.8386	test_loss: 0.1184 test_auc: 0.7961
# train: {'epoch': 97, 'time_epoch': 106.0951, 'eta': 214.07637, 'eta_hours': 0.05947, 'loss': 0.03598198, 'lr': 2.5e-07, 'params': 581405, 'time_iter': 0.10311, 'accuracy': 0.98714, 'precision': 0.87419, 'recall': 0.76705, 'f1': 0.81712, 'auc': 0.99338}
# val: {'epoch': 97, 'time_epoch': 5.86824, 'loss': 0.12822978, 'lr': 0, 'params': 581405, 'time_iter': 0.04549, 'accuracy': 0.97812, 'precision': 0.44, 'recall': 0.40741, 'f1': 0.42308, 'auc': 0.80597}
# test: {'epoch': 97, 'time_epoch': 5.82408, 'loss': 0.22171062, 'lr': 0, 'params': 581405, 'time_iter': 0.04515, 'accuracy': 0.96645, 'precision': 0.45, 'recall': 0.27692, 'f1': 0.34286, 'auc': 0.77473}
# > Epoch 97: took 117.9s (avg 119.0s) | Best so far: epoch 18	train_loss: 0.1006 train_auc: 0.8893	val_loss: 0.0715 val_auc: 0.8386	test_loss: 0.1184 test_auc: 0.7961
# train: {'epoch': 98, 'time_epoch': 106.17532, 'eta': 107.02947, 'eta_hours': 0.02973, 'loss': 0.03976897, 'lr': 1.1e-07, 'params': 581405, 'time_iter': 0.10318, 'accuracy': 0.98657, 'precision': 0.87264, 'recall': 0.75081, 'f1': 0.80716, 'auc': 0.99165}
# val: {'epoch': 98, 'time_epoch': 5.86418, 'loss': 0.12931952, 'lr': 0, 'params': 581405, 'time_iter': 0.04546, 'accuracy': 0.97593, 'precision': 0.39535, 'recall': 0.41975, 'f1': 0.40719, 'auc': 0.80141}
# test: {'epoch': 98, 'time_epoch': 5.8169, 'loss': 0.21818966, 'lr': 0, 'params': 581405, 'time_iter': 0.04509, 'accuracy': 0.9645, 'precision': 0.41489, 'recall': 0.3, 'f1': 0.34821, 'auc': 0.7754}
# > Epoch 98: took 118.0s (avg 119.0s) | Best so far: epoch 18	train_loss: 0.1006 train_auc: 0.8893	val_loss: 0.0715 val_auc: 0.8386	test_loss: 0.1184 test_auc: 0.7961
# train: {'epoch': 99, 'time_epoch': 105.28143, 'eta': 0.0, 'eta_hours': 0.0, 'loss': 0.03862464, 'lr': 3e-08, 'params': 581405, 'time_iter': 0.10231, 'accuracy': 0.98687, 'precision': 0.86969, 'recall': 0.7638, 'f1': 0.81331, 'auc': 0.99252}
# val: {'epoch': 99, 'time_epoch': 5.88918, 'loss': 0.12791004, 'lr': 0, 'params': 581405, 'time_iter': 0.04565, 'accuracy': 0.97496, 'precision': 0.36585, 'recall': 0.37037, 'f1': 0.3681, 'auc': 0.80159}
# test: {'epoch': 99, 'time_epoch': 5.84329, 'loss': 0.21960116, 'lr': 0, 'params': 581405, 'time_iter': 0.0453, 'accuracy': 0.96572, 'precision': 0.4382, 'recall': 0.3, 'f1': 0.35616, 'auc': 0.77025}
# > Epoch 99: took 117.1s (avg 119.0s) | Best so far: epoch 18	train_loss: 0.1006 train_auc: 0.8893	val_loss: 0.0715 val_auc: 0.8386	test_loss: 0.1184 test_auc: 0.7961
# Avg time per epoch: 118.97s
# Total train loop time: 3.30h
# wandb:
# wandb:
# wandb: Run history:
# wandb:       best/epoch ▁▂▂▄▅▅██████████████████████████████████
# wandb:    best/test_auc ▃▃▁▁▁▁▆▆▇▇▇▇████████████████████████████
# wandb:   best/test_loss █▁▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:   best/train_auc ▁▄▅▅▅███████████████████████████████████
# wandb:  best/train_loss █▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:     best/val_auc ▁▆▇▇████████████████████████████████████
# wandb:    best/val_loss █▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:    test/accuracy ▄▆▇▄█▇▇▆▇▄▇▆▃▅▇▇▅▆▆▄▄▄▄▄▃▃▂▃▁▃▃▃▂▃▃▃▄▄▃▃
# wandb:         test/auc ▁▁▃▅▄▇▆█▆▆▆▇▆▃▅▅▅▅▅▄▅▅▅▅▅▇▅▆▅▅▄▅▅▄▅▅▅▄▅▄
# wandb:       test/epoch ▁▁▁▁▂▂▂▃▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▅▅▆▆▇▇▇▇▇▇████
# wandb:          test/f1 ▂▁▂▇▇█▆▆▇█▇▅▆█▇█▇█▇▅▇▆▇▇▅▇▇▆▆▆▆▆▆▇▆▇▇▇▇▇
# wandb:        test/loss █▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂
# wandb:          test/lr ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:      test/params ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:   test/precision █▆▆▅▆▃▄▅▄▅▃▄▄▄▂▄▃▂▃▃▃▃▁▁▂▂▁▁▂▁▂▂▂▂▂▂▂▁▃▂
# wandb:      test/recall █▁▂▂▃▂▃▃▃▂▃▃▃▃▃▃▃▃▃▃▃▃▃▃▂▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃
# wandb:  test/time_epoch █▂▂▂▂▁▂▂▂▂▂▂▁▂▂▁▂▁▂▁▁▂▁▁▁▁▁▁▂▂▁▁▂▁▁▁▁▁▁▁
# wandb:   test/time_iter █▂▂▂▂▂▂▂▂▂▂▂▁▂▁▂▂▂▁▁▁▁▁▁▁▂▂▂▁▁▂▁▁▁▁▁▁▁▁▁
# wandb:   train/accuracy ▁███████████████████████████████████████
# wandb:        train/auc ▁▃▄▄▅▆▆▆▆▆▇▇▇▇▇▇▇▇██████████████████████
# wandb:      train/epoch ▁▁▂▂▂▂▂▂▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇▇▇██
# wandb:        train/eta █████▇▇▇▇▆▆▆▆▆▆▅▅▅▅▄▄▄▄▃▃▃▃▃▃▃▃▂▂▂▂▂▂▁▁▁
# wandb:  train/eta_hours ██▇▇▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▃▃▃▂▂▂▁▁▁▁
# wandb:         train/f1 ▁▁▃▃▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇██████████████
# wandb:       train/loss █▆▆▆▆▅▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:         train/lr ▁▂████████▇▇▇▇▆▆▆▅▅▅▅▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▁▁▁▁
# wandb:     train/params ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:  train/precision ▁▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇█████████████████
# wandb:     train/recall █▂▁▁▂▂▂▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▅▅▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆
# wandb: train/time_epoch ▅▅▃▃▇▄▃█▄▂▃▃▇▄▃▄▄▂▂▂▄▃▃▂▂▆▂▅▃▃▂▁▁▂▂▁▂▂▁▁
# wandb:  train/time_iter █▄▄▂▃▂▃▃▆▂▆▂▂▂▁▂▂▃▂▆▄▂▂▃▅▂▂▅▁▁▃▂▂▂▂▁▂▂▂▂
# wandb:     val/accuracy ▆▇▆▆▆██▇▁█▆▇▅█▆▆▇▅▆▇▆▆▅▆▅▄▄▃▄▅▅▃▆▄▄▅▅▆▅▃
# wandb:          val/auc ▄▂▃▇▅▆█▁█▃▆▅▆▅▆▅▃▂▅▄▃▆▆▅▅▅▅▅▅▄▅▄▃▅▅▄▃▄▄▄
# wandb:        val/epoch ▁▁▂▂▂▂▃▃▃▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇█████
# wandb:           val/f1 ▁▄▄█▇▇▇█▅▇▇██▇▇▇▇█▆▇█▇▇▇▇▆▇▆▆▇▇▇▇▇▇▇▆▇▇█
# wandb:         val/loss █▁▁▁▁▁▂▁▁▁▁▂▁▂▂▂▂▂▂▂▂▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃
# wandb:           val/lr ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:       val/params ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:    val/precision ▁▆▇▅▆▆▄▆█▆▆▅▆▅▅▅▆▅▆▅▅▅▅▄▄▄▅▄▄▅▅▅▅▄▅▅▅▅▅▄
# wandb:       val/recall ▁▂▅▄▄▆▇▇▇▆▆▇▇▇▇▅▇▇▇▆▇▇▇█▇▇▇█▇▇▇██▇█▇█▇▇█
# wandb:   val/time_epoch █▃▃▃▂▂▃▂▃▃▂▂▃▂▂▂▁▂▂▂▂▂▃▂▂▂▂▁▂▂▂▃▁▁▁▂▁▁▂▂
# wandb:    val/time_iter █▂▂▃▂▃▂▂▂▂▂▃▂▂▃▂▂▂▂▂▂▂▃▂▂▂▂▂▂▂▂▃▂▂▂▁▂▁▁▂
# wandb:
# wandb: Run summary:
# wandb:          best/epoch 18
# wandb:       best/test_auc 0.79609
# wandb:      best/test_loss 0.11845
# wandb:      best/train_auc 0.88931
# wandb:     best/train_loss 0.10057
# wandb:        best/val_auc 0.83859
# wandb:       best/val_loss 0.07152
# wandb:      best_test_perf 0.79609
# wandb:     best_train_perf 0.88931
# wandb:       best_val_perf 0.83859
# wandb: full_epoch_time_avg 118.96579
# wandb: full_epoch_time_sum 11896.57946
# wandb:       test/accuracy 0.96572
# wandb:            test/auc 0.77025
# wandb:          test/epoch 99
# wandb:             test/f1 0.35616
# wandb:           test/loss 0.2196
# wandb:             test/lr 0
# wandb:         test/params 581405
# wandb:      test/precision 0.4382
# wandb:         test/recall 0.3
# wandb:     test/time_epoch 5.84329
# wandb:      test/time_iter 0.0453
# wandb:      train/accuracy 0.98687
# wandb:           train/auc 0.99252
# wandb:         train/epoch 99
# wandb:           train/eta 0
# wandb:     train/eta_hours 0
# wandb:            train/f1 0.81331
# wandb:          train/loss 0.03862
# wandb:            train/lr 0.0
# wandb:        train/params 581405
# wandb:     train/precision 0.86969
# wandb:        train/recall 0.7638
# wandb:    train/time_epoch 105.28143
# wandb:     train/time_iter 0.10231
# wandb:        val/accuracy 0.97496
# wandb:             val/auc 0.80159
# wandb:           val/epoch 99
# wandb:              val/f1 0.3681
# wandb:            val/loss 0.12791
# wandb:              val/lr 0
# wandb:          val/params 581405
# wandb:       val/precision 0.36585
# wandb:          val/recall 0.37037
# wandb:      val/time_epoch 5.88918
# wandb:       val/time_iter 0.04565
# wandb:
# wandb: 🚀 View run use_softmax at: https://wandb.ai/omertalmi-tel-aviv-university/molhiv/runs/hr4kpctq
# wandb: ⭐️ View project at: https://wandb.ai/omertalmi-tel-aviv-university/molhiv
# wandb: Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20241002_061759-hr4kpctq/logs
# Task done, results saved in results/ogbg-molhiv-GPS/0
# 18
# {'epoch': 18, 'time_epoch': 107.56001, 'eta': 8744.40256, 'eta_hours': 2.429, 'loss': 0.1005746, 'lr': 9.545e-05, 'params': 581405, 'time_iter': 0.10453, 'accuracy': 0.97113, 'precision': 0.73422, 'recall': 0.35877, 'f1': 0.48201, 'auc': 0.88931}
# {'epoch': 18, 'time_epoch': 5.99847, 'loss': 0.1184454, 'lr': 0, 'params': 581405, 'time_iter': 0.0465, 'accuracy': 0.97034, 'precision': 0.59091, 'recall': 0.2, 'f1': 0.29885, 'auc': 0.79609}
# {'epoch': 18, 'time_epoch': 6.04088, 'loss': 0.07151548, 'lr': 0, 'params': 581405, 'time_iter': 0.04683, 'accuracy': 0.98274, 'precision': 0.6087, 'recall': 0.34568, 'f1': 0.44094, 'auc': 0.83859}
# Results aggregated across runs saved in results/ogbg-molhiv-GPS/agg
# [*] All done: 2024-10-02 09:36:21.931871

# %%
# !zip -r /kaggle/working/results_use_softmax.zip /kaggle/working/WeightedGraphGPS
# Out:
#   adding: kaggle/working/WeightedGraphGPS/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/main.py (deflated 68%)
#   adding: kaggle/working/WeightedGraphGPS/.gitattributes (deflated 4%)
#   adding: kaggle/working/WeightedGraphGPS/configs/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/configs/SAN/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/configs/SAN/peptides-func-SAN.yaml (deflated 52%)
#   adding: kaggle/working/WeightedGraphGPS/configs/SAN/ogbg-molhiv-SAN.yaml (deflated 52%)
#   adding: kaggle/working/WeightedGraphGPS/configs/SAN/zinc-SAN.yaml (deflated 53%)
#   adding: kaggle/working/WeightedGraphGPS/configs/SAN/ogbg-molpcba-SAN.yaml (deflated 52%)
#   adding: kaggle/working/WeightedGraphGPS/configs/SAN/peptides-struct-SAN.yaml (deflated 53%)
#   adding: kaggle/working/WeightedGraphGPS/configs/SAN/vocsuperpixels-SAN.yaml (deflated 50%)
#   adding: kaggle/working/WeightedGraphGPS/configs/SAN/cluster-SAN.yaml (deflated 52%)
#   adding: kaggle/working/WeightedGraphGPS/configs/SAN/pcqm-contact-SAN.yaml (deflated 52%)
#   adding: kaggle/working/WeightedGraphGPS/configs/SAN/cocosuperpixels-SAN.yaml (deflated 50%)
#   adding: kaggle/working/WeightedGraphGPS/configs/SAN/pattern-SAN.yaml (deflated 52%)
#   adding: kaggle/working/WeightedGraphGPS/configs/Graphormer/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/configs/Graphormer/zinc-Graphormer.yaml (deflated 53%)
#   adding: kaggle/working/WeightedGraphGPS/configs/Graphormer/webkb-wis-Graphormer.yaml (deflated 52%)
#   adding: kaggle/working/WeightedGraphGPS/configs/Graphormer/wn-chameleon-Graphormer.yaml (deflated 52%)
#   adding: kaggle/working/WeightedGraphGPS/configs/Graphormer/wn-squirrel-Graphormer.yaml (deflated 52%)
#   adding: kaggle/working/WeightedGraphGPS/configs/Graphormer/actor-Graphormer.yaml (deflated 52%)
#   adding: kaggle/working/WeightedGraphGPS/configs/Graphormer/webkb-tex-Graphormer.yaml (deflated 52%)
#   adding: kaggle/working/WeightedGraphGPS/configs/Graphormer/webkb-cor-Graphormer.yaml (deflated 52%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GINE/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GINE/peptides-func-GINE.yaml (deflated 48%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GINE/pcqm-contact-GINE.yaml (deflated 47%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GINE/cocosuperpixels-GINE.yaml (deflated 46%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GINE/vocsuperpixels-GINE.yaml (deflated 47%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GINE/peptides-struct-GINE.yaml (deflated 48%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/pcqm4m-GPSmedium+RWSE.yaml (deflated 51%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/ogbg-molpcba-GPS-LapPE+RWSE.yaml (deflated 52%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/ogbg-molhiv-GPS-ESLapPE.yaml (deflated 54%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/malnettiny-GPS+SNMLP.yaml (deflated 53%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/zinc-GPS-ESLapPE.yaml (deflated 53%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/pcqm4m-GPSdeep+RWSE.yaml (deflated 51%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/ogbg-molpcba-GPS.yaml (deflated 51%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/actor-GPS.yaml (deflated 54%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/malnettiny-GPS-ESLapPE.yaml (deflated 53%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/cifar10-GPS+SNMLP.yaml (deflated 51%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/zinc-GPS-LapPE+RWSE.yaml (deflated 53%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/ogbg-molpcba-GPS-SNDS+RWSE.yaml (deflated 51%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/vocsuperpixels-GPS.yaml (deflated 52%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/pattern-GPS.yaml (deflated 51%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/ogbg-molhiv-GPS+RWSE.yaml (deflated 53%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/pcqm4m-GPS+SNMLP.yaml (deflated 52%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/ogbg-molhiv-GPS.yaml (deflated 54%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/zinc-GPS+RWSE-inference.yaml (deflated 48%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/zinc-GPS.yaml (deflated 52%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/cifar10-GPS.yaml (deflated 51%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/pcqm4m-GPS-ESLapPE.yaml (deflated 51%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/ogbg-molpcba-GPS+RWSE.yaml (deflated 51%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/zinc-GPS+RWSE-ckptbest.yaml (deflated 51%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/malnettiny-GPS+RWSE.yaml (deflated 52%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/mnist-GPS-ESLapPE.yaml (deflated 53%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/zinc-GPSwGraphormer+VN.yaml (deflated 52%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/ogbg-ppa-GPS.yaml (deflated 51%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/wn-squirrel-GPS.yaml (deflated 54%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/pcqm4m-GPS.yaml (deflated 54%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/webkb-cor-GPS.yaml (deflated 54%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/ogbg-molhiv-GPS+RWSEdev.yaml (deflated 53%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/pcqm4m-GPS+RWSE.yaml (deflated 50%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/cifar10-GPS-ESLapPE.yaml (deflated 53%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/zinc-GPSwGraphormer.yaml (deflated 55%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/zinc-GPS+RWSE.yaml (deflated 52%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/pattern-GPS-ESLapPE.yaml (deflated 53%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/zinc-GPS+SNMLP.yaml (deflated 53%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/cifar10-GPS+SNDS.yaml (deflated 51%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/pcqm4m-GPS+SNDS.yaml (deflated 51%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/pcqm4m-GPSdeep-inference.yaml (deflated 47%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/malnettiny-GPS.yaml (deflated 54%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/mnist-GPS.yaml (deflated 51%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/pcqm-contact-GPS.yaml (deflated 53%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/peptides-struct-GPS.yaml (deflated 53%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/cifar10-GPS+RWSE.yaml (deflated 50%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/webkb-wis-GPS.yaml (deflated 54%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/wn-chameleon-GPS.yaml (deflated 54%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/peptides-func-GPS.yaml (deflated 53%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/cluster-GPS.yaml (deflated 51%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/zinc-GPS+SNDS.yaml (deflated 53%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/malnettiny-GPS+SNDS.yaml (deflated 53%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/malnettiny-GPS-noPE.yaml (deflated 52%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/cluster-GPS-ESLapPE.yaml (deflated 53%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/ogbg-code2-GPS.yaml (deflated 52%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/cocosuperpixels-GPS.yaml (deflated 52%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/webkb-tex-GPS.yaml (deflated 54%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GPS/ogbg-molpcba-GPS+SNDS.yaml (deflated 51%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GatedGCN/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GatedGCN/peptides-struct-GatedGCN.yaml (deflated 48%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GatedGCN/peptides-func-GatedGCN.yaml (deflated 48%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GatedGCN/pcqm-contact-GatedGCN.yaml (deflated 47%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GatedGCN/cocosuperpixels-GatedGCN.yaml (deflated 46%)
#   adding: kaggle/working/WeightedGraphGPS/configs/GatedGCN/vocsuperpixels-GatedGCN.yaml (deflated 46%)
#   adding: kaggle/working/WeightedGraphGPS/unittests/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/unittests/test_eigvecs.py (deflated 84%)
#   adding: kaggle/working/WeightedGraphGPS/unittests/test_negate_edge_index.py (deflated 77%)
#   adding: kaggle/working/WeightedGraphGPS/unittests/__init__.py (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/wandb/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/wandb/debug-internal.log (deflated 77%)
#   adding: kaggle/working/WeightedGraphGPS/wandb/latest-run/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/wandb/latest-run/files/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/wandb/latest-run/files/wandb-metadata.json (deflated 55%)
#   adding: kaggle/working/WeightedGraphGPS/wandb/latest-run/files/config.yaml (deflated 73%)
#   adding: kaggle/working/WeightedGraphGPS/wandb/latest-run/files/output.log (deflated 84%)
#   adding: kaggle/working/WeightedGraphGPS/wandb/latest-run/files/wandb-summary.json (deflated 59%)
#   adding: kaggle/working/WeightedGraphGPS/wandb/latest-run/run-hr4kpctq.wandb (deflated 83%)
#   adding: kaggle/working/WeightedGraphGPS/wandb/latest-run/tmp/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/wandb/latest-run/tmp/code/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/wandb/latest-run/logs/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/wandb/latest-run/logs/debug-internal.log (deflated 77%)
#   adding: kaggle/working/WeightedGraphGPS/wandb/latest-run/logs/debug.log (deflated 70%)
#   adding: kaggle/working/WeightedGraphGPS/wandb/latest-run/logs/debug-core.log (deflated 66%)
#   adding: kaggle/working/WeightedGraphGPS/wandb/debug.log (deflated 70%)
#   adding: kaggle/working/WeightedGraphGPS/wandb/run-20241002_061759-hr4kpctq/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/wandb/run-20241002_061759-hr4kpctq/files/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/wandb/run-20241002_061759-hr4kpctq/files/wandb-metadata.json (deflated 55%)
#   adding: kaggle/working/WeightedGraphGPS/wandb/run-20241002_061759-hr4kpctq/files/config.yaml (deflated 73%)
#   adding: kaggle/working/WeightedGraphGPS/wandb/run-20241002_061759-hr4kpctq/files/output.log (deflated 84%)
#   adding: kaggle/working/WeightedGraphGPS/wandb/run-20241002_061759-hr4kpctq/files/wandb-summary.json (deflated 59%)
#   adding: kaggle/working/WeightedGraphGPS/wandb/run-20241002_061759-hr4kpctq/run-hr4kpctq.wandb (deflated 83%)
#   adding: kaggle/working/WeightedGraphGPS/wandb/run-20241002_061759-hr4kpctq/tmp/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/wandb/run-20241002_061759-hr4kpctq/tmp/code/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/wandb/run-20241002_061759-hr4kpctq/logs/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/wandb/run-20241002_061759-hr4kpctq/logs/debug-internal.log (deflated 77%)
#   adding: kaggle/working/WeightedGraphGPS/wandb/run-20241002_061759-hr4kpctq/logs/debug.log (deflated 70%)
#   adding: kaggle/working/WeightedGraphGPS/wandb/run-20241002_061759-hr4kpctq/logs/debug-core.log (deflated 66%)
#   adding: kaggle/working/WeightedGraphGPS/setup.py (deflated 48%)
#   adding: kaggle/working/WeightedGraphGPS/README.md (deflated 57%)
#   adding: kaggle/working/WeightedGraphGPS/LICENSE (deflated 40%)
#   adding: kaggle/working/WeightedGraphGPS/GraphGPS.png (deflated 7%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/config/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/config/pretrained_config.py (deflated 49%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/config/posenc_config.py (deflated 64%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/config/optimizers_config.py (deflated 53%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/config/custom_gnn_config.py (deflated 34%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/config/__pycache__/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/config/__pycache__/graphormer_config.cpython-310.pyc (deflated 39%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/config/__pycache__/gt_config.cpython-310.pyc (deflated 37%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/config/__pycache__/custom_gnn_config.cpython-310.pyc (deflated 31%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/config/__pycache__/defaults_config.cpython-310.pyc (deflated 40%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/config/__pycache__/dataset_config.cpython-310.pyc (deflated 33%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/config/__pycache__/__init__.cpython-310.pyc (deflated 25%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/config/__pycache__/optimizers_config.cpython-310.pyc (deflated 36%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/config/__pycache__/pretrained_config.cpython-310.pyc (deflated 33%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/config/__pycache__/posenc_config.cpython-310.pyc (deflated 38%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/config/__pycache__/split_config.cpython-310.pyc (deflated 34%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/config/__pycache__/example.cpython-310.pyc (deflated 32%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/config/__pycache__/wandb_config.cpython-310.pyc (deflated 31%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/config/dataset_config.py (deflated 50%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/config/gt_config.py (deflated 57%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/config/defaults_config.py (deflated 51%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/config/split_config.py (deflated 51%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/config/wandb_config.py (deflated 46%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/config/example.py (deflated 61%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/config/graphormer_config.py (deflated 65%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/config/__init__.py (deflated 30%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/optimizer/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/optimizer/__pycache__/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/optimizer/__pycache__/__init__.cpython-310.pyc (deflated 26%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/optimizer/__pycache__/extra_optimizers.cpython-310.pyc (deflated 61%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/optimizer/extra_optimizers.py (deflated 77%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/optimizer/__init__.py (deflated 30%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/train/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/train/custom_train.py (deflated 75%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/train/__pycache__/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/train/__pycache__/__init__.cpython-310.pyc (deflated 26%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/train/__pycache__/example.cpython-310.pyc (deflated 42%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/train/__pycache__/custom_train.cpython-310.pyc (deflated 49%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/train/example.py (deflated 73%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/train/__init__.py (deflated 30%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/stage/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/stage/__pycache__/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/stage/__pycache__/__init__.cpython-310.pyc (deflated 25%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/stage/__pycache__/example.cpython-310.pyc (deflated 39%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/stage/example.py (deflated 56%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/stage/__init__.py (deflated 30%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/loss/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/loss/multilabel_classification_loss.py (deflated 53%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/loss/l1.py (deflated 59%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/loss/__pycache__/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/loss/__pycache__/subtoken_prediction_loss.cpython-310.pyc (deflated 34%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/loss/__pycache__/multilabel_classification_loss.cpython-310.pyc (deflated 36%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/loss/__pycache__/__init__.cpython-310.pyc (deflated 25%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/loss/__pycache__/weighted_cross_entropy.cpython-310.pyc (deflated 34%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/loss/__pycache__/l1.cpython-310.pyc (deflated 34%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/loss/weighted_cross_entropy.py (deflated 59%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/loss/subtoken_prediction_loss.py (deflated 55%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/loss/__init__.py (deflated 30%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/agg_runs.py (deflated 71%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/metric_wrapper.py (deflated 72%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/finetuning.py (deflated 68%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/pooling/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/pooling/graph_token.py (deflated 46%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/pooling/__pycache__/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/pooling/__pycache__/__init__.cpython-310.pyc (deflated 26%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/pooling/__pycache__/graph_token.cpython-310.pyc (deflated 36%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/pooling/__pycache__/example.cpython-310.pyc (deflated 31%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/pooling/example.py (deflated 40%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/pooling/__init__.py (deflated 30%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/layer/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/layer/graphormer_layer.py (deflated 67%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/layer/san2_layer.py (deflated 75%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/layer/bigbird_layer.py (deflated 82%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/layer/performer_layer.py (deflated 72%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/layer/gps_layer.py (deflated 76%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/layer/__pycache__/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/layer/__pycache__/san_layer.cpython-310.pyc (deflated 51%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/layer/__pycache__/graphormer_layer.cpython-310.pyc (deflated 46%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/layer/__pycache__/gps_layer.cpython-310.pyc (deflated 44%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/layer/__pycache__/__init__.cpython-310.pyc (deflated 26%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/layer/__pycache__/gatedgcn_layer.cpython-310.pyc (deflated 49%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/layer/__pycache__/gine_conv_layer.cpython-310.pyc (deflated 47%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/layer/__pycache__/performer_layer.cpython-310.pyc (deflated 53%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/layer/__pycache__/bigbird_layer.cpython-310.pyc (deflated 61%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/layer/__pycache__/example.cpython-310.pyc (deflated 53%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/layer/__pycache__/san2_layer.cpython-310.pyc (deflated 49%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/layer/gine_conv_layer.py (deflated 69%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/layer/gatedgcn_layer.py (deflated 72%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/layer/san_layer.py (deflated 77%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/layer/example.py (deflated 75%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/layer/__init__.py (deflated 30%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/utils.py (deflated 65%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/__pycache__/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/__pycache__/agg_runs.cpython-310.pyc (deflated 46%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/__pycache__/finetuning.cpython-310.pyc (deflated 47%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/__pycache__/__init__.cpython-310.pyc (deflated 36%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/__pycache__/metric_wrapper.cpython-310.pyc (deflated 51%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/__pycache__/metrics_ogb.cpython-310.pyc (deflated 52%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/__pycache__/logger.cpython-310.pyc (deflated 48%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/__pycache__/utils.cpython-310.pyc (deflated 46%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/network/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/network/custom_gnn.py (deflated 65%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/network/performer.py (deflated 61%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/network/__pycache__/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/network/__pycache__/performer.cpython-310.pyc (deflated 39%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/network/__pycache__/custom_gnn.cpython-310.pyc (deflated 42%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/network/__pycache__/big_bird.cpython-310.pyc (deflated 39%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/network/__pycache__/__init__.cpython-310.pyc (deflated 26%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/network/__pycache__/gps_model.cpython-310.pyc (deflated 44%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/network/__pycache__/example.cpython-310.pyc (deflated 41%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/network/__pycache__/san_transformer.cpython-310.pyc (deflated 40%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/network/__pycache__/graphormer.cpython-310.pyc (deflated 39%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/network/graphormer.py (deflated 63%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/network/san_transformer.py (deflated 66%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/network/example.py (deflated 63%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/network/gps_model.py (deflated 70%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/network/big_bird.py (deflated 60%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/network/__init__.py (deflated 30%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/act/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/act/__pycache__/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/act/__pycache__/__init__.cpython-310.pyc (deflated 25%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/act/__pycache__/example.cpython-310.pyc (deflated 36%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/act/example.py (deflated 53%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/act/__init__.py (deflated 30%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/metrics_ogb.py (deflated 74%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/encoder/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/encoder/graphormer_encoder.py (deflated 73%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/encoder/kernel_pos_encoder.py (deflated 68%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/encoder/dummy_edge_encoder.py (deflated 53%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/encoder/type_dict_encoder.py (deflated 62%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/encoder/voc_superpixels_encoder.py (deflated 65%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/encoder/__pycache__/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/encoder/__pycache__/type_dict_encoder.cpython-310.pyc (deflated 49%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/encoder/__pycache__/laplace_pos_encoder.cpython-310.pyc (deflated 43%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/encoder/__pycache__/__init__.cpython-310.pyc (deflated 26%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/encoder/__pycache__/voc_superpixels_encoder.cpython-310.pyc (deflated 47%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/encoder/__pycache__/composed_encoders.cpython-310.pyc (deflated 56%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/encoder/__pycache__/signnet_pos_encoder.cpython-310.pyc (deflated 52%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/encoder/__pycache__/equivstable_laplace_pos_encoder.cpython-310.pyc (deflated 40%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/encoder/__pycache__/ppa_encoder.cpython-310.pyc (deflated 47%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/encoder/__pycache__/linear_node_encoder.cpython-310.pyc (deflated 41%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/encoder/__pycache__/dummy_edge_encoder.cpython-310.pyc (deflated 39%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/encoder/__pycache__/ast_encoder.cpython-310.pyc (deflated 49%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/encoder/__pycache__/graphormer_encoder.cpython-310.pyc (deflated 53%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/encoder/__pycache__/example.cpython-310.pyc (deflated 45%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/encoder/__pycache__/kernel_pos_encoder.cpython-310.pyc (deflated 46%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/encoder/__pycache__/linear_edge_encoder.cpython-310.pyc (deflated 38%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/encoder/ppa_encoder.py (deflated 64%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/encoder/ast_encoder.py (deflated 67%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/encoder/signnet_pos_encoder.py (deflated 76%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/encoder/composed_encoders.py (deflated 77%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/encoder/example.py (deflated 65%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/encoder/equivstable_laplace_pos_encoder.py (deflated 57%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/encoder/laplace_pos_encoder.py (deflated 71%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/encoder/linear_node_encoder.py (deflated 51%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/encoder/linear_edge_encoder.py (deflated 51%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/encoder/__init__.py (deflated 30%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/logger.py (deflated 73%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/loader/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/loader/master_loader.py (deflated 76%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/loader/split_generator.py (deflated 74%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/loader/dataset/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/loader/dataset/voc_superpixels.py (deflated 68%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/loader/dataset/peptides_functional.py (deflated 64%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/loader/dataset/__pycache__/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/loader/dataset/__pycache__/voc_superpixels.cpython-310.pyc (deflated 55%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/loader/dataset/__pycache__/__init__.cpython-310.pyc (deflated 22%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/loader/dataset/__pycache__/aqsol_molecules.cpython-310.pyc (deflated 47%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/loader/dataset/__pycache__/malnet_tiny.cpython-310.pyc (deflated 51%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/loader/dataset/__pycache__/coco_superpixels.cpython-310.pyc (deflated 53%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/loader/dataset/malnet_tiny.py (deflated 66%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/loader/dataset/peptides_structural.py (deflated 65%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/loader/dataset/aqsol_molecules.py (deflated 63%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/loader/dataset/pcqm4mv2_contact.py (deflated 71%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/loader/dataset/coco_superpixels.py (deflated 67%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/loader/dataset/__init__.py (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/loader/__pycache__/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/loader/__pycache__/master_loader.cpython-310.pyc (deflated 55%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/loader/__pycache__/split_generator.cpython-310.pyc (deflated 52%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/loader/__pycache__/__init__.cpython-310.pyc (deflated 26%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/loader/__pycache__/ogbg_code2_utils.cpython-310.pyc (deflated 48%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/loader/ogbg_code2_utils.py (deflated 69%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/loader/__init__.py (deflated 30%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/head/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/head/inductive_node.py (deflated 58%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/head/graphormer_graph.py (deflated 62%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/head/inductive_edge.py (deflated 72%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/head/__pycache__/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/head/__pycache__/inductive_node.cpython-310.pyc (deflated 43%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/head/__pycache__/ogb_code_graph.cpython-310.pyc (deflated 40%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/head/__pycache__/__init__.cpython-310.pyc (deflated 25%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/head/__pycache__/infer_links.cpython-310.pyc (deflated 39%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/head/__pycache__/san_graph.cpython-310.pyc (deflated 41%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/head/__pycache__/graphormer_graph.cpython-310.pyc (deflated 43%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/head/__pycache__/example.cpython-310.pyc (deflated 41%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/head/__pycache__/inductive_edge.cpython-310.pyc (deflated 45%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/head/san_graph.py (deflated 63%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/head/infer_links.py (deflated 53%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/head/example.py (deflated 59%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/head/ogb_code_graph.py (deflated 59%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/head/__init__.py (deflated 30%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/transform/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/transform/__pycache__/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/transform/__pycache__/task_preprocessing.cpython-310.pyc (deflated 36%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/transform/__pycache__/__init__.cpython-310.pyc (deflated 26%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/transform/__pycache__/transforms.cpython-310.pyc (deflated 43%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/transform/__pycache__/posenc_stats.cpython-310.pyc (deflated 52%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/transform/transforms.py (deflated 65%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/transform/posenc_stats.py (deflated 74%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/transform/task_preprocessing.py (deflated 64%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/transform/__init__.py (deflated 30%)
#   adding: kaggle/working/WeightedGraphGPS/graphgps/__init__.py (deflated 72%)
#   adding: kaggle/working/WeightedGraphGPS/tests/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/tests/node_all_standard_split.sh (deflated 53%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/node/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/node/citeseer.yaml (deflated 41%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/node/pubmed.yaml (deflated 42%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/node/ogbn-arxiv.yaml (deflated 41%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/node/cora.yaml (deflated 41%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/node/default.yaml (deflated 42%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/mnist.yaml (deflated 43%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/cluster.yaml (deflated 41%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/ogbg-code2.yaml (deflated 48%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/zinc-SignNet.yaml (deflated 59%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/ogbg-ppa.yaml (deflated 48%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/malnettiny-SAN-sparse.yaml (deflated 51%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/ogbg-molpcba-GPS.yaml (deflated 52%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/enzymes.yaml (deflated 41%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/malnettiny.yaml (deflated 41%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/imdb-binary.yaml (deflated 40%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/ogbg-molhiv-SAN.yaml (deflated 52%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/pattern.yaml (deflated 41%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/nci1-Performer.yaml (deflated 49%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/zinc-SAN.yaml (deflated 54%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/zinc-GPSwLPE.yaml (deflated 52%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/zinc-SAN-LapPE+RWSE.yaml (deflated 53%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/zinc-GPS.yaml (deflated 52%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/ogbg-molpcba-SAN.yaml (deflated 52%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/zinc-GPS-small.yaml (deflated 59%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/malnettiny-GPS+RWSE.yaml (deflated 50%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/nci1-LapPE.yaml (deflated 45%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/ogbg-ppa-GPS.yaml (deflated 52%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/zinc-GPS-BigBird.yaml (deflated 57%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/pcqm4m.yaml (deflated 45%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/dd.yaml (deflated 42%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/ogbg-molpcba.yaml (deflated 47%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/malnettiny-LapPE.yaml (deflated 45%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/ogbl-collab.yaml (deflated 46%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/cifar10.yaml (deflated 43%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/ogbg-molhiv-RWSE.yaml (deflated 45%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/zinc-Performer.yaml (deflated 51%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/ogbg-molhiv-LapPE.yaml (deflated 46%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/collab.yaml (deflated 41%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/zinc-BigBird.yaml (deflated 50%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/nci1.yaml (deflated 41%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/zinc-SAN-small.yaml (deflated 52%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/cluster-SAN.yaml (deflated 52%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/zinc.yaml (deflated 51%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/malnettiny-GPS.yaml (deflated 51%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/ogbg-molhiv-SAN+RWSE.yaml (deflated 51%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/ogbg-molpcba-GPS+RWSE-inference.yaml (deflated 48%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/ogbg-molhiv.yaml (deflated 46%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/zinc-GPS+SignNet.yaml (deflated 58%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/zinc-LapPE.yaml (deflated 50%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/malnettiny-GPS-noPE.yaml (deflated 49%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/proteins.yaml (deflated 41%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/ogbg-molpcba-LapPE.yaml (deflated 47%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/ogbg-code2-GPS.yaml (deflated 52%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/imdb-multi.yaml (deflated 41%)
#   adding: kaggle/working/WeightedGraphGPS/tests/configs/graph/pattern-SAN.yaml (deflated 52%)
#   adding: kaggle/working/WeightedGraphGPS/tests/graph_run.sh (deflated 69%)
#   adding: kaggle/working/WeightedGraphGPS/tests/node_run.sh (deflated 49%)
#   adding: kaggle/working/WeightedGraphGPS/.git/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/.git/config (deflated 32%)
#   adding: kaggle/working/WeightedGraphGPS/.git/objects/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/.git/objects/info/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/.git/objects/pack/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/.git/objects/pack/pack-66c2e87909b48a1a168156fd27c26f3bf8e7c12c.pack (deflated 0%)
#   adding: kaggle/working/WeightedGraphGPS/.git/objects/pack/pack-66c2e87909b48a1a168156fd27c26f3bf8e7c12c.idx (deflated 3%)
#   adding: kaggle/working/WeightedGraphGPS/.git/branches/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/.git/info/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/.git/info/exclude (deflated 28%)
#   adding: kaggle/working/WeightedGraphGPS/.git/packed-refs (deflated 55%)
#   adding: kaggle/working/WeightedGraphGPS/.git/refs/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/.git/refs/remotes/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/.git/refs/remotes/origin/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/.git/refs/remotes/origin/HEAD (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/.git/refs/heads/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/.git/refs/heads/use_softmax (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/.git/refs/tags/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/.git/hooks/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/.git/hooks/update.sample (deflated 68%)
#   adding: kaggle/working/WeightedGraphGPS/.git/hooks/pre-applypatch.sample (deflated 38%)
#   adding: kaggle/working/WeightedGraphGPS/.git/hooks/commit-msg.sample (deflated 44%)
#   adding: kaggle/working/WeightedGraphGPS/.git/hooks/post-update.sample (deflated 27%)
#   adding: kaggle/working/WeightedGraphGPS/.git/hooks/pre-push.sample (deflated 49%)
#   adding: kaggle/working/WeightedGraphGPS/.git/hooks/fsmonitor-watchman.sample (deflated 62%)
#   adding: kaggle/working/WeightedGraphGPS/.git/hooks/pre-rebase.sample (deflated 59%)
#   adding: kaggle/working/WeightedGraphGPS/.git/hooks/applypatch-msg.sample (deflated 42%)
#   adding: kaggle/working/WeightedGraphGPS/.git/hooks/pre-merge-commit.sample (deflated 39%)
#   adding: kaggle/working/WeightedGraphGPS/.git/hooks/pre-receive.sample (deflated 40%)
#   adding: kaggle/working/WeightedGraphGPS/.git/hooks/pre-commit.sample (deflated 45%)
#   adding: kaggle/working/WeightedGraphGPS/.git/hooks/push-to-checkout.sample (deflated 55%)
#   adding: kaggle/working/WeightedGraphGPS/.git/hooks/prepare-commit-msg.sample (deflated 50%)
#   adding: kaggle/working/WeightedGraphGPS/.git/description (deflated 14%)
#   adding: kaggle/working/WeightedGraphGPS/.git/index (deflated 61%)
#   adding: kaggle/working/WeightedGraphGPS/.git/logs/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/.git/logs/refs/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/.git/logs/refs/remotes/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/.git/logs/refs/remotes/origin/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/.git/logs/refs/remotes/origin/HEAD (deflated 26%)
#   adding: kaggle/working/WeightedGraphGPS/.git/logs/refs/heads/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/.git/logs/refs/heads/use_softmax (deflated 26%)
#   adding: kaggle/working/WeightedGraphGPS/.git/logs/HEAD (deflated 26%)
#   adding: kaggle/working/WeightedGraphGPS/.git/HEAD (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/final-results.zip (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/results/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/results/ogbg-molhiv-GPS/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/results/ogbg-molhiv-GPS/0/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/results/ogbg-molhiv-GPS/0/train/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/results/ogbg-molhiv-GPS/0/train/stats.json (deflated 79%)
#   adding: kaggle/working/WeightedGraphGPS/results/ogbg-molhiv-GPS/0/test/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/results/ogbg-molhiv-GPS/0/test/stats.json (deflated 84%)
#   adding: kaggle/working/WeightedGraphGPS/results/ogbg-molhiv-GPS/0/ckpt/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/results/ogbg-molhiv-GPS/0/ckpt/99.ckpt (deflated 11%)
#   adding: kaggle/working/WeightedGraphGPS/results/ogbg-molhiv-GPS/0/logging.log (deflated 84%)
#   adding: kaggle/working/WeightedGraphGPS/results/ogbg-molhiv-GPS/0/val/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/results/ogbg-molhiv-GPS/0/val/stats.json (deflated 84%)
#   adding: kaggle/working/WeightedGraphGPS/results/ogbg-molhiv-GPS/config.yaml (deflated 64%)
#   adding: kaggle/working/WeightedGraphGPS/results/ogbg-molhiv-GPS/agg/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/results/ogbg-molhiv-GPS/agg/train/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/results/ogbg-molhiv-GPS/agg/train/best.json (deflated 60%)
#   adding: kaggle/working/WeightedGraphGPS/results/ogbg-molhiv-GPS/agg/train/events.out.tfevents.1727861780.a0ca319c4b35 (deflated 70%)
#   adding: kaggle/working/WeightedGraphGPS/results/ogbg-molhiv-GPS/agg/train/stats.json (deflated 89%)
#   adding: kaggle/working/WeightedGraphGPS/results/ogbg-molhiv-GPS/agg/test/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/results/ogbg-molhiv-GPS/agg/test/best.json (deflated 59%)
#   adding: kaggle/working/WeightedGraphGPS/results/ogbg-molhiv-GPS/agg/test/stats.json (deflated 92%)
#   adding: kaggle/working/WeightedGraphGPS/results/ogbg-molhiv-GPS/agg/test/events.out.tfevents.1727861781.a0ca319c4b35 (deflated 71%)
#   adding: kaggle/working/WeightedGraphGPS/results/ogbg-molhiv-GPS/agg/val/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/results/ogbg-molhiv-GPS/agg/val/best.json (deflated 59%)
#   adding: kaggle/working/WeightedGraphGPS/results/ogbg-molhiv-GPS/agg/val/stats.json (deflated 92%)
#   adding: kaggle/working/WeightedGraphGPS/results/ogbg-molhiv-GPS/agg/val/events.out.tfevents.1727861781.a0ca319c4b35 (deflated 71%)
#   adding: kaggle/working/WeightedGraphGPS/run/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/run/wrapper.sb (deflated 24%)
#   adding: kaggle/working/WeightedGraphGPS/run/run_experiments.sh (deflated 71%)
#   adding: kaggle/working/WeightedGraphGPS/run/cancel_all.sh (deflated 28%)
#   adding: kaggle/working/WeightedGraphGPS/.gitignore (deflated 50%)
#   adding: kaggle/working/WeightedGraphGPS/datasets/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/datasets/ogbg_molhiv/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/datasets/ogbg_molhiv/raw/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/datasets/ogbg_molhiv/raw/edge.csv.gz (deflated 0%)
#   adding: kaggle/working/WeightedGraphGPS/datasets/ogbg_molhiv/raw/edge-feat.csv.gz (deflated 0%)
#   adding: kaggle/working/WeightedGraphGPS/datasets/ogbg_molhiv/raw/graph-label.csv.gz (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/datasets/ogbg_molhiv/raw/num-node-list.csv.gz (deflated 0%)
#   adding: kaggle/working/WeightedGraphGPS/datasets/ogbg_molhiv/raw/num-edge-list.csv.gz (deflated 0%)
#   adding: kaggle/working/WeightedGraphGPS/datasets/ogbg_molhiv/raw/node-feat.csv.gz (deflated 0%)
#   adding: kaggle/working/WeightedGraphGPS/datasets/ogbg_molhiv/processed/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/datasets/ogbg_molhiv/processed/pre_transform.pt (deflated 64%)
#   adding: kaggle/working/WeightedGraphGPS/datasets/ogbg_molhiv/processed/pre_filter.pt (deflated 64%)
#   adding: kaggle/working/WeightedGraphGPS/datasets/ogbg_molhiv/processed/geometric_data_processed.pt (deflated 97%)
#   adding: kaggle/working/WeightedGraphGPS/datasets/ogbg_molhiv/RELEASE_v1.txt (deflated 4%)
#   adding: kaggle/working/WeightedGraphGPS/datasets/ogbg_molhiv/mapping/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/datasets/ogbg_molhiv/mapping/mol.csv.gz (deflated 0%)
#   adding: kaggle/working/WeightedGraphGPS/datasets/ogbg_molhiv/mapping/README.md (deflated 35%)
#   adding: kaggle/working/WeightedGraphGPS/datasets/ogbg_molhiv/split/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/datasets/ogbg_molhiv/split/scaffold/ (stored 0%)
#   adding: kaggle/working/WeightedGraphGPS/datasets/ogbg_molhiv/split/scaffold/test.csv.gz (deflated 1%)
#   adding: kaggle/working/WeightedGraphGPS/datasets/ogbg_molhiv/split/scaffold/valid.csv.gz (deflated 2%)
#   adding: kaggle/working/WeightedGraphGPS/datasets/ogbg_molhiv/split/scaffold/train.csv.gz (deflated 53%)
